# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
from yellowbrick.cluster import KElbowVisualizer
import matplotlib.pyplot as plt
import pandas as pd 
import seaborn as sns
from sklearn.cluster import KMeans
from sksurv.base import SurvivalAnalysisMixin as s
from sklearn.model_selection import train_test_split, RandomizedSearchCV, cross_val_score
from sksurv.preprocessing import encode_categorical
 
from sksurv.functions import StepFunction
from sksurv.linear_model import CoxPHSurvivalAnalysis, CoxnetSurvivalAnalysis
from sksurv.ensemble import (ComponentwiseGradientBoostingSurvivalAnalysis, 
                            RandomSurvivalForest, 
                            ExtraSurvivalTrees, 
                            GradientBoostingSurvivalAnalysis, 
                            ExtraSurvivalTrees)
from sksurv.meta import EnsembleSelection, EnsembleSelectionRegressor
from sksurv.metrics import integrated_brier_score
from matplotlib.colors import ListedColormap
from mlxtend.evaluate import paired_ttest_5x2cv
from mlxtend.evaluate import combined_ftest_5x2cv
from lifelines import KaplanMeierFitter
from scipy.cluster import hierarchy
from lifelines.statistics import logrank_test, multivariate_logrank_test, pairwise_logrank_test
from sklearn import preprocessing
from sklearn.model_selection import StratifiedKFold, KFold
from lifelines.plotting import add_at_risk_counts
import scipy.stats
import sklearn
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import optuna
from sklearn.model_selection import cross_val_score
from sksurv.metrics import integrated_brier_score
from lifelines import CoxPHFitter
from lifelines.statistics import proportional_hazard_test
import scipy.stats as stats
from statsmodels.stats.outliers_influence import variance_inflation_factor 
 
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'
from sklearn.preprocessing import MinMaxScaler

# %%
# OUS: Train data
OUS_D1 = pd.read_csv('OUS_D1.csv')
OUS_D2 = pd.read_csv('OUS_D2.csv')
OUS_D3 = pd.read_csv('OUS_D3.csv')
OUS_DFS_target = pd.read_csv('OUS_DFS_target.csv')
OUS_OS_target = pd.read_csv('OUS_OS_target.csv')
response_OUS = pd.read_csv('response_ous.csv', sep=';')

# MAASTRO: Test data 
MAASTRO_D1 = pd.read_csv('MAASTRO_D1.csv')
MAASTRO_D2 = pd.read_csv('MAASTRO_D2.csv')
MAASTRO_D3 = pd.read_csv('MAASTRO_D3.csv')
MAASTRO_DFS_target = pd.read_csv('MAASTRO_DFS_target.csv')
MAASTRO_OS_target = pd.read_csv('MAASTRO_OS_target.csv')
response_MAASTRO = pd.read_csv('maastro_response_full.csv', sep=',')

# %%
# Need to choose patient_id from OUS_D1 in response_OUS
data = list(OUS_D1['patient_id'])
mask = response_OUS['patient_id'].isin(data)
response_OUS = response_OUS[mask] 
response_OUS.head(10)

# Merge OUS_D1 with response_OUS
clinical_train = pd.merge(OUS_D1, response_OUS, on='patient_id', how='inner')
clinical_train = clinical_train.loc[:, ~clinical_train.columns.isin(['DFS', 'event_DFS', 'LRC', 'event_LRC'])]
clinical_train
# Out:
#     patient_id          OS  event_OS        DFS  event_DFS        LRC  \
# 2            5  114.312329         0  32.909589          0  32.909589
# 5           11  111.846575         0  27.715068          0  27.715068
# 6           12   49.479452         1  43.101370          1  49.479452
# 9           15   17.589041         1  17.589041          1  17.589041
# 10          16   66.739726         1  47.473973          1  47.473973
# 14          23   21.106849         1  10.126027          1  10.126027
# 15          24   87.978082         1  87.978082          1  87.978082
# 17          26   62.005479         1  53.983562          1  62.005479
# 18          27  105.073973         0  98.005479          0  98.005479
# 21          31   20.613699         1   3.419178          1   3.419178
#
#     event_LRC
# 2           0
# 5           0
# 6           0
# 9           0
# 10          0
# 14          1
# 15          0
# 17          0
# 18          0
# 21          1
#      patient_id        age  female  cavum_oris  oropharynx  hypopharynx  \
# 0             5  54.238356       1           0           1            0
# 1            11  54.539726       0           0           0            0
# 2            12  59.019178       0           1           0            0
# 3            15  70.726027       0           0           0            0
# 4            16  67.865753       0           0           0            0
# ..          ...        ...     ...         ...         ...          ...
# 134         249  60.435616       0           0           1            0
# 135         250  68.794521       0           0           1            0
# 136         252  57.498630       0           0           1            0
# 137         253  65.684932       0           0           1            0
# 138         254  61.676712       0           0           1            0
#
#      larynx  histgrade_high  hpv_related  charlson  pack_years  uicc8_III-IV  \
# 0         0               1          0.0         0    0.000000           0.0
# 1         1               0          0.0         1   27.404795           0.0
# 2         0               1          0.0         1   41.019178           1.0
# 3         1               0          0.0         1   37.500000           0.0
# 4         1               0          0.0         1   53.000000           0.0
# ..      ...             ...          ...       ...         ...           ...
# 134       0               1          1.0         0    0.000000           0.0
# 135       0               1          1.0         0    0.000000           1.0
# 136       0               1          1.0         1   39.498630           0.0
# 137       0               1          1.0         1   71.527397           1.0
# 138       0               1          1.0         0    2.250000           1.0
#
#        SUVpeak     MTV         TLG          OS  event_OS
# 0    14.473272   7.934   86.228420  114.312329         0
# 1     5.044678   1.656    7.040100  111.846575         0
# 2     7.839043  14.502   83.569669   49.479452         1
# 3     2.880631   2.440    5.567091   17.589041         1
# 4     5.402006   3.668   16.150550   66.739726         1
# ..         ...     ...         ...         ...       ...
# 134   9.290139   3.650   26.280140   42.805479         0
# 135   7.172883  18.967  101.754834   42.739726         0
# 136  13.873187   6.370   66.273201   42.312329         0
# 137   7.507419  12.443   71.832443   42.246575         0
# 138  13.053465   7.983   78.647696   42.049315         0
#
# [139 rows x 17 columns]

# %%
# Drop patient_id column
clinical_train = clinical_train.drop('patient_id', axis=1)

# %%
# Check null values in D1
clinical_train.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# ## Test dataset: MAASTRO

# %%
(MAASTRO_D1['patient_id'] == MAASTRO_OS_target['patient_id']).sum()
# Out:
# 99

# %%
# Rename the column name of response_MAASTRO 
response_MAASTRO.rename(columns = {'Index' : 'patient_id'}, inplace = True)

# %%
# need to choose patient_id from MAASTRO_D1 in response_MAASTRO
data = list(MAASTRO_D1['patient_id'])
mask = response_MAASTRO['patient_id'].isin(data)
response_MAASTRO = response_MAASTRO[mask] 
response_MAASTRO
# Out:
#      patient_id     OS  OS_event    LRC  LRC_event    DFS  DFS_event
# 0             1  62.43       0.0  62.43        0.0  62.43        0.0
# 1             2  60.00       0.0  60.00        0.0  60.00        0.0
# 2             3  44.43       1.0   8.83        1.0   8.83        1.0
# 3             4  37.20       1.0  19.37        0.0  19.73        1.0
# 5             6  59.23       0.0  59.23        0.0  59.23        0.0
# ..          ...    ...       ...    ...        ...    ...        ...
# 109         110  19.00       1.0  13.27        1.0  13.27        1.0
# 110         111  85.87       1.0  82.83        0.0  85.87        1.0
# 111         112  42.87       0.0  42.87        0.0  42.87        0.0
# 112         113  58.93       0.0  58.93        0.0  58.93        0.0
# 113         114  72.07       0.0  72.07        0.0  72.07        0.0
#
# [99 rows x 7 columns]

# %%
# Merge MAASTRO_D1 with response_MAASTRO
clinical_test = pd.merge(MAASTRO_D1, response_MAASTRO, on='patient_id', how='inner')
clinical_test = clinical_test.loc[:, ~clinical_test.columns.isin(['DFS', 'DFS_event', 'LRC', 'LRC_event'])]
clinical_test
# Out:
#     patient_id  age  female  cavum_oris  oropharynx  hypopharynx  larynx  \
# 0            1   55       0           0           1            0       0
# 1            2   55       0           0           1            0       0
# 2            3   55       0           0           1            0       0
# 3            4   61       1           0           0            0       1
# 4            6   70       0           0           1            0       0
# ..         ...  ...     ...         ...         ...          ...     ...
# 94         110   66       1           0           0            0       1
# 95         111   63       0           0           0            0       1
# 96         112   63       0           0           1            0       0
# 97         113   54       0           0           1            0       0
# 98         114   62       0           0           0            1       0
#
#     histgrade_high  hpv_related  charlson  pack_years  uicc8_III-IV  \
# 0                1            1         1           0             0
# 1                0            0         0          20             1
# 2                0            0         1           6             1
# 3                1            0         1          45             1
# 4                1            1         1          59             0
# ..             ...          ...       ...         ...           ...
# 94               0            0         0          55             1
# 95               0            0         1         174             1
# 96               1            1         1           0             1
# 97               1            1         0           0             0
# 98               1            0         0          40             1
#
#       SUVpeak     MTV         TLG     OS  OS_event
# 0   15.438583  22.841  263.611623  62.43       0.0
# 1    8.829353   5.660   36.980700  60.00       0.0
# 2   13.476123   7.791   74.636342  44.43       1.0
# 3    8.632732   7.908   46.791979  37.20       1.0
# 4    9.783954  15.237  107.637514  59.23       0.0
# ..        ...     ...         ...    ...       ...
# 94  31.338410   6.110  144.490782  19.00       1.0
# 95  13.041604   7.182   69.214868  85.87       1.0
# 96   8.944517  16.483  102.594274  42.87       0.0
# 97  14.184236   9.981  103.229492  58.93       0.0
# 98  10.414851   3.495   28.553212  72.07       0.0
#
# [99 rows x 17 columns]

# %%
# Drop patient_id column
clinical_test = clinical_test.drop('patient_id', axis=1)

# %%
# Some rows have null values in OS, OS_event -> Remove those rows
clinical_test[clinical_test.isnull().any(axis=1)]
clinical_test = clinical_test.dropna(how='any',axis=0)
# Out:
# Empty DataFrame
# Columns: [age, female, cavum_oris, oropharynx, hypopharynx, larynx, histgrade_high, hpv_related, charlson, pack_years, uicc8_III-IV, SUVpeak, MTV, TLG, OS, OS_event]
# Index: []

# %%
# X
X = clinical_train.loc[:, ~clinical_train.columns.isin(['OS', 'event_OS'])]

# y 
y = clinical_train.loc[:, ['OS', 'event_OS']]

# %%
# Set lower, upper time point and gbsg_times for IBS calculation later 
lower, upper = np.percentile(y['OS'], [10, 90])
gbsg_times = np.arange(lower, upper)

# y into array 
lists = [] 
for i, j in zip(y['event_OS'], y['OS']): 
    lists.append((i, j))

y = np.array(lists, dtype=[('status', bool), ('time', np.int32)])

# %%
# Shape
print('X_train: ', X.shape)
print('y_train: ', y.shape)
# Out:
# X_train:  (139, 14)
# y_train:  (139,)

# %%
clinical_test.rename(columns = {'OS_event' : 'event_OS'}, inplace = True)

# %%
# X
X_MAASTRO = clinical_test.loc[:, ~clinical_test.columns.isin(['OS', 'event_OS'])]

# y y_MAASTRO
y_MAASTRO = clinical_test.loc[:, ['OS', 'event_OS']]
lower, upper = np.percentile(y_MAASTRO['OS'], [10, 90])
gbsg_times = np.arange(lower, upper)

# y into array 
lists = [] 
for i, j in zip(y_MAASTRO['event_OS'], y_MAASTRO['OS']): 
    lists.append((i, j))

y_MAASTRO = np.array(lists, dtype=[('status', bool), ('time', np.int32)])

clinical_test.shape
# Out:
# (99, 16)

# %% [markdown]
# ## Standardization for Clustering

# %%
original_X = X.copy()

# %%
# Standardize the data 
## Save the column and index 
X_columns = X.columns 
X_index = X.index

## Standardize the data but not the categorical columns
categorical_columns = ['female', 
                        'cavum_oris',
                        'oropharynx',
                        'hypopharynx',
                        'larynx',
                        'histgrade_high',
                        'hpv_related',
                        'charlson',
                        'uicc8_III-IV']

### Separate the categorical and non-categorical columns
X_categorical = X[categorical_columns]
X_numeric = X.drop(categorical_columns, axis=1)
X_numeric_columns = X_numeric.columns
X_numeric_index = X_numeric.index

### Standardize non-categorical and then concat with the categorical
scaler = MinMaxScaler()
X_numeric_std = scaler.fit_transform(X_numeric)
X_numeric_std = pd.DataFrame(X_numeric_std, columns=X_numeric_columns, index=X_numeric_index)
X_std = pd.concat([X_categorical, X_numeric_std], axis=1)

## Sort the order of the columns as it was in the clinical train 
X_std = X_std[original_X.columns]

# %%
X_std
# Out:
#           age  female  cavum_oris  oropharynx  hypopharynx  larynx  \
# 0    0.365347       1           0           1            0       0
# 1    0.373041       0           0           0            0       1
# 2    0.487409       0           1           0            0       0
# 3    0.786304       0           0           0            0       1
# 4    0.713276       0           0           0            0       1
# ..        ...     ...         ...         ...          ...     ...
# 134  0.523573       0           0           1            0       0
# 135  0.736989       0           0           1            0       0
# 136  0.448587       0           0           1            0       0
# 137  0.657597       0           0           1            0       0
# 138  0.555260       0           0           1            0       0
#
#      histgrade_high  hpv_related  charlson  pack_years  uicc8_III-IV  \
# 0                 1          0.0         0    0.000000           0.0
# 1                 0          0.0         1    0.213981           0.0
# 2                 1          0.0         1    0.320284           1.0
# 3                 0          0.0         1    0.292806           0.0
# 4                 0          0.0         1    0.413832           0.0
# ..              ...          ...       ...         ...           ...
# 134               1          1.0         0    0.000000           0.0
# 135               1          1.0         0    0.000000           1.0
# 136               1          1.0         1    0.308411           0.0
# 137               1          1.0         1    0.558497           1.0
# 138               1          1.0         0    0.017568           1.0
#
#       SUVpeak       MTV       TLG
# 0    0.435155  0.074159  0.044798
# 1    0.089331  0.008512  0.001900
# 2    0.191823  0.142839  0.043358
# 3    0.009957  0.016710  0.001102
# 4    0.102437  0.029551  0.006835
# ..        ...       ...       ...
# 134  0.245047  0.029363  0.012323
# 135  0.167389  0.189529  0.053209
# 136  0.413145  0.057805  0.033988
# 137  0.179660  0.121309  0.037000
# 138  0.383079  0.074672  0.040692
#
# [139 rows x 14 columns]

# %% [markdown]
# ## Feature Selection

# %%
# Decide how many clusters to form 
X_transposed = X_std.T

kmeans = KMeans()
ssd = []
K = range(2, 10)

for k in K:
    kmeans = KMeans(n_clusters=k).fit(X_transposed)
    ssd.append(kmeans.inertia_)

kmeans = KMeans()
visu = KElbowVisualizer(kmeans, k=(2, 10))
visu.fit(clinical_train)
visu.show()
# Out:
# KElbowVisualizer(ax=<AxesSubplot:>, estimator=KMeans(n_clusters=9), k=(2, 10))
# <AxesSubplot:title={'center':'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %% [markdown]
# ### Using the highest feature importance

# %%
num_clusters = 3 
kmeans = KMeans(n_clusters=num_clusters)
kmeans.fit(X_std.T)
cluster_labels = kmeans.labels_

selected_features = [] 
for i in range(3):
    coxph = CoxPHFitter(penalizer=0.00001)
    X_cluster = X_std[X_std.columns[cluster_labels==i]]
    X_cluster = pd.concat([X_cluster, clinical_train[['OS', 'event_OS']]], axis=1)
    coxph.fit(X_cluster, duration_col='OS', event_col='event_OS')

    # Get coefficients and associated feature names
    coefficients = coxph.summary['coef']
    feature_names = coxph.summary.index

    # Create a DataFrame to store coefficients and feature names
    coefficients_df = pd.DataFrame({'Feature': feature_names, 'Coefficient': coefficients})

    # Take absolute values of coefficients
    coefficients_df['Abs_Coefficient'] = coefficients_df['Coefficient'].abs()

    # Sort coefficients by absolute value to identify important features
    sorted_coefficients_df = coefficients_df.sort_values(by='Abs_Coefficient', ascending=False)

    # Display the column with the highest feature importance and its coefficient value
    max_coefficient_feature = sorted_coefficients_df.loc[sorted_coefficients_df['Abs_Coefficient'].idxmax()]
    print(f"Cluster {i}: Most important feature: {max_coefficient_feature['Feature']}, Coefficient: {max_coefficient_feature['Coefficient']}")
    selected_features.append(max_coefficient_feature['Feature'])
# Out:
# KMeans(n_clusters=3)
# <lifelines.CoxPHFitter: fitted with 139 total observations, 82 right-censored observations>
# Cluster 0: Most important feature: uicc8_III-IV, Coefficient: 1.4550826053639634
# <lifelines.CoxPHFitter: fitted with 139 total observations, 82 right-censored observations>
# Cluster 1: Most important feature: MTV, Coefficient: 4.313172014507958
# <lifelines.CoxPHFitter: fitted with 139 total observations, 82 right-censored observations>
# Cluster 2: Most important feature: hpv_related, Coefficient: -1.3994025496184521

# %%
X_fs_fi = X.loc[:, selected_features]
X_new = X_fs_fi.copy()

X_MAASTRO_fs_fi = X_MAASTRO[selected_features]
MAASTRO_new = X_MAASTRO_fs_fi.copy()

# %% [markdown]
# # Standardization

# %%
# Standardize X_new, the new data with the selected features only 
categorical_columns = ['female', 
                        'cavum_oris',
                        'oropharynx',
                        'hypopharynx',
                        'larynx',
                        'histgrade_high',
                        'hpv_related',
                        'charlson',
                        'uicc8_III-IV']

# Set the columns_to_drop which are categorical 
columns_to_drop = [col for col in X_new.columns if col in categorical_columns]

# Drop the columns if they exist in the DataFrame and save the numeric part in X_new_numeric
X_new_categoric = X_new[columns_to_drop]
X_new_numeric = X_new.drop(columns=columns_to_drop, inplace=False)

# Do the standardization for the numeric part 
scaler = MinMaxScaler() 
X_new_numeric_columns = X_new_numeric.columns
X_new_numeric_index = X_new_numeric.index 
X_new_numeric_std = scaler.fit_transform(X_new_numeric)
X_new_numeric_std = pd.DataFrame(X_new_numeric_std,
                                 columns=X_new_numeric_columns, 
                                 index=X_new_numeric_index)
X_new_std = pd.concat([X_new_numeric_std, X_new_categoric], axis=1)

# %%
# Standardize X_MAASTRO 
# Set the columns_to_drop which are categorical 
columns_to_drop = [col for col in MAASTRO_new.columns if col in categorical_columns]

# Drop the columns if they exist in the DataFrame and save the numeric part in X_new_numeric
MAASTRO_new_categoric = MAASTRO_new[columns_to_drop]
MAASTRO_new_numeric = MAASTRO_new.drop(columns=columns_to_drop, inplace=False)

# Do the standardization for the numeric part 
MAASTRO_new_numeric_columns = MAASTRO_new_numeric.columns
MAASTRO_new_numeric_index = MAASTRO_new_numeric.index 
MAASTRO_new_numeric_std = scaler.transform(MAASTRO_new_numeric)
MAASTRO_new_numeric_std = pd.DataFrame(MAASTRO_new_numeric_std,
                                 columns=MAASTRO_new_numeric_columns, 
                                 index=MAASTRO_new_numeric_index)
MAASTRO_new_std = pd.concat([MAASTRO_new_numeric_std, MAASTRO_new_categoric], axis=1)

# Change the order of the X_new_std 
X_new_std = X_new_std[X_new.columns]
MAASTRO_new = MAASTRO_new[X_new.columns]
MAASTRO_new_std = MAASTRO_new_std[X_new.columns]

# %%
X_new
# Out:
#      uicc8_III-IV     MTV  hpv_related
# 0             0.0   7.934          0.0
# 1             0.0   1.656          0.0
# 2             1.0  14.502          0.0
# 3             0.0   2.440          0.0
# 4             0.0   3.668          0.0
# ..            ...     ...          ...
# 134           0.0   3.650          1.0
# 135           1.0  18.967          1.0
# 136           0.0   6.370          1.0
# 137           1.0  12.443          1.0
# 138           1.0   7.983          1.0
#
# [139 rows x 3 columns]

# %%
X_new_std
# Out:
#      uicc8_III-IV       MTV  hpv_related
# 0             0.0  0.074159          0.0
# 1             0.0  0.008512          0.0
# 2             1.0  0.142839          0.0
# 3             0.0  0.016710          0.0
# 4             0.0  0.029551          0.0
# ..            ...       ...          ...
# 134           0.0  0.029363          1.0
# 135           1.0  0.189529          1.0
# 136           0.0  0.057805          1.0
# 137           1.0  0.121309          1.0
# 138           1.0  0.074672          1.0
#
# [139 rows x 3 columns]

# %%
MAASTRO_new
# Out:
#     uicc8_III-IV     MTV  hpv_related
# 0              0  22.841            1
# 1              1   5.660            0
# 2              1   7.791            0
# 3              1   7.908            0
# 4              0  15.237            1
# ..           ...     ...          ...
# 94             1   6.110            0
# 95             1   7.182            0
# 96             1  16.483            1
# 97             0   9.981            1
# 98             1   3.495            0
#
# [99 rows x 3 columns]

# %%
MAASTRO_new_std
# Out:
#     uicc8_III-IV       MTV  hpv_related
# 0              0  0.230038            1
# 1              1  0.050381            0
# 2              1  0.072664            0
# 3              1  0.073887            0
# 4              0  0.150525            1
# ..           ...       ...          ...
# 94             1  0.055086            0
# 95             1  0.066296            0
# 96             1  0.163554            1
# 97             0  0.095564            1
# 98             1  0.027742            0
#
# [99 rows x 3 columns]

# %% [markdown]
# # Modelling

# %% [markdown]
# ### 1. CoxPHSurvivalAnalysis

# %% [markdown]
# #### Train

# %%
# Setting the y format for skf below  
y = clinical_train[['OS', 'event_OS']]

# Running to optuna for hyperparameter tuning 
def create_objective(model_class, metric, X, y):
    def objective(trial): 
        # Create and fit survival model 
        model = model_class()
        
        scores = [] 

        skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=123)
        
        for k, (train_index, test_index) in enumerate(skf.split(X, y.iloc[:, 1])): 
            X_train, X_test = X.iloc[train_index], X.iloc[test_index]
            y_train_df, y_test_df = y.iloc[train_index], y.iloc[test_index]
            
            # y_train into array 
            y_train = [] 
            for i, j in zip(y_train_df['event_OS'], y_train_df['OS']): 
                y_train.append((i, j))
            y_train = np.array(y_train, dtype=[('status', bool), ('time', np.int32)])

            # y_test into array
            y_test = [] 
            for i, j in zip(y_test_df['event_OS'], y_test_df['OS']): 
                y_test.append((i, j))
            y_test = np.array(y_test, dtype=[('status', bool), ('time', np.int32)])

            # Min Max Standardization
            excluded_columns = ['female', 
                                'cavum_oris',
                                'oropharynx',
                                'hypopharynx',
                                'larynx',
                                'histgrade_high',
                                'hpv_related',
                                'charlson',
                                'uicc8_III-IV'
                               ]
            excluded_columns = set(excluded_columns).intersection(X.columns)

            scaler = MinMaxScaler() 
            X_train_included = X_train.drop(excluded_columns, axis=1)
            X_test_included = X_test.drop(excluded_columns, axis=1)
                        
            if not X_train_included.empty and not X_test_included.empty:
                X_train_included_std = scaler.fit_transform(X_train_included)
                X_test_included_std = scaler.transform(X_test_included)
                
                # Concatenation
                X_train_std_df = pd.DataFrame(X_train_included_std, columns=X_train_included.columns, index=X_train_included.index)
                X_train_std = pd.concat([X_train_std_df, X_train[excluded_columns]], axis=1)

                X_test_std_df = pd.DataFrame(X_test_included_std, columns=X_test_included.columns, index=X_test_included.index)
                X_test_std = pd.concat([X_test_std_df, X_test[excluded_columns]], axis=1)
            
            else: 
                X_train_std = X_train
                X_test_std = X_test 
            
            model.fit(X_train_std, y_train)

            if metric == "c-index":
                # Make predictions using C-index 
                c_index_score = model.score(X_test_std, y_test)
                scores.append(c_index_score)
                print(f"Fold {k + 1} C-index: {c_index_score}")
                
            elif metric == "ibs":
                # Make predictions using IBS 
                lower, upper = np.percentile(y_test["time"], [10, 90])    
                gbsg_times = np.arange(lower, upper)
                cox_surv_prob = np.row_stack([fn(gbsg_times) for fn in model.predict_survival_function(X_test_std)])
                ibs = integrated_brier_score(y_test, y_test, cox_surv_prob, gbsg_times)
                scores.append(ibs)
                print(f"Fold {k + 1} IBS: {ibs}")
            else:
                raise ValueError("Invalid metric. Use 'C-index' or 'ibs'.")
        
        # Return the mean of scores
        return np.mean(scores)
    
    return objective

# C-index
study_cindex = optuna.create_study(direction="maximize", sampler=optuna.samplers.TPESampler(seed=123))
objective_cindex = create_objective(CoxPHSurvivalAnalysis, "c-index", X_new, y)
study_cindex.optimize(objective_cindex, n_trials=1, show_progress_bar=True)
print("\n")
print("* Best trial for C-index: \n", study_cindex.best_trial)
print("\n")
print("* Best Score for C-index: \n", study_cindex.best_value)

# Example usage for IBS
study_ibs = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(seed=123))
objective_ibs = create_objective(CoxPHSurvivalAnalysis, "ibs", X_new, y)
study_ibs.optimize(objective_ibs, n_trials=1, show_progress_bar=True)
print("\n")
print("* Best trial for IBS: \n", study_ibs.best_trial)
print("\n")
print("* Best Score for IBS: \n", study_ibs.best_value)
# Out:
# [I 2024-04-19 17:23:48,380] A new study created in memory with name: no-name-f424c680-1ca6-4a1a-850d-6c5a713ad801
#   0%|          | 0/1 [00:00<?, ?it/s]
# Fold 1 C-index: 0.6753246753246753
# Fold 2 C-index: 0.7544642857142857
# Fold 3 C-index: 0.8137254901960784
# Fold 4 C-index: 0.8227848101265823
# Fold 5 C-index: 0.6525821596244131
# [I 2024-04-19 17:23:50,404] Trial 0 finished with value: 0.743776284197207 and parameters: {}. Best is trial 0 with value: 0.743776284197207.
# [I 2024-04-19 17:23:50,461] A new study created in memory with name: no-name-4382cbd0-b520-4ccc-8b2b-ded105c3ab0b
# * Best trial for C-index:
#  FrozenTrial(number=0, state=TrialState.COMPLETE, values=[0.743776284197207], datetime_start=datetime.datetime(2024, 4, 19, 17, 23, 48, 769602), datetime_complete=datetime.datetime(2024, 4, 19, 17, 23, 50, 403978), params={}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={}, trial_id=0, value=None)
#
#
# * Best Score for C-index:
#  0.743776284197207
#   0%|          | 0/1 [00:00<?, ?it/s]
# Fold 1 IBS: 0.1759669182996373
# Fold 2 IBS: 0.2051378697422175
# Fold 3 IBS: 0.16460093493027647
# Fold 4 IBS: 0.14100715007612027
# Fold 5 IBS: 0.24271027564677294
# [I 2024-04-19 17:23:51,836] Trial 0 finished with value: 0.1858846297390049 and parameters: {}. Best is trial 0 with value: 0.1858846297390049.
#
#
# * Best trial for IBS:
#  FrozenTrial(number=0, state=TrialState.COMPLETE, values=[0.1858846297390049], datetime_start=datetime.datetime(2024, 4, 19, 17, 23, 50, 502236), datetime_complete=datetime.datetime(2024, 4, 19, 17, 23, 51, 836313), params={}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={}, trial_id=0, value=None)
#
#
# * Best Score for IBS:
#  0.1858846297390049

# %%
# Setting a dictionary to save the train results 
train_cindex = {} 
train_ibs = {} 

# Saving the values to the dictionary 
train_cindex['CoxPH'] = np.round(study_cindex.best_value, 3)
train_ibs['CoxPH'] = np.round(study_ibs.best_value, 3)

# %%
print("train_cindex: ", np.round(study_cindex.best_value, 3))
print("train_ibs: ", np.round(study_ibs.best_value, 3))
# Out:
# train_cindex:  0.744
# train_ibs:  0.186

# %% [markdown]
# #### Test

# %%
# y into array 
lists = [] 
for i, j in zip(y['event_OS'], y['OS']): 
    lists.append((i, j))

y = np.array(lists, dtype=[('status', bool), ('time', np.int32)])

# %%
# Test on MAASTRO 
cph = CoxPHSurvivalAnalysis()

cph.fit(X_new_std, y)

# Save C-index 
c_index = cph.score(MAASTRO_new_std, y_MAASTRO)
c_index = np.round(c_index, 3)
print('Concordance index:', c_index)

# Save IBS 
lower, upper = np.percentile(y_MAASTRO["time"], [10, 90])
gbsg_times = np.arange(lower, upper)
surv_prob = np.row_stack([fn(gbsg_times) for fn in cph.predict_survival_function(MAASTRO_new_std)])
ibs = integrated_brier_score(y_MAASTRO, y_MAASTRO, surv_prob, gbsg_times)
ibs = np.round(ibs, 3)
print('IBS score:', ibs)
# Out:
# CoxPHSurvivalAnalysis()
# Concordance index: 0.666
# IBS score: 0.222

# %%
# Setting a dictionary to save the test results 
test_cindex = {} 
test_ibs = {}

# %%
# Saving the values to the dictionary 
test_cindex['CoxPH'] = c_index
test_ibs['CoxPH'] = ibs

# %% [markdown]
# ### 2. CoxnetSurvivalAnalysis - Ridge

# %% [markdown]
# #### Train

# %%
# Setting the y format 
y = clinical_train[['OS', 'event_OS']]

# Running to optuna for hyperparameter tuning 
def create_objective(model_class, metric, X, y):
    def objective(trial): 
        # Create and fit survival model 
        model = model_class(l1_ratio=0.0000001, 
                            fit_baseline_model=True)
        
        scores = [] 

        skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=123)
        
        for k, (train_index, test_index) in enumerate(skf.split(X, y.iloc[:, 1])): 
            X_train, X_test = X.iloc[train_index], X.iloc[test_index]
            y_train_df, y_test_df = y.iloc[train_index], y.iloc[test_index]
            
            # y_train into array 
            y_train = [] 
            for i, j in zip(y_train_df['event_OS'], y_train_df['OS']): 
                y_train.append((i, j))
            y_train = np.array(y_train, dtype=[('status', bool), ('time', np.int32)])

            # y_test into array
            y_test = [] 
            for i, j in zip(y_test_df['event_OS'], y_test_df['OS']): 
                y_test.append((i, j))
            y_test = np.array(y_test, dtype=[('status', bool), ('time', np.int32)])

            # Min Max Standardization
            excluded_columns = ['female', 
                                'cavum_oris',
                                'oropharynx',
                                'hypopharynx',
                                'larynx',
                                'histgrade_high',
                                'hpv_related',
                                'charlson',
                                'uicc8_III-IV'
                               ]
            excluded_columns = set(excluded_columns).intersection(X.columns)

            scaler = MinMaxScaler() 
            X_train_included = X_train.drop(excluded_columns, axis=1)
            X_test_included = X_test.drop(excluded_columns, axis=1)
                        
            if not X_train_included.empty and not X_test_included.empty:
                X_train_included_std = scaler.fit_transform(X_train_included)
                X_test_included_std = scaler.transform(X_test_included)
                
                # Concatenation
                X_train_std_df = pd.DataFrame(X_train_included_std, columns=X_train_included.columns, index=X_train_included.index)
                X_train_std = pd.concat([X_train_std_df, X_train[excluded_columns]], axis=1)

                X_test_std_df = pd.DataFrame(X_test_included_std, columns=X_test_included.columns, index=X_test_included.index)
                X_test_std = pd.concat([X_test_std_df, X_test[excluded_columns]], axis=1)
            
            else: 
                X_train_std = X_train
                X_test_std = X_test 
            
            model.fit(X_train_std, y_train)

            if metric == "c-index":
                # Make predictions using C-index 
                c_index_score = model.score(X_test_std, y_test)
                scores.append(c_index_score)
                print(f"Fold {k + 1} C-index: {c_index_score}")
                
            elif metric == "ibs":
                # Make predictions using IBS 
                lower, upper = np.percentile(y_test["time"], [10, 90])    
                gbsg_times = np.arange(lower, upper)
                cox_surv_prob = np.row_stack([fn(gbsg_times) for fn in model.predict_survival_function(X_test_std)])
                ibs = integrated_brier_score(y_test, y_test, cox_surv_prob, gbsg_times)
                scores.append(ibs)
                print(f"Fold {k + 1} IBS: {ibs}")
            else:
                raise ValueError("Invalid metric. Use 'C-index' or 'ibs'.")
        
        # Return the mean of scores
        return np.mean(scores)
    
    return objective

# C-index
study_cindex = optuna.create_study(direction="maximize", sampler=optuna.samplers.TPESampler(seed=123))
objective_cindex = create_objective(CoxnetSurvivalAnalysis, "c-index", X_new, y)
study_cindex.optimize(objective_cindex, n_trials=1, show_progress_bar=True)
print("\n")
print("* Best trial for C-index: \n", study_cindex.best_trial)
print("\n")
print("* Best Score for C-index: \n", study_cindex.best_value)

# Example usage for IBS
study_ibs = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(seed=123))
objective_ibs = create_objective(CoxnetSurvivalAnalysis, "ibs", X_new, y)
study_ibs.optimize(objective_ibs, n_trials=1, show_progress_bar=True)
print("\n")
print("* Best trial for IBS: \n", study_ibs.best_trial)
print("\n")
print("* Best Score for IBS: \n", study_ibs.best_value)
# Out:
# [I 2024-04-19 17:23:52,894] A new study created in memory with name: no-name-329c494b-fa9b-448d-9828-f96aeb25a594
#   0%|          | 0/1 [00:00<?, ?it/s]
# Fold 1 C-index: 0.7424242424242424
# Fold 2 C-index: 0.6964285714285714
# Fold 3 C-index: 0.7745098039215687
# [I 2024-04-19 17:23:53,611] A new study created in memory with name: no-name-a263360a-62e7-4240-98d8-9525ceaa1e6d
# Fold 4 C-index: 0.8059071729957806
# Fold 5 C-index: 0.6150234741784038
# [I 2024-04-19 17:23:53,600] Trial 0 finished with value: 0.7268586529897133 and parameters: {}. Best is trial 0 with value: 0.7268586529897133.
#
#
# * Best trial for C-index:
#  FrozenTrial(number=0, state=TrialState.COMPLETE, values=[0.7268586529897133], datetime_start=datetime.datetime(2024, 4, 19, 17, 23, 53, 89768), datetime_complete=datetime.datetime(2024, 4, 19, 17, 23, 53, 600317), params={}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={}, trial_id=0, value=None)
#
#
# * Best Score for C-index:
#  0.7268586529897133
#   0%|          | 0/1 [00:00<?, ?it/s]
# Fold 1 IBS: 0.21397651777490725
# Fold 2 IBS: 0.2215779141699564
# Fold 3 IBS: 0.20453594224963634
# Fold 4 IBS: 0.224738034459558
# Fold 5 IBS: 0.2181243143679756
# [I 2024-04-19 17:23:54,457] Trial 0 finished with value: 0.2165905446044067 and parameters: {}. Best is trial 0 with value: 0.2165905446044067.
#
#
# * Best trial for IBS:
#  FrozenTrial(number=0, state=TrialState.COMPLETE, values=[0.2165905446044067], datetime_start=datetime.datetime(2024, 4, 19, 17, 23, 53, 640599), datetime_complete=datetime.datetime(2024, 4, 19, 17, 23, 54, 454050), params={}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={}, trial_id=0, value=None)
#
#
# * Best Score for IBS:
#  0.2165905446044067

# %%
train_cindex['CoxRidge'] = np.round(study_cindex.best_value, 3)
train_ibs['CoxRidge'] = np.round(study_ibs.best_value, 3)

# %%
print("train_cindex: ", np.round(study_cindex.best_value, 3))
print("train_ibs: ", np.round(study_ibs.best_value, 3))
# Out:
# train_cindex:  0.727
# train_ibs:  0.217

# %% [markdown]
# #### Test

# %%
# y into array 
lists = [] 
for i, j in zip(y['event_OS'], y['OS']): 
    lists.append((i, j))

y = np.array(lists, dtype=[('status', bool), ('time', np.int32)])

# %%
# A function for building the best model with the best parameters 
def create_best_model(model_class, best_params):
    best_params['l1_ratio'] = 0.0000001
    best_params['fit_baseline_model']=True
    return model_class(**best_params)

# Set the best model 
best_model_cindex = create_best_model(CoxnetSurvivalAnalysis, 
                                      study_cindex.best_params)

# Train the best model for C-index on the whole dataset
best_model_cindex.fit(X_new_std, y)

# Evaluate the best model for C-index on MAASTRO dataset
c_index = best_model_cindex.score(MAASTRO_new_std, y_MAASTRO)
c_index = np.round(c_index, 3)
print("test_cindex :", c_index)

# Set the best model 
best_model_ibs = create_best_model(CoxnetSurvivalAnalysis, study_ibs.best_params)

# Train the best model for IBS on the whole dataset
best_model_ibs.fit(X_new_std, y)

# Evaluate the best model for IBS on MAASTRO dataset
lower, upper = np.percentile(y_MAASTRO["time"], [10, 90])
gbsg_times = np.arange(lower, upper)
surv_prob = np.row_stack([fn(gbsg_times) for fn in best_model_ibs.predict_survival_function(MAASTRO_new_std)])
ibs = integrated_brier_score(y_MAASTRO, y_MAASTRO, surv_prob, gbsg_times)
ibs = np.round(ibs, 3)
print("test_ibs: ", ibs)
# Out:
# CoxnetSurvivalAnalysis(fit_baseline_model=True, l1_ratio=1e-07)
# test_cindex : 0.593
# CoxnetSurvivalAnalysis(fit_baseline_model=True, l1_ratio=1e-07)
# test_ibs:  0.221

# %%
# Saving the values to the dictionary 
test_cindex['CoxRidge'] = c_index
test_ibs['CoxRidge'] = ibs

# %% [markdown]
# ### 3. CoxnetSurvivalAnalysis - Lasso

# %% [markdown]
# #### Train

# %%
# Setting the y format 
y = clinical_train[['OS', 'event_OS']]

def create_objective(model_class, metric, X, y):
    def objective(trial): 
        # Create and fit survival model 
        model = model_class(l1_ratio=1, 
                            fit_baseline_model=True)
        
        scores = [] 

        skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=123)
        
        for k, (train_index, test_index) in enumerate(skf.split(X, y.iloc[:, 1])): 
            X_train, X_test = X.iloc[train_index], X.iloc[test_index]
            y_train_df, y_test_df = y.iloc[train_index], y.iloc[test_index]
            
            # y_train into array 
            y_train = [] 
            for i, j in zip(y_train_df['event_OS'], y_train_df['OS']): 
                y_train.append((i, j))
            y_train = np.array(y_train, dtype=[('status', bool), ('time', np.int32)])

            # y_test into array
            y_test = [] 
            for i, j in zip(y_test_df['event_OS'], y_test_df['OS']): 
                y_test.append((i, j))
            y_test = np.array(y_test, dtype=[('status', bool), ('time', np.int32)])

            # Min Max Standardization
            excluded_columns = ['female', 
                                'cavum_oris',
                                'oropharynx',
                                'hypopharynx',
                                'larynx',
                                'histgrade_high',
                                'hpv_related',
                                'charlson',
                                'uicc8_III-IV'
                               ]
            excluded_columns = set(excluded_columns).intersection(X.columns)

            scaler = MinMaxScaler() 
            X_train_included = X_train.drop(excluded_columns, axis=1)
            X_test_included = X_test.drop(excluded_columns, axis=1)
                        
            if not X_train_included.empty and not X_test_included.empty:
                X_train_included_std = scaler.fit_transform(X_train_included)
                X_test_included_std = scaler.transform(X_test_included)
                
                # Concatenation
                X_train_std_df = pd.DataFrame(X_train_included_std, columns=X_train_included.columns, index=X_train_included.index)
                X_train_std = pd.concat([X_train_std_df, X_train[excluded_columns]], axis=1)

                X_test_std_df = pd.DataFrame(X_test_included_std, columns=X_test_included.columns, index=X_test_included.index)
                X_test_std = pd.concat([X_test_std_df, X_test[excluded_columns]], axis=1)
            
            else: 
                X_train_std = X_train
                X_test_std = X_test 
            
            model.fit(X_train_std, y_train)

            if metric == "c-index":
                # Make predictions using C-index 
                c_index_score = model.score(X_test_std, y_test)
                scores.append(c_index_score)
                print(f"Fold {k + 1} C-index: {c_index_score}")
                
            elif metric == "ibs":
                # Make predictions using IBS 
                lower, upper = np.percentile(y_test["time"], [10, 90])    
                gbsg_times = np.arange(lower, upper)
                cox_surv_prob = np.row_stack([fn(gbsg_times) for fn in model.predict_survival_function(X_test_std)])
                ibs = integrated_brier_score(y_test, y_test, cox_surv_prob, gbsg_times)
                scores.append(ibs)
                print(f"Fold {k + 1} IBS: {ibs}")
            else:
                raise ValueError("Invalid metric. Use 'C-index' or 'ibs'.")
        
        # Return the mean of scores
        return np.mean(scores)
    
    return objective

# C-index
study_cindex = optuna.create_study(direction="maximize", sampler=optuna.samplers.TPESampler(seed=123))
objective_cindex = create_objective(CoxnetSurvivalAnalysis, "c-index", X_new, y)
study_cindex.optimize(objective_cindex, n_trials=1, show_progress_bar=True)
print("\n")
print("* Best trial for C-index: \n", study_cindex.best_trial)
print("\n")
print("* Best Score for C-index: \n", study_cindex.best_value)

# Example usage for IBS
study_ibs = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(seed=123))
objective_ibs = create_objective(CoxnetSurvivalAnalysis, "ibs", X_new, y)
study_ibs.optimize(objective_ibs, n_trials=1, show_progress_bar=True)
print("\n")
print("* Best trial for IBS: \n", study_ibs.best_trial)
print("\n")
print("* Best Score for IBS: \n", study_ibs.best_value)
# Out:
# [I 2024-04-19 17:23:55,094] A new study created in memory with name: no-name-2dba563e-d214-4ed4-a9a6-60ce82246d60
#   0%|          | 0/1 [00:00<?, ?it/s]
# Fold 1 C-index: 0.6753246753246753
# Fold 2 C-index: 0.7544642857142857
# Fold 3 C-index: 0.8137254901960784
# Fold 4 C-index: 0.8227848101265823
# [I 2024-04-19 17:23:56,960] A new study created in memory with name: no-name-651f10eb-1fcd-4881-8bfc-a1a66259fe36
# Fold 5 C-index: 0.6525821596244131
# [I 2024-04-19 17:23:56,953] Trial 0 finished with value: 0.743776284197207 and parameters: {}. Best is trial 0 with value: 0.743776284197207.
#
#
# * Best trial for C-index:
#  FrozenTrial(number=0, state=TrialState.COMPLETE, values=[0.743776284197207], datetime_start=datetime.datetime(2024, 4, 19, 17, 23, 55, 133257), datetime_complete=datetime.datetime(2024, 4, 19, 17, 23, 56, 953465), params={}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={}, trial_id=0, value=None)
#
#
# * Best Score for C-index:
#  0.743776284197207
#   0%|          | 0/1 [00:00<?, ?it/s]
# Fold 1 IBS: 0.17597494775871655
# Fold 2 IBS: 0.2054392658177408
# Fold 3 IBS: 0.1648543437868453
# Fold 4 IBS: 0.1422075064965473
# Fold 5 IBS: 0.24171986954154964
# [I 2024-04-19 17:23:59,246] Trial 0 finished with value: 0.1860391866802799 and parameters: {}. Best is trial 0 with value: 0.1860391866802799.
#
#
# * Best trial for IBS:
#  FrozenTrial(number=0, state=TrialState.COMPLETE, values=[0.1860391866802799], datetime_start=datetime.datetime(2024, 4, 19, 17, 23, 57, 4471), datetime_complete=datetime.datetime(2024, 4, 19, 17, 23, 59, 245870), params={}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={}, trial_id=0, value=None)
#
#
# * Best Score for IBS:
#  0.1860391866802799

# %%
train_cindex['CoxLasso'] = np.round(study_cindex.best_value, 3)
train_ibs['CoxLasso'] = np.round(study_ibs.best_value, 3)

# %%
print("train_cindex: ", np.round(study_cindex.best_value, 3))
print("train_ibs: ", np.round(study_ibs.best_value, 3))
# Out:
# train_cindex:  0.744
# train_ibs:  0.186

# %% [markdown]
# #### Test

# %%
# y into array 
lists = [] 
for i, j in zip(y['event_OS'], y['OS']): 
    lists.append((i, j))

y = np.array(lists, dtype=[('status', bool), ('time', np.int32)])

# %%
# A function for building the best model with the best parameters 
def create_best_model(model_class, best_params):
    best_params['l1_ratio'] = 1
    best_params['fit_baseline_model']=True
    return model_class(**best_params)

# Set the best model 
best_model_cindex = create_best_model(CoxnetSurvivalAnalysis, 
                                      study_cindex.best_params)

# Train the best model for C-index on the whole dataset
best_model_cindex.fit(X_new_std, y)

# Evaluate the best model for C-index on MAASTRO dataset
c_index = best_model_cindex.score(MAASTRO_new_std, y_MAASTRO)
c_index = np.round(c_index, 3)
print("test_cindex :", c_index)

# Set the best model 
best_model_ibs = create_best_model(CoxnetSurvivalAnalysis, study_ibs.best_params)

# Train the best model for IBS on the whole dataset
best_model_ibs.fit(X_new_std, y)

# Evaluate the best model for IBS on MAASTRO dataset
lower, upper = np.percentile(y_MAASTRO["time"], [10, 90])
gbsg_times = np.arange(lower, upper)
surv_prob = np.row_stack([fn(gbsg_times) for fn in best_model_ibs.predict_survival_function(MAASTRO_new_std)])
ibs = integrated_brier_score(y_MAASTRO, y_MAASTRO, surv_prob, gbsg_times)
ibs = np.round(ibs, 3)
print("test_ibs: ", ibs)
# Out:
# CoxnetSurvivalAnalysis(fit_baseline_model=True, l1_ratio=1)
# test_cindex : 0.666
# CoxnetSurvivalAnalysis(fit_baseline_model=True, l1_ratio=1)
# test_ibs:  0.221

# %%
# Saving the values to the dictionary 
test_cindex['CoxLasso'] = c_index
test_ibs['CoxLasso'] = ibs

# %% [markdown]
# ### 4. CoxnetSurvivalAnalysis - ElasticNet

# %% [markdown]
# #### Train

# %%
# Setting the y format 
y = clinical_train[['OS', 'event_OS']]

def create_objective(model_class, metric, X, y):
    def objective(trial): 
        # Suggest values for hyperparameters
        l1_ratio = trial.suggest_float("l1_ratio", 0.0001, 1)
        
        # Create and fit survival model 
        model = model_class(l1_ratio=l1_ratio, 
                           fit_baseline_model=True)
        
        scores = [] 

        skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=123)
        
        for k, (train_index, test_index) in enumerate(skf.split(X, y.iloc[:, 1])): 
            X_train, X_test = X.iloc[train_index], X.iloc[test_index]
            y_train_df, y_test_df = y.iloc[train_index], y.iloc[test_index]
            
            # y_train into array 
            y_train = [] 
            for i, j in zip(y_train_df['event_OS'], y_train_df['OS']): 
                y_train.append((i, j))
            y_train = np.array(y_train, dtype=[('status', bool), ('time', np.int32)])

            # y_test into array
            y_test = [] 
            for i, j in zip(y_test_df['event_OS'], y_test_df['OS']): 
                y_test.append((i, j))
            y_test = np.array(y_test, dtype=[('status', bool), ('time', np.int32)])

            # Min Max Standardization
            excluded_columns = ['female', 
                                'cavum_oris',
                                'oropharynx',
                                'hypopharynx',
                                'larynx',
                                'histgrade_high',
                                'hpv_related',
                                'charlson',
                                'uicc8_III-IV'
                               ]
            excluded_columns = set(excluded_columns).intersection(X.columns)

            scaler = MinMaxScaler() 
            X_train_included = X_train.drop(excluded_columns, axis=1)
            X_test_included = X_test.drop(excluded_columns, axis=1)
                        
            if not X_train_included.empty and not X_test_included.empty:
                X_train_included_std = scaler.fit_transform(X_train_included)
                X_test_included_std = scaler.transform(X_test_included)
                
                # Concatenation
                X_train_std_df = pd.DataFrame(X_train_included_std, columns=X_train_included.columns, index=X_train_included.index)
                X_train_std = pd.concat([X_train_std_df, X_train[excluded_columns]], axis=1)

                X_test_std_df = pd.DataFrame(X_test_included_std, columns=X_test_included.columns, index=X_test_included.index)
                X_test_std = pd.concat([X_test_std_df, X_test[excluded_columns]], axis=1)
            
            else: 
                X_train_std = X_train
                X_test_std = X_test 
            
            model.fit(X_train_std, y_train)

            if metric == "c-index":
                # Make predictions using C-index 
                c_index_score = model.score(X_test_std, y_test)
                scores.append(c_index_score)
                print(f"Fold {k + 1} C-index: {c_index_score}")
                
            elif metric == "ibs":
                # Make predictions using IBS 
                lower, upper = np.percentile(y_test["time"], [10, 90])    
                gbsg_times = np.arange(lower, upper)
                cox_surv_prob = np.row_stack([fn(gbsg_times) for fn in model.predict_survival_function(X_test_std)])
                ibs = integrated_brier_score(y_test, y_test, cox_surv_prob, gbsg_times)
                scores.append(ibs)
                print(f"Fold {k + 1} IBS: {ibs}")
            else:
                raise ValueError("Invalid metric. Use 'C-index' or 'ibs'.")
        
        # Return the mean of scores
        return np.mean(scores)
    
    return objective

# C-index
study_cindex = optuna.create_study(direction="maximize", sampler=optuna.samplers.TPESampler(seed=123))
objective_cindex = create_objective
. Best is trial 11 with value: 0.7538206701909601.
# Fold 1 C-index: 0.7424242424242424
# Fold 2 C-index: 0.6964285714285714
# Fold 3 C-index: 0.7794117647058824
# Fold 4 C-index: 0.8059071729957806
# Fold 5 C-index: 0.6103286384976526
# [I 2024-04-19 17:25:42,641] Trial 63 finished with value: 0.7269000780104259 and parameters: {'l1_ratio': 0.0001126294223321167}. Best is trial 11 with value: 0.7538206701909601.
# Fold 1 C-index: 0.6753246753246753
# Fold 2 C-index: 0.7544642857142857
# Fold 3 C-index: 0.8137254901960784
# Fold 4 C-index: 0.8227848101265823
# Fold 5 C-index: 0.6525821596244131
# [I 2024-04-19 17:25:44,707] Trial 64 finished with value: 0.743776284197207 and parameters: {'l1_ratio': 0.08104227444800237}. Best is trial 11 with value: 0.7538206701909601.
# Fold 1 C-index: 0.6753246753246753
# Fold 2 C-index: 0.7544642857142857
# Fold 3 C-index: 0.8137254901960784
# Fold 4 C-index: 0.8227848101265823
# Fold 5 C-index: 0.6525821596244131
# [I 2024-04-19 17:25:46,512] Trial 65 finished with value: 0.743776284197207 and parameters: {'l1_ratio': 0.12312388872555138}. Best is trial 11 with value: 0.7538206701909601.
# Fold 1 C-index: 0.7424242424242424
# Fold 2 C-index: 0.7544642857142857
# Fold 3 C-index: 0.8137254901960784
# Fold 4 C-index: 0.8059071729957806
# Fold 5 C-index: 0.6525821596244131
# [I 2024-04-19 17:25:47,949] Trial 66 finished with value: 0.7538206701909601 and parameters: {'l1_ratio': 0.04481142111322664}. Best is trial 11 with value: 0.7538206701909601.
# Fold 1 C-index: 0.6753246753246753
# Fold 2 C-index: 0.7544642857142857
# Fold 3 C-index: 0.8137254901960784
# Fold 4 C-index: 0.8227848101265823
# Fold 5 C-index: 0.6525821596244131
# [I 2024-04-19 17:25:49,970] Trial 67 finished with value: 0.743776284197207 and parameters: {'l1_ratio': 0.10022359348974141}. Best is trial 11 with value: 0.7538206701909601.
# Fold 1 C-index: 0.7424242424242424
# Fold 2 C-index: 0.6964285714285714
# Fold 3 C-index: 0.7794117647058824
# Fold 4 C-index: 0.8059071729957806
# Fold 5 C-index: 0.6525821596244131
# [I 2024-04-19 17:25:50,838] Trial 68 finished with value: 0.735350782235778 and parameters: {'l1_ratio': 0.024699604168553366}. Best is trial 11 with value: 0.7538206701909601.
# Fold 1 C-index: 0.6753246753246753
# Fold 2 C-index: 0.7544642857142857
# Fold 3 C-index: 0.8137254901960784
# Fold 4 C-index: 0.8227848101265823
# Fold 5 C-index: 0.6525821596244131
# [I 2024-04-19 17:25:52,829] Trial 69 finished with value: 0.743776284197207 and parameters: {'l1_ratio': 0.14881965141192482}. Best is trial 11 with value: 0.7538206701909601.
# Fold 1 C-index: 0.6753246753246753
# Fold 2 C-index: 0.7544642857142857
# Fold 3 C-index: 0.8137254901960784
# Fold 4 C-index: 0.8227848101265823
# Fold 5 C-index: 0.6525821596244131
# [I 2024-04-19 17:25:54,702] Trial 70 finished with value: 0.743776284197207 and parameters: {'l1_ratio': 0.06609107585587619}. Best is trial 11 with value: 0.7538206701909601.
# Fold 1 C-index: 0.7424242424242424
# Fold 2 C-index: 0.7544642857142857
# Fold 3 C-index: 0.8137254901960784
# Fold 4 C-index: 0.8059071729957806
# Fold 5 C-index: 0.6525821596244131
# [I 2024-04-19 17:25:56,103] Trial 71 finished with value: 0.7538206701909601 and parameters: {'l1_ratio': 0.0320309224506544}. Best is trial 11 with value: 0.7538206701909601.
# Fold 1 C-index: 0.7424242424242424
# Fold 2 C-index: 0.6964285714285714
# Fold 3 C-index: 0.7794117647058824
# Fold 4 C-index: 0.8059071729957806
# Fold 5 C-index: 0.6525821596244131
# [I 2024-04-19 17:25:56,907] Trial 72 finished with value: 0.735350782235778 and parameters: {'l1_ratio': 0.02465445597903016}. Best is trial 11 with value: 0.7538206701909601.
# Fold 1 C-index: 0.6753246753246753
# Fold 2 C-index: 0.7544642857142857
# Fold 3 C-index: 0.8137254901960784
# Fold 4 C-index: 0.8227848101265823
# Fold 5 C-index: 0.6525821596244131
# [I 2024-04-19 17:25:58,963] Trial 73 finished with value: 0.743776284197207 and parameters: {'l1_ratio': 0.06995815931451195}. Best is trial 11 with value: 0.7538206701909601.
# Fold 1 C-index: 0.6753246753246753
# Fold 2 C-index: 0.7544642857142857
# Fold 3 C-index: 0.8137254901960784
# Fold 4 C-index: 0.8227848101265823
# Fold 5 C-index: 0.6525821596244131
# [I 2024-04-19 17:26:00,720] Trial 74 finished with value: 0.743776284197207 and parameters: {'l1_ratio': 0.09028412968596146}. Best is trial 11 with value: 0.7538206701909601.
# Fold 1 C-index: 0.6753246753246753
# Fold 2 C-index: 0.7544642857142857
# Fold 3 C-index: 0.8137254901960784
# Fold 4 C-index: 0.8227848101265823
# Fold 5 C-index: 0.6525821596244131
# [I 2024-04-19 17:26:02,587] Trial 75 finished with value: 0.743776284197207 and parameters: {'l1_ratio': 0.1268681670380729}. Best is trial 11 with value: 0.7538206701909601.
# Fold 1 C-index: 0.7424242424242424
# Fold 2 C-index: 0.7544642857142857
# Fold 3 C-index: 0.8137254901960784
# Fold 4 C-index: 0.8059071729957806
# Fold 5 C-index: 0.6525821596244131
# [I 2024-04-19 17:26:04,188] Trial 76 finished with value: 0.7538206701909601 and parameters: {'l1_ratio': 0.04949427453171838}. Best is trial 11 with value: 0.7538206701909601.
# Fold 1 C-index: 0.6753246753246753
# Fold 2 C-index: 0.7544642857142857
# Fold 3 C-index: 0.8137254901960784
# Fold 4 C-index: 0.8227848101265823
# Fold 5 C-index: 0.6525821596244131
# [I 2024-04-19 17:26:05,854] Trial 77 finished with value: 0.743776284197207 and parameters: {'l1_ratio': 0.22130120881217713}. Best is trial 11 with value: 0.7538206701909601.
# Fold 1 C-index: 0.7424242424242424
# Fold 2 C-index: 0.6964285714285714
# Fold 3 C-index: 0.7794117647058824
# Fold 4 C-index: 0.8059071729957806
# Fold 5 C-index: 0.6103286384976526
# [I 2024-04-19 17:26:06,259] Trial 78 finished with value: 0.7269000780104259 and parameters: {'l1_ratio': 0.00019085318277831803}. Best is trial 11 with value: 0.7538206701909601.
# Fold 1 C-index: 0.6753246753246753
# Fold 2 C-index: 0.7544642857142857
# Fold 3 C-index: 0.8137254901960784
# Fold 4 C-index: 0.8227848101265823
# Fold 5 C-index: 0.6525821596244131
# [I 2024-04-19 17:26:08,070] Trial 79 finished with value: 0.743776284197207 and parameters: {'l1_ratio': 0.17024111984488197}. Best is trial 11 with value: 0.7538206701909601.
# Fold 1 C-index: 0.7424242424242424
# Fold 2 C-index: 0.7544642857142857
# Fold 3 C-index: 0.8137254901960784
# Fold 4 C-index: 0.8059071729957806
# Fold 5 C-index: 0.6525821596244131
# [I 2024-04-19 17:26:09,485] Trial 80 finished with value: 0.7538206701909601 and parameters: {'l1_ratio': 0.03434323969178929}. Best is trial 11 with value: 0.7538206701909601.
# Fold 1 C-index: 0.7424242424242424
# Fold 2 C-index: 0.7544642857142857
# Fold 3 C-index: 0.8137254901960784
# Fold 4 C-index: 0.8059071729957806
# Fold 5 C-index: 0.6525821596244131
# [I 2024-04-19 17:26:10,830] Trial 81 finished with value: 0.7538206701909601 and parameters: {'l1_ratio': 0.029745851153293923}. Best is trial 11 with value: 0.7538206701909601.
# Fold 1 C-index: 0.6753246753246753
# Fold 2 C-index: 0.7544642857142857
# Fold 3 C-index: 0.8137254901960784
# Fold 4 C-index: 0.8227848101265823
# Fold 5 C-index: 0.6525821596244131
# [I 2024-04-19 17:26:12,714] Trial 82 finished with value: 0.743776284197207 and parameters: {'l1_ratio': 0.0641530844638994}. Best is trial 11 with value: 0.7538206701909601.
# Fold 1 C-index: 0.6753246753246753
# Fold 2 C-index: 0.7544642857142857
# Fold 3 C-index: 0.8137254901960784
# Fold 4 C-index: 0.8227848101265823
# Fold 5 C-index: 0.6525821596244131
# [I 2024-04-19 17:26:14,757] Trial 83 finished with value: 0.743776284197207 and parameters: {'l1_ratio': 0.10431925545782703}. Best is trial 11 with value: 0.7538206701909601.
# Fold 1 C-index: 0.6753246753246753
# Fold 2 C-index: 0.7544642857142857
# Fold 3 C-index: 0.8137254901960784
# Fold 4 C-index: 0.8227848101265823
# Fold 5 C-index: 0.6525821596244131
# [I 2024-04-19 17:26:16,757] Trial 84 finished with value: 0.743776284197207 and parameters: {'l1_ratio': 0.08878082067301499}. Best is trial 11 with value: 0.7538206701909601.
# Fold 1 C-index: 0.7424242424242424
# Fold 2 C-index: 0.6964285714285714
# Fold 3 C-index: 0.8137254901960784
# Fold 4 C-index: 0.8059071729957806
# Fold 5 C-index: 0.6525821596244131
# [I 2024-04-19 17:26:17,804] Trial 85 finished with value: 0.7422135273338173 and parameters: {'l1_ratio': 0.026276429990039592}. Best is trial 11 with value: 0.7538206701909601.
# Fold 1 C-index: 0.6753246753246753
# Fold 2 C-index: 0.7544642857142857
# Fold 3 C-index: 0.8137254901960784
# Fold 4 C-index: 0.8059071729957806
# Fold 5 C-index: 0.6525821596244131
# [I 2024-04-19 17:26:19,446] Trial 86 finished with value: 0.7404007567710467 and parameters: {'l1_ratio': 0.052707802795599557}. Best is trial 11 with value: 0.7538206701909601.
# Fold 1 C-index: 0.6753246753246753
# Fold 2 C-index: 0.7544642857142857
# Fold 3 C-index: 0.8137254901960784
# Fold 4 C-index: 0.8227848101265823
# Fold 5 C-index: 0.6525821596244131
# [I 2024-04-19 17:26:21,107] Trial 87 finished with value: 0.743776284197207 and parameters: {'l1_ratio': 0.12860336043453072}. Best is trial 11 with value: 0.7538206701909601.
# Fold 1 C-index: 0.7424242424242424
# Fold 2 C-index: 0.6964285714285714
# Fold 3 C-index: 0.7794117647058824
# Fold 4 C-index: 0.8059071729957806
# Fold 5 C-index: 0.6525821596244131
# [I 2024-04-19 17:26:21,921] Trial 88 finished with value: 0.735350782235778 and parameters: {'l1_ratio': 0.01769745480525614}. Best is trial 11 with value: 0.7538206701909601.
# Fold 1 C-index: 0.6753246753246753
# Fold 2 C-index: 0.7544642857142857
# Fold 3 C-index: 0.8137254901960784
# Fold 4 C-index: 0.8227848101265823
# Fold 5 C-index: 0.6525821596244131
# [I 2024-04-19 17:26:23,910] Trial 89 finished with value: 0.743776284197207 and parameters: {'l1_ratio': 0.15080387033966203}. Best is trial 11 with value: 0.7538206701909601.
# Fold 1 C-index: 0.6753246753246753
# Fold 2 C-index: 0.7544642857142857
# Fold 3 C-index: 0.8137254901960784
# Fold 4 C-index: 0.8227848101265823
# Fold 5 C-index: 0.6525821596244131
# [I 2024-04-19 17:26:25,857] Trial 90 finished with value: 0.743776284197207 and parameters: {'l1_ratio': 0.19424226552044016}. Best is trial 11 with value: 0.7538206701909601.
# Fold 1 C-index: 0.7424242424242424
# Fold 2 C-index: 0.7544642857142857
# Fold 3 C-index: 0.8137254901960784
# Fold 4 C-index: 0.8059071729957806
# Fold 5 C-index: 0.6525821596244131
# [I 2024-04-19 17:26:27,195] Trial 91 finished with value: 0.7538206701909601 and parameters: {'l1_ratio': 0.04388855859421961}. Best is trial 11 with value: 0.7538206701909601.
# Fold 1 C-index: 0.6753246753246753
# Fold 2 C-index: 0.7544642857142857
# Fold 3 C-index: 0.8137254901960784
# Fold 4 C-index: 0.8227848101265823
# Fold 5 C-index: 0.6525821596244131
# [I 2024-04-19 17:26:29,276] Trial 92 finished with value: 0.743776284197207 and parameters: {'l1_ratio': 0.07740755012639516}. Best is trial 11 with value: 0.7538206701909601.
# Fold 1 C-index: 0.6753246753246753
# Fold 2 C-index: 0.7544642857142857
# Fold 3 C-index: 0.8137254901960784
# Fold 4 C-index: 0.8059071729957806
# Fold 5 C-index: 0.6525821596244131
# [I 2024-04-19 17:26:31,075] Trial 93 finished with value: 0.7404007567710467 and parameters: {'l1_ratio': 0.052158816995152055}. Best is trial 11 with value: 0.7538206701909601.
# Fold 1 C-index: 0.7424242424242424
# Fold 2 C-index: 0.6964285714285714
# Fold 3 C-index: 0.7794117647058824
# Fold 4 C-index: 0.8059071729957806
# Fold 5 C-index: 0.6103286384976526
# [I 2024-04-19 17:26:31,515] Trial 94 finished with value: 0.7269000780104259 and parameters: {'l1_ratio': 0.014682381809551177}. Best is trial 11 with value: 0.7538206701909601.
# Fold 1 C-index: 0.6753246753246753
# Fold 2 C-index: 0.7544642857142857
# Fold 3 C-index: 0.8137254901960784
# Fold 4 C-index: 0.8227848101265823
# Fold 5 C-index: 0.6525821596244131
# [I 2024-04-19 17:26:33,090] Trial 95 finished with value: 0.743776284197207 and parameters: {'l1_ratio': 0.7567861239820235}. Best is trial 11 with value: 0.7538206701909601.
# Fold 1 C-index: 0.6753246753246753
# Fold 2 C-index: 0.7544642857142857
# Fold 3 C-index: 0.8137254901960784
# Fold 4 C-index: 0.8227848101265823
# Fold 5 C-index: 0.6525821596244131
# [I 2024-04-19 17:26:35,068] Trial 96 finished with value: 0.743776284197207 and parameters: {'l1_ratio': 0.09831179007244592}. Best is trial 11 with value: 0.7538206701909601.
# Fold 1 C-index: 0.7424242424242424
# Fold 2 C-index: 0.7544642857142857
# Fold 3 C-index: 0.8137254901960784
# Fold 4 C-index: 0.8059071729957806
# Fold 5 C-index: 0.6525821596244131
# [I 2024-04-19 17:26:36,671] Trial 97 finished with value: 0.7538206701909601 and parameters: {'l1_ratio': 0.04354725622856351}. Best is trial 11 with value: 0.7538206701909601.
# Fold 1 C-index: 0.7424242424242424
# Fold 2 C-index: 0.6964285714285714
# Fold 3 C-index: 0.7794117647058824
# Fold 4 C-index: 0.8059071729957806
# Fold 5 C-index: 0.6103286384976526
# [I 2024-04-19 17:26:37,155] Trial 98 finished with value: 0.7269000780104259 and parameters: {'l1_ratio': 0.0016355878214057117}. Best is trial 11 with value: 0.7538206701909601.
# Fold 1 C-index: 0.6753246753246753
# Fold 2 C-index: 0.7544642857142857
# Fold 3 C-index: 0.8137254901960784
# Fold 4 C-index: 0.8227848101265823
# [I 2024-04-19 17:26:39,128] A new study created in memory with name: no-name-61ade854-f5ac-4f51-b19c-58aa43d70201
# Fold 5 C-index: 0.6525821596244131
# [I 2024-04-19 17:26:39,120] Trial 99 finished with value: 0.743776284197207 and parameters: {'l1_ratio': 0.07276692609324145}. Best is trial 11 with value: 0.7538206701909601.
#
#
# * Best trial for C-index:
#  FrozenTrial(number=11, state=TrialState.COMPLETE, values=[0.7538206701909601], datetime_start=datetime.datetime(2024, 4, 19, 17, 24, 20, 105119), datetime_complete=datetime.datetime(2024, 4, 19, 17, 24, 21, 534338), params={'l1_ratio': 0.046971505265140434}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'l1_ratio': FloatDistribution(high=1.0, log=False, low=0.0001, step=None)}, trial_id=11, value=None)
#
#
# * Best Score for C-index:
#  0.7538206701909601
#   0%|          | 0/100 [00:00<?, ?it/s]
# Fold 1 IBS: 0.1758737134508119
# Fold 2 IBS: 0.20531114233224612
# Fold 3 IBS: 0.16485440776217242
# Fold 4 IBS: 0.14217014378942325
# Fold 5 IBS: 0.24160201681168947
# [I 2024-04-19 17:26:40,832] Trial 0 finished with value: 0.18596228482926863 and parameters: {'l1_ratio': 0.6964995386793018}. Best is trial 0 with value: 0.18596228482926863.
# Fold 1 IBS: 0.17578450165810483
# Fold 2 IBS: 0.20520830908073703
# Fold 3 IBS: 0.16485167711888415
# Fold 4 IBS: 0.1422252463504685
# Fold 5 IBS: 0.2415953182255313
# [I 2024-04-19 17:26:42,690] Trial 1 finished with value: 0.18593301048674515 and parameters: {'l1_ratio': 0.28621072101688444}. Best is trial 1 with value: 0.18593301048674515.
# Fold 1 IBS: 0.17577860605115775
# Fold 2 IBS: 0.20519263048162514
# Fold 3 IBS: 0.16484380678169838
# Fold 4 IBS: 0.1421848562759624
# Fold 5 IBS: 0.24161291043077684
# [I 2024-04-19 17:26:44,725] Trial 2 finished with value: 0.18592256200424412 and parameters: {'l1_ratio': 0.22692876841884668}. Best is trial 2 with value: 0.18592256200424412.
# Fold 1 IBS: 0.17584543130965488
# Fold 2 IBS: 0.20527219802308697
# Fold 3 IBS: 0.16485448287585483
# Fold 4 IBS: 0.14215552137380263
# Fold 5 IBS: 0.24165090262371625
# [I 2024-04-19 17:26:46,430] Trial 3 finished with value: 0.1859557072412231 and parameters: {'l1_ratio': 0.5513596376059829}. Best is trial 2 with value: 0.18592256200424412.
# Fold 1 IBS: 0.1758745350760852
# Fold 2 IBS: 0.20533068696640483
# Fold 3 IBS: 0.16486938800501
# Fold 4 IBS: 0.1422362486034388
# Fold 5 IBS: 0.24165049302094432
# [I 2024-04-19 17:26:48,428] Trial 4 finished with value: 0.18599227033437662 and parameters: {'l1_ratio': 0.7194970228885845}. Best is trial 2 with value: 0.18592256200424412.
# Fold 1 IBS: 0.17580916257172435
# Fold 2 IBS: 0.20524442878764412
# Fold 3 IBS: 0.1648610470686924
# Fold 4 IBS: 0.14217064366038437
# Fold 5 IBS: 0.2416057773981788
# [I 2024-04-19 17:26:50,337] Trial 5 finished with value: 0.1859382118973248 and parameters: {'l1_ratio': 0.4231641494784485}. Best is trial 2 with value: 0.18592256200424412.
# Fold 1 IBS: 0.17596788969346808
# Fold 2 IBS: 0.20540843863214686
# Fold 3 IBS: 0.16486180056895988
# Fold 4 IBS: 0.1421256693603648
# Fold 5 IBS: 0.24168514375279207
# [I 2024-04-19 17:26:51,956] Trial 6 finished with value: 0.1860097884015463 and parameters: {'l1_ratio': 0.980766121964777}. Best is trial 2 with value: 0.18592256200424412.
# Fold 1 IBS: 0.17586745856984287
# Fold 2 IBS: 0.20531258683445258
# Fold 3 IBS: 0.16486009998133389
# Fold 4 IBS: 0.1421929967447851
# Fold 5 IBS: 0.24168279611743335
# [I 2024-04-19 17:26:53,622] Trial 7 finished with value: 0.1859831876495696 and parameters: {'l1_ratio': 0.6848612556110047}. Best is trial 2 with value: 0.18592256200424412.
# Fold 1 IBS: 0.17583239530341427
# Fold 2 IBS: 0.2052499189676977
# Fold 3 IBS: 0.1648470026799829
# Fold 4 IBS: 0.14222380235135187
# Fold 5 IBS: 0.24165957388854797
# [I 2024-04-19 17:26:55,427] Trial 8 finished with value: 0.18596253863819895 and parameters: {'l1_ratio': 0.4809838082942125}. Best is trial 2 with value: 0.18592256200424412.
# Fold 1 IBS: 0.17580319877942405
# Fold 2 IBS: 0.20523579000513714
# Fold 3 IBS: 0.1648588647593587
# Fold 4 IBS: 0.14215889851595656
# Fold 5 IBS: 0.24160612040320117
# [I 2024-04-19 17:26:57,016] Trial 9 finished with value: 0.18593257449261552 and parameters: {'l1_ratio': 0.3921783064423311}. Best is trial 2 with value: 0.18592256200424412.
# Fold 1 IBS: 0.17576992739190797
# Fold 2 IBS: 0.205165753603796
# Fold 3 IBS: 0.1648467750606292
# Fold 4 IBS: 0.14218585034776823
# Fold 5 IBS: 0.24157276067125374
# [I 2024-04-19 17:26:59,368] Trial 10 finished with value: 0.18590821341507102 and parameters: {'l1_ratio': 0.08382735104105443}. Best is trial 10 with value: 0.18590821341507102.
# Fold 1 IBS: 0.21346964983530048
# Fold 2 IBS: 0.22121270918193192
# Fold 3 IBS: 0.20392115963695906
# Fold 4 IBS: 0.22389588069403651
# Fold 5 IBS: 0.21801814763966146
# [I 2024-04-19 17:27:00,006] Trial 11 finished with value: 0.2161035093975779 and parameters: {'l1_ratio': 0.012263077917218868}. Best is trial 10 with value: 0.18590821341507102.
# Fold 1 IBS: 0.17576967020276138
# Fold 2 IBS: 0.20516581455378627
# Fold 3 IBS: 0.16484704736668754
# Fold 4 IBS: 0.14218703424021192
# Fold 5 IBS: 0.24157166538421682
# [I 2024-04-19 17:27:02,312] Trial 12 finished with value: 0.1859082463495328 and parameters: {'l1_ratio': 0.0837403091112675}. Best is trial 10 with value: 0.18590821341507102.
# Fold 1 IBS: 0.213843246294805
# Fold 2 IBS: 0.22148174610444765
# Fold 3 IBS: 0.20437422244595427
# Fold 4 IBS: 0.2245166687910639
# Fold 5 IBS: 0.21809610440370716
# [I 2024-04-19 17:27:02,944] Trial 13 finished with value: 0.21646239760799563 and parameters: {'l1_ratio': 0.0031985064812224406}. Best is trial 10 with value: 0.18590821341507102.
# Fold 1 IBS: 0.1757795578789129
# Fold 2 IBS: 0.20517754035938443
# Fold 3 IBS: 0.1648478535312954
# Fold 4 IBS: 0.1421955368300091
# Fold 5 IBS: 0.24158010606359445
# [I 2024-04-19 17:27:05,155] Trial 14 finished with value: 0.18591611893263926 and parameters: {'l1_ratio': 0.14354731809284052}. Best is trial 10 with value: 0.18590821341507102.
# Fold 1 IBS: 0.1757828842490752
# Fold 2 IBS: 0.20517674326657478
# Fold 3 IBS: 0.16484430364723218
# Fold 4 IBS: 0.1421800786740375
# Fold 5 IBS: 0.24159444614340334
# [I 2024-04-19 17:27:07,163] Trial 15 finished with value: 0.1859156911960646 and parameters: {'l1_ratio': 0.14547377630010583}. Best is trial 10 with value: 0.18590821341507102.
# Fold 1 IBS: 0.17578366543315432
# Fold 2 IBS: 0.20517364133865157
# Fold 3 IBS: 0.1648656367647671
# Fold 4 IBS: 0.14227247016234162
# Fold 5 IBS: 0.24160603860094457
# [I 2024-04-19 17:27:09,392] Trial 16 finished with value: 0.18594029045997182 and parameters: {'l1_ratio': 0.13463318817607284}. Best is trial 10 with value: 0.18590821341507102.
# Fold 1 IBS: 0.1757889740993729
# Fold 2 IBS: 0.2052073079175886
# Fold 3 IBS: 0.16484736535488245
# Fold 4 IBS: 0.14220645777489638
# Fold 5 IBS: 0.2416128276682723
# [I 2024-04-19 17:27:11,218] Trial 17 finished with value: 0.18593258656300254 and parameters: {'l1_ratio': 0.2906031874230555}. Best is trial 10 with value: 0.18590821341507102.
# Fold 1 IBS: 0.17577789487046505
# Fold 2 IBS: 0.2051657981620295
# Fold 3 IBS: 0.1648584018992901
# Fold 4 IBS: 0.14223508270031232
# Fold 5 IBS: 0.24161921824504637
# [I 2024-04-19 17:27:13,504] Trial 18 finished with value: 0.18593127917542868 and parameters: {'l1_ratio': 0.0668769468789637}. Best is trial 10 with value: 0.18590821341507102.
# Fold 1 IBS: 0.17597144474772805
# Fold 2 IBS: 0.20544016096610093
# Fold 3 IBS: 0.16485704795947267
# Fold 4 IBS: 0.1421081251006314
# Fold 5 IBS: 0.24170723821567291
# [I 2024-04-19 17:27:14,967] Trial 19 finished with value: 0.1860168033979212 and parameters: {'l1_ratio': 0.9929341434741732}. Best is trial 10 with value: 0.18590821341507102.
# Fold 1 IBS: 0.17579261509497615
# Fold 2 IBS: 0.20519912523840728
# Fold 3 IBS: 0.16485379063363936
# Fold 4 IBS: 0.14223017038674496
# Fold 5 IBS: 0.24157680369528195
# [I 2024-04-19 17:27:16,980] Trial 20 finished with value: 0.18593050100980993 and parameters: {'l1_ratio': 0.2388803760219412}. Best is trial 10 with value: 0.18590821341507102.
# Fold 1 IBS: 0.17577041477712232
# Fold 2 IBS: 0.2051717078929622
# Fold 3 IBS: 0.16485111952585133
# Fold 4 IBS: 0.14220687061595558
# Fold 5 IBS: 0.24156034432325432
# [I 2024-04-19 17:27:19,220] Trial 21 finished with value: 0.18591209142702916 and parameters: {'l1_ratio': 0.10825799833043775}. Best is trial 10 with value: 0.18590821341507102.
# Fold 1 IBS: 0.17577547181641603
# Fold 2 IBS: 0.2051682877514742
# Fold 3 IBS: 0.16484397955314903
# Fold 4 IBS: 0.14217504462027483
# Fold 5 IBS: 0.24158722167918747
# [I 2024-04-19 17:27:21,394] Trial 22 finished with value: 0.18591000108410033 and parameters: {'l1_ratio': 0.10159828709381563}. Best is trial 10 with value: 0.18590821341507102.
# Fold 1 IBS: 0.1757912921143369
# Fold 2 IBS: 0.20518959280073923
# Fold 3 IBS: 0.16484728732694084
# Fold 4 IBS: 0.14219837135097615
# Fold 5 IBS: 0.24159484022533992
# [I 2024-04-19 17:27:23,402] Trial 23 finished with value: 0.1859242767636666 and parameters: {'l1_ratio': 0.20521786879010379}. Best is trial 10 with value: 0.18590821341507102.
# Fold 1 IBS: 0.17579578944898866
# Fold 2 IBS: 0.20522010452708248
# Fold 3 IBS: 0.16485220766143352
# Fold 4 IBS: 0.14223271591462916
# Fold 5 IBS: 0.24160530603869482
# [I 2024-04-19 17:27:25,276] Trial 24 finished with value: 0.1859412247181657 and parameters: {'l1_ratio': 0.3389201479305571}. Best is trial 10 with value: 0.18590821341507102.
# Fold 1 IBS: 0.21236908797861867
# Fold 2 IBS: 0.20515834723353793
# Fold 3 IBS: 0.16484986049334427
# Fold 4 IBS: 0.22206582514781645
# Fold 5 IBS: 0.24155227932132817
# [I 2024-04-19 17:27:26,771] Trial 25 finished with value: 0.2091990800349291 and parameters: {'l1_ratio': 0.03981317955666948}. Best is trial 10 with value: 0.18590821341507102.
# Fold 1 IBS: 0.17578803044608182
# Fold 2 IBS: 0.20518612381175227
# Fold 3 IBS: 0.16484735229622535
# Fold 4 IBS: 0.14219713628363068
# Fold 5 IBS: 0.24159100409482068
# [I 2024-04-19 17:27:28,907] Trial 26 finished with value: 0.18592192938650218 and parameters: {'l1_ratio': 0.18783928730207888}. Best is trial 10 with value: 0.18590821341507102.
# Fold 1 IBS: 0.17576379176349735
# Fold 2 IBS: 0.20516554518759395
# Fold 3 IBS: 0.1648519158413674
# Fold 4 IBS: 0.14220757298349923
# Fold 5 IBS: 0.24155078595245708
# [I 2024-04-19 17:27:30,845] Trial 27 finished with value: 0.18590792234568299 and parameters: {'l1_ratio': 0.07505393448412474}. Best is trial 27 with value: 0.18590792234568299.
# Fold 1 IBS: 0.1758540411721588
# Fold 2 IBS: 0.20530112394396943
# Fold 3 IBS: 0.16484510051641676
# Fold 4 IBS: 0.1422299652455861
# Fold 5 IBS: 0.24161210265874572
# [I 2024-04-19 17:27:32,301] Trial 28 finished with value: 0.18596846670737538 and parameters: {'l1_ratio': 0.6145983886185702}. Best is trial 27 with value: 0.18590792234568299.
# Fold 1 IBS: 0.1759308221350225
# Fold 2 IBS: 0.20538929407209774
# Fold 3 IBS: 0.16484877543230558
# Fold 4 IBS: 0.14216756245314843
# Fold 5 IBS: 0.24169048541833033
# [I 2024-04-19 17:27:33,780] Trial 29 finished with value: 0.18600538790218094 and parameters: {'l1_ratio': 0.8830970003537575}. Best is trial 27 with value: 0.18590792234568299.
# Fold 1 IBS: 0.17579925131572252
# Fold 2 IBS: 0.20522392085506427
# Fold 3 IBS: 0.1648428521611671
# Fold 4 IBS: 0.14218917125216698
# Fold 5 IBS: 0.24163708046111507
# [I 2024-04-19 17:27:35,385] Trial 30 finished with value: 0.1859384552090472 and parameters: {'l1_ratio': 0.32170963481394405}. Best is trial 27 with value: 0.18590792234568299.
# Fold 1 IBS: 0.17577269997208855
# Fold 2 IBS: 0.20516693094591038
# Fold 3 IBS: 0.16484530741411285
# Fold 4 IBS: 0.14218011488263746
# Fold 5 IBS: 0.24158019073158324
# [I 2024-04-19 17:27:37,272] Trial 31 finished with value: 0.1859090487892665 and parameters: {'l1_ratio': 0.09232011433900482}. Best is trial 27 with value: 0.18590792234568299.
# Fold 1 IBS: 0.1757725356554237
# Fold 2 IBS: 0.20516195859729397
# Fold 3 IBS: 0.16486592935228764
# Fold 4 IBS: 0.1422680483717986
# Fold 5 IBS: 0.24159271362682824
# [I 2024-04-19 17:27:39,176] Trial 32 finished with value: 0.18593223712072643 and parameters: {'l1_ratio': 0.0713123037303855}. Best is trial 27 with value: 0.18590792234568299.
# Fold 1 IBS: 0.1757864224153609
# Fold 2 IBS: 0.2051865163985429
# Fold 3 IBS: 0.16484907452938696
# Fold 4 IBS: 0.14220463198249225
# Fold 5 IBS: 0.24158404496417507
# [I 2024-04-19 17:27:40,986] Trial 33 finished with value: 0.1859221380579916 and parameters: {'l1_ratio': 0.18665523735409972}. Best is trial 27 with value: 0.18590792234568299.
# Fold 1 IBS: 0.17578414309765963
# Fold 2 IBS: 0.2052012988891577
# Fold 3 IBS: 0.1648628497612886
# Fold 4 IBS: 0.14226939526224014
# Fold 5 IBS: 0.24163574746333066
# [I 2024-04-19 17:27:42,803] Trial 34 finished with value: 0.18595068689473532 and parameters: {'l1_ratio': 0.23148463885526435}. Best is trial 27 with value: 0.18590792234568299.
# Fold 1 IBS: 0.21392008128092224
# Fold 2 IBS: 0.22153716710899574
# Fold 3 IBS: 0.204467439922913
# Fold 4 IBS: 0.22464428727234262
# Fold 5 IBS: 0.21811233671120012
# ...
# Fold 1 IBS: 0.17577775494057984
# Fold 2 IBS: 0.2051673796537947
# Fold 3 IBS: 0.16485980217207027
# Fold 4 IBS: 0.14224166909775587
# Fold 5 IBS: 0.24161523865406434
# [I 2024-04-19 17:28:17,536] Trial 54 finished with value: 0.185932368903653 and parameters: {'l1_ratio': 0.07290025578394965}. Best is trial 42 with value: 0.1859052303821749.
# Fold 1 IBS: 0.1757881387885894
# Fold 2 IBS: 0.20519507533903875
# Fold 3 IBS: 0.16485444191344337
# Fold 4 IBS: 0.14223114964277297
# Fold 5 IBS: 0.24156988227719678
# [I 2024-04-19 17:28:19,204] Trial 55 finished with value: 0.18592773759220824 and parameters: {'l1_ratio': 0.21836609368258242}. Best is trial 42 with value: 0.1859052303821749.
# Fold 1 IBS: 0.17578194177084874
# Fold 2 IBS: 0.20520266622959296
# Fold 3 IBS: 0.16484919354742877
# Fold 4 IBS: 0.1422122045333747
# Fold 5 IBS: 0.24160014209767613
# [I 2024-04-19 17:28:20,783] Trial 56 finished with value: 0.18592922963578426 and parameters: {'l1_ratio': 0.2648546369631394}. Best is trial 42 with value: 0.1859052303821749.
# Fold 1 IBS: 0.21274225483936055
# Fold 2 IBS: 0.20515630996909565
# Fold 3 IBS: 0.16484873802178918
# Fold 4 IBS: 0.22268662400217332
# Fold 5 IBS: 0.24155498947765563
# [I 2024-04-19 17:28:22,283] Trial 57 finished with value: 0.20939778326201486 and parameters: {'l1_ratio': 0.03032405488700684}. Best is trial 42 with value: 0.1859052303821749.
# Fold 1 IBS: 0.1757762383565158
# Fold 2 IBS: 0.2051815795398994
# Fold 3 IBS: 0.16485396867902177
# Fold 4 IBS: 0.1422232360524182
# Fold 5 IBS: 0.24155818935097947
# [I 2024-04-19 17:28:23,875] Trial 58 finished with value: 0.18591864239576691 and parameters: {'l1_ratio': 0.15348496991160415}. Best is trial 42 with value: 0.1859052303821749.
# Fold 1 IBS: 0.1757657107399424
# Fold 2 IBS: 0.20517062926133225
# Fold 3 IBS: 0.1648543146669618
# Fold 4 IBS: 0.14221992959062918
# Fold 5 IBS: 0.2415457094399045
# [I 2024-04-19 17:28:25,435] Trial 59 finished with value: 0.185911258739754 and parameters: {'l1_ratio': 0.09772365703783965}. Best is trial 42 with value: 0.1859052303821749.
# Fold 1 IBS: 0.17575862661400213
# Fold 2 IBS: 0.20516259888851862
# Fold 3 IBS: 0.1648540077416272
# Fold 4 IBS: 0.14221514767019827
# Fold 5 IBS: 0.24153898818813704
# [I 2024-04-19 17:28:27,368] Trial 60 finished with value: 0.18590587382049664 and parameters: {'l1_ratio': 0.056601035957100816}. Best is trial 42 with value: 0.1859052303821749.
# Fold 1 IBS: 0.17576478058551542
# Fold 2 IBS: 0.20515997817733042
# Fold 3 IBS: 0.16484661195789602
# Fold 4 IBS: 0.22121227257631795
# Fold 5 IBS: 0.24156764039259024
# [I 2024-04-19 17:28:29,305] Trial 61 finished with value: 0.20171025673793 and parameters: {'l1_ratio': 0.053112242537948634}. Best is trial 42 with value: 0.1859052303821749.
# Fold 1 IBS: 0.17577653751926717
# Fold 2 IBS: 0.20517533678189576
# Fold 3 IBS: 0.16484871493974002
# Fold 4 IBS: 0.14219824132789768
# Fold 5 IBS: 0.2415742011348089
# [I 2024-04-19 17:28:30,985] Trial 62 finished with value: 0.18591460634072193 and parameters: {'l1_ratio': 0.13081097781900883}. Best is trial 42 with value: 0.1859052303821749.
# Fold 1 IBS: 0.21397164678042058
# Fold 2 IBS: 0.22157439600633255
# Fold 3 IBS: 0.20453002877172016
# Fold 4 IBS: 0.22472994288775602
# Fold 5 IBS: 0.21812327876014045
# [I 2024-04-19 17:28:31,500] Trial 63 finished with value: 0.21658585864127394 and parameters: {'l1_ratio': 0.00011673611749878077}. Best is trial 42 with value: 0.1859052303821749.
# Fold 1 IBS: 0.17577441390841012
# Fold 2 IBS: 0.2051665278737689
# Fold 3 IBS: 0.16484348705426982
# Fold 4 IBS: 0.14217218716768848
# Fold 5 IBS: 0.24158753567411587
# [I 2024-04-19 17:28:33,371] Trial 64 finished with value: 0.18590883033565062 and parameters: {'l1_ratio': 0.09296842057180908}. Best is trial 42 with value: 0.1859052303821749.
# Fold 1 IBS: 0.1757789886286182
# Fold 2 IBS: 0.20518445303432217
# Fold 3 IBS: 0.16485388442719195
# Fold 4 IBS: 0.14222413464474906
# Fold 5 IBS: 0.2415614542708827
# [I 2024-04-19 17:28:35,089] Trial 65 finished with value: 0.18592058300115283 and parameters: {'l1_ratio': 0.16784602779682933}. Best is trial 42 with value: 0.1859052303821749.
# Fold 1 IBS: 0.17577683535216948
# Fold 2 IBS: 0.20516609203234115
# Fold 3 IBS: 0.1648596486091498
# Fold 4 IBS: 0.14224046189533948
# Fold 5 IBS: 0.24161461910949836
# [I 2024-04-19 17:28:37,053] Trial 66 finished with value: 0.18593153139969965 and parameters: {'l1_ratio': 0.06657296809426158}. Best is trial 42 with value: 0.1859052303821749.
# Fold 1 IBS: 0.17578791029613386
# Fold 2 IBS: 0.20519042476389293
# Fold 3 IBS: 0.16485091462405665
# Fold 4 IBS: 0.14221415494213305
# Fold 5 IBS: 0.24158018015166174
# [I 2024-04-19 17:28:38,972] Trial 67 finished with value: 0.18592471695557564 and parameters: {'l1_ratio': 0.20252704968854432}. Best is trial 42 with value: 0.1859052303821749.
# Fold 1 IBS: 0.2127635228550672
# Fold 2 IBS: 0.20515737016031
# Fold 3 IBS: 0.16485341457536448
# Fold 4 IBS: 0.22272199558442118
# Fold 5 IBS: 0.2415363158835761
# [I 2024-04-19 17:28:40,432] Trial 68 finished with value: 0.2094065238117478 and parameters: {'l1_ratio': 0.02978791572148142}. Best is trial 42 with value: 0.1859052303821749.
# Fold 1 IBS: 0.17577860984716687
# Fold 2 IBS: 0.20517217560362616
# Fold 3 IBS: 0.16484436638505479
# Fold 4 IBS: 0.14217837103514888
# Fold 5 IBS: 0.24158952228996994
# [I 2024-04-19 17:28:42,216] Trial 69 finished with value: 0.18591260903219334 and parameters: {'l1_ratio': 0.12153311282241723}. Best is trial 42 with value: 0.1859052303821749.
# Fold 1 IBS: 0.17577519815069048
# Fold 2 IBS: 0.20516451834204436
# Fold 3 IBS: 0.16486565176293622
# Fold 4 IBS: 0.1422681173133542
# Fold 5 IBS: 0.2415964500552872
# [I 2024-04-19 17:28:43,958] Trial 70 finished with value: 0.18593398712486248 and parameters: {'l1_ratio': 0.08565774630578807}. Best is trial 42 with value: 0.1859052303821749.
# Fold 1 IBS: 0.1757635626578913
# Fold 2 IBS: 0.20516268199274043
# Fold 3 IBS: 0.16484982857810546
# Fold 4 IBS: 0.14219748949889646
# Fold 5 IBS: 0.24155674865139748
# [I 2024-04-19 17:28:45,765] Trial 71 finished with value: 0.18590606227580625 and parameters: {'l1_ratio': 0.06301381496313624}. Best is trial 42 with value: 0.1859052303821749.
# Fold 1 IBS: 0.21236971306286181
# Fold 2 IBS: 0.20515837102587467
# Fold 3 IBS: 0.16484996587246997
# Fold 4 IBS: 0.22206686532514255
# Fold 5 IBS: 0.2415518578072304
# [I 2024-04-19 17:28:47,115] Trial 72 finished with value: 0.20919935461871586 and parameters: {'l1_ratio': 0.0397971528571628}. Best is trial 42 with value: 0.1859052303821749.
# Fold 1 IBS: 0.17578380882317252
# Fold 2 IBS: 0.2051765236241702
# Fold 3 IBS: 0.164843314992139
# Fold 4 IBS: 0.14217576743255989
# Fold 5 IBS: 0.24159844967668367
# [I 2024-04-19 17:28:48,713] Trial 73 finished with value: 0.18591557290974506 and parameters: {'l1_ratio': 0.14601977946850792}. Best is trial 42 with value: 0.1859052303821749.
# Fold 1 IBS: 0.17575755392624193
# Fold 2 IBS: 0.2051655281221142
# Fold 3 IBS: 0.16485725046842892
# Fold 4 IBS: 0.14223011102481198
# Fold 5 IBS: 0.24154192255046125
# [I 2024-04-19 17:28:50,658] Trial 74 finished with value: 0.18591047321841164 and parameters: {'l1_ratio': 0.0671602290627743}. Best is trial 42 with value: 0.1859052303821749.
# Fold 1 IBS: 0.21291493575860848
# Fold 2 IBS: 0.22081517939226117
# Fold 3 IBS: 0.16486538289744085
# Fold 4 IBS: 0.2229737877867912
# Fold 5 IBS: 0.24158623742591784
# [I 2024-04-19 17:28:51,905] Trial 75 finished with value: 0.21263110465220394 and parameters: {'l1_ratio': 0.0259852949888425}. Best is trial 42 with value: 0.1859052303821749.
# Fold 1 IBS: 0.17576695809269388
# Fold 2 IBS: 0.20517255045000024
# Fold 3 IBS: 0.1648547714571889
# Fold 4 IBS: 0.14222269643044372
# Fold 5 IBS: 0.24154570294150648
# [I 2024-04-19 17:28:53,707] Trial 76 finished with value: 0.18591253587436662 and parameters: {'l1_ratio': 0.10680685509565718}. Best is trial 42 with value: 0.1859052303821749.
# Fold 1 IBS: 0.1757983555850335
# Fold 2 IBS: 0.2051976908670853
# Fold 3 IBS: 0.1648476111113026
# Fold 4 IBS: 0.14220328762559545
# Fold 5 IBS: 0.24160179462548176
# [I 2024-04-19 17:28:55,305] Trial 77 finished with value: 0.1859297479628997 and parameters: {'l1_ratio': 0.2442101236664688}. Best is trial 42 with value: 0.1859052303821749.
# Fold 1 IBS: 0.17576987418156884
# Fold 2 IBS: 0.2051657662087516
# Fold 3 IBS: 0.1648468314038354
# Fold 4 IBS: 0.1421860953248321
# Fold 5 IBS: 0.2415725340178483
# [I 2024-04-19 17:28:57,084] Trial 78 finished with value: 0.18590822022736725 and parameters: {'l1_ratio': 0.08380932587587814}. Best is trial 42 with value: 0.1859052303821749.
# Fold 1 IBS: 0.17588170372582482
# Fold 2 IBS: 0.2053316968031449
# Fold 3 IBS: 0.16484708377986418
# Fold 4 IBS: 0.14214062062622895
# Fold 5 IBS: 0.2416351703692903
# [I 2024-04-19 17:28:58,585] Trial 79 finished with value: 0.18596725506087064 and parameters: {'l1_ratio': 0.7120921418578845}. Best is trial 42 with value: 0.1859052303821749.
# Fold 1 IBS: 0.17577625181922485
# Fold 2 IBS: 0.20518513480977676
# Fold 3 IBS: 0.164856791654672
# Fold 4 IBS: 0.14223672862552075
# Fold 5 IBS: 0.24156330601591072
# [I 2024-04-19 17:29:00,631] Trial 80 finished with value: 0.185923642585021 and parameters: {'l1_ratio': 0.1661026639117391}. Best is trial 42 with value: 0.1859052303821749.
# Fold 1 IBS: 0.17575850605589174
# Fold 2 IBS: 0.2051685176384082
# Fold 3 IBS: 0.16485880585284088
# Fold 4 IBS: 0.1422379684391723
# Fold 5 IBS: 0.24162021808546624
# [I 2024-04-19 17:29:02,469] Trial 81 finished with value: 0.18592880321435587 and parameters: {'l1_ratio': 0.08015050568342319}. Best is trial 42 with value: 0.1859052303821749.
# Fold 1 IBS: 0.1757766970386325
# Fold 2 IBS: 0.20516344633738917
# Fold 3 IBS: 0.16485766128483362
# Fold 4 IBS: 0.22103964427645106
# Fold 5 IBS: 0.24153816010245885
# [I 2024-04-19 17:29:04,178] Trial 82 finished with value: 0.20167512180795302 and parameters: {'l1_ratio': 0.05583850435106322}. Best is trial 42 with value: 0.1859052303821749.
# Fold 1 IBS: 0.17577539915132426
# Fold 2 IBS: 0.20517294064068917
# Fold 3 IBS: 0.16484778304864284
# Fold 4 IBS: 0.14219324275721493
# Fold 5 IBS: 0.24157573903471477
# [I 2024-04-19 17:29:06,223] Trial 83 finished with value: 0.18591302092651718 and parameters: {'l1_ratio': 0.11997198568143072}. Best is trial 42 with value: 0.1859052303821749.
# Fold 1 IBS: 0.21299063058205675
# Fold 2 IBS: 0.22086928822058619
# Fold 3 IBS: 0.20334119142048737
# Fold 4 IBS: 0.22309964696021164
# Fold 5 IBS: 0.24160276939253894
# [I 2024-04-19 17:29:07,181] Trial 84 finished with value: 0.2203807053151762 and parameters: {'l1_ratio': 0.024093600159763584}. Best is trial 42 with value: 0.1859052303821749.
# Fold 1 IBS: 0.17576528357441684
# Fold 2 IBS: 0.2051707337279022
# Fold 3 IBS: 0.16485476482555445
# Fold 4 IBS: 0.14222187816047624
# Fold 5 IBS: 0.2415439117261297
# [I 2024-04-19 17:29:08,991] Trial 85 finished with value: 0.18591131440289593 and parameters: {'l1_ratio': 0.09756175651867886}. Best is trial 42 with value: 0.1859052303821749.
# Fold 1 IBS: 0.17577895809513117
# Fold 2 IBS: 0.20519267803334085
# Fold 3 IBS: 0.16486046104817803
# Fold 4 IBS: 0.14225552613258458
# Fold 5 IBS: 0.2415554366913909
# [I 2024-04-19 17:29:10,583] Trial 86 finished with value: 0.1859286120001251 and parameters: {'l1_ratio': 0.19577924550572226}. Best is trial 42 with value: 0.1859052303821749.
# Fold 1 IBS: 0.17577924847415424
# Fold 2 IBS: 0.20517761504263657
# Fold 3 IBS: 0.16484818316842853
# Fold 4 IBS: 0.14219697052387115
# Fold 5 IBS: 0.2415787772364429
# [I 2024-04-19 17:29:12,225] Trial 87 finished with value: 0.18591615888910668 and parameters: {'l1_ratio': 0.1433710803066638}. Best is trial 42 with value: 0.1859052303821749.
# Fold 1 IBS: 0.21204922140551244
# Fold 2 IBS: 0.20515957543678237
# Fold 3 IBS: 0.1648486587051876
# Fold 4 IBS: 0.2215334061888699
# Fold 5 IBS: 0.24155858900275054
# [I 2024-04-19 17:29:13,928] Trial 88 finished with value: 0.20902989014782056 and parameters: {'l1_ratio': 0.04807373177782703}. Best is trial 42 with value: 0.1859052303821749.
# Fold 1 IBS: 0.21334960456474933
# Fold 2 IBS: 0.22112648534924506
# Fold 3 IBS: 0.2037757226658084
# Fold 4 IBS: 0.22369637542795992
# Fold 5 IBS: 0.21799348275348807
# [I 2024-04-19 17:29:14,500] Trial 89 finished with value: 0.21598833415225016 and parameters: {'l1_ratio': 0.015205401015787379}. Best is trial 42 with value: 0.1859052303821749.
# Fold 1 IBS: 0.17577490437195162
# Fold 2 IBS: 0.20516458648502975
# Fold 3 IBS: 0.16486599642535968
# Fold 4 IBS: 0.14226959893789845
# Fold 5 IBS: 0.24159518565401553
# [I 2024-04-19 17:29:16,221] Trial 90 finished with value: 0.185934054374851 and parameters: {'l1_ratio': 0.08555333533062398}. Best is trial 42 with value: 0.1859052303821749.
# Fold 1 IBS: 0.1757583970438132
# Fold 2 IBS: 0.20516265440112036
# Fold 3 IBS: 0.16485424856363182
# Fold 4 IBS: 0.14221618962183
# Fold 5 IBS: 0.24153802825148685
# [I 2024-04-19 17:29:18,115] Trial 91 finished with value: 0.18590590357637646 and parameters: {'l1_ratio': 0.05655011826462692}. Best is trial 42 with value: 0.1859052303821749.
# Fold 1 IBS: 0.17575863637629285
# Fold 2 IBS: 0.2051625965289243
# Fold 3 IBS: 0.1648539974997415
# Fold 4 IBS: 0.14221510335381143
# Fold 5 IBS: 0.24153902901853785
# [I 2024-04-19 17:29:19,987] Trial 92 finished with value: 0.1859058725554616 and parameters: {'l1_ratio': 0.056603203509205585}. Best is trial 42 with value: 0.1859052303821749.
# Fold 1 IBS: 0.17586332513968447
# Fold 2 IBS: 0.20529573153056196
# Fold 3 IBS: 0.16484960474094193
# Fold 4 IBS: 0.14214534043565036
# Fold 5 IBS: 0.2416069313213764
# [I 2024-04-19 17:29:21,385] Trial 93 finished with value: 0.18595218663364302 and parameters: {'l1_ratio': 0.6547273520711029}. Best is trial 42 with value: 0.1859052303821749.
# Fold 1 IBS: 0.17577005157500358
# Fold 2 IBS: 0.20515875233682693
# Fold 3 IBS: 0.16486545484212206
# Fold 4 IBS: 0.22113822457413265
# Fold 5 IBS: 0.2415912232132629
# [I 2024-04-19 17:29:23,056] Trial 94 finished with value: 0.20170474130826962 and parameters: {'l1_ratio': 0.05428012596125901}. Best is trial 42 with value: 0.1859052303821749.
# Fold 1 IBS: 0.17595722390225432
# Fold 2 IBS: 0.2054109620824258
# Fold 3 IBS: 0.1648709578388852
# Fold 4 IBS: 0.14215933129817468
# Fold 5 IBS: 0.24172987282031308
# [I 2024-04-19 17:29:24,450] Trial 95 finished with value: 0.18602566958841063 and parameters: {'l1_ratio': 0.9581798098798909}. Best is trial 42 with value: 0.1859052303821749.
# Fold 1 IBS: 0.17589250291904102
# Fold 2 IBS: 0.2053264044698532
# Fold 3 IBS: 0.16485292129336632
# Fold 4 IBS: 0.1421702162339903
# Fold 5 IBS: 0.24162734210706324
# [I 2024-04-19 17:29:25,753] Trial 96 finished with value: 0.1859738774046628 and parameters: {'l1_ratio': 0.754234381640172}. Best is trial 42 with value: 0.1859052303821749.
# Fold 1 IBS: 0.17577676475940282
# Fold 2 IBS: 0.20517261404060141
# Fold 3 IBS: 0.16484633107959523
# Fold 4 IBS: 0.1421869266171584
# Fold 5 IBS: 0.2415815902915071
# [I 2024-04-19 17:29:27,592] Trial 97 finished with value: 0.18591284535765298 and parameters: {'l1_ratio': 0.12063036321094205}. Best is trial 42 with value: 0.1859052303821749.
# Fold 1 IBS: 0.2138869839857808
# Fold 2 IBS: 0.2215132864441773
# Fold 3 IBS: 0.204427279454442
# Fold 4 IBS: 0.22458931277025793
# Fold 5 IBS: 0.21810533395232984
# [I 2024-04-19 17:29:28,243] Trial 98 finished with value: 0.2165044393213976 and parameters: {'l1_ratio': 0.002147182167590196}. Best is trial 42 with value: 0.1859052303821749.
# Fold 1 IBS: 0.17577238938597767
# Fold 2 IBS: 0.20516061371038552
# Fold 3 IBS: 0.16486486657485327
# Fold 4 IBS: 0.14226293245479832
# Fold 5 IBS: 0.24159543134468645
# [I 2024-04-19 17:29:30,278] Trial 99 finished with value: 0.18593124669414024 and parameters: {'l1_ratio': 0.06533078986577541}. Best is trial 42 with value: 0.1859052303821749.
#
#
# * Best trial for IBS:
#  FrozenTrial(number=42, state=TrialState.COMPLETE, values=[0.1859052303821749], datetime_start=datetime.datetime(2024, 4, 19, 17, 27, 54, 697729), datetime_complete=datetime.datetime(2024, 4, 19, 17, 27, 56, 731779), params={'l1_ratio': 0.05774346219526162}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'l1_ratio': FloatDistribution(high=1.0, log=False, low=0.0001, step=None)}, trial_id=42, value=None)
#
#
# * Best Score for IBS:
#  0.1859052303821749

# %%
train_cindex['CoxElastic'] = np.round(study_cindex.best_value, 3)
train_ibs['CoxElastic'] = np.round(study_ibs.best_value, 3)

# %%
print("train_cindex: ", np.round(study_cindex.best_value, 3))
print("train_ibs: ", np.round(study_ibs.best_value, 3))
# Out:
# train_cindex:  0.754
# train_ibs:  0.186

# %% [markdown]
# #### Test

# %%
# y into array 
lists = [] 
for i, j in zip(y['event_OS'], y['OS']): 
    lists.append((i, j))

y = np.array(lists, dtype=[('status', bool), ('time', np.int32)])

# %%
# A function for building the best model with the best parameters 
def create_best_model(model_class, best_params):
    return model_class(**best_params, fit_baseline_model=True)

# Set the best model 
best_model_cindex = create_best_model(CoxnetSurvivalAnalysis, 
                                      study_cindex.best_params)

# Train the best model for C-index on the whole dataset
best_model_cindex.fit(X_new_std, y)

# Evaluate the best model for C-index on MAASTRO dataset
c_index = best_model_cindex.score(MAASTRO_new_std, y_MAASTRO)
c_index = np.round(c_index, 3)
print("test_cindex :", c_index)

# Set the best model 
best_model_ibs = create_best_model(CoxnetSurvivalAnalysis, study_ibs.best_params)

# Train the best model for IBS on the whole dataset
best_model_ibs.fit(X_new_std, y)

# Evaluate the best model for IBS on MAASTRO dataset
lower, upper = np.percentile(y_MAASTRO["time"], [10, 90])
gbsg_times = np.arange(lower, upper)
surv_prob = np.row_stack([fn(gbsg_times) for fn in best_model_ibs.predict_survival_function(MAASTRO_new_std)])
ibs = integrated_brier_score(y_MAASTRO, y_MAASTRO, surv_prob, gbsg_times)
ibs = np.round(ibs, 3)
print("test_ibs: ", ibs)
# Out:
# CoxnetSurvivalAnalysis(fit_baseline_model=True, l1_ratio=0.046971505265140434)
# test_cindex : 0.666
# CoxnetSurvivalAnalysis(fit_baseline_model=True, l1_ratio=0.05774346219526162)
# test_ibs:  0.221

# %%
# Saving the values to the dictionary 
test_cindex['CoxElastic'] = c_index
test_ibs['CoxElastic'] = ibs

# %% [markdown]
# ### 5. Random Survival Forest

# %% [markdown]
# #### Train

# %%
# Setting the y format 
y = clinical_train[['OS', 'event_OS']]

def create_objective(model_class, metric, X, y):
    def objective(trial): 
        # Suggest values for hyperparameters
        min_samples_split = trial.suggest_int("min_samples_split", 2, 20)
        max_leaf_nodes = trial.suggest_int("max_leaf_nodes", 2, 20)
        min_samples_leaf = trial.suggest_int("min_samples_leaf", 1, 20)
        max_depth = trial.suggest_int("max_depth", 1, 20)
        n_estimators = trial.suggest_int("n_estimators", 1, 500)
        oob_score = trial.suggest_categorical("oob_score", [True, False])
        max_samples = trial.suggest_float("max_samples", 0.1, 1.0) 
        max_features = trial.suggest_categorical("max_features", ["auto", "sqrt", "log2", None])
        min_weight_fraction_leaf = trial.suggest_float("min_weight_fraction_leaf", 0.0, 0.5)
        
        # Include warm_start for C-index optimization
        if metric == "c-index":
            warm_start = trial.suggest_categorical("warm_start", [True, False])
        else:
            warm_start = False  # Exclude warm_start for other metrics
        
        # Create and fit survival model 
        model = model_class(min_samples_split=min_samples_split,
                            min_samples_leaf=min_samples_leaf,
                            max_leaf_nodes=max_leaf_nodes,
                            n_estimators=n_estimators, 
                            oob_score=oob_score,
                            warm_start=warm_start,
                            max_depth=max_depth,
                            max_features=max_features,
                            min_weight_fraction_leaf=min_weight_fraction_leaf, 
                            max_samples=max_samples, 
                            random_state=123)

        scores = [] 

        skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=123)
        
        for k, (train_index, test_index) in enumerate(skf.split(X, y.iloc[:, 1])): 
            X_train, X_test = X.iloc[train_index], X.iloc[test_index]
            y_train_df, y_test_df = y.iloc[train_index], y.iloc[test_index]
            
            # y_train into array 
            y_train = [] 
            for i, j in zip(y_train_df['event_OS'], y_train_df['OS']): 
                y_train.append((i, j))
            y_train = np.array(y_train, dtype=[('status', bool), ('time', np.int32)])

            # y_test into array
            y_test = [] 
            for i, j in zip(y_test_df['event_OS'], y_test_df['OS']): 
                y_test.append((i, j))
            y_test = np.array(y_test, dtype=[('status', bool), ('time', np.int32)])
            
            model.fit(X_train, y_train)

            if metric == "c-index":
                # Make predictions using C-index 
                c_index_score = model.score(X_test, y_test)
                scores.append(c_index_score)
                print(f"Fold {k + 1} C-index: {c_index_score}")
                
            elif metric == "ibs":
                # Make predictions using IBS 
                lower, upper = np.percentile(y_test["time"], [10, 90])    
                gbsg_times = np.arange(lower, upper)
                cox_surv_prob = np.row_stack([fn(gbsg_times) for fn in model.predict_survival_function(X_test)])
                ibs = integrated_brier_score(y_test, y_test, cox_surv_prob, gbsg_times)
                scores.append(ibs)
                print(f"Fold {k + 1} IBS: {ibs}")
            else:
                raise ValueError("Invalid metric. Use 'C-index' or 'ibs'.")
        
        # Return the mean of scores
        return np.mean(scores)
    
    return objective

# C-index
study_cindex = optuna.create_study(direction="maximize", sampler=optuna.samplers.TPESampler(seed=123))
objective_cindex = create_objective(RandomSurvivalForest, "c-index", X_new, y)
study_cindex.optimize(objective_cindex, n_trials=100, show_progress_bar=True)
print("\n")
print("* Best trial for C-index: \n", study_cindex.best_trial)
print("\n")
print("* Best Score for C-index: \n", study_cindex.best_value)

# Example usage for IBS
study_ibs = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(seed=123))
objective_ibs = create_objective(RandomSurvivalForest, "ibs", X_new, y)
study_ibs.optimize(objective_ibs, n_trials=100, show_progress_bar=True)
print("\n")
print("* Best trial for IBS: \n", study_ibs.best_trial)
print("\n")
print("* Best Score for IBS: \n", study_ibs.best_value)
# Out:
# [I 2024-04-19 17:29:31,225] A new study created in memory with name: no-name-f93ff0e5-8f36-44b0-b035-c1cbe7c3ed9b
#   0%|          | 0/100 [00:00<?, ?it/s]
# Fold 1 C-index: 0.6796536796536796
# Fold 2 C-index: 0.7366071428571429
# Fold 3 C-index: 0.8112745098039216
# Fold 4 C-index: 0.8396624472573839
# Fold 5 C-index: 0.6619718309859155
# [I 2024-04-19 17:29:42,970] Trial 0 finished with value: 0.7458339221116087 and parameters: {'min_samples_split': 15, 'max_leaf_nodes': 7, 'min_samples_leaf': 5, 'max_depth': 12, 'n_estimators': 360, 'oob_score': False, 'max_samples': 0.7163467647263769, 'max_features': None, 'min_weight_fraction_leaf': 0.2192861223398122, 'warm_start': False}. Best is trial 0 with value: 0.7458339221116087.
# Fold 1 C-index: 0.7012987012987013
# Fold 2 C-index: 0.7477678571428571
# Fold 3 C-index: 0.75
# Fold 4 C-index: 0.8227848101265823
# Fold 5 C-index: 0.6784037558685446
# [I 2024-04-19 17:29:51,963] Trial 1 finished with value: 0.7400510248873371 and parameters: {'min_samples_split': 16, 'max_leaf_nodes': 5, 'min_samples_leaf': 4, 'max_depth': 11, 'n_estimators': 266, 'oob_score': False, 'max_samples': 0.7520097923745717, 'max_features': 'sqrt', 'min_weight_fraction_leaf': 0.11413161543947781, 'warm_start': False}. Best is trial 0 with value: 0.7458339221116087.
# Fold 1 C-index: 0.6926406926406926
# Fold 2 C-index: 0.7611607142857143
# Fold 3 C-index: 0.7352941176470589
# Fold 4 C-index: 0.8481012658227848
# Fold 5 C-index: 0.6971830985915493
# [I 2024-04-19 17:29:58,729] Trial 2 finished with value: 0.7468759777975599 and parameters: {'min_samples_split': 3, 'max_leaf_nodes': 10, 'min_samples_leaf': 9, 'max_depth': 10, 'n_estimators': 213, 'oob_score': False, 'max_samples': 0.9040502468054213, 'max_features': 'auto', 'min_weight_fraction_leaf': 0
and parameters: {'min_samples_split': 3, 'max_leaf_nodes': 20, 'min_samples_leaf': 3, 'max_depth': 14, 'n_estimators': 234, 'oob_score': False, 'max_samples': 0.8522469582649989, 'max_features': 'auto', 'min_weight_fraction_leaf': 0.016120472120011053, 'warm_start': True}. Best is trial 82 with value: 0.8263333549436241.
# Fold 1 C-index: 0.7121212121212122
# Fold 2 C-index: 0.8214285714285714
# ...
# Fold 1 IBS: 0.17405636674966463
# Fold 2 IBS: 0.19250017536239278
# Fold 3 IBS: 0.16731634269655948
# Fold 4 IBS: 0.14584248992676513
# Fold 5 IBS: 0.21898914683592052
# [I 2024-04-19 19:04:03,816] Trial 73 finished with value: 0.17974090431426054 and parameters: {'min_samples_split': 4, 'max_leaf_nodes': 19, 'min_samples_leaf': 8, 'max_depth': 12, 'n_estimators': 499, 'oob_score': True, 'max_samples': 0.8811629662724652, 'max_features': 'sqrt', 'min_weight_fraction_leaf': 0.05561809788206867}. Best is trial 67 with value: 0.17968342154570133.
# Fold 1 IBS: 0.17451066102487495
# Fold 2 IBS: 0.1913172807721589
# Fold 3 IBS: 0.1679486453425643
# Fold 4 IBS: 0.14844909360606806
# Fold 5 IBS: 0.21911402796797239
# [I 2024-04-19 19:04:36,335] Trial 74 finished with value: 0.1802679417427277 and parameters: {'min_samples_split': 3, 'max_leaf_nodes': 17, 'min_samples_leaf': 9, 'max_depth': 12, 'n_estimators': 499, 'oob_score': True, 'max_samples': 0.8897917648310779, 'max_features': 'sqrt', 'min_weight_fraction_leaf': 0.041273462321798106}. Best is trial 67 with value: 0.17968342154570133.
# Fold 1 IBS: 0.17370685526773227
# Fold 2 IBS: 0.19400518952894952
# Fold 3 IBS: 0.1666196990115092
# Fold 4 IBS: 0.14549958126239382
# Fold 5 IBS: 0.21925029904942459
# [I 2024-04-19 19:05:05,365] Trial 75 finished with value: 0.17981632482400187 and parameters: {'min_samples_split': 5, 'max_leaf_nodes': 18, 'min_samples_leaf': 8, 'max_depth': 11, 'n_estimators': 475, 'oob_score': True, 'max_samples': 0.9418275530611047, 'max_features': 'sqrt', 'min_weight_fraction_leaf': 0.055218514639724874}. Best is trial 67 with value: 0.17968342154570133.
# Fold 1 IBS: 0.17516352372050512
# Fold 2 IBS: 0.19036456943282473
# Fold 3 IBS: 0.1684088607804022
# Fold 4 IBS: 0.15061326967808017
# Fold 5 IBS: 0.21958499113958635
# [I 2024-04-19 19:05:32,985] Trial 76 finished with value: 0.1808270429502797 and parameters: {'min_samples_split': 5, 'max_leaf_nodes': 18, 'min_samples_leaf': 10, 'max_depth': 13, 'n_estimators': 474, 'oob_score': True, 'max_samples': 0.9387036183630947, 'max_features': 'sqrt', 'min_weight_fraction_leaf': 0.05372616413513118}. Best is trial 67 with value: 0.17968342154570133.
# Fold 1 IBS: 0.1740653304371807
# Fold 2 IBS: 0.19313416023460675
# Fold 3 IBS: 0.16739799263384403
# Fold 4 IBS: 0.1458492840904207
# Fold 5 IBS: 0.21985616956374543
# [I 2024-04-19 19:06:00,111] Trial 77 finished with value: 0.18006058739195951 and parameters: {'min_samples_split': 4, 'max_leaf_nodes': 18, 'min_samples_leaf': 8, 'max_depth': 14, 'n_estimators': 458, 'oob_score': True, 'max_samples': 0.8819395772441071, 'max_features': 'sqrt', 'min_weight_fraction_leaf': 0.0718886172945185}. Best is trial 67 with value: 0.17968342154570133.
# Fold 1 IBS: 0.1774467891380575
# Fold 2 IBS: 0.1902678642422465
# Fold 3 IBS: 0.1688977565074806
# Fold 4 IBS: 0.15337103341098868
# Fold 5 IBS: 0.21830226346860807
# [I 2024-04-19 19:06:24,600] Trial 78 finished with value: 0.18165714135347627 and parameters: {'min_samples_split': 5, 'max_leaf_nodes': 17, 'min_samples_leaf': 11, 'max_depth': 11, 'n_estimators': 426, 'oob_score': True, 'max_samples': 0.9088045514364999, 'max_features': 'sqrt', 'min_weight_fraction_leaf': 0.03876717758859873}. Best is trial 67 with value: 0.17968342154570133.
# Fold 1 IBS: 0.17399482632177518
# Fold 2 IBS: 0.1939334957455722
# Fold 3 IBS: 0.16619608313874237
# Fold 4 IBS: 0.14527948258311044
# Fold 5 IBS: 0.21941819279052371
# [I 2024-04-19 19:06:52,104] Trial 79 finished with value: 0.17976441611594476 and parameters: {'min_samples_split': 3, 'max_leaf_nodes': 10, 'min_samples_leaf': 8, 'max_depth': 9, 'n_estimators': 473, 'oob_score': True, 'max_samples': 0.9998040692779598, 'max_features': 'sqrt', 'min_weight_fraction_leaf': 0.10276493190831093}. Best is trial 67 with value: 0.17968342154570133.
# Fold 1 IBS: 0.17446873955550304
# Fold 2 IBS: 0.19192303405505196
# Fold 3 IBS: 0.16697277672581967
# Fold 4 IBS: 0.1474135662689339
# Fold 5 IBS: 0.21828396213206663
# [I 2024-04-19 19:07:14,643] Trial 80 finished with value: 0.17981241574747503 and parameters: {'min_samples_split': 3, 'max_leaf_nodes': 10, 'min_samples_leaf': 9, 'max_depth': 9, 'n_estimators': 403, 'oob_score': True, 'max_samples': 0.9998849075030385, 'max_features': 'sqrt', 'min_weight_fraction_leaf': 0.016032579652846768}. Best is trial 67 with value: 0.17968342154570133.
# Fold 1 IBS: 0.17342637332001862
# Fold 2 IBS: 0.19202750914085331
# Fold 3 IBS: 0.16700201553540825
# Fold 4 IBS: 0.14711131822601375
# Fold 5 IBS: 0.21893434733795336
# [I 2024-04-19 19:07:43,781] Trial 81 finished with value: 0.17970031271204948 and parameters: {'min_samples_split': 3, 'max_leaf_nodes': 11, 'min_samples_leaf': 9, 'max_depth': 9, 'n_estimators': 481, 'oob_score': True, 'max_samples': 0.9947730859780035, 'max_features': 'sqrt', 'min_weight_fraction_leaf': 0.016635604832504165}. Best is trial 67 with value: 0.17968342154570133.
# Fold 1 IBS: 0.1743780073923229
# Fold 2 IBS: 0.19303704611491104
# Fold 3 IBS: 0.16705087786739636
# Fold 4 IBS: 0.14650904324584602
# Fold 5 IBS: 0.2192428081700243
# [I 2024-04-19 19:08:10,563] Trial 82 finished with value: 0.18004355655810012 and parameters: {'min_samples_split': 4, 'max_leaf_nodes': 10, 'min_samples_leaf': 8, 'max_depth': 9, 'n_estimators': 481, 'oob_score': True, 'max_samples': 0.8589279789144427, 'max_features': 'sqrt', 'min_weight_fraction_leaf': 0.028857604982161094}. Best is trial 67 with value: 0.17968342154570133.
# Fold 1 IBS: 0.17499073849467484
# Fold 2 IBS: 0.19076613159305417
# Fold 3 IBS: 0.16871158003369865
# Fold 4 IBS: 0.150862477077533
# Fold 5 IBS: 0.2199642403756975
# [I 2024-04-19 19:08:33,094] Trial 83 finished with value: 0.18105903351493163 and parameters: {'min_samples_split': 3, 'max_leaf_nodes': 11, 'min_samples_leaf': 10, 'max_depth': 12, 'n_estimators': 454, 'oob_score': True, 'max_samples': 0.921468169574945, 'max_features': 'sqrt', 'min_weight_fraction_leaf': 0.101176850147525}. Best is trial 67 with value: 0.17968342154570133.
# Fold 1 IBS: 0.17430342142883676
# Fold 2 IBS: 0.1908271402568216
# Fold 3 IBS: 0.16807045035504506
# Fold 4 IBS: 0.14967261405090446
# Fold 5 IBS: 0.22012546124359933
# [I 2024-04-19 19:08:53,817] Trial 84 finished with value: 0.18059981746704146 and parameters: {'min_samples_split': 4, 'max_leaf_nodes': 9, 'min_samples_leaf': 9, 'max_depth': 9, 'n_estimators': 431, 'oob_score': True, 'max_samples': 0.8305098540108901, 'max_features': 'sqrt', 'min_weight_fraction_leaf': 0.039260890080409866}. Best is trial 67 with value: 0.17968342154570133.
# Fold 1 IBS: 0.17429181559108492
# Fold 2 IBS: 0.1923832156611411
# Fold 3 IBS: 0.16738604482078087
# Fold 4 IBS: 0.1456075857920359
# Fold 5 IBS: 0.2189705859802673
# [I 2024-04-19 19:09:12,911] Trial 85 finished with value: 0.17972784956906201 and parameters: {'min_samples_split': 3, 'max_leaf_nodes': 11, 'min_samples_leaf': 8, 'max_depth': 9, 'n_estimators': 468, 'oob_score': True, 'max_samples': 0.9047091135698835, 'max_features': 'sqrt', 'min_weight_fraction_leaf': 0.0786298485339795}. Best is trial 67 with value: 0.17968342154570133.
# Fold 1 IBS: 0.17353949689321943
# Fold 2 IBS: 0.19466959421965777
# Fold 3 IBS: 0.16628807628723746
# Fold 4 IBS: 0.1454430689054813
# Fold 5 IBS: 0.21935019293330454
# [I 2024-04-19 19:09:32,372] Trial 86 finished with value: 0.17985808584778012 and parameters: {'min_samples_split': 2, 'max_leaf_nodes': 11, 'min_samples_leaf': 8, 'max_depth': 9, 'n_estimators': 468, 'oob_score': True, 'max_samples': 0.9763378310472921, 'max_features': 'sqrt', 'min_weight_fraction_leaf': 0.0889861307528011}. Best is trial 67 with value: 0.17968342154570133.
# Fold 1 IBS: 0.1739478859346362
# Fold 2 IBS: 0.19080122806291375
# Fold 3 IBS: 0.16809336678467313
# Fold 4 IBS: 0.1481326378122537
# Fold 5 IBS: 0.21909716267258572
# [I 2024-04-19 19:09:52,758] Trial 87 finished with value: 0.1800144562534125 and parameters: {'min_samples_split': 3, 'max_leaf_nodes': 9, 'min_samples_leaf': 9, 'max_depth': 11, 'n_estimators': 500, 'oob_score': True, 'max_samples': 0.9123972647726973, 'max_features': 'sqrt', 'min_weight_fraction_leaf': 0.0796516806721002}. Best is trial 67 with value: 0.17968342154570133.
# Fold 1 IBS: 0.1768136847826268
# Fold 2 IBS: 0.19369189528320194
# Fold 3 IBS: 0.17220774248623893
# Fold 4 IBS: 0.1708112874275263
# Fold 5 IBS: 0.2128135659233106
# [I 2024-04-19 19:10:12,074] Trial 88 finished with value: 0.18526763518058093 and parameters: {'min_samples_split': 19, 'max_leaf_nodes': 12, 'min_samples_leaf': 10, 'max_depth': 12, 'n_estimators': 484, 'oob_score': True, 'max_samples': 0.9477624847476083, 'max_features': 'sqrt', 'min_weight_fraction_leaf': 0.29333601346205307}. Best is trial 67 with value: 0.17968342154570133.
# Fold 1 IBS: 0.17426908662707694
# Fold 2 IBS: 0.19234694530492988
# Fold 3 IBS: 0.1678410062019447
# Fold 4 IBS: 0.14770579786315835
# Fold 5 IBS: 0.21993197092575492
# [I 2024-04-19 19:10:30,710] Trial 89 finished with value: 0.18041896138457297 and parameters: {'min_samples_split': 6, 'max_leaf_nodes': 12, 'min_samples_leaf': 8, 'max_depth': 17, 'n_estimators': 464, 'oob_score': True, 'max_samples': 0.7871023887502244, 'max_features': 'sqrt', 'min_weight_fraction_leaf': 0.048318268492309434}. Best is trial 67 with value: 0.17968342154570133.
# Fold 1 IBS: 0.17470685176554804
# Fold 2 IBS: 0.19054938154214585
# Fold 3 IBS: 0.16801893675666146
# Fold 4 IBS: 0.1493119892536286
# Fold 5 IBS: 0.219605127278762
# [I 2024-04-19 19:10:47,752] Trial 90 finished with value: 0.1804384573193492 and parameters: {'min_samples_split': 3, 'max_leaf_nodes': 8, 'min_samples_leaf': 9, 'max_depth': 10, 'n_estimators': 424, 'oob_score': True, 'max_samples': 0.8656475232632749, 'max_features': 'sqrt', 'min_weight_fraction_leaf': 0.014099539249874664}. Best is trial 67 with value: 0.17968342154570133.
# Fold 1 IBS: 0.1716552514605917
# Fold 2 IBS: 0.1969357382276248
# Fold 3 IBS: 0.16712465400444926
# Fold 4 IBS: 0.14458667327678065
# Fold 5 IBS: 0.21856594230276635
# [I 2024-04-19 19:11:06,148] Trial 91 finished with value: 0.17977365185444255 and parameters: {'min_samples_split': 4, 'max_leaf_nodes': 10, 'min_samples_leaf': 7, 'max_depth': 8, 'n_estimators': 448, 'oob_score': True, 'max_samples': 0.8921493056675597, 'max_features': 'sqrt', 'min_weight_fraction_leaf': 0.06539559113933376}. Best is trial 67 with value: 0.17968342154570133.
# Fold 1 IBS: 0.1745993364679144
# Fold 2 IBS: 0.19283199549877508
# Fold 3 IBS: 0.1676445858914052
# Fold 4 IBS: 0.14723833057279057
# Fold 5 IBS: 0.21935953002037412
# [I 2024-04-19 19:11:24,964] Trial 92 finished with value: 0.18033475569025187 and parameters: {'min_samples_split': 3, 'max_leaf_nodes': 10, 'min_samples_leaf': 8, 'max_depth': 8, 'n_estimators': 480, 'oob_score': True, 'max_samples': 0.8268333598435286, 'max_features': 'sqrt', 'min_weight_fraction_leaf': 0.06745502255846879}. Best is trial 67 with value: 0.17968342154570133.
# Fold 1 IBS: 0.17123206030431487
# Fold 2 IBS: 0.19908184248163796
# Fold 3 IBS: 0.16614720769746116
# Fold 4 IBS: 0.14441332201913504
# Fold 5 IBS: 0.21830976189633358
# [I 2024-04-19 19:11:43,737] Trial 93 finished with value: 0.17983683887977653 and parameters: {'min_samples_split': 2, 'max_leaf_nodes': 10, 'min_samples_leaf': 7, 'max_depth': 9, 'n_estimators': 448, 'oob_score': True, 'max_samples': 0.9302662358894548, 'max_features': 'sqrt', 'min_weight_fraction_leaf': 0.03180179191726157}. Best is trial 67 with value: 0.17968342154570133.
# Fold 1 IBS: 0.17086418271737477
# Fold 2 IBS: 0.20343924346006084
# Fold 3 IBS: 0.16605012361219545
# Fold 4 IBS: 0.1441672117666803
# Fold 5 IBS: 0.21871135580430207
# [I 2024-04-19 19:12:01,625] Trial 94 finished with value: 0.1806464234721227 and parameters: {'min_samples_split': 4, 'max_leaf_nodes': 11, 'min_samples_leaf': 6, 'max_depth': 8, 'n_estimators': 436, 'oob_score': True, 'max_samples': 0.9065581606409051, 'max_features': 'sqrt', 'min_weight_fraction_leaf': 0.06371884542587777}. Best is trial 67 with value: 0.17968342154570133.
# Fold 1 IBS: 0.1715163441566942
# Fold 2 IBS: 0.19777285868555608
# Fold 3 IBS: 0.16559328859194794
# Fold 4 IBS: 0.14415450952170134
# Fold 5 IBS: 0.21847901084040455
# [I 2024-04-19 19:12:21,786] Trial 95 finished with value: 0.17950320235926084 and parameters: {'min_samples_split': 3, 'max_leaf_nodes': 5, 'min_samples_leaf': 7, 'max_depth': 10, 'n_estimators': 490, 'oob_score': True, 'max_samples': 0.9844885683401962, 'max_features': 'sqrt', 'min_weight_fraction_leaf': 0.0853461900960533}. Best is trial 95 with value: 0.17950320235926084.
# Fold 1 IBS: 0.17291159109191123
# Fold 2 IBS: 0.18656636690906972
# Fold 3 IBS: 0.1688651856627537
# Fold 4 IBS: 0.16631849706885754
# Fold 5 IBS: 0.21208810116898189
# [I 2024-04-19 19:12:44,182] Trial 96 finished with value: 0.1813499483803148 and parameters: {'min_samples_split': 5, 'max_leaf_nodes': 2, 'min_samples_leaf': 9, 'max_depth': 10, 'n_estimators': 491, 'oob_score': True, 'max_samples': 0.9937919935018643, 'max_features': 'log2', 'min_weight_fraction_leaf': 0.10248502283319733}. Best is trial 95 with value: 0.17950320235926084.
# Fold 1 IBS: 0.1765654006095996
# Fold 2 IBS: 0.19051320047649548
# Fold 3 IBS: 0.16848605188903346
# Fold 4 IBS: 0.15292559341173614
# Fold 5 IBS: 0.21910137466091176
# [I 2024-04-19 19:13:04,468] Trial 97 finished with value: 0.1815183242095553 and parameters: {'min_samples_split': 2, 'max_leaf_nodes': 6, 'min_samples_leaf': 11, 'max_depth': 11, 'n_estimators': 469, 'oob_score': True, 'max_samples': 0.9563260884378038, 'max_features': 'sqrt', 'min_weight_fraction_leaf': 0.1201270975782226}. Best is trial 95 with value: 0.17950320235926084.
# Fold 1 IBS: 0.1860106460254092
# Fold 2 IBS: 0.21687021824980127
# Fold 3 IBS: 0.16983653113015101
# Fold 4 IBS: 0.14555127226235712
# Fold 5 IBS: 0.23793998006645276
# [I 2024-04-19 19:13:24,432] Trial 98 finished with value: 0.19124172954683427 and parameters: {'min_samples_split': 3, 'max_leaf_nodes': 5, 'min_samples_leaf': 8, 'max_depth': 10, 'n_estimators': 489, 'oob_score': True, 'max_samples': 0.9791599069624067, 'max_features': None, 'min_weight_fraction_leaf': 0.1500399623948983}. Best is trial 95 with value: 0.17950320235926084.
# Fold 1 IBS: 0.17294484214329123
# Fold 2 IBS: 0.19350381662654104
# Fold 3 IBS: 0.16610459044354028
# Fold 4 IBS: 0.14410427240440224
# Fold 5 IBS: 0.2190200286914635
# [I 2024-04-19 19:13:44,356] Trial 99 finished with value: 0.17913551006184766 and parameters: {'min_samples_split': 3, 'max_leaf_nodes': 4, 'min_samples_leaf': 6, 'max_depth': 13, 'n_estimators': 477, 'oob_score': True, 'max_samples': 0.8167504386100544, 'max_features': 'sqrt', 'min_weight_fraction_leaf': 0.08050368156727956}. Best is trial 99 with value: 0.17913551006184766.
#
#
# * Best trial for IBS:
#  FrozenTrial(number=99, state=TrialState.COMPLETE, values=[0.17913551006184766], datetime_start=datetime.datetime(2024, 4, 19, 19, 13, 24, 441379), datetime_complete=datetime.datetime(2024, 4, 19, 19, 13, 44, 354439), params={'min_samples_split': 3, 'max_leaf_nodes': 4, 'min_samples_leaf': 6, 'max_depth': 13, 'n_estimators': 477, 'oob_score': True, 'max_samples': 0.8167504386100544, 'max_features': 'sqrt', 'min_weight_fraction_leaf': 0.08050368156727956}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'min_samples_split': IntDistribution(high=20, log=False, low=2, step=1), 'max_leaf_nodes': IntDistribution(high=20, log=False, low=2, step=1), 'min_samples_leaf': IntDistribution(high=20, log=False, low=1, step=1), 'max_depth': IntDistribution(high=20, log=False, low=1, step=1), 'n_estimators': IntDistribution(high=500, log=False, low=1, step=1), 'oob_score': CategoricalDistribution(choices=(True, False)), 'max_samples': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'max_features': CategoricalDistribution(choices=('auto', 'sqrt', 'log2', None)), 'min_weight_fraction_leaf': FloatDistribution(high=0.5, log=False, low=0.0, step=None)}, trial_id=99, value=None)
#
#
# * Best Score for IBS:
#  0.17913551006184766

# %%
train_cindex['Randomsurvivalforest'] = np.round(study_cindex.best_value, 3)
train_ibs['Randomsurvivalforest'] = np.round(study_ibs.best_value, 3)

# %%
print("train_cindex: ", np.round(study_cindex.best_value, 3))
print("train_ibs: ", np.round(study_ibs.best_value, 3))
# Out:
# train_cindex:  0.86
# train_ibs:  0.179

# %% [markdown]
# #### Test

# %%
# y into array 
lists = [] 
for i, j in zip(y['event_OS'], y['OS']): 
    lists.append((i, j))
    
y = np.array(lists, dtype=[('status', bool), ('time', np.int32)])

# %%
# A function for building the best model with the best parameters 
def create_best_model(model_class, best_params):
    best_params["random_state"]=123
    return model_class(**best_params)

# Set the best model 
best_model_cindex = create_best_model(RandomSurvivalForest, study_cindex.best_params)

# Train the best model for C-index on the whole dataset
best_model_cindex.fit(X_new, y)

# Evaluate the best model for C-index on MAASTRO dataset
c_index = best_model_cindex.score(MAASTRO_new, y_MAASTRO)
c_index = np.round(c_index, 3)
print("test_cindex: ", c_index)

# Set the best model 
best_model_ibs = create_best_model(RandomSurvivalForest, study_ibs.best_params)

# Train the best model for IBS on the whole dataset
best_model_ibs.fit(X_new, y)

# Evaluate the best model for IBS on MAASTRO dataset
lower, upper = np.percentile(y_MAASTRO["time"], [10, 90])
gbsg_times = np.arange(lower, upper)
surv_prob = np.row_stack([fn(gbsg_times) for fn in best_model_ibs.predict_survival_function(MAASTRO_new)])
ibs = integrated_brier_score(y_MAASTRO, y_MAASTRO, surv_prob, gbsg_times)
ibs = np.round(ibs, 3)
print("test_ibs: ", ibs)
# Out:
# RandomSurvivalForest(max_depth=15, max_features='auto', max_leaf_nodes=20,
#                      max_samples=0.8495954044615595, min_samples_leaf=2,
#                      min_samples_split=2,
#                      min_weight_fraction_leaf=0.015108612851438236,
#                      n_estimators=171, random_state=123, warm_start=True)
# test_cindex:  0.642
# RandomSurvivalForest(max_depth=13, max_leaf_nodes=4,
#                      max_samples=0.8167504386100544, min_samples_leaf=6,
#                      min_samples_split=3,
#                      min_weight_fraction_leaf=0.08050368156727956,
#                      n_estimators=477, oob_score=True, random_state=123)
# test_ibs:  0.206

# %%
# Saving the values to the dictionary 
test_cindex['Randomsurvivalforest'] = c_index
test_ibs['Randomsurvivalforest'] = ibs

# %% [markdown]
# ### 6. ExtraSurvivalTrees

# %% [markdown]
# #### Train

# %%
# Setting the y format 
y = clinical_train[['OS', 'event_OS']]

def create_objective(model_class, metric, X, y):
    def objective(trial): 
        # Suggest values for hyperparameters 
        min_samples_split = trial.suggest_int("min_samples_split", 2, 20)
        max_leaf_nodes = trial.suggest_int("max_leaf_nodes", 2, 20)
        min_samples_leaf = trial.suggest_int("min_samples_leaf", 1, 20)
        max_depth = trial.suggest_int("max_depth", 1, 20)
        n_estimators = trial.suggest_int("n_estimators", 1, 500)
        oob_score = trial.suggest_categorical("oob_score", [True, False])
        warm_start = trial.suggest_categorical("warm_start", [True, False])
        max_features = trial.suggest_categorical("max_features", ["auto", "sqrt", "log2", None, 0.1, 1])
        max_samples = trial.suggest_float("max_samples", 0.1, 1.0) 
        min_weight_fraction_leaf = trial.suggest_float("min_weight_fraction_leaf", 0.0, 0.5)
        
        # Include warm_start for C-index optimization
        if metric == "c-index":
            warm_start = trial.suggest_categorical("warm_start", [True, False])
        else:
            warm_start = False  # Exclude warm_start for other metrics

        
        # Create and fit survival model 
        model = model_class(min_samples_split=min_samples_split,
                            min_samples_leaf=min_samples_leaf,
                            max_leaf_nodes=max_leaf_nodes,
                            n_estimators=n_estimators, 
                            oob_score=oob_score, 
                            max_features=max_features, 
                            warm_start=warm_start, 
                            max_samples=max_samples,
                            min_weight_fraction_leaf=min_weight_fraction_leaf, 
                            max_depth=max_depth, 
                            random_state=123) 
        
        scores = [] 
        
        skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=123)
        
        for k, (train_index, test_index) in enumerate(skf.split(X, y.iloc[:, 1])): 
            X_train, X_test = X.iloc[train_index], X.iloc[test_index]
            y_train_df, y_test_df = y.iloc[train_index], y.iloc[test_index]
            
            # y_train into array 
            y_train = [] 
            for i, j in zip(y_train_df['event_OS'], y_train_df['OS']): 
                y_train.append((i, j))
            y_train = np.array(y_train, dtype=[('status', bool), ('time', np.int32)])

            # y_test into array
            y_test = [] 
            for i, j in zip(y_test_df['event_OS'], y_test_df['OS']): 
                y_test.append((i, j))
            y_test = np.array(y_test, dtype=[('status', bool), ('time', np.int32)])

            model.fit(X_train, y_train)

            if metric == "c-index":
                # Make predictions using C-index 
                c_index_score = model.score(X_test, y_test)
                scores.append(c_index_score)
                print(f"Fold {k + 1} C-index: {c_index_score}")
                
            elif metric == "ibs":
                # Make predictions using IBS 
                lower, upper = np.percentile(y_test["time"], [10, 90])    
                gbsg_times = np.arange(lower, upper)
                surv_prob = np.row_stack([fn(gbsg_times) for fn in model.predict_survival_function(X_test)])
                ibs = integrated_brier_score(y_test, y_test, surv_prob, gbsg_times)
                scores.append(ibs)
                print(f"Fold {k + 1} IBS: {ibs}")
            else:
                raise ValueError("Invalid metric. Use 'C-index' or 'ibs'.")
        
        # Return the mean of scores
        return np.mean(scores)
    
    return objective

# C-index
study_cindex = optuna.create_study(direction="maximize", sampler=optuna.samplers.TPESampler(seed=123))
objective_cindex = create_objective(ExtraSurvivalTrees, "c-index", X_new, y)
study_cindex.optimize(objective_cindex, n_trials=100, show_progress_bar=True)
print("\n")
print("* Best trial for C-index: \n", study_cindex.best_trial)
print("\n")
print("* Best Score for C-index: \n", study_cindex.best_value)

# Example usage for IBS
study_ibs = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(seed=123))
objective_ibs = create_objective(ExtraSurvivalTrees, "ibs", X_new, y)
study_ibs.optimize(objective_ibs, n_trials=100, show_progress_bar=True)
print("\n")
print("* Best trial for IBS: \n", study_ibs.best_trial)
print("\n")
print("* Best Score for IBS: \n", study_ibs.best_value)
# Out:
# [I 2024-04-19 19:13:48,923] A new study created in memory with name: no-name-ba6b722d-ee2a-4af6-b1e6-5d69bd9213fe
#   0%|          | 0/100 [00:00<?, ?it/s]
# Fold 1 C-index: 0.7012987012987013
# Fold 2 C-index: 0.7790178571428571
# Fold 3 C-index: 0.8235294117647058
# Fold 4 C-index: 0.8481012658227848
# Fold 5 C-index: 0.6502347417840375
# [I 2024-04-19 19:13:51,674] Trial 0 finished with value: 0.7604363955626174 and parameters: {'min_samples_split': 15, 'max_leaf_nodes': 7, 'min_samples_leaf': 5, 'max_depth': 12, 'n_estimators': 360, 'oob_score': False, 'warm_start': True, 'max_features': 'log2', 'max_samples': 0.7641958651588321, 'min_weight_fraction_leaf': 0.09124586522674999}. Best is trial 0 with value: 0.7604363955626174.
# Fold 1 C-index: 0.5
# Fold 2 C-index: 0.5
# Fold 3 C-index: 0.5
# Fold 4 C-index: 0.5
# Fold 5 C-index: 0.5
# [I 2024-04-19 19:13:59,491] Trial 1 finished with value: 0.5 and parameters: {'min_samples_split': 5, 'max_leaf_nodes': 12, 'min_samples_leaf': 11, 'max_depth': 13, 'n_estimators': 425, 'oob_score': True, 'warm_start': True, 'max_features': None, 'max_samples': 0.4877764869966794, 'min_weight_fraction_leaf': 0.2468425488251531}. Best is trial 0 with value: 0.7604363955626174.
# Fold 1 C-index: 0.7077922077922078
# Fold 2 C-index: 0.7410714285714286
# Fold 3 C-index: 0.8186274509803921
# Fold 4 C-index: 0.8607594936708861
# Fold 5 C-index: 0.6502347417840375
# [I 2024-04-19 19:14:15,823] Trial 2 finished with value: 0.7556970645597905 and parameters: {'min_samples_split': 10, 'max_leaf_nodes': 7, 'min_samples_leaf': 9, 'max_depth': 18, 'n_estimators': 473, 'oob_score': False, 'warm_start': False, 'max_features': 0.1, 'max_samples': 0.6516050731866709, 'min_weight_fraction_leaf': 0.06031433299516187}. Best is trial 0 with value: 0.7604363955626174.
# Fold 1 C-index: 0.7380952380952381
# Fold 2 C-index: 0.78125
# Fold 3 C-index: 0.8235294117647058
# Fold 4 C-index: 0.8459915611814346
# Fold 5 C-index: 0.6338028169014085
# [I 2024-04-19 19:14:17,402] Trial 3 finished with value: 0.7645338055885573 and parameters: {'min_samples_split': 17, 'max_leaf_nodes': 13, 'min_samples_leaf': 11, 'max_depth': 7, 'n_estimators': 153, 'oob_score': False, 'warm_start': True, 'max_features': 0.1, 'max_samples': 0.7873145572990043, 'min_weight_fraction_leaf': 0.121833187268437}. Best is trial 3 with value: 0.7645338055885573.
# Fold 1 C-index: 0.5
# Fold 2 C-index: 0.5
# Fold 3 C-index: 0.5
# Fold 4 C-index: 0.5
# Fold 5 C-index: 0.5
# [I 2024-04-19 19:14:22,971] Trial 4 finished with value: 0.5 and parameters: {'min_samples_split': 5, 'max_leaf_nodes': 12, 'min_samples_leaf': 2, 'max_depth': 18, 'n_estimators': 314, 'oob_score': True, 'warm_start': True, 'max_features': 'log2', 'max_samples': 0.4500555167108301, 'min_weight_fraction_leaf': 0.46256624480699304}. Best is trial 3 with value: 0.7645338055885573.
# Fold 1 C-index: 0.5
# Fold 2 C-index: 0.5
# Fold 3 C-index: 0.5
# Fold 4 C-index: 0.5
# Fold 5 C-index: 0.5
# [I 2024-04-19 19:14:30,106] Trial 5 finished with value: 0.5 and parameters: {'min_samples_split': 17, 'max_leaf_nodes': 8, 'min_samples_leaf': 1, 'max_depth': 7, 'n_estimators': 200, 'oob_score': False, 'warm_start': False, 'max_features': 'sqrt', 'max_samples': 0.561815338779102, 'min_weight_fraction_leaf': 0.3333122750820358}. Best is trial 3 with value: 0.7645338055885573.
# Fold 1 C-index: 0.6991341991341992
# Fold 2 C-index: 0.7745535714285714
# Fold 3 C-index: 0.8186274509803921
# Fold 4 C-index: 0.8396624472573839
# Fold 5 C-index: 0.6455399061032864
# [I 2024-04-19 19:14:34,588] Trial 6 finished with value: 0.7555035149807666 and parameters: {'min_samples_split': 4, 'max_leaf_nodes': 4, 'min_samples_leaf': 7, 'max_depth': 14, 'n_estimators': 424, 'oob_score': False, 'warm_start': True, 'max_features': 'log2', 'max_samples': 0.5693797534575991, 'min_weight_fraction_leaf': 0.001344032287160346}. Best is trial 3 with value: 0.7645338055885573.
# Fold 1 C-index: 0.7272727272727273
# Fold 2 C-index: 0.6919642857142857
# Fold 3 C-index: 0.8284313725490197
# Fold 4 C-index: 0.8312236286919831
# Fold 5 C-index: 0.6596244131455399
# [I 2024-04-19 19:14:43,784] Trial 7 finished with value: 0.7477032854747112 and parameters: {'min_samples_split': 20, 'max_leaf_nodes': 19, 'min_samples_leaf': 5, 'max_depth': 6, 'n_estimators': 261, 'oob_score': False, 'warm_start': False, 'max_features': 1, 'max_samples': 0.9851694482832, 'min_weight_fraction_leaf': 0.03968289518900786}. Best is trial 3 with value: 0.7645338055885573.
# Fold 1 C-index: 0.7229437229437229
# Fold 2 C-index: 0.7723214285714286
# Fold 3 C-index: 0.821078431372549
# Fold 4 C-index: 0.8459915611814346
# Fold 5 C-index: 0.6267605633802817
# [I 2024-04-19 19:14:44,332] Trial 8 finished with value: 0.7578191414898834 and parameters: {'min_samples_split': 10, 'max_leaf_nodes': 5, 'min_samples_leaf': 10, 'max_depth': 11, 'n_estimators': 47, 'oob_score': False, 'warm_start': True, 'max_features': 0.1, 'max_samples': 0.8028981441999615, 'min_weight_fraction_leaf': 0.14326830836455096}. Best is trial 3 with value: 0.7645338055885573.
# Fold 1 C-index: 0.7142857142857143
# Fold 2 C-index: 0.7723214285714286
# Fold 3 C-index: 0.8137254901960784
# Fold 4 C-index: 0.8459915611814346
# Fold 5 C-index: 0.6314553990610329
# [I 2024-04-19 19:15:02,511] Trial 9 finished with value: 0.7555559186591377 and parameters: {'min_samples_split': 7, 'max_leaf_nodes': 14, 'min_samples_leaf': 3, 'max_depth': 14, 'n_estimators': 444, 'oob_score': True, 'warm_start': False, 'max_features': 1, 'max_samples': 0.7756453003088511, 'min_weight_fraction_leaf': 0.28703191257498223}. Best is trial 3 with value: 0.7645338055885573.
# Fold 1 C-index: 0.5
# Fold 2 C-index: 0.5
# Fold 3 C-index: 0.5
# Fold 4 C-index: 0.5
# Fold 5 C-index: 0.5
# [I 2024-04-19 19:15:04,739] Trial 10 finished with value: 0.5 and parameters: {'min_samples_split': 14, 'max_leaf_nodes': 17, 'min_samples_leaf': 17, 'max_depth': 1, 'n_estimators': 120, 'oob_score': True, 'warm_start': True, 'max_features': 0.1, 'max_samples': 0.25578614141973877, 'min_weight_fraction_leaf': 0.1775271775427378}. Best is trial 3 with value: 0.7645338055885573.
# Fold 1 C-index: 0.7294372294372294
# Fold 2 C-index: 0.78125
# Fold 3 C-index: 0.8137254901960784
# Fold 4 C-index: 0.8417721518987342
# Fold 5 C-index: 0.6455399061032864
# [I 2024-04-19 19:15:07,938] Trial 11 finished with value: 0.7623449555270658 and parameters: {'min_samples_split': 14, 'max_leaf_nodes': 9, 'min_samples_leaf': 14, 'max_depth': 7, 'n_estimators': 339, 'oob_score': False, 'warm_start': True, 'max_features': 'auto', 'max_samples': 0.9547450918366839, 'min_weight_fraction_leaf': 0.13639294401318086}. Best is trial 3 with value: 0.7645338055885573.
# Fold 1 C-index: 0.7294372294372294
# Fold 2 C-index: 0.7723214285714286
# Fold 3 C-index: 0.8259803921568627
# Fold 4 C-index: 0.8459915611814346
# Fold 5 C-index: 0.6455399061032864
# [I 2024-04-19 19:15:09,720] Trial 12 finished with value: 0.7638541034900483 and parameters: {'min_samples_split': 19, 'max_leaf_nodes': 15, 'min_samples_leaf': 14, 'max_depth': 6, 'n_estimators': 174, 'oob_score': False, 'warm_start': True, 'max_features': 'auto', 'max_samples': 0.9861268838969514, 'min_weight_fraction_leaf': 0.17573308388274628}. Best is trial 3 with value: 0.7645338055885573.
# Fold 1 C-index: 0.7121212121212122
# Fold 2 C-index: 0.765625
# Fold 3 C-index: 0.8235294117647058
# Fold 4 C-index: 0.879746835443038
# Fold 5 C-index: 0.6408450704225352
# [I 2024-04-19
# Fold 3 C-index: 0.8186274509803921
# Fold 4 C-index: 0.879746835443038
# Fold 5 C-index: 0.6455399061032864
# [I 2024-04-19 19:21:38,442] Trial 84 finished with value: 0.7674029683754733 and parameters: {'min_samples_split': 7, 'max_leaf_nodes': 6, 'min_samples_leaf': 5, 'max_depth': 12, 'n_estimators': 420, 'oob_score': True, 'warm_start': True, 'max_features': 0.1, 'max_samples': 0.7503860226013218, 'min_weight_fraction_leaf': 0.013557353799660502}. Best is trial 73 with value: 0.7934110648911179.
# Fold 1 C-index: 0.7380952380952381
# Fold 2 C-index: 0.78125
# Fold 3 C-index: 0.8235294117647058
# Fold 4 C-index: 0.8713080168776371
# Fold 5 C-index: 0.6830985915492958
# ...
# Fold 1 IBS: 0.16798176173306806
# Fold 2 IBS: 0.20396717393877337
# Fold 3 IBS: 0.17268471742663605
# Fold 4 IBS: 0.16338030696708697
# Fold 5 IBS: 0.221964458050046
# [I 2024-04-19 19:34:35,285] Trial 74 finished with value: 0.18599568362312208 and parameters: {'min_samples_split': 5, 'max_leaf_nodes': 17, 'min_samples_leaf': 1, 'max_depth': 17, 'n_estimators': 120, 'oob_score': True, 'warm_start': False, 'max_features': 0.1, 'max_samples': 0.8946121232318437, 'min_weight_fraction_leaf': 0.0730856233747402}. Best is trial 61 with value: 0.18121799149024395.
# Fold 1 IBS: 0.1575129268099459
# Fold 2 IBS: 0.22771762262094636
# Fold 3 IBS: 0.17001530168764217
# Fold 4 IBS: 0.14523198022570893
# Fold 5 IBS: 0.24183024423793772
# [I 2024-04-19 19:34:38,582] Trial 75 finished with value: 0.18846161511643625 and parameters: {'min_samples_split': 8, 'max_leaf_nodes': 11, 'min_samples_leaf': 4, 'max_depth': 12, 'n_estimators': 65, 'oob_score': True, 'warm_start': False, 'max_features': None, 'max_samples': 0.857534157499198, 'min_weight_fraction_leaf': 0.049132894255676886}. Best is trial 61 with value: 0.18121799149024395.
# Fold 1 IBS: 0.16574639679759626
# Fold 2 IBS: 0.20682161735931565
# Fold 3 IBS: 0.17054591435384123
# Fold 4 IBS: 0.1596024156771391
# Fold 5 IBS: 0.22496493403551546
# [I 2024-04-19 19:34:40,746] Trial 76 finished with value: 0.1855362556446815 and parameters: {'min_samples_split': 10, 'max_leaf_nodes': 16, 'min_samples_leaf': 3, 'max_depth': 14, 'n_estimators': 38, 'oob_score': True, 'warm_start': False, 'max_features': 0.1, 'max_samples': 0.8199310538059053, 'min_weight_fraction_leaf': 0.027974733760366362}. Best is trial 61 with value: 0.18121799149024395.
# Fold 1 IBS: 0.1677992984487592
# Fold 2 IBS: 0.2053845007665244
# Fold 3 IBS: 0.1826789618487132
# Fold 4 IBS: 0.14793952214585832
# Fold 5 IBS: 0.24206261770296333
# [I 2024-04-19 19:34:41,695] Trial 77 finished with value: 0.1891729801825637 and parameters: {'min_samples_split': 5, 'max_leaf_nodes': 13, 'min_samples_leaf': 1, 'max_depth': 11, 'n_estimators': 6, 'oob_score': True, 'warm_start': False, 'max_features': 0.1, 'max_samples': 0.9683715248267519, 'min_weight_fraction_leaf': 0.0014009234669797102}. Best is trial 61 with value: 0.18121799149024395.
# Fold 1 IBS: 0.1721855334088519
# Fold 2 IBS: 0.19995400917898185
# Fold 3 IBS: 0.1731707247472599
# Fold 4 IBS: 0.169182807390768
# Fold 5 IBS: 0.21932472268246034
# [I 2024-04-19 19:34:47,816] Trial 78 finished with value: 0.1867635594816644 and parameters: {'min_samples_split': 11, 'max_leaf_nodes': 14, 'min_samples_leaf': 4, 'max_depth': 16, 'n_estimators': 132, 'oob_score': True, 'warm_start': False, 'max_features': 'auto', 'max_samples': 0.24833924440991573, 'min_weight_fraction_leaf': 0.015075056056582775}. Best is trial 61 with value: 0.18121799149024395.
# Fold 1 IBS: 0.16699620114629699
# Fold 2 IBS: 0.2041155331222707
# Fold 3 IBS: 0.17220407228282877
# Fold 4 IBS: 0.16294856641927863
# Fold 5 IBS: 0.22224954022074336
# [I 2024-04-19 19:34:52,592] Trial 79 finished with value: 0.1857027826382837 and parameters: {'min_samples_split': 7, 'max_leaf_nodes': 10, 'min_samples_leaf': 6, 'max_depth': 15, 'n_estimators': 103, 'oob_score': True, 'warm_start': False, 'max_features': 0.1, 'max_samples': 0.9407058569789184, 'min_weight_fraction_leaf': 0.041329152535869496}. Best is trial 61 with value: 0.18121799149024395.
# Fold 1 IBS: 0.17305003493990628
# Fold 2 IBS: 0.20049319984465064
# Fold 3 IBS: 0.17370377313342997
# Fold 4 IBS: 0.16987225208489318
# Fold 5 IBS: 0.21962771709527462
# [I 2024-04-19 19:35:00,187] Trial 80 finished with value: 0.18734939541963094 and parameters: {'min_samples_split': 9, 'max_leaf_nodes': 15, 'min_samples_leaf': 2, 'max_depth': 17, 'n_estimators': 171, 'oob_score': True, 'warm_start': False, 'max_features': 0.1, 'max_samples': 0.35277360385569917, 'min_weight_fraction_leaf': 0.06243505023515206}. Best is trial 61 with value: 0.18121799149024395.
# Fold 1 IBS: 0.16094348264152739
# Fold 2 IBS: 0.20876847475806706
# Fold 3 IBS: 0.16897945641863363
# Fold 4 IBS: 0.14684271812889768
# Fold 5 IBS: 0.22390414303026052
# [I 2024-04-19 19:35:04,271] Trial 81 finished with value: 0.18188765499547727 and parameters: {'min_samples_split': 6, 'max_leaf_nodes': 14, 'min_samples_leaf': 2, 'max_depth': 13, 'n_estimators': 85, 'oob_score': True, 'warm_start': False, 'max_features': 0.1, 'max_samples': 0.9111470647078989, 'min_weight_fraction_leaf': 0.009270786096778758}. Best is trial 61 with value: 0.18121799149024395.
# Fold 1 IBS: 0.16342275776056572
# Fold 2 IBS: 0.20268030301734055
# Fold 3 IBS: 0.168212537003939
# Fold 4 IBS: 0.15356185482516244
# Fold 5 IBS: 0.22502408301519983
# [I 2024-04-19 19:35:10,981] Trial 82 finished with value: 0.1825803071244415 and parameters: {'min_samples_split': 3, 'max_leaf_nodes': 13, 'min_samples_leaf': 3, 'max_depth': 14, 'n_estimators': 143, 'oob_score': True, 'warm_start': False, 'max_features': 0.1, 'max_samples': 0.9095739305094848, 'min_weight_fraction_leaf': 0.02358899325409339}. Best is trial 61 with value: 0.18121799149024395.
# Fold 1 IBS: 0.16080233348663536
# Fold 2 IBS: 0.20788023194246028
# Fold 3 IBS: 0.1687155862582711
# Fold 4 IBS: 0.14509641889082298
# Fold 5 IBS: 0.223896867161199
# [I 2024-04-19 19:35:15,573] Trial 83 finished with value: 0.18127828754787773 and parameters: {'min_samples_split': 8, 'max_leaf_nodes': 16, 'min_samples_leaf': 1, 'max_depth': 13, 'n_estimators': 90, 'oob_score': True, 'warm_start': False, 'max_features': 0.1, 'max_samples': 0.8661522713369854, 'min_weight_fraction_leaf': 0.017859183881848813}. Best is trial 61 with value: 0.18121799149024395.
# Fold 1 IBS: 0.17206193584573753
# Fold 2 IBS: 0.200894325838246
# Fold 3 IBS: 0.1743594391890907
# Fold 4 IBS: 0.16790244554022898
# Fold 5 IBS: 0.21674325942762454
# [I 2024-04-19 19:35:17,853] Trial 84 finished with value: 0.18639228116818554 and parameters: {'min_samples_split': 7, 'max_leaf_nodes': 15, 'min_samples_leaf': 1, 'max_depth': 11, 'n_estimators': 43, 'oob_score': True, 'warm_start': False, 'max_features': 0.1, 'max_samples': 0.1443115068222393, 'min_weight_fraction_leaf': 0.01651902902400695}. Best is trial 61 with value: 0.18121799149024395.
# Fold 1 IBS: 0.1625481763997366
# Fold 2 IBS: 0.20411442806150007
# Fold 3 IBS: 0.17073553161912905
# Fold 4 IBS: 0.1572601998028383
# Fold 5 IBS: 0.22324766101268878
# [I 2024-04-19 19:35:21,093] Trial 85 finished with value: 0.18358119937917855 and parameters: {'min_samples_split': 6, 'max_leaf_nodes': 12, 'min_samples_leaf': 2, 'max_depth': 12, 'n_estimators': 66, 'oob_score': True, 'warm_start': False, 'max_features': 'sqrt', 'max_samples': 0.8705885374510871, 'min_weight_fraction_leaf': 0.044729349902010135}. Best is trial 61 with value: 0.18121799149024395.
# Fold 1 IBS: 0.16686767771495845
# Fold 2 IBS: 0.20348990042979143
# Fold 3 IBS: 0.17328298205633533
# Fold 4 IBS: 0.16344268470538786
# Fold 5 IBS: 0.2230302682389359
# [I 2024-04-19 19:35:26,088] Trial 86 finished with value: 0.18602270262908177 and parameters: {'min_samples_split': 8, 'max_leaf_nodes': 17, 'min_samples_leaf': 1, 'max_depth': 10, 'n_estimators': 113, 'oob_score': True, 'warm_start': False, 'max_features': 0.1, 'max_samples': 0.8401282857063122, 'min_weight_fraction_leaf': 0.07996945969338447}. Best is trial 61 with value: 0.18121799149024395.
# Fold 1 IBS: 0.1606709117433291
# Fold 2 IBS: 0.20499822700813683
# Fold 3 IBS: 0.1707377639828606
# Fold 4 IBS: 0.15100768267391493
# Fold 5 IBS: 0.222140644174047
# [I 2024-04-19 19:35:30,404] Trial 87 finished with value: 0.1819110459164577 and parameters: {'min_samples_split': 6, 'max_leaf_nodes': 14, 'min_samples_leaf': 2, 'max_depth': 12, 'n_estimators': 88, 'oob_score': True, 'warm_start': False, 'max_features': 0.1, 'max_samples': 0.8970376766579063, 'min_weight_fraction_leaf': 0.026906928557137534}. Best is trial 61 with value: 0.18121799149024395.
# Fold 1 IBS: 0.16993969118982363
# Fold 2 IBS: 0.2082353904481683
# Fold 3 IBS: 0.176924792609168
# Fold 4 IBS: 0.17669877912879303
# Fold 5 IBS: 0.22458513783901193
# [I 2024-04-19 19:35:31,853] Trial 88 finished with value: 0.191276758242993 and parameters: {'min_samples_split': 5, 'max_leaf_nodes': 14, 'min_samples_leaf': 1, 'max_depth': 12, 'n_estimators': 18, 'oob_score': True, 'warm_start': False, 'max_features': 0.1, 'max_samples': 0.8844434368302098, 'min_weight_fraction_leaf': 0.23418814674021785}. Best is trial 61 with value: 0.18121799149024395.
# Fold 1 IBS: 0.1576922479258321
# Fold 2 IBS: 0.2239911635583728
# Fold 3 IBS: 0.16515154759852188
# Fold 4 IBS: 0.14404377493142576
# Fold 5 IBS: 0.2392229953919981
# [I 2024-04-19 19:35:35,819] Trial 89 finished with value: 0.18602034588123012 and parameters: {'min_samples_split': 6, 'max_leaf_nodes': 12, 'min_samples_leaf': 2, 'max_depth': 14, 'n_estimators': 81, 'oob_score': True, 'warm_start': False, 'max_features': None, 'max_samples': 0.6036688877353382, 'min_weight_fraction_leaf': 0.03094469104285619}. Best is trial 61 with value: 0.18121799149024395.
# Fold 1 IBS: 0.17012514471237863
# Fold 2 IBS: 0.20155696469015327
# Fold 3 IBS: 0.17352484281550176
# Fold 4 IBS: 0.16708692512945908
# Fold 5 IBS: 0.2210594879459064
# [I 2024-04-19 19:35:41,640] Trial 90 finished with value: 0.18667067305867985 and parameters: {'min_samples_split': 4, 'max_leaf_nodes': 14, 'min_samples_leaf': 4, 'max_depth': 15, 'n_estimators': 127, 'oob_score': True, 'warm_start': False, 'max_features': 'log2', 'max_samples': 0.8220244057494425, 'min_weight_fraction_leaf': 0.09492806921255982}. Best is trial 61 with value: 0.18121799149024395.
# Fold 1 IBS: 0.16022188650318997
# Fold 2 IBS: 0.207875689870737
# Fold 3 IBS: 0.1706052546708212
# Fold 4 IBS: 0.14885746387443788
# Fold 5 IBS: 0.22322548147397295
# [I 2024-04-19 19:35:46,321] Trial 91 finished with value: 0.1821571552786318 and parameters: {'min_samples_split': 7, 'max_leaf_nodes': 15, 'min_samples_leaf': 2, 'max_depth': 13, 'n_estimators': 89, 'oob_score': True, 'warm_start': False, 'max_features': 0.1, 'max_samples': 0.8994449775064419, 'min_weight_fraction_leaf': 0.013459041360236523}. Best is trial 61 with value: 0.18121799149024395.
# Fold 1 IBS: 0.16498522802175805
# Fold 2 IBS: 0.20307740394927007
# Fold 3 IBS: 0.1716304440181178
# Fold 4 IBS: 0.1609976034130331
# Fold 5 IBS: 0.22251793878462633
# [I 2024-04-19 19:35:50,995] Trial 92 finished with value: 0.18464172363736106 and parameters: {'min_samples_split': 6, 'max_leaf_nodes': 13, 'min_samples_leaf': 3, 'max_depth': 12, 'n_estimators': 103, 'oob_score': True, 'warm_start': False, 'max_features': 0.1, 'max_samples': 0.9238945535983697, 'min_weight_fraction_leaf': 0.054397966201170725}. Best is trial 61 with value: 0.18121799149024395.
# Fold 1 IBS: 0.15874531441823125
# Fold 2 IBS: 0.19788895349195867
# Fold 3 IBS: 0.17040815635830278
# Fold 4 IBS: 0.15368918990343533
# Fold 5 IBS: 0.2225237842470909
# [I 2024-04-19 19:35:53,723] Trial 93 finished with value: 0.18065107968380376 and parameters: {'min_samples_split': 8, 'max_leaf_nodes': 16, 'min_samples_leaf': 2, 'max_depth': 13, 'n_estimators': 56, 'oob_score': True, 'warm_start': False, 'max_features': 0.1, 'max_samples': 0.5134770002652083, 'min_weight_fraction_leaf': 0.0109413791966115}. Best is trial 93 with value: 0.18065107968380376.
# Fold 1 IBS: 0.1599588562993381
# Fold 2 IBS: 0.2061533272216183
# Fold 3 IBS: 0.1701411278176696
# Fold 4 IBS: 0.1510588857093582
# Fold 5 IBS: 0.219004771549214
# [I 2024-04-19 19:35:56,570] Trial 94 finished with value: 0.18126339371943967 and parameters: {'min_samples_split': 5, 'max_leaf_nodes': 13, 'min_samples_leaf': 1, 'max_depth': 13, 'n_estimators': 51, 'oob_score': True, 'warm_start': False, 'max_features': 0.1, 'max_samples': 0.7891950072094205, 'min_weight_fraction_leaf': 0.026353911320462685}. Best is trial 93 with value: 0.18065107968380376.
# Fold 1 IBS: 0.1680859816937997
# Fold 2 IBS: 0.2024799403653161
# Fold 3 IBS: 0.17378805800994826
# Fold 4 IBS: 0.16592854165000898
# Fold 5 IBS: 0.22086757034805093
# [I 2024-04-19 19:35:59,532] Trial 95 finished with value: 0.18623001841342482 and parameters: {'min_samples_split': 5, 'max_leaf_nodes': 13, 'min_samples_leaf': 1, 'max_depth': 11, 'n_estimators': 54, 'oob_score': True, 'warm_start': False, 'max_features': 0.1, 'max_samples': 0.8506950525428612, 'min_weight_fraction_leaf': 0.1128515138586906}. Best is trial 93 with value: 0.18065107968380376.
# Fold 1 IBS: 0.16701676965411436
# Fold 2 IBS: 0.2028694746579074
# Fold 3 IBS: 0.17452789056822343
# Fold 4 IBS: 0.16436961423792879
# Fold 5 IBS: 0.22147690006179124
# [I 2024-04-19 19:36:01,685] Trial 96 finished with value: 0.186052129835993 and parameters: {'min_samples_split': 7, 'max_leaf_nodes': 11, 'min_samples_leaf': 2, 'max_depth': 18, 'n_estimators': 37, 'oob_score': True, 'warm_start': False, 'max_features': 0.1, 'max_samples': 0.42314798257173786, 'min_weight_fraction_leaf': 0.029975588483663183}. Best is trial 93 with value: 0.18065107968380376.
# Fold 1 IBS: 0.16241510151615302
# Fold 2 IBS: 0.20567948921602666
# Fold 3 IBS: 0.17643848316100505
# Fold 4 IBS: 0.16302525235283083
# Fold 5 IBS: 0.23397117453966612
# [I 2024-04-19 19:36:03,014] Trial 97 finished with value: 0.18830590015713633 and parameters: {'min_samples_split': 3, 'max_leaf_nodes': 17, 'min_samples_leaf': 1, 'max_depth': 16, 'n_estimators': 18, 'oob_score': True, 'warm_start': False, 'max_features': 0.1, 'max_samples': 0.6583241870431692, 'min_weight_fraction_leaf': 0.041473416191933746}. Best is trial 93 with value: 0.18065107968380376.
# Fold 1 IBS: 0.16373226063401664
# Fold 2 IBS: 0.20062759423933463
# Fold 3 IBS: 0.17166520349582112
# Fold 4 IBS: 0.15804012515098947
# Fold 5 IBS: 0.22188054948773325
# [I 2024-04-19 19:36:06,181] Trial 98 finished with value: 0.18318914660157903 and parameters: {'min_samples_split': 9, 'max_leaf_nodes': 15, 'min_samples_leaf': 3, 'max_depth': 14, 'n_estimators': 63, 'oob_score': True, 'warm_start': False, 'max_features': 'auto', 'max_samples': 0.47102531633778555, 'min_weight_fraction_leaf': 0.013257117629977546}. Best is trial 93 with value: 0.18065107968380376.
# Fold 1 IBS: 0.16265506436368757
# Fold 2 IBS: 0.19942347007031952
# Fold 3 IBS: 0.17488813002189604
# Fold 4 IBS: 0.15411082381750038
# Fold 5 IBS: 0.2193560305192995
# [I 2024-04-19 19:36:08,996] Trial 99 finished with value: 0.1820867037585406 and parameters: {'min_samples_split': 5, 'max_leaf_nodes': 16, 'min_samples_leaf': 2, 'max_depth': 12, 'n_estimators': 53, 'oob_score': True, 'warm_start': False, 'max_features': 0.1, 'max_samples': 0.5241090515866025, 'min_weight_fraction_leaf': 0.025913140991148526}. Best is trial 93 with value: 0.18065107968380376.
#
#
# * Best trial for IBS:
#  FrozenTrial(number=93, state=TrialState.COMPLETE, values=[0.18065107968380376], datetime_start=datetime.datetime(2024, 4, 19, 19, 35, 51, 624), datetime_complete=datetime.datetime(2024, 4, 19, 19, 35, 53, 722318), params={'min_samples_split': 8, 'max_leaf_nodes': 16, 'min_samples_leaf': 2, 'max_depth': 13, 'n_estimators': 56, 'oob_score': True, 'warm_start': False, 'max_features': 0.1, 'max_samples': 0.5134770002652083, 'min_weight_fraction_leaf': 0.0109413791966115}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'min_samples_split': IntDistribution(high=20, log=False, low=2, step=1), 'max_leaf_nodes': IntDistribution(high=20, log=False, low=2, step=1), 'min_samples_leaf': IntDistribution(high=20, log=False, low=1, step=1), 'max_depth': IntDistribution(high=20, log=False, low=1, step=1), 'n_estimators': IntDistribution(high=500, log=False, low=1, step=1), 'oob_score': CategoricalDistribution(choices=(True, False)), 'warm_start': CategoricalDistribution(choices=(True, False)), 'max_features': CategoricalDistribution(choices=('auto', 'sqrt', 'log2', None, 0.1, 1)), 'max_samples': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'min_weight_fraction_leaf': FloatDistribution(high=0.5, log=False, low=0.0, step=None)}, trial_id=93, value=None)
#
#
# * Best Score for IBS:
#  0.18065107968380376

# %%
train_cindex['ExtraSurvivalTrees'] = np.round(study_cindex.best_value, 3)
train_ibs['ExtraSurvivalTrees'] = np.round(study_ibs.best_value, 3)

# %%
print("train_cindex: ", np.round(study_cindex.best_value, 3))
print("train_ibs: ", np.round(study_ibs.best_value, 3))
# Out:
# train_cindex:  0.793
# train_ibs:  0.181

# %% [markdown]
# #### Test

# %%
# y into array 
lists = [] 
for i, j in zip(y['event_OS'], y['OS']): 
    lists.append((i, j))

y = np.array(lists, dtype=[('status', bool), ('time', np.int32)])

# %%
# A function for building the best model with the best parameters 
def create_best_model(model_class, best_params):
    best_params["random_state"]=123
    return model_class(**best_params)

# Set the best model 
best_model_cindex = create_best_model(ExtraSurvivalTrees, study_cindex.best_params)

# Train the best model for C-index on the whole dataset
best_model_cindex.fit(X_new, y)

# Evaluate the best model for C-index on MAASTRO dataset
c_index = best_model_cindex.score(MAASTRO_new, y_MAASTRO)
c_index = np.round(c_index, 3)
print("C-index score:", c_index)

# Set the best model 
best_model_ibs = create_best_model(ExtraSurvivalTrees, study_ibs.best_params)

# Train the best model for IBS on the whole dataset
best_model_ibs.fit(X_new, y)

# Evaluate the best model for IBS on MAASTRO dataset
lower, upper = np.percentile(y_MAASTRO["time"], [10, 90])
gbsg_times = np.arange(lower, upper)
surv_prob = np.row_stack([fn(gbsg_times) for fn in best_model_ibs.predict_survival_function(MAASTRO_new)])
ibs = integrated_brier_score(y_MAASTRO, y_MAASTRO, surv_prob, gbsg_times)
ibs = np.round(ibs, 3)
print("IBS:", ibs)
# Out:
# ExtraSurvivalTrees(max_depth=12, max_features=None, max_leaf_nodes=9,
#                    max_samples=0.6518029481375588, min_samples_leaf=1,
#                    min_samples_split=9,
#                    min_weight_fraction_leaf=0.016060481668585008,
#                    n_estimators=363, oob_score=True, random_state=123,
#                    warm_start=True)
# C-index score: 0.667
# ExtraSurvivalTrees(max_depth=13, max_features=0.1, max_leaf_nodes=16,
#                    max_samples=0.5134770002652083, min_samples_leaf=2,
#                    min_samples_split=8,
#                    min_weight_fraction_leaf=0.0109413791966115, n_estimators=56,
#                    oob_score=True, random_state=123)
# IBS: 0.211

# %%
# Saving the values to the dictionary 
test_cindex['ExtraSurvivalTrees'] = c_index
test_ibs['ExtraSurvivalTrees'] = ibs

# %% [markdown]
# ### 7. GradientBoostingSurvivalAnalysis

# %% [markdown]
# #### Train

# %%
# Setting the y format 
y = clinical_train[['OS', 'event_OS']]

# Running to optuna for hyperparameter tuning
def create_objective(model_class, metric, X, y):
    def objective(trial): 
        # Suggest values for hyperparameters
        subsample = trial.suggest_float("subsample", 0.1, 1)
        learning_rate = trial.suggest_float("learning_rate", 0.001, 0.1)
        dropout_rate = trial.suggest_float("dropout_rate", 0.1, 1)
        n_estimators = trial.suggest_int("n_estimators", 1, 500)
        criterion = trial.suggest_categorical('criterion', ['friedman_mse', 'squared_error'])
        ccp_alpha = trial.suggest_float("ccp_alpha", 0.0, 10)
        min_weight_fraction_leaf = trial.suggest_float("min_weight_fraction_leaf", 0.0, 0.5)
        max_features = trial.suggest_categorical("max_features", ["auto", "sqrt", "log2", None, 0.1, 1])
        min_impurity_decrease = trial.suggest_loguniform('min_impurity_decrease', 1e-7, 1e-1)
        validation_fraction = trial.suggest_float("validation_fraction", 0.0, 1.0)
        min_samples_split = trial.suggest_int("min_samples_split", 2, 20)
        max_leaf_nodes = trial.suggest_int("max_leaf_nodes", 2, 20)
        min_samples_leaf = trial.suggest_int("min_samples_leaf", 1, 20)
        max_depth = trial.suggest_int("max_depth", 1, 20)
        
        # Create and fit survival model 
        model = model_class(subsample=subsample,
                            learning_rate=learning_rate,
                            dropout_rate=dropout_rate,
                            n_estimators=n_estimators,
                            ccp_alpha=ccp_alpha, 
                            criterion=criterion,
                            min_samples_split=min_samples_split,
                            min_samples_leaf=min_samples_leaf,
                            min_weight_fraction_leaf=min_weight_fraction_leaf,
                            max_depth=max_depth,
                            max_features=max_features,
                            max_leaf_nodes=max_leaf_nodes, 
                            min_impurity_decrease=min_impurity_decrease,
                            validation_fraction=validation_fraction, 
                            random_state=123)
        
        scores = [] 
        
        skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=123)
        
        for k, (train_index, test_index) in enumerate(skf.split(X, y.iloc[:, 1])): 
            X_train, X_test = X.iloc[train_index], X.iloc[test_index]
            y_train_df, y_test_df = y.iloc[train_index], y.iloc[test_index]
            
            # y_train into array 
            y_train = [] 
            for i, j in zip(y_train_df['event_OS'], y_train_df['OS']): 
                y_train.append((i, j))
            y_train = np.array(y_train, dtype=[('status', bool), ('time', np.int32)])

            # y_test into array
            y_test = [] 
            for i, j in zip(y_test_df['event_OS'], y_test_df['OS']): 
                y_test.append((i, j))
            y_test = np.array(y_test, dtype=[('status', bool), ('time', np.int32)])

            model.fit(X_train, y_train)

            if metric == "c-index":
                # Make predictions using C-index 
                c_index_score = model.score(X_test, y_test)
                scores.append(c_index_score)
                print(f"Fold {k + 1} C-index: {c_index_score}")
                
            elif metric == "ibs":
                # Make predictions using IBS 
                lower, upper = np.percentile(y_test["time"], [10, 90])    
                gbsg_times = np.arange(lower, upper)
                surv_prob = np.row_stack([fn(gbsg_times) for fn in model.predict_survival_function(X_test)])
                ibs = integrated_brier_score(y_test, y_test, surv_prob, gbsg_times)
                scores.append(ibs)
                print(f"Fold {k + 1} IBS: {ibs}")
            else:
                raise ValueError("Invalid metric. Use 'C-index' or 'ibs'.")
        
        # Return the mean of scores
        return np.mean(scores)
    
    return objective

# C-index
study_cindex = optuna.create_study(direction="maximize", sampler=optuna.samplers.TPESampler(seed=123))
objective_cindex = create_objective(GradientBoostingSurvivalAnalysis, "c-index", X_new, y)
study_cindex.optimize(objective_cindex, n_trials=100, show_progress_bar=True)
print("\n")
print("* Best trial for C-index: \n", study_cindex.best_trial)
print("\n")
print("* Best Score for C-index: \n", study_cindex.best_value)

# Example usage for IBS
study_ibs = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(seed=123))
objective_ibs = create_objective(GradientBoostingSurvivalAnalysis, "ibs", X_new, y)
study_ibs.optimize(objective_ibs, n_trials=100, show_progress_bar=True)
print("\n")
print("* Best trial for IBS: \n", study_ibs.best_trial)
print("\n")
print("* Best Score for IBS: \n", study_ibs.best_value)
# Out:
# [I 2024-04-19 19:36:12,374] A new study created in memory with name: no-name-39659945-1fba-492a-82e2-a0b942e561c9
#   0%|          | 0/100 [00:00<?, ?it/s]
# Fold 1 C-index: 0.5
# Fold 2 C-index: 0.5
# Fold 3 C-index: 0.5
# Fold 4 C-index: 0.5
# Fold 5 C-index: 0.5
# [I 2024-04-19 19:37:19,563] Trial 0 finished with value: 0.5 and parameters: {'subsample': 0.7268222670380755, 'learning_rate': 0.02932779416008757, 'dropout_rate': 0.3041663082077828, 'n_estimators': 276, 'criterion': 'friedman_mse', 'ccp_alpha': 9.807641983846155, 'min_weight_fraction_leaf': 0.34241486929243165, 'max_features': None, 'min_impurity_decrease': 2.4449249473284515e-05, 'validation_fraction': 0.7379954057320357, 'min_samples_split': 5, 'max_leaf_nodes': 5, 'min_samples_leaf': 11, 'max_depth': 11}. Best is trial 0 with value: 0.5.
# Fold 1 C-index: 0.5
# Fold 2 C-index: 0.5
# Fold 3 C-index: 0.5
# Fold 4 C-index: 0.5
# Fold 5 C-index: 0.5
# [I 2024-04-19 19:38:02,386] Trial 1 finished with value: 0.5 and parameters: {'subsample': 0.6709608626961889, 'learning_rate': 0.08509374761370117, 'dropout_rate': 0.7520097923745717, 'n_estimators': 306, 'criterion': 'friedman_mse', 'ccp_alpha': 3.617886556223141, 'min_weight_fraction_leaf': 0.11413161543947781, 'max_features': 'sqrt', 'min_impurity_decrease': 3.589068454832194e-05, 'validation_fraction': 0.3122612229724653, 'min_samples_split': 10, 'max_leaf_nodes': 18, 'min_samples_leaf': 19, 'max_depth': 11}. Best is trial 0 with value: 0.5.
# Fold 1 C-index: 0.5
# Fold 2 C-index: 0.5
# Fold 3 C-index: 0.5
# Fold 4 C-index: 0.5
# Fold 5 C-index: 0.5
# [I 2024-04-19 19:38:41,398] Trial 2 finished with value: 0.5 and parameters: {'subsample': 0.6615576566129001, 'learning_rate': 0.012446221112850278, 'dropout_rate': 0.3855569336382888, 'n_estimators': 208, 'criterion': 'friedman_mse', 'ccp_alpha': 4.830342642627043, 'min_weight_fraction_leaf': 0.4927798928053525, 'max_features': None, 'min_impurity_decrease': 1.139155477212975e-05, 'validation_fraction': 0.3041207890271841, 'min_samples_split': 9, 'max_leaf_nodes': 14, 'min_samples_leaf': 18, 'max_depth': 11}. Best is trial 0 with value: 0.5.
# Fold 1 C-index: 0.5
# Fold 2 C-index: 0.5
# Fold 3 C-index: 0.5
# Fold 4 C-index: 0.5
# Fold 5 C-index: 0.5
# [I 2024-04-19 19:39:42,886] Trial 3 finished with value: 0.5 and parameters: {'subsample': 0.7023824046660451, 'learning_rate': 0.059007718703659076, 'dropout_rate': 0.6624131518860399, 'n_estimators': 338, 'criterion': 'friedman_mse', 'ccp_alpha': 7.636828414433382, 'min_weight_fraction_leaf': 0.121833187268437, 'max_features': None, 'min_impurity_decrease': 1.2496121527731156e-07, 'validation_fraction': 0.5944318794450425, 'min_samples_split': 12, 'max_leaf_nodes': 5, 'min_samples_leaf': 4, 'max_depth': 14}. Best is trial 0 with value: 0.5.
# Fold 1 C-index: 0.5
# Fold 2 C-index: 0.5
# Fold 3 C-index: 0.5
# Fold 4 C-index: 0.5
# Fold 5 C-index: 0.5
# [I 2024-04-19 19:40:07,651] Trial 4 finished with value: 0.5 and parameters: {'subsample': 0.38688978374368876, 'learning_rate': 0.06950505925765015, 'dropout_rate': 0.5989449247459949, 'n_estimators': 195, 'criterion': 'friedman_mse', 'ccp_alpha': 3.573975666831762, 'min_weight_fraction_leaf': 0.021795731899520276, 'max_features': None, 'min_impurity_decrease': 0.0003622942983888231, 'validation_fraction': 0.6917017987001771, 'min_samples_split': 4, 'max_leaf_nodes': 9, 'min_samples_leaf': 5, 'max_depth': 7}. Best is trial 0 with value: 0.5.
# Fold 1 C-index: 0.5
# Fold 2 C-index: 0.5
# Fold 3 C-index: 0.5
# Fold 4 C-index: 0.5
# Fold 5 C-index: 0.5
# [I 2024-04-19 19:40:13,969] Trial 5 finished with value: 0.5 and parameters: {'subsample': 0.561815338779102, 'learning_rate': 0.06699583046624309, 'dropout_rate': 0.19531763655113243, 'n_estimators': 66, 'criterion': 'squared_error', 'ccp_alpha': 8.46506225270722, 'min_weight_fraction_leaf': 0.2766286723983567, 'max_features': 'auto', 'min_impurity_decrease': 1.0765273688465228e-05, 'validation_fraction': 0.5523700752940731, 'min_samples_split': 12, 'max_leaf_nodes': 11, 'min_samples_leaf': 1, 'max_depth': 20}. Best is trial 0 with value: 0.5.
# Fold 1 C-index: 0.5
# Fold 2 C-index: 0.5
# Fold 3 C-index: 0.5
# Fold 4 C-index: 0.5
# Fold 5 C-index: 0.5
# [I 2024-04-19 19:41:20,769] Trial 6 finished with value: 0.5 and parameters: {'subsample': 0.9148074180954489, 'learning_rate': 0.021555950258436127, 'dropout_rate': 0.3632404715131823, 'n_estimators': 261, 'criterion': 'squared_error', 'ccp_alpha': 2.575420641540831, 'min_weight_fraction_leaf': 0.28217952146239084, 'max_features': 1, 'min_impurity_decrease': 0.07963970730486686, 'validation_fraction': 0.07936579037801572, 'min_samples_split': 10, 'max_leaf_nodes': 5, 'min_samples_leaf': 10, 'max_depth': 11}. Best is trial 0 with value: 0.5.
# Fold 1 C-index: 0.5
# Fold 2 C-index: 0.5
# Fold 3 C-index: 0.5
# Fold 4 C-index: 0.5
# Fold 5 C-index: 0.5
# [I 2024-04-19 19:41:39,237] Trial 7 finished with value: 0.5 and parameters: {'subsample': 0.1839940393328387, 'learning_rate': 0.03038921677258727, 'dropout_rate': 0.9348258161369327, 'n_estimators': 285, 'criterion': 'squared_error', 'ccp_alpha': 7.418621518420373, 'min_weight_fraction_leaf': 0.024289516422134394, 'max_features': 'sqrt', 'min_impurity_decrease': 0.000980773656231882, 'validation_fraction': 0.11139217160771575, 'min_samples_split': 14, 'max_leaf_nodes': 18, 'min_samples_leaf': 14, 'max_depth': 9}. Best is trial 0 with value: 0.5.
# Fold 1 C-index: 0.5
# Fold 2 C-index: 0.5
# Fold 3 C-index: 0.5
# Fold 4 C-index: 0.5
# Fold 5 C-index: 0.5
# [I 2024-04-19 19:41:41,222] Trial 8 finished with value: 0.5 and parameters: {'subsample': 0.4943929459395022, 'learning_rate': 0.07674451342869135, 'dropout_rate': 0.6090778011032946, 'n_estimators': 43, 'criterion': 'squared_error', 'ccp_alpha': 3.3706638344760997, 'min_weight_fraction_leaf': 0.46378828978769476, 'max_features': 0.1, 'min_impurity_decrease': 0.028789223922376057, 'validation_fraction': 0.12863119750938, 'min_samples_split': 3, 'max_leaf_nodes': 4, 'min_samples_leaf': 8, 'max_depth': 9}. Best is trial 0 with value: 0.5.
# Fold 1 C-index: 0.7337662337662337
# Fold 2 C-index: 0.6964285714285714
# Fold 3 C-index: 0.8186274509803921
# Fold 4 C-index: 0.8523206751054853
# Fold 5 C-index: 0.6408450704225352
# [I 2024-04-19 19:44:17,518] Trial 9 finished with value: 0.7483976003406434 and parameters: {'subsample': 0.6059965408578151, 'learning_rate': 0.013102111413618, 'dropout_rate': 0.28125955124323376, 'n_estimators': 406, 'criterion': 'squared_error', 'ccp_alpha': 0.07426378544613033, 'min_weight_fraction_leaf': 0.27579636299120275, 'max_features': 'auto', 'min_impurity_decrease': 1.4994028685178666e-07, 'validation_fraction': 0.6359003593513561, 'min_samples_split': 2, 'max_leaf_nodes': 16, 'min_samples_leaf': 10, 'max_depth': 3}. Best is trial 9 with value: 0.7483976003406434.
# Fold 1 C-index: 0.6753246753246753
# Fold 2 C-index: 0.6004464285714286
# Fold 3 C-index: 0.7794117647058824
# Fold 4 C-index: 0.7637130801687764
# Fold 5 C-index: 0.6103286384976526
# [I 2024-04-19 19:48:08,477] Trial 10 finished with value: 0.685844917453683 and parameters: {'subsample': 0.985919291330434, 'learning_rate': 0.001978698361179733, 'dropout_rate': 0.1492094724532367, 'n_estimators': 471, 'criterion': 'squared_error', 'ccp_alpha': 0.064533742198293, 'min_weight_fraction_leaf': 0.3875179554315872, 'max_features': 'auto', 'min_impurity_decrease': 1.349041793173596e-07, 'validation_fraction': 0.998633732405058, 'min_samples_split': 20, 'max_leaf_nodes': 15, 'min_samples_leaf': 14, 'max_depth': 1}. Best is trial 9 with value: 0.7483976003406434.
# Fold 1 C-index: 0.5
# Fold 2 C-index: 0.5
# Fold 3 C-index: 0.5
# Fold 4 C-index: 0.5
# Fold 5 C-index: 0.5
# [I 2024-04-19 19:52:24,498] Trial 11 finished with value: 0.5 and parameters: {'subsample': 0.9974069032156301, 'learning_rate': 0.006595153873193416, 'dropout_rate': 0.11379276107227315, 'n_estimators': 494, 'criterion': 'squared_error', 'ccp_alpha': 0
 'min_samples_split': 20, 'max_leaf_nodes': 14, 'min_samples_leaf': 18, 'max_depth': 1}. Best is trial 9 with value: 0.7483976003406434.
# Fold 1 C-index: 0.5
# Fold 2 C-index: 0.5
# Fold 3 C-index: 0.5
# Fold 4 C-index: 0.5
# Fold 5 C-index: 0.5
# [I 2024-04-19 20:50:31,360] Trial 34 finished with value: 0.5 and parameters: {'subsample': 0.7050414276319562, 'learning_rate': 0.01736580349254983, 'dropout_rate': 0.22658656718653286, 'n_estimators': 469, 'criterion': 'friedman_mse', 'ccp_alpha': 0.6387415680643302, 'min_weight_fraction_leaf': 0.4889718572023061, 'max_features': 'sqrt', 'min_impurity_decrease': 2.6432989441697915e-07, 'validation_fraction': 0.996536937663533, 'min_samples_split': 15, 'max_leaf_nodes': 19, 'min_samples_leaf': 11, 'max_depth': 5}. Best is trial 9 with value: 0.7483976003406434.
# Fold 1 C-index: 0.5
# Fold 2 C-index: 0.5
# Fold 3 C-index: 0.5
# Fold 4 C-index: 0.5
# Fold 5 C-index: 0.5
# [I 2024-04-19 20:51:06,669] Trial 35 finished with value: 0.5 and parameters: {'subsample': 0.9259773449771448, 'learning_rate': 0.0013702833078771113, 'dropout_rate': 0.34791628140951375, 'n_estimators': 210, 'criterion': 'friedman_mse', 'ccp_alpha': 1.892552268167881, 'min_weight_fraction_leaf': 0.3235914313183653, 'max_features': None, 'min_impurity_decrease': 2.4072948146321942e-05, 'validation_fraction': 0.35098020419861614, 'min_samples_split': 19, 'max_leaf_nodes': 18, 'min_samples_leaf': 15, 'max_depth': 3}. Best is trial 9 with value: 0.7483976003406434.
# Fold 1 C-index: 0.5
# Fold 2 C-index: 0.5
# Fold 3 C-index: 0.5
# Fold 4 C-index: 0.5
# Fold 5 C-index: 0.5
# [I 2024-04-19 20:53:51,848] Trial 36 finished with value: 0.5 and parameters: {'subsample': 0.7969176327337065, 'learning_rate': 0.02571949043074776, 'dropout_rate': 0.14643759904477674, 'n_estimators': 437, 'criterion': 'squared_error', 'ccp_alpha': 0.48997012949363994, 'min_weight_fraction_leaf': 0.2382235703018389, 'max_features': 'auto', 'min_impurity_decrease': 2.2723634470889422e-07, 'validation_fraction': 0.6516623501512859, 'min_samples_split': 12, 'max_leaf_nodes': 14, 'min_samples_leaf': 18, 'max_depth': 18}. Best is trial 9 with value: 0.7483976003406434.
# Fold 1 C-index: 0.5
# Fold 2 C-index: 0.5
# Fold 3 C-index: 0.5
# Fold 4 C-index: 0.5
# Fold 5 C-index: 0.5
# [I 2024-04-19 20:53:56,233] Trial 37 finished with value: 0.5 and parameters: {'subsample': 0.9918756329516758, 'learning_rate': 0.00951363179460697, 'dropout_rate': 0.7511928761026783, 'n_estimators': 98, 'criterion': 'squared_error', 'ccp_alpha': 3.090891310373169, 'min_weight_fraction_leaf': 0.4368222726762345, 'max_features': None, 'min_impurity_decrease': 6.512646857242401e-06, 'validation_fraction': 0.7869508417751669, 'min_samples_split': 9, 'max_leaf_nodes': 12, 'min_samples_leaf': 13, 'max_depth': 5}. Best is trial 9 with value: 0.7483976003406434.
# Fold 1 C-index: 0.5
# Fold 2 C-index: 0.5
# Fold 3 C-index: 0.5
# Fold 4 C-index: 0.5
# Fold 5 C-index: 0.5
# [I 2024-04-19 20:54:53,550] Trial 38 finished with value: 0.5 and parameters: {'subsample': 0.6539493205119853, 'learning_rate': 0.020515226007100745, 'dropout_rate': 0.4076069474884072, 'n_estimators': 305, 'criterion': 'friedman_mse', 'ccp_alpha': 4.262315932175718, 'min_weight_fraction_leaf': 0.2917882999283137, 'max_features': 'auto', 'min_impurity_decrease': 1.0494748289619345e-07, 'validation_fraction': 0.012692984164186849, 'min_samples_split': 5, 'max_leaf_nodes': 10, 'min_samples_leaf': 2, 'max_depth': 2}. Best is trial 9 with value: 0.7483976003406434.
# Fold 1 C-index: 0.5
# Fold 2 C-index: 0.5
# Fold 3 C-index: 0.5
# Fold 4 C-index: 0.5
# Fold 5 C-index: 0.5
# [I 2024-04-19 20:56:18,871] Trial 39 finished with value: 0.5 and parameters: {'subsample': 0.9054539953742826, 'learning_rate': 0.008896528916563095, 'dropout_rate': 0.19989910804141944, 'n_estimators': 341, 'criterion': 'squared_error', 'ccp_alpha': 1.1534181050612955, 'min_weight_fraction_leaf': 0.49878571807534433, 'max_features': 1, 'min_impurity_decrease': 7.705817626656289e-07, 'validation_fraction': 0.9432676198570591, 'min_samples_split': 17, 'max_leaf_nodes': 7, 'min_samples_leaf': 15, 'max_depth': 7}. Best is trial 9 with value: 0.7483976003406434.
# Fold 1 C-index: 0.5
# Fold 2 C-index: 0.5
# Fold 3 C-index: 0.5
# Fold 4 C-index: 0.5
# Fold 5 C-index: 0.5
# [I 2024-04-19 20:58:37,613] Trial 40 finished with value: 0.5 and parameters: {'subsample': 0.6882525064531181, 'learning_rate': 0.03063064644312167, 'dropout_rate': 0.32312131703374025, 'n_estimators': 477, 'criterion': 'squared_error', 'ccp_alpha': 0.5303400047432362, 'min_weight_fraction_leaf': 0.07781604608486586, 'max_features': 'auto', 'min_impurity_decrease': 3.430163547552312e-05, 'validation_fraction': 0.5293758628752836, 'min_samples_split': 11, 'max_leaf_nodes': 2, 'min_samples_leaf': 9, 'max_depth': 4}. Best is trial 9 with value: 0.7483976003406434.
# Fold 1 C-index: 0.6753246753246753
# Fold 2 C-index: 0.6004464285714286
# Fold 3 C-index: 0.7205882352941176
# Fold 4 C-index: 0.7637130801687764
# Fold 5 C-index: 0.
 'max_leaf_nodes': 14, 'min_samples_leaf': 12, 'max_depth': 4}. Best is trial 9 with value: 0.7483976003406434.
# Fold 1 C-index: 0.5
# Fold 2 C-index: 0.5
# Fold 3 C-index: 0.5
# Fold 4 C-index: 0.5
# Fold 5 C-index: 0.5
# [I 2024-04-19 21:06:51,716] Trial 56 finished with value: 0.5 and parameters: {'subsample': 0.72294472419416, 'learning_rate': 0.030529655796453406, 'dropout_rate': 0.1042670173421051, 'n_estimators': 484, 'criterion': 'squared_error', 'ccp_alpha': 1.0260576154507228, 'min_weight_fraction_leaf': 0.26869875361297285, 'max_features': 1, 'min_impurity_decrease': 1.0882152569265186e-06, 'validation_fraction': 0.9043438819355977, 'min_samples_split': 18, 'max_leaf_nodes': 16, 'min_samples_leaf': 9, 'max_depth': 5}. Best is trial 9 with value: 0.7483976003406434.
# Fold 1 C-index: 0.5
# Fold 2 C-index: 0.5
# Fold 3 C-index: 0.5
# Fold 4 C-index: 0.5
# Fold 5 C-index: 0.5
# [I 2024-04-19 21:07:02,747] Trial 57 finished with value: 0.5 and parameters: {'subsample': 0.781561535505851, 'learning_rate': 0.019599111388603693, 'dropout_rate': 0.28746581622574, 'n_estimators': 118, 'criterion': 'squared_error', 'ccp_alpha': 1.6775249385492055, 'min_weight_fraction_leaf': 0.4147367845229429, 'max_features': 'auto', 'min_impurity_decrease': 5.608534822955176e-07, 'validation_fraction': 0.5838562151808616, 'min_samples_split': 9, 'max_leaf_nodes': 14, 'min_samples_leaf': 13, 'max_depth': 3}. Best is trial 9 with value: 0.7483976003406434.
# Fold 1 C-index: 0.5
# Fold 2 C-index: 0.5
# Fold 3 C-index: 0.5
# Fold 4 C-index: 0.5
# Fold 5 C-index: 0.5
# [I 2024-04-19 21:07:23,505] Trial 58 finished with value: 0.5 and parameters: {'subsample': 0.4443705051573945, 'learning_rate': 0.04030629833839253, 'dropout_rate': 0.24216293738207553, 'n_estimators': 164, 'criterion': 'squared_error', 'ccp_alpha': 0.7497240498249881, 'min_weight_fraction_leaf': 0.33754637584813874, 'max_features': 0.1, 'min_impurity_decrease': 3.445912059389303e-07, 'validation_fraction': 0.7729698485030033, 'min_samples_split': 16, 'max_leaf_nodes': 17, 'min_samples_leaf': 11, 'max_depth': 7}. Best is trial 9 with value: 0.7483976003406434.
# Fold 1 C-index: 0.5
# Fold 2 C-index: 0.5
# Fold 3 C-index: 0.5
# Fold 4 C-index: 0.5
# Fold 5 C-index: 0.5
# [I 2024-04-19 21:09:58,252] Trial 59 finished with value: 0.5 and parameters: {'subsample': 0.9301898151121387, 'learning_rate': 0.014811565508437466, 'dropout_rate': 0.1837704285299646, 'n_estimators': 456, 'criterion': 'squared_error', 'ccp_alpha': 8.343149270456218, 'min_weight_fraction_leaf': 0.302647558909275, 'max_features': 'log2', 'min_impurity_decrease': 4.132096543200702e-07, 'validation_fraction': 0.9254022058214465, 'min_samples_split': 19, 'max_leaf_nodes': 11, 'min_samples_leaf': 12, 'max_depth': 6}. Best is trial 9 with value: 0.7483976003406434.
# Fold 1 C-index: 0.5
# Fold 2 C-index: 0.5
# Fold 3 C-index: 0.5
# Fold 4 C-index: 0.5
# Fold 5 C-index: 0.5
# [I 2024-04-19 21:10:52,986] Trial 60 finished with value: 0.5 and parameters: {'subsample': 0.2779429418662181, 'learning_rate': 0.005013007250233982, 'dropout_rate': 0.14183557134552166, 'n_estimators': 261, 'criterion': 'squared_error', 'ccp_alpha': 1.322729891908786, 'min_weight_fraction_leaf': 0.2834981878637842, 'max_features': 'auto', 'min_impurity_decrease': 1.9418303906939395e-06, 'validation_fraction': 0.8435510786021796, 'min_samples_split': 17, 'max_leaf_nodes': 16, 'min_samples_leaf': 7, 'max_depth': 1}. Best is trial 9 with value: 0.7483976003406434.
# Fold 1 C-index: 0.5
# Fold 2 C-index: 0.5
# Fold 3 C-index: 0.5
# Fold 4 C-index: 0.5
# Fold 5 C-index: 0.5
# [I 2024-04-19 21:10:57,763] Trial 61 finished with value: 0.5 and parameters: {'subsample': 0.953217517548262, 'learning_rate': 0.009978939472425662, 'dropout_rate': 0.2238557425834033, 'n_estimators': 70, 'criterion': 'squared_error', 'ccp_alpha': 0.20542807578152888, 'min_weight_fraction_leaf': 0.4432436454062534, 'max_features': 'auto', 'min_impurity_decrease': 1.92080140518381e-07, 'validation_fraction': 0.9540853929856796, 'min_samples_split': 20, 'max_leaf_nodes': 19, 'min_samples_leaf': 14, 'max_depth': 2}. Best is trial 9 with value: 0.7483976003406434.
# Fold 1 C-index: 0.6753246753246753
# Fold 2 C-index: 0.6004464285714286
# Fold 3 C-index: 0.7794117647058824
# Fold 4 C-index: 0.7637130801687764
# Fold 5 C-index: 0.6103286384976526
# [I 2024-04-19 21:11:23,467] Trial 62 finished with value: 0.685844917453683 and parameters: {'subsample': 0.9949849995633986, 'learning_rate': 0.00590733686751327, 'dropout_rate': 0.15426665038628304, 'n_estimators': 175, 'criterion': 'squared_error', 'ccp_alpha': 0.022717462020606087, 'min_weight_fraction_leaf': 0.3771525913161122, 'max_features': 'auto', 'min_impurity_decrease': 1.6541961435697376e-07, 'validation_fraction': 0.998924391459097, 'min_samples_split': 20, 'max_leaf_nodes': 15, 'min_samples_leaf': 16, 'max_depth': 2}. Best is trial 9 with value: 0.7483976003406434.
# Fold 1 C-index: 0.6753246753246753
# Fold 2 C-index: 0.6964285714285714
# Fold 3 C-index: 0.7794117647058824
# Fold 4 C-index: 0.8059071729957806
# Fold 5 C-index: 0.6197183098591549
# [I 2024-04-19 21:11:27,228] Trial 63 finished with value: 0.715358098862813 and parameters: {'subsample': 0.8686583129899306, 'learning_rate': 0.001290161829137394, 'dropout_rate': 0.1898785022640528, 'n_estimators': 58, 'criterion': 'squared_error', 'ccp_alpha': 0.018078806214999348, 'min_weight_fraction_leaf': 0.3861329521141052, 'max_features': 'auto', 'min_impurity_decrease': 8.327527140717665e-07, 'validation_fraction': 0.932887892507485, 'min_samples_split': 18, 'max_leaf_nodes': 15, 'min_samples_leaf': 15, 'max_depth': 1}. Best is trial 9 with value: 0.7483976003406434.
# Fold 1 C-index: 0.5
# Fold 2 C-index: 0.5
# Fold 3 C-index: 0.5
# Fold 4 C-index: 0.5
# Fold 5 C-index: 0.5
# [I 2024-04-19 21:11:33,959] Trial 64 finished with value: 0.5 and parameters: {'subsample': 0.8645070165323501, 'learning_rate': 0.09405807235270042, 'dropout_rate': 0.18802779859574847, 'n_estimators': 85, 'criterion': 'squared_error', 'ccp_alpha': 0.7050476759364486, 'min_weight_fraction_leaf': 0.35251200695718055, 'max_features': 'auto', 'min_impurity_decrease': 9.420976138154327e-07, 'validation_fraction': 0.9231276840562984, 'min_samples_split': 18, 'max_leaf_nodes': 13, 'min_samples_leaf': 18, 'max_depth': 4}. Best is trial 9 with value: 0.7483976003406434.
# Fold 1 C-index: 0.5
# Fold 2 C-index: 0.5
# Fold 3 C-index: 0.5
# Fold 4 C-index: 0.5
# Fold 5 C-index: 0.5
# [I 2024-04-19 21:11:45,810] Trial 65 finished with value: 0.5 and parameters: {'subsample': 0.903563418868777, 'learning_rate': 0.0016217786521075337, 'dropout_rate': 0.27304642297183634, 'n_estimators': 121, 'criterion': 'squared_error', 'ccp_alpha': 0.35075027656676333, 'min_weight_fraction_leaf': 0.46836556984836597, 'max_features': 'auto', 'min_impurity_decrease': 0.00018567504305581884, 'validation_fraction': 0.8837902558696593, 'min_samples_split': 19, 'max_leaf_nodes': 16, 'min_samples_leaf': 17, 'max_depth': 1}. Best is trial 9 with value: 0.7483976003406434.
# Fold 1 C-index: 0.5
# Fold 2 C-index: 0.5
# Fold 3 C-index: 0.5
# Fold 4 C-index: 0.5
# Fold 5 C-index: 0.5
# [I 2024-04-19 21:14:51,490] Trial 66 finished with value: 0.5 and parameters: {'subsample': 0.8164719060956207, 'learning_rate': 0.012803396580721372, 'dropout_rate': 0.13161439171907266, 'n_estimators': 489, 'criterion': 'squared_error', 'ccp_alpha': 0.8927340743616367, 'min_weight_fraction_leaf': 0.24360172036034505, 'max_features': 'sqrt', 'min_impurity_decrease': 5.724092120969544e-07, 'validation_fraction': 0.9783741103646215, 'min_samples_split': 18, 'max_leaf_nodes': 17, 'min_samples_leaf': 14, 'max_depth': 3}. Best is trial 9 with value: 0.7483976003406434.
# Fold 1 C-index: 0.5
# Fold 2 C-index: 0.5
# Fold 3 C-index: 0.5
# Fold 4 C-index: 0.5
# Fold 5 C-index: 0.5
# [I 2024-04-19 21:14:53,575] Trial 67 finished with value: 0.5 and parameters: {'subsample': 0.8652614464897083, 'learning_rate': 0.017792589526001042, 'dropout_rate': 0.4308859881762669, 'n_estimators': 45, 'criterion': 'friedman_mse', 'ccp_alpha': 2.352310671798754, 'min_weight_fraction_leaf': 0.4527437444308926, 'max_features': 'auto', 'min_impurity_decrease': 3.132340488371029e-07, 'validation_fraction': 0.6922946122950581, 'min_samples_split': 16, 'max_leaf_nodes': 14, 'min_samples_leaf': 12, 'max_depth': 1}. Best is trial 9 with value: 0.7483976003406434.
# Fold 1 C-index: 0.6753246753246753
# Fold 2 C-index: 0.7366071428571429
# Fold 3 C-index: 0.7328431372549019
# Fold 4 C-index: 0.5
# Fold 5 C-index: 0.5
# [I 2024-04-19 21:15:34,963] Trial 68 finished with value: 0.6289549910873441 and parameters: {'subsample': 0.1828808967076968, 'learning_rate': 0.009763210879301733, 'dropout_rate': 0.227818798660288, 'n_estimators': 235, 'criterion': 'squared_error', 'ccp_alpha': 0.29598676708348526, 'min_weight_fraction_leaf': 0.4165856705288462, 'max_features': 'auto', 'min_impurity_decrease': 1.2512174866550223e-06, 'validation_fraction': 0.4611449164937295, 'min_samples_split': 19, 'max_leaf_nodes': 18, 'min_samples_leaf': 10, 'max_depth': 3}. Best is trial 9 with value: 0.7483976003406434.
# Fold 1 C-index: 0.5
# Fold 2 C-index: 0.5
# Fold 3 C-index: 0.5
# Fold 4 C-index: 0.5
# Fold 5 C-index: 0.5
# [I 2024-04-19 21:15:38,195] Trial 69 finished with value: 0.5 and parameters: {'subsample': 0.7498611166680669, 'learning_rate': 0.04820609879441119, 'dropout_rate': 0.32090257654334975, 'n_estimators': 56, 'criterion': 'squared_error', 'ccp_alpha': 0.7413034944146035, 'min_weight_fraction_leaf': 0.18420157386134117, 'max_features': None, 'min_impurity_decrease': 2.3700234556978203e-06, 'validation_fraction': 0.8668588900403627, 'min_samples_split': 20, 'max_leaf_nodes': 20, 'min_samples_leaf': 16, 'max_depth': 2}. Best is trial 9 with value: 0.7483976003406434.
# ...
# Fold 5 IBS: 0.21794236296813735
# [I 2024-04-19 22:26:55,635] Trial 81 finished with value: 0.21602998017301278 and parameters: {'subsample': 0.9579178853393634, 'learning_rate': 0.006802404808842085, 'dropout_rate': 0.2523609841831704, 'n_estimators': 466, 'criterion': 'squared_error', 'ccp_alpha': 0.02552688345155017, 'min_weight_fraction_leaf': 0.2563778007434269, 'max_features': 'auto', 'min_impurity_decrease': 1.475357902881004e-06, 'validation_fraction': 0.9513185761421921, 'min_samples_split': 20, 'max_leaf_nodes': 20, 'min_samples_leaf': 16, 'max_depth': 2}. Best is trial 64 with value: 0.21534529367183214.
# Fold 1 IBS: 0.2128978914565675
# Fold 2 IBS: 0.22130024752158883
# Fold 3 IBS: 0.20349938547270316
# Fold 4 IBS: 0.22340751310345847
# Fold 5 IBS: 0.2178843745343965
# [I 2024-04-19 22:27:41,302] Trial 82 finished with value: 0.2157978824177429 and parameters: {'subsample': 0.9489306245007673, 'learning_rate': 0.009537962827339893, 'dropout_rate': 0.24835205265056934, 'n_estimators': 433, 'criterion': 'squared_error', 'ccp_alpha': 0.01786403260693046, 'min_weight_fraction_leaf': 0.25238532068511227, 'max_features': 'auto', 'min_impurity_decrease': 3.678228764913404e-07, 'validation_fraction': 0.8437068592458034, 'min_samples_split': 20, 'max_leaf_nodes': 20, 'min_samples_leaf': 16, 'max_depth': 3}. Best is trial 64 with value: 0.21534529367183214.
# Fold 1 IBS: 0.21397652195149613
# Fold 2 IBS: 0.22157791718667938
# Fold 3 IBS: 0.20453594732018135
# Fold 4 IBS: 0.2247380413976268
# Fold 5 IBS: 0.21812431525609582
# [I 2024-04-19 22:28:29,130] Trial 83 finished with value: 0.21659054862241586 and parameters: {'subsample': 0.8909479551758591, 'learning_rate': 0.008698584299413689, 'dropout_rate': 0.19603029206268366, 'n_estimators': 431, 'criterion': 'squared_error', 'ccp_alpha': 0.42128028941162715, 'min_weight_fraction_leaf': 0.2701739605759479, 'max_features': 'auto', 'min_impurity_decrease': 3.391910324173177e-07, 'validation_fraction': 0.840128049836426, 'min_samples_split': 8, 'max_leaf_nodes': 20, 'min_samples_leaf': 19, 'max_depth': 3}. Best is trial 64 with value: 0.21534529367183214.
# Fold 1 IBS: 0.21397652195149613
# Fold 2 IBS: 0.2215774545526113
# Fold 3 IBS: 0.20453448768184096
# Fold 4 IBS: 0.2247380413976268
# Fold 5 IBS: 0.21812461605629674
# [I 2024-04-19 22:28:57,282] Trial 84 finished with value: 0.2165902243279744 and parameters: {'subsample': 0.411624430892823, 'learning_rate': 0.013253369992371197, 'dropout_rate': 0.6818395627907664, 'n_estimators': 492, 'criterion': 'squared_error', 'ccp_alpha': 0.262145494050454, 'min_weight_fraction_leaf': 0.2241886442071409, 'max_features': 'auto', 'min_impurity_decrease': 1.4746211325351277e-07, 'validation_fraction': 0.8721184166614867, 'min_samples_split': 19, 'max_leaf_nodes': 19, 'min_samples_leaf': 18, 'max_depth': 6}. Best is trial 64 with value: 0.21534529367183214.
# Fold 1 IBS: 0.21397652195149613
# Fold 2 IBS: 0.22157791718667935
# Fold 3 IBS: 0.20453594732018132
# Fold 4 IBS: 0.22473804139762676
# Fold 5 IBS: 0.21812431525609557
# [I 2024-04-19 22:29:40,744] Trial 85 finished with value: 0.21659054862241583 and parameters: {'subsample': 0.9383822999446213, 'learning_rate': 0.004428584874362775, 'dropout_rate': 0.31165883881469014, 'n_estimators': 439, 'criterion': 'squared_error', 'ccp_alpha': 0.9670160633661875, 'min_weight_fraction_leaf': 0.20250430497823585, 'max_features': 'auto', 'min_impurity_decrease': 2.429626863306918e-07, 'validation_fraction': 0.9063310436430493, 'min_samples_split': 11, 'max_leaf_nodes': 18, 'min_samples_leaf': 10, 'max_depth': 4}. Best is trial 64 with value: 0.21534529367183214.
# Fold 1 IBS: 0.21397652195149613
# Fold 2 IBS: 0.22157791718667938
# Fold 3 IBS: 0.20453594732018138
# Fold 4 IBS: 0.22473804139762676
# Fold 5 IBS: 0.21812431525609582
# [I 2024-04-19 22:30:15,424] Trial 86 finished with value: 0.21659054862241592 and parameters: {'subsample': 0.977350105743944, 'learning_rate': 0.03629425342023726, 'dropout_rate': 0.23799870869674608, 'n_estimators': 373, 'criterion': 'squared_error', 'ccp_alpha': 0.6167289216517252, 'min_weight_fraction_leaf': 0.17880882745231644, 'max_features': 'sqrt', 'min_impurity_decrease': 4.288209257735315e-07, 'validation_fraction': 0.6826441761790084, 'min_samples_split': 4, 'max_leaf_nodes': 19, 'min_samples_leaf': 16, 'max_depth': 2}. Best is trial 64 with value: 0.21534529367183214.
# Fold 1 IBS: 0.21397652195149613
# Fold 2 IBS: 0.22157791718667938
# Fold 3 IBS: 0.20453594732018138
# Fold 4 IBS: 0.22473804139762676
# Fold 5 IBS: 0.21812431525609566
# [I 2024-04-19 22:30:32,765] Trial 87 finished with value: 0.21659054862241586 and parameters: {'subsample': 0.9170197609712742, 'learning_rate': 0.010398408890295672, 'dropout_rate': 0.28818253710899827, 'n_estimators': 266, 'criterion': 'squared_error', 'ccp_alpha': 0.2360731219383721, 'min_weight_fraction_leaf': 0.08564634548645714, 'max_features': 'auto', 'min_impurity_decrease': 9.04473503463962e-07, 'validation_fraction': 0.46137820435469984, 'min_samples_split': 10, 'max_leaf_nodes': 18, 'min_samples_leaf': 17, 'max_depth': 3}. Best is trial 64 with value: 0.21534529367183214.
# Fold 1 IBS: 0.21397652195149616
# Fold 2 IBS: 0.22157791718667935
# Fold 3 IBS: 0.20453594732018135
# Fold 4 IBS: 0.2247380413976268
# Fold 5 IBS: 0.21812431525609582
# [I 2024-04-19 22:31:15,767] Trial 88 finished with value: 0.21659054862241586 and parameters: {'subsample': 0.7762725560789899, 'learning_rate': 0.01892201466815226, 'dropout_rate': 0.17679523101040587, 'n_estimators': 407, 'criterion': 'squared_error', 'ccp_alpha': 1.3457840140168202, 'min_weight_fraction_leaf': 0.026102976372990007, 'max_features': 0.1, 'min_impurity_decrease': 1.670779640182278e-07, 'validation_fraction': 0.9785089071587038, 'min_samples_split': 16, 'max_leaf_nodes': 20, 'min_samples_leaf': 15, 'max_depth': 5}. Best is trial 64 with value: 0.21534529367183214.
# Fold 1 IBS: 0.21397652195149616
# Fold 2 IBS: 0.22157791718667938
# Fold 3 IBS: 0.20453594732018135
# Fold 4 IBS: 0.2247380413976268
# Fold 5 IBS: 0.2181243152560957
# [I 2024-04-19 22:31:49,923] Trial 89 finished with value: 0.21659054862241586 and parameters: {'subsample': 0.8566436667378682, 'learning_rate': 0.015358704013366007, 'dropout_rate': 0.5090990897137027, 'n_estimators': 455, 'criterion': 'squared_error', 'ccp_alpha': 1.5765552790097783, 'min_weight_fraction_leaf': 0.32660393012969136, 'max_features': 'auto', 'min_impurity_decrease': 0.0002510369481096692, 'validation_fraction': 0.8757107738634061, 'min_samples_split': 12, 'max_leaf_nodes': 17, 'min_samples_leaf': 14, 'max_depth': 1}. Best is trial 64 with value: 0.21534529367183214.
# Fold 1 IBS: 0.21397652195149616
# Fold 2 IBS: 0.22157791718667938
# Fold 3 IBS: 0.20453594732018135
# Fold 4 IBS: 0.22473804139762676
# Fold 5 IBS: 0.2181243152560957
# [I 2024-04-19 22:32:46,609] Trial 90 finished with value: 0.21659054862241586 and parameters: {'subsample': 0.3053150575440778, 'learning_rate': 0.023776989936818642, 'dropout_rate': 0.2211659220380504, 'n_estimators': 476, 'criterion': 'squared_error', 'ccp_alpha': 5.0331221171402944, 'min_weight_fraction_leaf': 0.23590851864115261, 'max_features': 'auto', 'min_impurity_decrease': 6.014966438611826e-07, 'validation_fraction': 0.8108160232539862, 'min_samples_split': 19, 'max_leaf_nodes': 19, 'min_samples_leaf': 7, 'max_depth': 4}. Best is trial 64 with value: 0.21534529367183214.
# Fold 1 IBS: 0.21317714686984474
# Fold 2 IBS: 0.22137085046754393
# Fold 3 IBS: 0.20376981700554747
# Fold 4 IBS: 0.22375282828731824
# Fold 5 IBS: 0.21793917865809317
# [I 2024-04-19 22:33:37,517] Trial 91 finished with value: 0.21600196425766952 and parameters: {'subsample': 0.9507142228314903, 'learning_rate': 0.007241139952955489, 'dropout_rate': 0.2545202950399433, 'n_estimators': 465, 'criterion': 'squared_error', 'ccp_alpha': 0.037605992845398076, 'min_weight_fraction_leaf': 0.2530417506759593, 'max_features': 'auto', 'min_impurity_decrease': 0.0009910717111428719, 'validation_fraction': 0.9441656625516887, 'min_samples_split': 20, 'max_leaf_nodes': 20, 'min_samples_leaf': 16, 'max_depth': 2}. Best is trial 64 with value: 0.21534529367183214.
# Fold 1 IBS: 0.21397652195149613
# Fold 2 IBS: 0.22157791718667938
# Fold 3 IBS: 0.20453594732018138
# Fold 4 IBS: 0.22473804139762676
# Fold 5 IBS: 0.21812431525609563
# [I 2024-04-19 22:34:21,767] Trial 92 finished with value: 0.21659054862241586 and parameters: {'subsample': 0.5328328014893517, 'learning_rate': 0.008355415464780407, 'dropout_rate': 0.3358781097044133, 'n_estimators': 450, 'criterion': 'squared_error', 'ccp_alpha': 0.6060790594568926, 'min_weight_fraction_leaf': 0.2547447580026079, 'max_features': 'auto', 'min_impurity_decrease': 0.005772421697347885, 'validation_fraction': 0.9761923045843292, 'min_samples_split': 20, 'max_leaf_nodes': 20, 'min_samples_leaf': 18, 'max_depth': 2}. Best is trial 64 with value: 0.21534529367183214.
# Fold 1 IBS: 0.21368037516567145
# Fold 2 IBS: 0.22150088453361605
# Fold 3 IBS: 0.204239890519218
# Fold 4 IBS: 0.22437491812535867
# Fold 5 IBS: 0.21805707006429398
# [I 2024-04-19 22:35:19,078] Trial 93 finished with value: 0.21637062768163165 and parameters: {'subsample': 0.985469912366224, 'learning_rate': 0.0026733232082094757, 'dropout_rate': 0.2555494460557131, 'n_estimators': 494, 'criterion': 'squared_error', 'ccp_alpha': 0.0468994669584406, 'min_weight_fraction_leaf': 0.35084867155938515, 'max_features': 'auto', 'min_impurity_decrease': 0.038054394076187645, 'validation_fraction': 0.9108508896652943, 'min_samples_split': 18, 'max_leaf_nodes': 19, 'min_samples_leaf': 17, 'max_depth': 17}. Best is trial 64 with value: 0.21534529367183214.
# Fold 1 IBS: 0.21397652195149616
# Fold 2 IBS: 0.22157791718667938
# Fold 3 IBS: 0.20453594732018135
# Fold 4 IBS: 0.2247380413976268
# Fold 5 IBS: 0.21812431525609563
# [I 2024-04-19 22:35:54,316] Trial 94 finished with value: 0.21659054862241586 and parameters: {'subsample': 0.8769527409943936, 'learning_rate': 0.011407958024775846, 'dropout_rate': 0.3807313546610083, 'n_estimators': 418, 'criterion': 'squared_error', 'ccp_alpha': 0.43911457703007306, 'min_weight_fraction_leaf': 0.29029834445265057, 'max_features': None, 'min_impurity_decrease': 0.0015502959014071815, 'validation_fraction': 0.9420817998227241, 'min_samples_split': 20, 'max_leaf_nodes': 20, 'min_samples_leaf': 16, 'max_depth': 19}. Best is trial 64 with value: 0.21534529367183214.
# Fold 1 IBS: 0.21397652195149613
# Fold 2 IBS: 0.22157791718667938
# Fold 3 IBS: 0.20453594732018132
# Fold 4 IBS: 0.2247380413976268
# Fold 5 IBS: 0.21812431525609566
# [I 2024-04-19 22:36:42,854] Trial 95 finished with value: 0.21659054862241583 and parameters: {'subsample': 0.950546738122462, 'learning_rate': 0.0056488981484495914, 'dropout_rate': 0.1994368878376317, 'n_estimators': 433, 'criterion': 'squared_error', 'ccp_alpha': 0.9667788649271946, 'min_weight_fraction_leaf': 0.27370655050516296, 'max_features': 'auto', 'min_impurity_decrease': 0.0014191640573658591, 'validation_fraction': 0.8419785232408533, 'min_samples_split': 19, 'max_leaf_nodes': 19, 'min_samples_leaf': 15, 'max_depth': 3}. Best is trial 64 with value: 0.21534529367183214.
# Fold 1 IBS: 0.21397652195149613
# Fold 2 IBS: 0.22157791718667938
# Fold 3 IBS: 0.20453594732018135
# Fold 4 IBS: 0.2247380413976268
# Fold 5 IBS: 0.21812431525609566
# [I 2024-04-19 22:37:19,282] Trial 96 finished with value: 0.21659054862241583 and parameters: {'subsample': 0.9093479894471503, 'learning_rate': 0.01201648482675106, 'dropout_rate': 0.27495368719691143, 'n_estimators': 395, 'criterion': 'friedman_mse', 'ccp_alpha': 0.21195644213399334, 'min_weight_fraction_leaf': 0.3146087285283485, 'max_features': 'auto', 'min_impurity_decrease': 3.7692898074829784e-07, 'validation_fraction': 0.8900721460788676, 'min_samples_split': 17, 'max_leaf_nodes': 18, 'min_samples_leaf': 17, 'max_depth': 16}. Best is trial 64 with value: 0.21534529367183214.
# Fold 1 IBS: 0.21397652195149613
# Fold 2 IBS: 0.22157791718667938
# Fold 3 IBS: 0.20453594732018135
# Fold 4 IBS: 0.2247380413976268
# Fold 5 IBS: 0.21812431525609563
# [I 2024-04-19 22:38:15,397] Trial 97 finished with value: 0.21659054862241583 and parameters: {'subsample': 0.9305670119729215, 'learning_rate': 0.01611575855497043, 'dropout_rate': 0.23209927256512322, 'n_estimators': 480, 'criterion': 'squared_error', 'ccp_alpha': 0.6306125569094019, 'min_weight_fraction_leaf': 0.20617498897572903, 'max_features': 0.1, 'min_impurity_decrease': 0.0030083540287240158, 'validation_fraction': 0.9962791477505377, 'min_samples_split': 20, 'max_leaf_nodes': 20, 'min_samples_leaf': 18, 'max_depth': 1}. Best is trial 64 with value: 0.21534529367183214.
# Fold 1 IBS: 0.21397652195149616
# Fold 2 IBS: 0.22157791718667938
# Fold 3 IBS: 0.20453594732018138
# Fold 4 IBS: 0.22473804139762676
# Fold 5 IBS: 0.21812431525609566
# [I 2024-04-19 22:39:14,608] Trial 98 finished with value: 0.21659054862241586 and parameters: {'subsample': 0.6177124108403683, 'learning_rate': 0.008065099839499686, 'dropout_rate': 0.11590233860021854, 'n_estimators': 456, 'criterion': 'squared_error', 'ccp_alpha': 0.2351987698633502, 'min_weight_fraction_leaf': 0.249289688142755, 'max_features': 1, 'min_impurity_decrease': 9.035981184447585e-06, 'validation_fraction': 0.7662757498554207, 'min_samples_split': 19, 'max_leaf_nodes': 17, 'min_samples_leaf': 12, 'max_depth': 5}. Best is trial 64 with value: 0.21534529367183214.
# Fold 1 IBS: 0.20342944121315945
# Fold 2 IBS: 0.21978752240119506
# Fold 3 IBS: 0.1942164658309045
# Fold 4 IBS: 0.21114252920820517
# Fold 5 IBS: 0.21709877407340555
# [I 2024-04-19 22:40:17,402] Trial 99 finished with value: 0.20913494654537396 and parameters: {'subsample': 0.9990408546535117, 'learning_rate': 0.07301056755099848, 'dropout_rate': 0.1545897918844559, 'n_estimators': 468, 'criterion': 'squared_error', 'ccp_alpha': 0.004422201299274769, 'min_weight_fraction_leaf': 0.2841987960315815, 'max_features': 'auto', 'min_impurity_decrease': 0.00015837847703956763, 'validation_fraction': 0.9402824230130423, 'min_samples_split': 18, 'max_leaf_nodes': 16, 'min_samples_leaf': 16, 'max_depth': 2}. Best is trial 99 with value: 0.20913494654537396.
#
#
# * Best trial for IBS:
#  FrozenTrial(number=99, state=TrialState.COMPLETE, values=[0.20913494654537396], datetime_start=datetime.datetime(2024, 4, 19, 22, 39, 14, 624654), datetime_complete=datetime.datetime(2024, 4, 19, 22, 40, 17, 400958), params={'subsample': 0.9990408546535117, 'learning_rate': 0.07301056755099848, 'dropout_rate': 0.1545897918844559, 'n_estimators': 468, 'criterion': 'squared_error', 'ccp_alpha': 0.004422201299274769, 'min_weight_fraction_leaf': 0.2841987960315815, 'max_features': 'auto', 'min_impurity_decrease': 0.00015837847703956763, 'validation_fraction': 0.9402824230130423, 'min_samples_split': 18, 'max_leaf_nodes': 16, 'min_samples_leaf': 16, 'max_depth': 2}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'subsample': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'learning_rate': FloatDistribution(high=0.1, log=False, low=0.001, step=None), 'dropout_rate': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'n_estimators': IntDistribution(high=500, log=False, low=1, step=1), 'criterion': CategoricalDistribution(choices=('friedman_mse', 'squared_error')), 'ccp_alpha': FloatDistribution(high=10.0, log=False, low=0.0, step=None), 'min_weight_fraction_leaf': FloatDistribution(high=0.5, log=False, low=0.0, step=None), 'max_features': CategoricalDistribution(choices=('auto', 'sqrt', 'log2', None, 0.1, 1)), 'min_impurity_decrease': FloatDistribution(high=0.1, log=True, low=1e-07, step=None), 'validation_fraction': FloatDistribution(high=1.0, log=False, low=0.0, step=None), 'min_samples_split': IntDistribution(high=20, log=False, low=2, step=1), 'max_leaf_nodes': IntDistribution(high=20, log=False, low=2, step=1), 'min_samples_leaf': IntDistribution(high=20, log=False, low=1, step=1), 'max_depth': IntDistribution(high=20, log=False, low=1, step=1)}, trial_id=99, value=None)
#
#
# * Best Score for IBS:
#  0.20913494654537396

# %%
train_cindex['GradientBoosting'] = np.round(study_cindex.best_value, 3)
train_ibs['GradientBoosting'] = np.round(study_ibs.best_value, 3)

# %%
print("train_cindex: ", np.round(study_cindex.best_value, 3))
print("train_ibs: ", np.round(study_ibs.best_value, 3))
# Out:
# train_cindex:  0.748
# train_ibs:  0.209

# %% [markdown]
# #### Test

# %%
# y into array 
lists = [] 
for i, j in zip(y['event_OS'], y['OS']): 
    lists.append((i, j))

y = np.array(lists, dtype=[('status', bool), ('time', np.int32)])

# %%
# A function for building the best model with the best parameters 
def create_best_model(model_class, best_params):
    best_params["random_state"]=123
    return model_class(**best_params)

# Set the best model 
best_model_cindex = create_best_model(GradientBoostingSurvivalAnalysis, study_cindex.best_params)

# Train the best model for C-index on the whole dataset
best_model_cindex.fit(X_new, y)

# Evaluate the best model for C-index on MAASTRO dataset
c_index = best_model_cindex.score(MAASTRO_new, y_MAASTRO)
c_index = np.round(c_index, 3)
print("C-index score:", c_index)

# Set the best model 
best_model_ibs = create_best_model(GradientBoostingSurvivalAnalysis, study_ibs.best_params)

# Train the best model for IBS on the whole dataset
best_model_ibs.fit(X_new, y)

# Evaluate the best model for IBS on MAASTRO dataset
lower, upper = np.percentile(y_MAASTRO["time"], [10, 90])
gbsg_times = np.arange(lower, upper)
surv_prob = np.row_stack([fn(gbsg_times) for fn in best_model_ibs.predict_survival_function(MAASTRO_new)])
ibs = integrated_brier_score(y_MAASTRO, y_MAASTRO, surv_prob, gbsg_times)
ibs = np.round(ibs, 3)
print("IBS:", ibs)
# Out:
# GradientBoostingSurvivalAnalysis(ccp_alpha=0.07426378544613033,
#                                  criterion='squared_error',
#                                  dropout_rate=0.28125955124323376,
#                                  learning_rate=0.013102111413618,
#                                  max_features='auto', max_leaf_nodes=16,
#                                  min_impurity_decrease=1.4994028685178666e-07,
#                                  min_samples_leaf=10,
#                                  min_weight_fraction_leaf=0.27579636299120275,
#                                  n_estimators=406, random_state=123,
#                                  subsample=0.6059965408578151,
#                                  validation_fraction=0.6359003593513561)
# C-index score: 0.649
# GradientBoostingSurvivalAnalysis(ccp_alpha=0.004422201299274769,
#                                  criterion='squared_error',
#                                  dropout_rate=0.1545897918844559,
#                                  learning_rate=0.07301056755099848, max_depth=2,
#                                  max_features='auto', max_leaf_nodes=16,
#                                  min_impurity_decrease=0.00015837847703956763,
#                                  min_samples_leaf=16, min_samples_split=18,
#                                  min_weight_fraction_leaf=0.2841987960315815,
#                                  n_estimators=468, random_state=123,
#                                  subsample=0.9990408546535117,
#                                  validation_fraction=0.9402824230130423)
# IBS: 0.213

# %%
# Saving the values to the dictionary 
test_cindex['GradientBoosting'] = c_index
test_ibs['GradientBoosting'] = ibs

# %% [markdown]
# ### 8. ComponentwiseGradientBoostingSurvivalAnalysis

# %% [markdown]
# #### Train

# %%
# Setting the y format 
y = clinical_train[['OS', 'event_OS']]

def create_objective(model_class, metric, X, y):
    def objective(trial): 
        # Suggest values for hyperparameters
        subsample = trial.suggest_float("subsample", 0.1, 1)
        dropout_rate = trial.suggest_float("dropout_rate", 0.1, 1)
        n_estimators = trial.suggest_int("n_estimators", 1, 500)
        learning_rate = trial.suggest_float("learning_rate", 0.001, 0.1)
        
        # Create and fit survival model 
        model = model_class(subsample=subsample,
                            dropout_rate=dropout_rate,
                            n_estimators=n_estimators,
                            learning_rate=learning_rate,
                            random_state=123)
                
        scores = [] 
        
        skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=123)
        
        for k, (train_index, test_index) in enumerate(skf.split(X, y.iloc[:, 1])): 
            X_train, X_test = X.iloc[train_index], X.iloc[test_index]
            y_train_df, y_test_df = y.iloc[train_index], y.iloc[test_index]
            
            # y_train into array 
            y_train = [] 
            for i, j in zip(y_train_df['event_OS'], y_train_df['OS']): 
                y_train.append((i, j))
            y_train = np.array(y_train, dtype=[('status', bool), ('time', np.int32)])

            # y_test into array
            y_test = [] 
            for i, j in zip(y_test_df['event_OS'], y_test_df['OS']): 
                y_test.append((i, j))
            y_test = np.array(y_test, dtype=[('status', bool), ('time', np.int32)])

            # Min Max Standardization
            excluded_columns = ['female', 
                                'cavum_oris',
                                'oropharynx',
                                'hypopharynx',
                                'larynx',
                                'histgrade_high',
                                'hpv_related',
                                'charlson',
                                'uicc8_III-IV'
                               ]
            excluded_columns = set(excluded_columns).intersection(X.columns)

            scaler = MinMaxScaler() 
            X_train_included = X_train.drop(excluded_columns, axis=1)
            X_test_included = X_test.drop(excluded_columns, axis=1)
                        
            if not X_train_included.empty and not X_test_included.empty:
                X_train_included_std = scaler.fit_transform(X_train_included)
                X_test_included_std = scaler.transform(X_test_included)
                
                # Concatenation
                X_train_std_df = pd.DataFrame(X_train_included_std, columns=X_train_included.columns, index=X_train_included.index)
                X_train_std = pd.concat([X_train_std_df, X_train[excluded_columns]], axis=1)

                X_test_std_df = pd.DataFrame(X_test_included_std, columns=X_test_included.columns, index=X_test_included.index)
                X_test_std = pd.concat([X_test_std_df, X_test[excluded_columns]], axis=1)
            
            else: 
                X_train_std = X_train
                X_test_std = X_test 
            
            model.fit(X_train_std, y_train)

            if metric == "c-index":
                # Make predictions using C-index 
                c_index_score = model.score(X_test_std, y_test)
                scores.append(c_index_score)
                print(f"Fold {k + 1} C-index: {c_index_score}")
                
            elif metric == "ibs":
                # Make predictions using IBS 
                lower, upper = np.percentile(y_test["time"], [10, 90])    
                gbsg_times = np.arange(lower, upper)
                surv_prob = np.row_stack([fn(gbsg_times) for fn in model.predict_survival_function(X_test_std)])
                ibs = integrated_brier_score(y_test, y_test, surv_prob, gbsg_times)
                scores.append(ibs)
                print(f"Fold {k + 1} IBS: {ibs}")
            else:
                raise ValueError("Invalid metric. Use 'C-index' or 'ibs'.")
        
        # Return the mean of scores
        return np.mean(scores)
    
    return objective


# C-index
study_cindex = optuna.create_study(direction="maximize", sampler=optuna.samplers.TPESampler(seed=123))
objective_cindex = create_objective(ComponentwiseGradientBoostingSurvivalAnalysis, "c-index", X_new, y)
study_cindex.optimize(objective_cindex, n_trials=100, show_progress_bar=True)
print("\n")
print("* Best trial for C-index: \n", study_cindex.best_trial)
print("\n")
print("* Best hyperparameters for C-index: \n", study_cindex.best_params)
print("\n")
print("* Best Score for C-index: \n", study_cindex.best_value)

# IBS
study_ibs = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(seed=123))
objective_ibs = create_objective(ComponentwiseGradientBoostingSurvivalAnalysis, "ibs", X_new, y)
study_ibs.optimize(objective_ibs, n_trials=100, show_progress_bar=True)
print("\n")
print("* Best trial for IBS: \n", study_ibs.best_trial)
print("\n")
print("* Best hyperparameters for IBS: \n", study_ibs.best_params)
print("\n")
print("* Best Score for IBS: \n", study_ibs.best_value)
# Out:
# [I 2024-04-19 22:40:39,064] A new study created in memory with name: no-name-2c46a7a9-ef6e-4144-a474-f342b1ea628a
#   0%|          | 0/100 [00:00<?, ?it/s]
# Fold 1 C-index: 0.6753246753246753
# Fold 2 C-index: 0.6964285714285714
# Fold 3 C-index: 0.7794117647058824
# Fold 4 C-index: 0.7637130801687764
# Fold 5 C-index: 0.6103286384976526
# [I 2024-04-19 22:40:39,911] Trial 0 finished with value: 0.7050413460251115 and parameters: {'subsample': 0.7268222670380755, 'dropout_rate': 0.3575254014553415, 'n_estimators': 114, 'learning_rate': 0.05558016213920623}. Best is trial 0 with value: 0.7050413460251115.
# Fold 1 C-index: 0.6753246753246753
# Fold 2 C-index: 0.6964285714285714
# Fold 3 C-index: 0.7794117647058824
# Fold 4 C-index: 0.8059071729957806
# Fold 5 C-index: 0.6103286384976526
# [I 2024-04-19 22:40:46,588] Trial 1 finished with value: 0.7134801645905124 and parameters: {'subsample': 0.7475220728070068, 'dropout_rate': 0.4807958141120149, 'n_estimators': 491, 'learning_rate': 0.06879814411990147}. Best is trial 1 with value: 0.7134801645905124.
# Fold 1 C-index: 0.7424242424242424
# Fold 2 C-index: 0.6964285714285714
# Fold 3 C-index: 0.7794117647058824
# Fold 4 C-index: 0.8059071729957806
# Fold 5 C-index: 0.6103286384976526
# [I 2024-04-19 22:40:47,777] Trial 2 finished with value: 0.7269000780104259 and parameters: {'subsample': 0.5328387113359249, 'dropout_rate': 0.45290576637473545, 'n_estimators': 172, 'learning_rate': 0.07317592103102012}. Best is trial 2 with value: 0.7269000780104259.
# Fold 1 C-index: 0.7424242424242424
# Fold 2 C-index: 0.6964285714285714
# Fold 3 C-index: 0.7794117647058824
# Fold 4 C-index: 0.8059071729957806
# Fold 5 C-index: 0.6103286384976526
# [I 2024-04-19 22:40:49,458] Trial 3 finished with value: 0.7269000780104259 and parameters: {'subsample': 0.494715020211662, 'dropout_rate': 0.15371010694861154, 'n_estimators': 200, 'learning_rate': 0.07406154516747154}. Best is trial 2 with value: 0.7269000780104259.
# Fold 1 C-index: 0.70995670995671
# Fold 2 C-index: 0.6964285714285714
# Fold 3 C-index: 0.7794117647058824
# Fold 4 C-index: 0.8059071729957806
# Fold 5 C-index: 0.6103286384976526
# [I 2024-04-19 22:40:52,201] Trial 4 finished with value: 0.7204065715169194 and parameters: {'subsample': 0.26424255740815, 'dropout_rate': 0.2579065805327433, 'n_estimators': 266, 'learning_rate': 0.05365093112258974}. Best is trial 2 with value: 0.7269000780104259.
# Fold 1 C-index: 0.6753246753246753
# Fold 2 C-index: 0.6964285714285714
# Fold 3 C-index: 0.7794117647058824
# Fold 4 C-index: 0.7637130801687764
# Fold 5 C-index: 0.6103286384976526
# [I 2024-04-19 22:40:55,689] Trial 5 finished with value: 0.7050413460251115 and parameters: {'subsample': 0.6709608626961889, 'dropout_rate': 0.8644886146700106, 'n_estimators': 363, 'learning_rate': 0.061491327557080706}. Best is trial 2 with value: 0.7269000780104259.
# Fold 1 C-index: 0.6753246753246753
# Fold 2 C-index: 0.6964285714285714
# Fold 3 C-index: 0.7794117647058824
# Fold 4 C-index: 0.7637130801687764
# Fold 5 C-index: 0.5821596244131455
# [I 2024-04-19 22:40:57,069] Trial 6 finished with value: 0.6994075432082101 and parameters: {'subsample': 0.7501990443131994, 'dropout_rate': 0.39066302246786044, 'n_estimators': 181, 'learning_rate': 0.023598059857016608}. Best is trial 2 with value: 0.7269000780104259.
# Fold 1 C-index: 0.6753246753246753
# Fold 2 C-index: 0.6964285714285714
# Fold 3 C-index: 0.7794117647058824
# Fold 4 C-index: 0.8059071729957806
# Fold 5 C-index: 0.6103286384976526
# [I 2024-04-19 22:40:57,284] Trial 7 finished with value: 0.7134801645905124 and parameters: {'subsample': 0.36434264174994646, 'dropout_rate': 0.667878511469039, 'n_estimators': 47, 'learning_rate': 0.043936416095273295}. Best is trial 2 with value: 0.7269000780104259.
# Fold 1 C-index: 0.7424242424242424
# Fold 2 C-index: 0.6964285714285714
# Fold 3 C-index: 0.7794117647058824
# Fold 4 C-index: 0.8059071729957806
# Fold 5 C-index: 0.6103286384976526
# [I 2024-04-19 22:40:58,874] Trial 8 finished with value: 0.7269000780104259 and parameters: {'subsample': 0.4877764869966794, 'dropout_rate': 0.5443165878852756, 'n_estimators': 213, 'learning_rate': 0.03191386107427406}. Best is trial 2 with value: 0.7269000780104259.
# Fold 1 C-index: 0.7424242424242424
# Fold 2 C-index: 0.6964285714285714
# Fold 3 C-index: 0.7794117647058824
# Fold 4 C-index: 0.8059071729957806
# Fold 5 C-index: 0.6103286384976526
# [I 2024-04-19 22:41:03,845] Trial 9 finished with value: 0.7269000780104259 and parameters: {'subsample': 0.4837161762665274, 'dropout_rate': 0.9040502468054213, 'n_estimators': 473, 'learning_rate': 0.050681830912549325}. Best is trial 2 with value: 0.7269000780104259.
# Fold 1 C-index: 0.6753246753246753
# Fold 2 C-index: 0.6004464285714286
# Fold 3 C-index: 0.7205882352941176
# Fold 4 C-index: 0.7637130801687764
# Fold 5 C-index: 0.5821596244131455
# [I 2024-04-19 22:41:06,504] Trial 10 finished with value: 0.6684464087544287 and parameters: {'subsample': 0.985919291330434, 'dropout_rate': 0.7165502912345604, 'n_estimators': 322, 'learning_rate': 0.09279671898160717}. Best is trial 2 with value: 0.7269000780104259.
# Fold 1 C-index: 0.6883116883116883
# Fold 2 C-index: 0.6964285714285714
# Fold 3 C-index: 0.8235294117647058
# Fold 4 C-index: 0.8227848101265823
# Fold 5 C-index: 0.6103286384976526
# [I 2024-04-19 22:41:07,350] Trial 11 finished with value: 0.7282766240258401 and parameters: {'subsample': 0.1795750652194426, 'dropout_rate': 0.10580803679784617, 'n_estimators': 112, 'learning_rate': 0.08422813202882692}. Best is trial 11 with value: 0.7282766240258401.
# Fold 1 C-index: 0.6883116883116883
# Fold 2 C-index: 0.7410714285714286
# Fold 3 C-index: 0.8235294117647058
# Fold 4 C-index: 0.8059071729957806
# Fold 5 C-index: 0.6103286384976526
# [I 2024-04-19 22:41:07,699] Trial 12 finished with value: 0.7338296680282512 and parameters: {'subsample': 0.12126277795618136, 'dropout_rate': 0.11480483431808647, 'n_estimators': 53, 'learning_rate': 0.09635955935176935}. Best is trial 12 with value: 0.7338296680282512.
# Fold 1 C-index: 0.6190476190476191
# Fold 2 C-index: 0.6964285714285714
# Fold 3 C-index: 0.7794117647058824
# Fold 4 C-index: 0.7637130801687764
# Fold 5 C-index: 0.6197183098591549
# [I 2024-04-19 22:41:07,873] Trial 13 finished with value: 0.695663869042001 and parameters: {'subsample': 0.10962845348392786, 'dropout_rate': 0.10204657427249281, 'n_estimators': 4, 'learning_rate': 0.09914998942829482}. Best is trial 12 with value: 0.7338296680282512.
# Fold 1 C-index: 0.696969696969697
# Fold 2 C-index: 0.7410714285714286
# Fold 3 C-index: 0.8235294117647058
# Fold 4 C-index: 0.8227848101265823
# Fold 5 C-index: 0.6103286384976526
# [I 2024-04-19 22:41:08,509] Trial 14 finished with value: 0.7389367971860132 and parameters: {'subsample': 0.11379276107227315, 'dropout_rate': 0.24475605651992097, 'n_estimators': 85, 'learning_rate': 0.0025916531369806137}. Best is trial 14 with value: 0.7389367971860132.
# Fold 1 C-index: 0.7424242424242424
# Fold 2 C-index: 0.6964285714285714
# Fold 3 C-index: 0.7794117647058824
# Fold 4 C-index: 0.8059071729957806
# Fold 5 C-index: 0.6103286384976526
# [I 2024-04-19 22:41:09,000] Trial 15 finished with value: 0.7269000780104259 and parameters: {'subsample': 0.3097269046019761, 'dropout_rate': 0.2641000268605627, 'n_estimators': 71, 'learning_rate': 0.008515792260345753}. Best is trial 14 with value: 0.7389367971860132.
# Fold 1 C-index: 0.6536796536796536
# Fold 2 C-index: 0.6004464285714286
# Fold 3 C-index: 0.7794117647058824
# Fold 4 C-index: 0.8059071729957806
# Fold 5 C-index: 0.6103286384976526
# [I 2024-04-19 22:41:09,166] Trial 16 finished with value: 0.6899547316900796 and parameters: {'subsample': 0.10330987234502886, 'dropout_rate': 0.27661215111082393, 'n_estimators': 3, 'learning_rate': 0.0022091115777638677}. Best is trial 14 with value: 0.7389367971860132.
# Fold 1 C-index: 0.70995670995671
# Fold 2 C-index: 0.6964285714285714
# Fold 3 C-index: 0.7794117647058824
# Fold 4 C-index: 0.8059071729957806
# Fold 5 C-index: 0.6103286384976526
# [I 2024-04-19 22:41
. Best is trial 54 with value: 0.7481069697364676.
# Fold 1 C-index: 0.70995670995671
# Fold 2 C-index: 0.7410714285714286
# Fold 3 C-index: 0.8235294117647058
# Fold 4 C-index: 0.8227848101265823
# Fold 5 C-index: 0.6431924882629108
# [I 2024-04-19 22:44:50,678] Trial 91 finished with value: 0.7481069697364676 and parameters: {'subsample': 0.11926803495967304, 'dropout_rate': 0.5897518424041504, 'n_estimators': 372, 'learning_rate': 0.09975467300481922}. Best is trial 54 with value: 0.7481069697364676.
# Fold 1 C-index: 0.70995670995671
# Fold 2 C-index: 0.6964285714285714
# Fold 3 C-index: 0.8235294117647058
# Fold 4 C-index: 0.8227848101265823
# Fold 5 C-index: 0.6431924882629108
# [I 2024-04-19 22:44:54,083] Trial 92 finished with value: 0.7391783983078961 and parameters: {'subsample': 0.14288446823606762, 'dropout_rate': 0.630911383430701, 'n_estimators': 386, 'learning_rate': 0.09462961598373563}. Best is trial 54 with value: 0.7481069697364676.
# Fold 1 C-index: 0.70995670995671
# Fold 2 C-index: 0.7410714285714286
# Fold 3 C-index: 0.8235294117647058
# Fold 4 C-index: 0.8227848101265823
# Fold 5 C-index: 0.6431924882629108
# [I 2024-04-19 22:44:56,985] Trial 93 finished with value: 0.7481069697364676 and parameters: {'subsample': 0.10126901462038117, 'dropout_rate': 0.5211279410602707, 'n_estimators': 337, 'learning_rate': 0.09098997827678755}. Best is trial 54 with value: 0.7481069697364676.
# Fold 1 C-index: 0.70995670995671
# Fold 2 C-index: 0.6964285714285714
# Fold 3 C-index: 0.8235294117647058
# Fold 4 C-index: 0.8227848101265823
# Fold 5 C-index: 0.6431924882629108
# [I 2024-04-19 22:45:00,165] Trial 94 finished with value: 0.7391783983078961 and parameters: {'subsample': 0.16958922382416908, 'dropout_rate': 0.5802509271489456, 'n_estimators': 359, 'learning_rate': 0.09979038665914047}. Best is trial 54 with value: 0.7481069697364676.
# Fold 1 C-index: 0.7012987012987013
# Fold 2 C-index: 0.6964285714285714
# Fold 3 C-index: 0.8235294117647058
# Fold 4 C-index: 0.8227848101265823
# Fold 5 C-index: 0.6431924882629108
# [I 2024-04-19 22:45:04,377] Trial 95 finished with value: 0.7374467965762943 and parameters: {'subsample': 0.12140601660484042, 'dropout_rate': 0.4827598475899177, 'n_estimators': 400, 'learning_rate': 0.09703953563724052}. Best is trial 54 with value: 0.7481069697364676.
# Fold 1 C-index: 0.70995670995671
# Fold 2 C-index: 0.6964285714285714
# Fold 3 C-index: 0.7794117647058824
# Fold 4 C-index: 0.8227848101265823
# Fold 5 C-index: 0.6103286384976526
# [I 2024-04-19 22:45:07,415] Trial 96 finished with value: 0.7237820989430797 and parameters: {'subsample': 0.289315010353668, 'dropout_rate': 0.6111950693949487, 'n_estimators': 369, 'learning_rate': 0.09400881054764008}. Best is trial 54 with value: 0.7481069697364676.
# Fold 1 C-index: 0.70995670995671
# Fold 2 C-index: 0.6517857142857143
# Fold 3 C-index: 0.8235294117647058
# Fold 4 C-index: 0.8227848101265823
# Fold 5 C-index: 0.6431924882629108
# [I 2024-04-19 22:45:12,095] Trial 97 finished with value: 0.7302498268793247 and parameters: {'subsample': 0.1475735819873282, 'dropout_rate': 0.5012507996615155, 'n_estimators': 458, 'learning_rate': 0.08919569376411804}. Best is trial 54 with value: 0.7481069697364676.
# Fold 1 C-index: 0.70995670995671
# Fold 2 C-index: 0.7410714285714286
# Fold 3 C-index: 0.7794117647058824
# Fold 4 C-index: 0.8227848101265823
# Fold 5 C-index: 0.6431924882629108
# [I 2024-04-19 22:45:14,911] Trial 98 finished with value: 0.7392834403247027 and parameters: {'subsample': 0.22400114273541616, 'dropout_rate': 0.5592205628297775, 'n_estimators': 345, 'learning_rate': 0.09760441759064652}. Best is trial 54 with value: 0.7481069697364676.
# Fold 1 C-index: 0.7012987012987013
# Fold 2 C-index: 0.6964285714285714
# Fold 3 C-index: 0.8235294117647058
# Fold 4 C-index: 0.8227848101265823
# [I 2024-04-19 22:45:18,696] A new study created in memory with name: no-name-5e86f964-55df-442a-a90b-87e826cf11e5
# Fold 5 C-index: 0.6431924882629108
# [I 2024-04-19 22:45:18,683] Trial 99 finished with value: 0.7374467965762943 and parameters: {'subsample': 0.11943492385817843, 'dropout_rate': 0.42484516533860367, 'n_estimators': 382, 'learning_rate': 0.09249945285213439}. Best is trial 54 with value: 0.7481069697364676.
#
#
# * Best trial for C-index:
#  FrozenTrial(number=54, state=TrialState.COMPLETE, values=[0.7481069697364676], datetime_start=datetime.datetime(2024, 4, 19, 22, 42, 39, 656965), datetime_complete=datetime.datetime(2024, 4, 19, 22, 42, 41, 333423), params={'subsample': 0.12556777712756245, 'dropout_rate': 0.5248153052289104, 'n_estimators': 237, 'learning_rate': 0.0812443732119593}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'subsample': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'dropout_rate': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'n_estimators': IntDistribution(high=500, log=False, low=1, step=1), 'learning_rate': FloatDistribution(high=0.1, log=False, low=0.001, step=None)}, trial_id=54, value=None)
#
#
# * Best hyperparameters for C-index:
#  {'subsample': 0.12556777712756245, 'dropout_rate': 0.5248153052289104, 'n_estimators': 237, 'learning_rate': 0.0812443732119593}
#
#
# * Best Score for C-index:
#  0.7481069697364676
#   0%|          | 0/100 [00:00<?, ?it/s]
# Fold 1 IBS: 0.18504584755520848
# Fold 2 IBS: 0.24179973682352504
# Fold 3 IBS: 0.16652277988504283
# Fold 4 IBS: 0.16884354353720807
# Fold 5 IBS: 0.23318480871469416
# [I 2024-04-19 22:45:19,342] Trial 0 finished with value: 0.19907934330313573 and parameters: {'subsample': 0.7268222670380755, 'dropout_rate': 0.3575254014553415, 'n_estimators': 114, 'learning_rate': 0.05558016213920623}. Best is trial 0 with value: 0.19907934330313573.
# Fold 1 IBS: 0.20370621643796663
# Fold 2 IBS: 0.2887077060706083
# Fold 3 IBS: 0.17786466393154174
# Fold 4 IBS: 0.1729408126951147
# Fold 5 IBS: 0.27370157532625616
# [I 2024-04-19 22:45:24,409] Trial 1 finished with value: 0.22338419489229752 and parameters: {'subsample': 0.7475220728070068, 'dropout_rate': 0.4807958141120149, 'n_estimators': 491, 'learning_rate': 0.06879814411990147}. Best is trial 0 with value: 0.19907934330313573.
# Fold 1 IBS: 0.19661103906383703
# Fold 2 IBS: 0.2697617358478736
# Fold 3 IBS: 0.17326819431573745
# Fold 4 IBS: 0.16863180341613299
# Fold 5 IBS: 0.26506003175161774
# [I 2024-04-19 22:45:25,385] Trial 2 finished with value: 0.21466656087903974 and parameters: {'subsample': 0.5328387113359249, 'dropout_rate': 0.45290576637473545, 'n_estimators': 172, 'learning_rate': 0.07317592103102012}. Best is trial 0 with value: 0.19907934330313573.
# Fold 1 IBS: 0.19558922476579008
# Fold 2 IBS: 0.2588149025222109
# Fold 3 IBS: 0.17441636128502397
# Fold 4 IBS: 0.16640724372364674
# Fold 5 IBS: 0.26786281926556355
# [I 2024-04-19 22:45:26,724] Trial 3 finished with value: 0.21261811031244707 and parameters: {'subsample': 0.494715020211662, 'dropout_rate': 0.15371010694861154, 'n_estimators': 200, 'learning_rate': 0.07406154516747154}. Best is trial 0 with value: 0.19907934330313573.
# Fold 1 IBS: 0.1821774414375662
# Fold 2 IBS: 0.25869334633865737
# Fold 3 IBS: 0.17638865799129108
# Fold 4 IBS: 0.15903206702046035
# Fold 5 IBS: 0.26907192503413213
# ...
# Fold 1 IBS: 0.16828176721645238
# Fold 2 IBS: 0.21941635800151613
# Fold 3 IBS: 0.16755421628459435
# Fold 4 IBS: 0.15713724842734358
# Fold 5 IBS: 0.23485343122319233
# [I 2024-04-19 22:46:21,613] Trial 66 finished with value: 0.18944860423061977 and parameters: {'subsample': 0.1393046029080525, 'dropout_rate': 0.23854510167627319, 'n_estimators': 123, 'learning_rate': 0.056981583513164374}. Best is trial 44 with value: 0.18788754008383918.
# Fold 1 IBS: 0.17853904007955013
# Fold 2 IBS: 0.21468168598733697
# Fold 3 IBS: 0.16747977789468704
# Fold 4 IBS: 0.16732673614974727
# Fold 5 IBS: 0.2216422740903246
# [I 2024-04-19 22:46:22,162] Trial 67 finished with value: 0.1899339028403292 and parameters: {'subsample': 0.23876180943265374, 'dropout_rate': 0.2700299765509323, 'n_estimators': 95, 'learning_rate': 0.05057481351597392}. Best is trial 44 with value: 0.18788754008383918.
# Fold 1 IBS: 0.17359456049707092
# Fold 2 IBS: 0.21089685063368882
# Fold 3 IBS: 0.16999015148834773
# Fold 4 IBS: 0.16876194099872144
# Fold 5 IBS: 0.21968398403675612
# [I 2024-04-19 22:46:22,614] Trial 68 finished with value: 0.18858549753091702 and parameters: {'subsample': 0.10363439894155282, 'dropout_rate': 0.23160420765531153, 'n_estimators': 77, 'learning_rate': 0.053828393062133634}. Best is trial 44 with value: 0.18788754008383918.
# Fold 1 IBS: 0.1743655123698442
# Fold 2 IBS: 0.20865758973732185
# Fold 3 IBS: 0.16881439492201122
# Fold 4 IBS: 0.1714284081288199
# Fold 5 IBS: 0.22056539086179028
# [I 2024-04-19 22:46:23,062] Trial 69 finished with value: 0.18876625920395748 and parameters: {'subsample': 0.11059240103917886, 'dropout_rate': 0.24095031458399324, 'n_estimators': 77, 'learning_rate': 0.05452181969732228}. Best is trial 44 with value: 0.18788754008383918.
# Fold 1 IBS: 0.178546686066023
# Fold 2 IBS: 0.20905511898683968
# Fold 3 IBS: 0.17157637434360468
# Fold 4 IBS: 0.17884772195271423
# Fold 5 IBS: 0.21756996005176074
# [I 2024-04-19 22:46:23,462] Trial 70 finished with value: 0.1911191722801885 and parameters: {'subsample': 0.12990464706491467, 'dropout_rate': 0.771839325426505, 'n_estimators': 76, 'learning_rate': 0.047582976871327745}. Best is trial 44 with value: 0.18788754008383918.
# Fold 1 IBS: 0.16319011586241033
# Fold 2 IBS: 0.21890181330599526
# Fold 3 IBS: 0.1701364353320474
# Fold 4 IBS: 0.15413860816036343
# Fold 5 IBS: 0.23404619467024299
# [I 2024-04-19 22:46:24,271] Trial 71 finished with value: 0.18808263346621187 and parameters: {'subsample': 0.10706800069060031, 'dropout_rate': 0.22929930766296366, 'n_estimators': 135, 'learning_rate': 0.053077693766743456}. Best is trial 44 with value: 0.18788754008383918.
# Fold 1 IBS: 0.17403370053430584
# Fold 2 IBS: 0.2107710518434017
# Fold 3 IBS: 0.17023969686584572
# Fold 4 IBS: 0.16936796631734455
# Fold 5 IBS: 0.22044316838468536
# [I 2024-04-19 22:46:24,686] Trial 72 finished with value: 0.18897111678911663 and parameters: {'subsample': 0.10298462358759597, 'dropout_rate': 0.23728994115165516, 'n_estimators': 77, 'learning_rate': 0.05274487725663095}. Best is trial 44 with value: 0.18788754008383918.
# Fold 1 IBS: 0.19145062285018083
# Fold 2 IBS: 0.21497550760841566
# Fold 3 IBS: 0.18482439077248064
# Fold 4 IBS: 0.19582337001843708
# Fold 5 IBS: 0.21545011745852077
# [I 2024-04-19 22:46:24,926] Trial 73 finished with value: 0.20050480174160698 and parameters: {'subsample': 0.20194727096987047, 'dropout_rate': 0.28552343881121417, 'n_estimators': 34, 'learning_rate': 0.05428322379865269}. Best is trial 44 with value: 0.18788754008383918.
# Fold 1 IBS: 0.17557529455552684
# Fold 2 IBS: 0.2665002120298944
# Fold 3 IBS: 0.19802881781612006
# Fold 4 IBS: 0.15400892869372332
# Fold 5 IBS: 0.29378636893440135
# [I 2024-04-19 22:46:28,752] Trial 74 finished with value: 0.21757992440593318 and parameters: {'subsample': 0.1462338443844065, 'dropout_rate': 0.22221181419435482, 'n_estimators': 386, 'learning_rate': 0.0632622109717847}. Best is trial 44 with value: 0.18788754008383918.
# Fold 1 IBS: 0.16692971327128875
# Fold 2 IBS: 0.22708848413619726
# Fold 3 IBS: 0.16760015446806023
# Fold 4 IBS: 0.15853216181395827
# Fold 5 IBS: 0.23435870533352962
# [I 2024-04-19 22:46:29,546] Trial 75 finished with value: 0.1909018438046068 and parameters: {'subsample': 0.1260241580509198, 'dropout_rate': 0.19293458702137822, 'n_estimators': 130, 'learning_rate': 0.057668857508518974}. Best is trial 44 with value: 0.18788754008383918.
# Fold 1 IBS: 0.1755252460588786
# Fold 2 IBS: 0.2152780491156862
# Fold 3 IBS: 0.1684272943675743
# Fold 4 IBS: 0.16816894984594796
# Fold 5 IBS: 0.22316000800197508
# [I 2024-04-19 22:46:30,112] Trial 76 finished with value: 0.19011190947801243 and parameters: {'subsample': 0.19237162820837594, 'dropout_rate': 0.34829268282242476, 'n_estimators': 102, 'learning_rate': 0.047405349654266904}. Best is trial 44 with value: 0.18788754008383918.
# Fold 1 IBS: 0.16700595416925748
# Fold 2 IBS: 0.22992308628679056
# Fold 3 IBS: 0.17329686365133204
# Fold 4 IBS: 0.15077194070332572
# Fold 5 IBS: 0.25440711351834033
# [I 2024-04-19 22:46:31,287] Trial 77 finished with value: 0.19508099166580922 and parameters: {'subsample': 0.10011572535904745, 'dropout_rate': 0.16394919761225535, 'n_estimators': 174, 'learning_rate': 0.05967079734846142}. Best is trial 44 with value: 0.18788754008383918.
# Fold 1 IBS: 0.1660331977360475
# Fold 2 IBS: 0.2305631174348927
# Fold 3 IBS: 0.16730770244657714
# Fold 4 IBS: 0.15630386983791542
# Fold 5 IBS: 0.23710814242424125
# [I 2024-04-19 22:46:32,189] Trial 78 finished with value: 0.1914632059759348 and parameters: {'subsample': 0.16029285019310485, 'dropout_rate': 0.3133123290183424, 'n_estimators': 146, 'learning_rate': 0.051321271138936454}. Best is trial 44 with value: 0.18788754008383918.
# Fold 1 IBS: 0.17747670944679658
# Fold 2 IBS: 0.21059844987946752
# Fold 3 IBS: 0.16867108274739176
# Fold 4 IBS: 0.16996600000380144
# Fold 5 IBS: 0.21892285969387093
# [I 2024-04-19 22:46:32,649] Trial 79 finished with value: 0.18912702035426565 and parameters: {'subsample': 0.25137131057246515, 'dropout_rate': 0.1371792005752136, 'n_estimators': 79, 'learning_rate': 0.05558904281641333}. Best is trial 44 with value: 0.18788754008383918.
# Fold 1 IBS: 0.17710483669688581
# Fold 2 IBS: 0.21572876627810572
# Fold 3 IBS: 0.1663461514577251
# Fold 4 IBS: 0.16606973148297355
# Fold 5 IBS: 0.22281514052024814
# [I 2024-04-19 22:46:33,327] Trial 80 finished with value: 0.18961292528718765 and parameters: {'subsample': 0.29509125144368054, 'dropout_rate': 0.24122245143602183, 'n_estimators': 118, 'learning_rate': 0.04565212894811446}. Best is trial 44 with value: 0.18788754008383918.
# Fold 1 IBS: 0.16609921279928094
# Fold 2 IBS: 0.21333483749458998
# Fold 3 IBS: 0.16776344606243543
# Fold 4 IBS: 0.16114487630877228
# Fold 5 IBS: 0.2318544370379775
# [I 2024-04-19 22:46:33,970] Trial 81 finished with value: 0.18803936194061122 and parameters: {'subsample': 0.11570376903040414, 'dropout_rate': 0.2717598628799628, 'n_estimators': 105, 'learning_rate': 0.0623108932999312}. Best is trial 44 with value: 0.18788754008383918.
# Fold 1 IBS: 0.16455663200242213
# Fold 2 IBS: 0.21351861328395402
# Fold 3 IBS: 0.16848255356846395
# Fold 4 IBS: 0.1624241700139299
# Fold 5 IBS: 0.23038558786237734
# [I 2024-04-19 22:46:34,561] Trial 82 finished with value: 0.18787351134622945 and parameters: {'subsample': 0.12517511668126804, 'dropout_rate': 0.2694712055548494, 'n_estimators': 101, 'learning_rate': 0.06267475924045825}. Best is trial 82 with value: 0.18787351134622945.
# Fold 1 IBS: 0.16382343268705496
# Fold 2 IBS: 0.22420700581272585
# Fold 3 IBS: 0.16966293778791688
# Fold 4 IBS: 0.15621362261198687
# Fold 5 IBS: 0.24225477767674103
# [I 2024-04-19 22:46:35,377] Trial 83 finished with value: 0.19123235531528512 and parameters: {'subsample': 0.12514978311880154, 'dropout_rate': 0.2625892803711813, 'n_estimators': 134, 'learning_rate': 0.06289148538703425}. Best is trial 82 with value: 0.18787351134622945.
# Fold 1 IBS: 0.15120398462828147
# Fold 2 IBS: 0.2700324314313729
# Fold 3 IBS: 0.20750890302609534
# Fold 4 IBS: 0.15545398356805193
# Fold 5 IBS: 0.29866830470643047
# [I 2024-04-19 22:46:41,008] Trial 84 finished with value: 0.21657352147204642 and parameters: {'subsample': 0.1432565265641765, 'dropout_rate': 0.35651197854224725, 'n_estimators': 494, 'learning_rate': 0.06585995942082219}. Best is trial 82 with value: 0.18787351134622945.
# Fold 1 IBS: 0.17749488483995263
# Fold 2 IBS: 0.2121364738882218
# Fold 3 IBS: 0.1708924484790043
# Fold 4 IBS: 0.17410823117798538
# Fold 5 IBS: 0.2182910829978751
# [I 2024-04-19 22:46:41,585] Trial 85 finished with value: 0.19058462427660786 and parameters: {'subsample': 0.21715286428544836, 'dropout_rate': 0.28094842199381054, 'n_estimators': 102, 'learning_rate': 0.03918139309039054}. Best is trial 82 with value: 0.18787351134622945.
# Fold 1 IBS: 0.17283354214262303
# Fold 2 IBS: 0.20849557425349183
# Fold 3 IBS: 0.1708328433175319
# Fold 4 IBS: 0.17725716755207818
# Fold 5 IBS: 0.21804742844817637
# [I 2024-04-19 22:46:41,971] Trial 86 finished with value: 0.18949331114278029 and parameters: {'subsample': 0.11692641547260092, 'dropout_rate': 0.2041672249602161, 'n_estimators': 66, 'learning_rate': 0.05942268112563097}. Best is trial 82 with value: 0.18787351134622945.
# Fold 1 IBS: 0.1667209370332251
# Fold 2 IBS: 0.24256022833210553
# Fold 3 IBS: 0.17094525909912078
# Fold 4 IBS: 0.15367444523046386
# Fold 5 IBS: 0.2494709971144904
# [I 2024-04-19 22:46:42,967] Trial 87 finished with value: 0.19667437336188115 and parameters: {'subsample': 0.15366485952498626, 'dropout_rate': 0.30797722673110894, 'n_estimators': 160, 'learning_rate': 0.06147130770506648}. Best is trial 82 with value: 0.18787351134622945.
# Fold 1 IBS: 0.18386945849345968
# Fold 2 IBS: 0.20379334977514812
# Fold 3 IBS: 0.1795874848283044
# Fold 4 IBS: 0.1925251008758893
# Fold 5 IBS: 0.21488255205368648
# [I 2024-04-19 22:46:43,278] Trial 88 finished with value: 0.19493158920529757 and parameters: {'subsample': 0.12093756633295784, 'dropout_rate': 0.2495907064301645, 'n_estimators': 47, 'learning_rate': 0.055675811743164653}. Best is trial 82 with value: 0.18787351134622945.
# Fold 1 IBS: 0.1863395948274145
# Fold 2 IBS: 0.2406344937135454
# Fold 3 IBS: 0.16725347389894615
# Fold 4 IBS: 0.165594563305091
# Fold 5 IBS: 0.24116923874844398
# [I 2024-04-19 22:46:43,864] Trial 89 finished with value: 0.20019827289868825 and parameters: {'subsample': 0.5132134792119997, 'dropout_rate': 0.6436774805198799, 'n_estimators': 112, 'learning_rate': 0.06897767605356266}. Best is trial 82 with value: 0.18787351134622945.
# Fold 1 IBS: 0.1720445955744617
# Fold 2 IBS: 0.21706873606350832
# Fold 3 IBS: 0.16653090390178435
# Fold 4 IBS: 0.16239957188541215
# Fold 5 IBS: 0.22562016296089873
# [I 2024-04-19 22:46:44,423] Trial 90 finished with value: 0.18873279407721305 and parameters: {'subsample': 0.16772697824192873, 'dropout_rate': 0.22939987726930675, 'n_estimators': 97, 'learning_rate': 0.05825282379476288}. Best is trial 82 with value: 0.18787351134622945.
# Fold 1 IBS: 0.1737392354859858
# Fold 2 IBS: 0.21443100250382643
# Fold 3 IBS: 0.16766274167192052
# Fold 4 IBS: 0.16574596677340095
# Fold 5 IBS: 0.22184758897287155
# [I 2024-04-19 22:46:44,969] Trial 91 finished with value: 0.18868530708160103 and parameters: {'subsample': 0.16704662784208493, 'dropout_rate': 0.22424889940363044, 'n_estimators': 95, 'learning_rate': 0.051735927294152516}. Best is trial 82 with value: 0.18787351134622945.
# Fold 1 IBS: 0.17710285171763485
# Fold 2 IBS: 0.20777376836369918
# Fold 3 IBS: 0.16892670992533743
# Fold 4 IBS: 0.16802085913376738
# Fold 5 IBS: 0.2193899777489083
# [I 2024-04-19 22:46:45,520] Trial 92 finished with value: 0.18824283337786946 and parameters: {'subsample': 0.20767654711774325, 'dropout_rate': 0.18050762557534772, 'n_estimators': 95, 'learning_rate': 0.04886051074293694}. Best is trial 82 with value: 0.18787351134622945.
# Fold 1 IBS: 0.17556745217397104
# Fold 2 IBS: 0.21205395755112502
# Fold 3 IBS: 0.16673915345425114
# Fold 4 IBS: 0.163203885316202
# Fold 5 IBS: 0.2258122587052623
# [I 2024-04-19 22:46:46,236] Trial 93 finished with value: 0.18867534144016232 and parameters: {'subsample': 0.22160267175914775, 'dropout_rate': 0.1690892072602066, 'n_estimators': 119, 'learning_rate': 0.048573824190215796}. Best is trial 82 with value: 0.18787351134622945.
# Fold 1 IBS: 0.17552962082071957
# Fold 2 IBS: 0.2188280644661504
# Fold 3 IBS: 0.16673138619996408
# Fold 4 IBS: 0.15981767521044365
# Fold 5 IBS: 0.2300429988207966
# [I 2024-04-19 22:46:46,999] Trial 94 finished with value: 0.19018994910361486 and parameters: {'subsample': 0.21455600259143576, 'dropout_rate': 0.19608552474904095, 'n_estimators': 127, 'learning_rate': 0.052763991107750666}. Best is trial 82 with value: 0.18787351134622945.
# Fold 1 IBS: 0.17721641877960248
# Fold 2 IBS: 0.21802389160786934
# Fold 3 IBS: 0.16657128370453747
# Fold 4 IBS: 0.15878714072454508
# Fold 5 IBS: 0.231604841376724
# [I 2024-04-19 22:46:47,897] Trial 95 finished with value: 0.19044071523865566 and parameters: {'subsample': 0.19332220033444253, 'dropout_rate': 0.12862729022296376, 'n_estimators': 142, 'learning_rate': 0.048816262618501534}. Best is trial 82 with value: 0.18787351134622945.
# Fold 1 IBS: 0.17217995509898318
# Fold 2 IBS: 0.21517391091972324
# Fold 3 IBS: 0.16751698964265932
# Fold 4 IBS: 0.16476013310643878
# Fold 5 IBS: 0.2265988112473419
# [I 2024-04-19 22:46:48,587] Trial 96 finished with value: 0.1892459600030293 and parameters: {'subsample': 0.14040209898404546, 'dropout_rate': 0.16736437554083133, 'n_estimators': 117, 'learning_rate': 0.04509236308457335}. Best is trial 82 with value: 0.18787351134622945.
# Fold 1 IBS: 0.1817667986528851
# Fold 2 IBS: 0.21388776437434748
# Fold 3 IBS: 0.17123048196925195
# Fold 4 IBS: 0.17609367263889258
# Fold 5 IBS: 0.21520431753253275
# [I 2024-04-19 22:46:49,096] Trial 97 finished with value: 0.19163660703358196 and parameters: {'subsample': 0.33846670341980367, 'dropout_rate': 0.27771488676688577, 'n_estimators': 89, 'learning_rate': 0.04071453518360497}. Best is trial 82 with value: 0.18787351134622945.
# Fold 1 IBS: 0.17573178775034495
# Fold 2 IBS: 0.23145716138844594
# Fold 3 IBS: 0.16704791400793076
# Fold 4 IBS: 0.15778722944208895
# Fold 5 IBS: 0.2367328054194092
# [I 2024-04-19 22:46:50,078] Trial 98 finished with value: 0.19375137960164396 and parameters: {'subsample': 0.23390142808660813, 'dropout_rate': 0.20777382649929046, 'n_estimators': 155, 'learning_rate': 0.05024135363936}. Best is trial 82 with value: 0.18787351134622945.
# Fold 1 IBS: 0.16715057732611172
# Fold 2 IBS: 0.24257408859735832
# Fold 3 IBS: 0.17153544570624912
# Fold 4 IBS: 0.15515205349749714
# Fold 5 IBS: 0.2521172304504646
# [I 2024-04-19 22:46:52,252] Trial 99 finished with value: 0.19770587911553617 and parameters: {'subsample': 0.1825029520072145, 'dropout_rate': 0.33620098261117537, 'n_estimators': 278, 'learning_rate': 0.03740597240081432}. Best is trial 82 with value: 0.18787351134622945.
#
#
# * Best trial for IBS:
#  FrozenTrial(number=82, state=TrialState.COMPLETE, values=[0.18787351134622945], datetime_start=datetime.datetime(2024, 4, 19, 22, 46, 33, 975838), datetime_complete=datetime.datetime(2024, 4, 19, 22, 46, 34, 560739), params={'subsample': 0.12517511668126804, 'dropout_rate': 0.2694712055548494, 'n_estimators': 101, 'learning_rate': 0.06267475924045825}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'subsample': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'dropout_rate': FloatDistribution(high=1.0, log=False, low=0.1, step=None), 'n_estimators': IntDistribution(high=500, log=False, low=1, step=1), 'learning_rate': FloatDistribution(high=0.1, log=False, low=0.001, step=None)}, trial_id=82, value=None)
#
#
# * Best hyperparameters for IBS:
#  {'subsample': 0.12517511668126804, 'dropout_rate': 0.2694712055548494, 'n_estimators': 101, 'learning_rate': 0.06267475924045825}
#
#
# * Best Score for IBS:
#  0.18787351134622945

# %%
train_cindex['ComponentwiseGradientBoosting'] = np.round(study_cindex.best_value, 3)
train_ibs['ComponentwiseGradientBoosting'] = np.round(study_ibs.best_value, 3)

# %%
print("train_cindex: ", np.round(study_cindex.best_value, 3))
print("train_ibs: ", np.round(study_ibs.best_value, 3))
# Out:
# train_cindex:  0.748
# train_ibs:  0.188

# %% [markdown]
# #### Test

# %%
# y into array 
lists = [] 
for i, j in zip(y['event_OS'], y['OS']): 
    lists.append((i, j))

y = np.array(lists, dtype=[('status', bool), ('time', np.int32)])

# %%
# A function for building the best model with the best parameters 
def create_best_model(model_class, best_params):
    best_params["random_state"]=123
    return model_class(**best_params)

# Set the best model 
best_model_cindex = create_best_model(ComponentwiseGradientBoostingSurvivalAnalysis, study_cindex.best_params)

# Train the best model for C-index on the whole dataset
best_model_cindex.fit(X_new_std, y)

# Evaluate the best model for C-index on MAASTRO dataset
c_index = best_model_cindex.score(MAASTRO_new_std, y_MAASTRO)
c_index = np.round(c_index, 3)
print("C-index score:", c_index)

# Set the best model 
best_model_ibs = create_best_model(ComponentwiseGradientBoostingSurvivalAnalysis, study_ibs.best_params)

# Train the best model for IBS on the whole dataset
best_model_ibs.fit(X_new_std, y)

# Evaluate the best model for IBS on MAASTRO dataset
lower, upper = np.percentile(y_MAASTRO["time"], [10, 90])
gbsg_times = np.arange(lower, upper)
surv_prob = np.row_stack([fn(gbsg_times) for fn in best_model_ibs.predict_survival_function(MAASTRO_new_std)])
ibs = integrated_brier_score(y_MAASTRO, y_MAASTRO, surv_prob, gbsg_times)
ibs = np.round(ibs, 3)
print("IBS:", ibs)
# Out:
# ComponentwiseGradientBoostingSurvivalAnalysis(dropout_rate=0.5248153052289104,
#                                               learning_rate=0.0812443732119593,
#                                               n_estimators=237,
#                                               random_state=123,
#                                               subsample=0.12556777712756245)
# C-index score: 0.593
# ComponentwiseGradientBoostingSurvivalAnalysis(dropout_rate=0.2694712055548494,
#                                               learning_rate=0.06267475924045825,
#                                               n_estimators=101,
#                                               random_state=123,
#                                               subsample=0.12517511668126804)
# IBS: 0.213

# %%
# Saving the values to the dictionary 
test_cindex['ComponentwiseGradientBoosting'] = c_index
test_ibs['ComponentwiseGradientBoosting'] = ibs

# %% [markdown]
# ## Results

# %%
df_train_cindex = pd.DataFrame(train_cindex, index=['C-index']).transpose().sort_values(by='C-index', ascending=False)
df_train_cindex['rank'] = df_train_cindex['C-index'].rank(ascending=False)
df_train_cindex
# Out:
#                                C-index  rank
# Randomsurvivalforest             0.860   1.0
# ExtraSurvivalTrees               0.793   2.0
# CoxElastic                       0.754   3.0
# GradientBoosting                 0.748   4.5
# ComponentwiseGradientBoosting    0.748   4.5
# CoxPH                            0.744   6.5
# CoxLasso                         0.744   6.5
# CoxRidge                         0.727   8.0

# %%
df_train_ibs = pd.DataFrame(train_ibs, index=['IBS']).transpose().sort_values(by='IBS', ascending=True)
df_train_ibs['rank'] = df_train_ibs['IBS'].rank(ascending=True)
df_train_ibs
# Out:
#                                  IBS  rank
# Randomsurvivalforest           0.179   1.0
# ExtraSurvivalTrees             0.181   2.0
# CoxPH                          0.186   4.0
# CoxLasso                       0.186   4.0
# CoxElastic                     0.186   4.0
# ComponentwiseGradientBoosting  0.188   6.0
# GradientBoosting               0.209   7.0
# CoxRidge                       0.217   8.0

# %%
df_test_cindex = pd.DataFrame(test_cindex, index=['C-index']).transpose().sort_values(by='C-index', ascending=False)
df_test_cindex['rank'] = df_test_cindex['C-index'].rank(ascending=False)
df_test_cindex
# Out:
#                                C-index  rank
# ExtraSurvivalTrees               0.667   1.0
# CoxPH                            0.666   3.0
# CoxLasso                         0.666   3.0
# CoxElastic                       0.666   3.0
# GradientBoosting                 0.649   5.0
# Randomsurvivalforest             0.642   6.0
# CoxRidge                         0.593   7.5
# ComponentwiseGradientBoosting    0.593   7.5

# %%
df_test_ibs = pd.DataFrame(test_ibs, index=['IBS']).transpose().sort_values(by='IBS', ascending=True)
df_test_ibs['rank'] = df_test_ibs['IBS'].rank(ascending=True)
df_test_ibs
# Out:
#                                  IBS  rank
# Randomsurvivalforest           0.206   1.0
# ExtraSurvivalTrees             0.211   2.0
# GradientBoosting               0.213   3.5
# ComponentwiseGradientBoosting  0.213   3.5
# CoxRidge                       0.221   6.0
# CoxLasso                       0.221   6.0
# CoxElastic                     0.221   6.0
# CoxPH                          0.222   8.0

# %%
# Renaming the column "index" to "model" 
df_train_cindex = df_train_cindex.reset_index().rename(columns={"index": "model"})
df_train_ibs = df_train_ibs.reset_index().rename(columns={"index": "model"})
df_test_cindex = df_test_cindex.reset_index().rename(columns={"index": "model"})
df_test_ibs = df_test_ibs.reset_index().rename(columns={"index": "model"})

# Save the files 
dfs = [df_train_cindex, df_train_ibs, df_test_cindex, df_test_ibs]  
file_path = 'path_to_your_folder/'  

# List of corresponding file names
file_names = ['train_cindex.csv', 'train_ibs.csv', 'test_cindex.csv', 'test_ibs.csv']


dfs = [df_train_cindex, df_train_ibs, df_test_cindex, df_test_ibs]  
file_path = '/Users/minjeongcheon/Desktop/results_thesis/d1/os/minmax/fs_fi/'  

# List of corresponding file names
file_names = ['train_cindex.csv', 'train_ibs.csv', 'test_cindex.csv', 'test_ibs.csv']

# Modify the file names to match the desired format
modified_file_names = ['d1_os_minmax_fs_fi_' + file_name for file_name in file_names]

# Loop through each DataFrame and save them with corresponding modified file names
for df, modified_file_name in zip(dfs, modified_file_names):
    file_path_name = file_path + modified_file_name  # Construct the full file path
    df.to_csv(file_path_name, index=False)  # Save the DataFrame to CSV file

# %%
from datetime import date
today = date.today()
print("Date: ", today)
# Out:
# Date:  2024-04-19
