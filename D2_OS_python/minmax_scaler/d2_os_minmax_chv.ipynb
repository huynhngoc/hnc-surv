# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
from yellowbrick.cluster import KElbowVisualizer
import matplotlib.pyplot as plt
import pandas as pd 
import seaborn as sns
from sklearn.cluster import KMeans
from sksurv.base import SurvivalAnalysisMixin as s
from sklearn.model_selection import train_test_split, RandomizedSearchCV, cross_val_score
from sksurv.preprocessing import encode_categorical
 
from sksurv.functions import StepFunction
from sksurv.linear_model import CoxPHSurvivalAnalysis, CoxnetSurvivalAnalysis
from sksurv.ensemble import (ComponentwiseGradientBoostingSurvivalAnalysis, 
                            RandomSurvivalForest, 
                            ExtraSurvivalTrees, 
                            GradientBoostingSurvivalAnalysis, 
                            ExtraSurvivalTrees)
from sksurv.meta import EnsembleSelection, EnsembleSelectionRegressor
from sksurv.metrics import integrated_brier_score
from matplotlib.colors import ListedColormap
from mlxtend.evaluate import paired_ttest_5x2cv
from mlxtend.evaluate import combined_ftest_5x2cv
from lifelines import KaplanMeierFitter
from scipy.cluster import hierarchy
from lifelines.statistics import logrank_test, multivariate_logrank_test, pairwise_logrank_test
from sklearn import preprocessing
from sklearn.model_selection import StratifiedKFold, KFold
from lifelines.plotting import add_at_risk_counts
import scipy.stats
import sklearn
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import optuna
from sklearn.model_selection import cross_val_score
from sksurv.metrics import integrated_brier_score
from lifelines import CoxPHFitter
from lifelines.statistics import proportional_hazard_test
import scipy.stats as stats
from statsmodels.stats.outliers_influence import variance_inflation_factor 
import statsmodels.api as sm
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'
from sklearn.preprocessing import MinMaxScaler

# %%
# OUS: Train data
OUS_D1 = pd.read_csv('OUS_D1.csv')
OUS_D2 = pd.read_csv('OUS_D2.csv')
OUS_D3 = pd.read_csv('OUS_D3.csv')
OUS_DFS_target = pd.read_csv('OUS_DFS_target.csv')
OUS_OS_target = pd.read_csv('OUS_OS_target.csv')
response_OUS = pd.read_csv('response_ous.csv', sep=';')

# MAASTRO: Test data 
MAASTRO_D1 = pd.read_csv('MAASTRO_D1.csv')
MAASTRO_D2 = pd.read_csv('MAASTRO_D2.csv')
MAASTRO_D3 = pd.read_csv('MAASTRO_D3.csv')
MAASTRO_DFS_target = pd.read_csv('MAASTRO_DFS_target.csv')
MAASTRO_OS_target = pd.read_csv('MAASTRO_OS_target.csv')
response_MAASTRO = pd.read_csv('maastro_response_full.csv', sep=',')

# %%
# Need to choose patient_id from OUS_D2 in response_OUS
data = list(OUS_D2['patient_id'])
mask = response_OUS['patient_id'].isin(data)
response_OUS = response_OUS[mask] 

# Merge OUS_D2 with response_OUS
clinical_train = pd.merge(OUS_D2, response_OUS, on='patient_id', how='inner')
clinical_train = clinical_train.loc[:, ~clinical_train.columns.isin(['DFS', 'event_DFS', 'LRC', 'event_LRC'])]

# %%
# Drop patient_id column
clinical_train = clinical_train.drop('patient_id', axis=1)

# %%
# Check null values in D2 
clinical_train.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# ## Test dataset: MAASTRO

# %%
(MAASTRO_D2['patient_id'] == MAASTRO_OS_target['patient_id']).sum()
# Out:
# 99

# %%
# Rename the column name of response_MAASTRO 
response_MAASTRO.rename(columns = {'Index' : 'patient_id'}, inplace = True)

# %%
# need to choose patient_id from MAASTRO_D2 in response_MAASTRO
data = list(MAASTRO_D2['patient_id'])
mask = response_MAASTRO['patient_id'].isin(data)
response_MAASTRO = response_MAASTRO[mask] 
response_MAASTRO
# Out:
#      patient_id     OS  OS_event    LRC  LRC_event    DFS  DFS_event
# 0             1  62.43       0.0  62.43        0.0  62.43        0.0
# 1             2  60.00       0.0  60.00        0.0  60.00        0.0
# 2             3  44.43       1.0   8.83        1.0   8.83        1.0
# 3             4  37.20       1.0  19.37        0.0  19.73        1.0
# 5             6  59.23       0.0  59.23        0.0  59.23        0.0
# ..          ...    ...       ...    ...        ...    ...        ...
# 109         110  19.00       1.0  13.27        1.0  13.27        1.0
# 110         111  85.87       1.0  82.83        0.0  85.87        1.0
# 111         112  42.87       0.0  42.87        0.0  42.87        0.0
# 112         113  58.93       0.0  58.93        0.0  58.93        0.0
# 113         114  72.07       0.0  72.07        0.0  72.07        0.0
#
# [99 rows x 7 columns]

# %%
# Merge MAASTRO_D2 with response_MAASTRO
clinical_test = pd.merge(MAASTRO_D2, response_MAASTRO, on='patient_id', how='inner')
clinical_test = clinical_test.loc[:, ~clinical_test.columns.isin(['DFS', 'DFS_event', 'LRC', 'LRC_event'])]
clinical_test
# Out:
#     patient_id  shape_Elongation  shape_Flatness  shape_LeastAxisLength  \
# 0            1          0.765178        0.610062              30.504395
# 1            2          0.776540        0.504616              21.069386
# 2            3          0.697164        0.478604              21.238275
# 3            4          0.574636        0.446059              20.570459
# 4            6          0.633419        0.480378              26.130155
# ..         ...               ...             ...                    ...
# 94         110          0.882411        0.577884              19.774388
# 95         111          0.535802        0.455642              23.259099
# 96         112          0.716610        0.631485              31.838169
# 97         113          0.665145        0.628338              28.213278
# 98         114          0.616262        0.469139              17.158420
#
#     shape_MajorAxisLength  shape_Maximum2DDiameterColumn  \
# 0               50.002093                      52.886671
# 1               41.753334                      44.922155
# 2               44.375483                      48.466483
# 3               46.115989                      42.544095
# 4               54.394967                      66.030296
# ..                    ...                            ...
# 94              34.218615                      41.785165
# 95              51.046869                      51.264022
# 96              50.417953                      46.324939
# 97              44.901412                      50.289164
# 98              36.574294                      42.953463
#
#     shape_Maximum2DDiameterRow  shape_Maximum2DDiameterSlice  \
# 0                    58.000000                     47.759816
# 1                    44.294469                     44.147480
# 2                    45.891176                     37.656341
# 3                    47.507894                     33.837849
# 4                    56.320511                     45.398238
# ..                         ...                           ...
# 94                   40.261644                     35.805028
# 95                   51.264022                     33.600595
# 96                   56.035703                     57.070132
# 97                   50.596443                     35.777088
# 98                   39.204592                     26.076810
#
#     shape_Maximum3DDiameter  shape_MeshVolume  ...  LBP_021_PET  LBP_030_PET  \
# 0                 58.864251      38067.208333  ...     0.028808     0.837387
# 1                 48.723711      17870.791667  ...     0.049615     0.806842
# 2                 48.969378      17426.500000  ...     0.019514     0.830272
# 3                 55.226805      12463.791667  ...     0.047155     0.760949
# 4                 67.089492      28300.125000  ...     0.033990     0.824865
# ..                      ...               ...  ...          ...          ...
# 94                43.520110      12822.458333  ...     0.017489     0.834590
# 95                52.440442      18368.291667  ...     0.029979     0.821431
# 96                57.671483      35384.541667  ...     0.017354     0.859957
# 97                51.478151      26180.208333  ...     0.025399     0.847908
# 98                43.485630       8857.958333  ...     0.018885     0.812275
#
#     LBP_102_PET  LBP_111_PET  LBP_120_PET  LBP_201_PET  LBP_210_PET  \
# 0      0.000026     0.001705     0.122209     0.000026     0.008291
# 1      0.000167     0.002958     0.128976     0.000167     0.008148
# 2      0.000057     0.001831     0.137282     0.000000     0.008641
# 3      0.000000     0.003597     0.171595     0.000080     0.013187
# 4      0.000000     0.002116     0.128134     0.000035     0.009379
# ..          ...          ...          ...          ...          ...
# 94     0.000000     0.001321     0.137194     0.000078     0.008706
# 95     0.000000     0.000543     0.137620     0.000054     0.008907
# 96     0.000000     0.000988     0.115099     0.000028     0.005700
# 97     0.000000     0.001487     0.117654     0.000000     0.005759
# 98     0.000000     0.000899     0.156924     0.000112     0.010342
#
#     LBP_300_PET     OS  OS_event
# 0      0.000341  62.43       0.0
# 1      0.000335  60.00       0.0
# 2      0.000229  44.43       1.0
# 3      0.000240  37.20       1.0
# 4      0.000529  59.23       0.0
# ..          ...    ...       ...
# 94     0.000078  19.00       1.0
# 95     0.000489  85.87       1.0
# 96     0.000141  42.87       0.0
# 97     0.000038  58.93       0.0
# 98     0.000337  72.07       0.0
#
# [99 rows x 377 columns]

# %%
# Drop patient_id column
clinical_test = clinical_test.drop('patient_id', axis=1)

# %%
# Some rows have null values in OS, OS_event -> Remove those rows
clinical_test[clinical_test.isnull().any(axis=1)]
clinical_test = clinical_test.dropna(how='any',axis=0)
# Out:
# Empty DataFrame
# Columns: [shape_Elongation, shape_Flatness, shape_LeastAxisLength, shape_MajorAxisLength, shape_Maximum2DDiameterColumn, shape_Maximum2DDiameterRow, shape_Maximum2DDiameterSlice, shape_Maximum3DDiameter, shape_MeshVolume, shape_MinorAxisLength, shape_Sphericity, shape_SurfaceArea, shape_SurfaceVolumeRatio, shape_VoxelVolume, first_order_10Percentile_CT, first_order_90Percentile_CT, first_order_Energy_CT, first_order_Entropy_CT_b20, first_order_InterquartileRange_CT, first_order_Kurtosis_CT, first_order_Maximum_CT, first_order_MeanAbsoluteDeviation_CT, first_order_Mean_CT, first_order_Median_CT, first_order_Minimum_CT, first_order_Range_CT, first_order_RobustMeanAbsoluteDeviation_CT, first_order_RootMeanSquared_CT, first_order_Skewness_CT, first_order_TotalEnergy_CT, first_order_Uniformity_CT_b20, first_order_Variance_CT, glszm_GrayLevelNonUniformity_CT_b20, glszm_GrayLevelNonUniformityNormalized_CT_b20, glszm_GrayLevelVariance_CT_b20, glszm_HighGrayLevelZoneEmphasis_CT_b20, glszm_LargeAreaEmphasis_CT_b20, glszm_LargeAreaHighGrayLevelEmphasis_CT_b20, glszm_LargeAreaLowGrayLevelEmphasis_CT_b20, glszm_LowGrayLevelZoneEmphasis_CT_b20, glszm_SizeZoneNonUniformity_CT_b20, glszm_SizeZoneNonUniformityNormalized_CT_b20, glszm_SmallAreaEmphasis_CT_b20, glszm_SmallAreaHighGrayLevelEmphasis_CT_b20, glszm_SmallAreaLowGrayLevelEmphasis_CT_b20, glszm_ZoneEntropy_CT_b20, glszm_ZonePercentage_CT_b20, glszm_ZoneVariance_CT_b20, glrlm_GrayLevelNonUniformity_CT_b20, glrlm_GrayLevelNonUniformityNormalized_CT_b20, glrlm_GrayLevelVariance_CT_b20, glrlm_HighGrayLevelRunEmphasis_CT_b20, glrlm_LongRunEmphasis_CT_b20, glrlm_LongRunHighGrayLevelEmphasis_CT_b20, glrlm_LongRunLowGrayLevelEmphasis_CT_b20, glrlm_LowGrayLevelRunEmphasis_CT_b20, glrlm_RunEntropy_CT_b20, glrlm_RunLengthNonUniformity_CT_b20, glrlm_RunLengthNonUniformityNormalized_CT_b20, glrlm_RunPercentage_CT_b20, glrlm_RunVariance_CT_b20, glrlm_ShortRunEmphasis_CT_b20, glrlm_ShortRunHighGrayLevelEmphasis_CT_b20, glrlm_ShortRunLowGrayLevelEmphasis_CT_b20, ngtdm_Busyness_d_1_CT_b20, ngtdm_Coarseness_d_1_CT_b20, ngtdm_Complexity_d_1_CT_b20, ngtdm_Contrast_d_1_CT_b20, ngtdm_Strength_d_1_CT_b20, gldm_DependenceEntropy_d_1_CT_b20, gldm_DependenceNonUniformity_d_1_CT_b20, gldm_DependenceNonUniformityNormalized_d_1_CT_b20, gldm_DependenceVariance_d_1_CT_b20, gldm_GrayLevelNonUniformity_d_1_CT_b20, gldm_GrayLevelVariance_d_1_CT_b20, gldm_HighGrayLevelEmphasis_d_1_CT_b20, gldm_LargeDependenceEmphasis_d_1_CT_b20, gldm_LargeDependenceHighGrayLevelEmphasis_d_1_CT_b20, gldm_LargeDependenceLowGrayLevelEmphasis_d_1_CT_b20, gldm_LowGrayLevelEmphasis_d_1_CT_b20, gldm_SmallDependenceEmphasis_d_1_CT_b20, gldm_SmallDependenceHighGrayLevelEmphasis_d_1_CT_b20, gldm_SmallDependenceLowGrayLevelEmphasis_d_1_CT_b20, glcm_Autocorrelation_d_1_CT_b20, glcm_ClusterProminence_d_1_CT_b20, glcm_ClusterShade_d_1_CT_b20, glcm_ClusterTendency_d_1_CT_b20, glcm_Contrast_d_1_CT_b20, glcm_Correlation_d_1_CT_b20, glcm_DifferenceAverage_d_1_CT_b20, glcm_DifferenceEntropy_d_1_CT_b20, glcm_DifferenceVariance_d_1_CT_b20, glcm_Id_d_1_CT_b20, glcm_Idm_d_1_CT_b20, glcm_Idmn_d_1_CT_b20, glcm_Idn_d_1_CT_b20, glcm_Imc1_d_1_CT_b20, glcm_Imc2_d_1_CT_b20, glcm_InverseVariance_d_1_CT_b20, glcm_JointAverage_d_1_CT_b20, ...]
# Index: []
#
# [0 rows x 376 columns]

# %%
# X
X = clinical_train.loc[:, ~clinical_train.columns.isin(['OS', 'event_OS'])]

# y 
y = clinical_train.loc[:, ['OS', 'event_OS']]

# %%
# Set lower, upper time point and times for IBS calculation later 
lower, upper = np.percentile(y['OS'], [10, 90])
times = np.arange(lower, upper)

# y into array 
lists = [] 
for i, j in zip(y['event_OS'], y['OS']): 
    lists.append((i, j))

y = np.array(lists, dtype=[('status', bool), ('time', np.int32)])

# %%
# Shape
print('X_train: ', X.shape)
print('y_train: ', y.shape)
# Out:
# X_train:  (139, 374)
# y_train:  (139,)

# %%
clinical_test.rename(columns = {'OS_event' : 'event_OS'}, inplace = True)

# %%
# X
X_MAASTRO = clinical_test.loc[:, ~clinical_test.columns.isin(['OS', 'event_OS'])]

# y y_MAASTRO
y_MAASTRO = clinical_test.loc[:, ['OS', 'event_OS']]
lower, upper = np.percentile(y_MAASTRO['OS'], [10, 90])
times = np.arange(lower, upper)

# y into array 
lists = [] 
for i, j in zip(y_MAASTRO['event_OS'], y_MAASTRO['OS']): 
    lists.append((i, j))

y_MAASTRO = np.array(lists, dtype=[('status', bool), ('time', np.int32)])

clinical_test.shape
# Out:
# (99, 376)

# %% [markdown]
# # Standardization for Clustering

# %%
original_X = X.copy()

# %%
# Standardize the data 
## Save the column and index 
X_columns = X.columns 
X_index = X.index

### Standardize non-categorical and then concat with the categorical
scaler = MinMaxScaler()  
X_std = scaler.fit_transform(X)
X_std = pd.DataFrame(X_std, columns=X.columns, index=X.index)

# %%
X_std
# Out:
#      shape_Elongation  shape_Flatness  shape_LeastAxisLength  \
# 0            0.461898        0.499075               0.224562
# 1            0.829873        0.220565               0.009452
# 2            0.724738        0.602909               0.323454
# 3            0.839273        0.284579               0.030943
# 4            0.814436        0.345369               0.110132
# ..                ...             ...                    ...
# 134          0.583257        0.479962               0.141584
# 135          0.702369        0.831212               0.347022
# 136          0.720597        0.686245               0.243971
# 137          0.504667        0.427891               0.225551
# 138          0.907943        0.865592               0.231706
#
#      shape_MajorAxisLength  shape_Maximum2DDiameterColumn  \
# 0                 0.350904                       0.324971
# 1                 0.123069                       0.098241
# 2                 0.428640                       0.431058
# 3                 0.135806                       0.084805
# 4                 0.254489                       0.165934
# ..                     ...                            ...
# 134               0.233413                       0.215527
# 135               0.337469                       0.361149
# 136               0.279727                       0.190136
# 137               0.400455                       0.339899
# 138               0.198096                       0.179290
#
#      shape_Maximum2DDiameterRow  shape_Maximum2DDiameterSlice  \
# 0                      0.329524                      0.197367
# 1                      0.105313                      0.112770
# 2                      0.394219                      0.289334
# 3                      0.090131                      0.164684
# 4                      0.259726                      0.189977
# ..                          ...                           ...
# 134                    0.254755                      0.126540
# 135                    0.408289                      0.267366
# 136                    0.307936                      0.291232
# 137                    0.348108                      0.222720
# 138                    0.272710                      0.202202
#
#      shape_Maximum3DDiameter  shape_MeshVolume  shape_MinorAxisLength  ...  \
# 0                   0.298726          0.054040               0.236549  ...
# 1                   0.099559          0.007092               0.167245  ...
# 2                   0.430358          0.098901               0.416103  ...
# 3                   0.145809          0.008753               0.182093  ...
# 4                   0.222333          0.014595               0.290508  ...
# ..                       ...               ...                    ...  ...
# 134                 0.198864          0.026267               0.194288  ...
# 135                 0.351455          0.086360               0.325084  ...
# 136                 0.251133          0.050921               0.280811  ...
# 137                 0.342192          0.061894               0.290628  ...
# 138                 0.216592          0.040149               0.264165  ...
#
#      LBP_003_PET  LBP_012_PET  LBP_021_PET  LBP_030_PET  LBP_102_PET  \
# 0       0.103491     0.073737     0.246552     0.828332     0.000000
# 1       0.293049     0.527489     0.491288     0.381507     0.000000
# 2       0.000000     0.110703     0.324605     0.844232     0.066875
# 3       0.251423     0.433705     0.502847     0.418154     0.000000
# 4       0.000000     0.125399     0.481924     0.337066     0.386334
# ..           ...          ...          ...          ...          ...
# 134     0.000000     0.098308     0.242188     0.782563     0.000000
# 135     0.033028     0.123853     0.382084     0.730419     0.000000
# 136     0.000000     0.020534     0.134210     0.895114     0.000000
# 137     0.000000     0.064801     0.319657     0.711658     0.000000
# 138     0.000000     0.005130     0.095224     0.888815     0.000000
#
#      LBP_111_PET  LBP_120_PET  LBP_201_PET  LBP_210_PET  LBP_300_PET
# 0       0.146370     0.174091     0.088609     0.117134     0.129992
# 1       0.627983     0.456736     0.501821     0.522593     0.262640
# 2       0.181100     0.097341     0.000000     0.100822     0.147717
# 3       0.237064     0.464144     0.000000     0.385850     0.343574
# 4       0.644928     0.518081     0.572624     0.718823     0.543835
# ..           ...          ...          ...          ...          ...
# 134     0.103713     0.242682     0.000000     0.109365     0.126149
# 135     0.294427     0.187835     0.113114     0.172107     0.234892
# 136     0.065712     0.175602     0.000000     0.091309     0.191396
# 137     0.226079     0.265036     0.077871     0.177208     0.265078
# 138     0.070357     0.214934     0.000000     0.076330     0.145166
#
# [139 rows x 374 columns]

# %% [markdown]
# # Feature Selection

# %%
# Choose how many clusters to make 
X_transposed = X_std.T

kmeans = KMeans()
ssd = []
K = range(2, 10)

for k in K:
    kmeans = KMeans(n_clusters=k).fit(X_transposed)
    ssd.append(kmeans.inertia_)

kmeans = KMeans()
visu = KElbowVisualizer(kmeans, k=(2, 10))
visu.fit(clinical_train)
visu.show()
# Out:
# KElbowVisualizer(ax=<AxesSubplot:>, estimator=KMeans(n_clusters=9), k=(2, 10))
# <AxesSubplot:title={'center':'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %%
num_clusters = 5  
kmeans = KMeans(n_clusters=num_clusters)
kmeans.fit(X_std.T)
cluster_labels = kmeans.labels_

selected_features = [] 
for i in range(5):
    variance = X_std[X_std.columns[cluster_labels==i]].var()

    # Find the most correlated column
    high_variance_column = variance.abs().idxmax()

    # Get the correlation coefficient of the most correlated column
    max_variance = variance.abs().max()

    print(i)
    print("Most correlated column:", high_variance_column)
    print("Correlation coefficient:", max_variance)
    print('\n')
    selected_features.append(high_variance_column)
# Out:
# KMeans(n_clusters=5)
# 0
# Most correlated column: glrlm_LowGrayLevelRunEmphasis_PET_b2
# Correlation coefficient: 0.053518478713590514
#
#
# 1
# Most correlated column: gldm_HighGrayLevelEmphasis_d_1_CT_b20
# Correlation coefficient: 0.061791693422458445
#
#
# 2
# Most correlated column: glcm_Autocorrelation_d_1_CT_c16
# Correlation coefficient: 0.05627117308757032
#
#
# 3
# Most correlated column: glszm_SmallAreaEmphasis_PET_b2
# Correlation coefficient: 0.06340059435118155
#
#
# 4
# Most correlated column: first_order_Maximum_CT
# Correlation coefficient: 0.04633836690921384

# %%
selected_features
# Out:
# ['glrlm_LowGrayLevelRunEmphasis_PET_b2',
#  'gldm_HighGrayLevelEmphasis_d_1_CT_b20',
#  'glcm_Autocorrelation_d_1_CT_c16',
#  'glszm_SmallAreaEmphasis_PET_b2',
#  'first_order_Maximum_CT']

# %%
# Selecting features in the DataFrame
X_fs_hv = X[selected_features]
X_new = X_fs_hv.copy()

X_MAASTRO_fs_hv = X_MAASTRO[selected_features]
MAASTRO_new = X_MAASTRO_fs_hv.copy()

# %% [markdown]
# # Standardization

# %%
# Standardize X_new, the new data with the selected features only 
categorical_columns = ['female', 
                        'cavum_oris',
                        'oropharynx',
                        'hypopharynx',
                        'larynx',
                        'histgrade_high',
                        'hpv_related',
                        'charlson',
                        'uicc8_III-IV']

# Set the columns_to_drop which are categorical 
columns_to_drop = [col for col in X_new.columns if col in categorical_columns]

# Drop the columns if they exist in the DataFrame and save the numeric part in X_new_numeric
X_new_categoric = X_new[columns_to_drop]
X_new_numeric = X_new.drop(columns=columns_to_drop, inplace=False)

# Do the standardization for the numeric part 
scaler = MinMaxScaler() 
X_new_numeric_columns = X_new_numeric.columns
X_new_numeric_index = X_new_numeric.index 
X_new_numeric_std = scaler.fit_transform(X_new_numeric)
X_new_numeric_std = pd.DataFrame(X_new_numeric_std,
                                 columns=X_new_numeric_columns, 
                                 index=X_new_numeric_index)
X_new_std = pd.concat([X_new_numeric_std, X_new_categoric], axis=1)

# Change the order of the X_new_std 
X_new_std = X_new_std[X_new.columns]

# %%
# Standardize X_MAASTRO 
# Set the columns_to_drop which are categorical 
columns_to_drop = [col for col in MAASTRO_new.columns if col in categorical_columns]

# Drop the columns if they exist in the DataFrame and save the numeric part in X_new_numeric
MAASTRO_new_categoric = MAASTRO_new[columns_to_drop]
MAASTRO_new_numeric = MAASTRO_new.drop(columns=columns_to_drop, inplace=False)

# Do the standardization for the numeric part 
MAASTRO_new_numeric_columns = MAASTRO_new_numeric.columns
MAASTRO_new_numeric_columns = MAASTRO_new_numeric.columns
MAASTRO_new_numeric_index = MAASTRO_new_numeric.index 
MAASTRO_new_numeric_std = scaler.transform(MAASTRO_new_numeric)
MAASTRO_new_numeric_std = pd.DataFrame(MAASTRO_new_numeric_std,
                                 columns=MAASTRO_new_numeric_columns, 
                                 index=MAASTRO_new_numeric_index)
MAASTRO_new_std = pd.concat([MAASTRO_new_numeric_std, MAASTRO_new_categoric], axis=1)

# Change the order of the X_new_std 
MAASTRO_new_std = MAASTRO_new_std[MAASTRO_new.columns]

# %%
X_new
# Out:
#      glrlm_LowGrayLevelRunEmphasis_PET_b2  \
# 0                                0.133833
# 1                                0.408878
# 2                                0.298136
# 3                                0.713169
# 4                                0.310074
# ..                                    ...
# 134                              0.247042
# 135                              0.237124
# 136                              0.111749
# 137                              0.195533
# 138                              0.084911
#
#      gldm_HighGrayLevelEmphasis_d_1_CT_b20  glcm_Autocorrelation_d_1_CT_c16  \
# 0                              2017.837794                        94.224171
# 1                              1272.602864                       119.164361
# 2                              2671.911415                       116.129599
# 3                              2064.407252                       164.460301
# 4                              1763.529494                       210.184151
# ..                                     ...                              ...
# 134                             842.189040                       170.013539
# 135                            1642.213124                        80.363559
# 136                            1551.393291                       119.378154
# 137                            1051.797561                       197.371851
# 138                            1979.927116                       162.092375
#
#      glszm_SmallAreaEmphasis_PET_b2  first_order_Maximum_CT
# 0                          0.411776             1763.283818
# 1                          0.289067             1432.109636
# 2                          0.167885             1685.931373
# 3                          0.000244             1329.347515
# 4                          0.137526             1197.225910
# ..                              ...                     ...
# 134                        0.125003             1267.959716
# 135                        0.263911             1788.278096
# 136                        0.294605             1478.297861
# 137                        0.237261             1207.068493
# 138                        0.202735             1368.499199
#
# [139 rows x 5 columns]

# %%
X_new_std
# Out:
#      glrlm_LowGrayLevelRunEmphasis_PET_b2  \
# 0                                0.148239
# 1                                0.552620
# 2                                0.389803
# 3                                1.000000
# 4                                0.407354
# ..                                    ...
# 134                              0.314682
# 135                              0.300101
# 136                              0.115769
# 137                              0.238951
# 138                              0.076311
#
#      gldm_HighGrayLevelEmphasis_d_1_CT_b20  glcm_Autocorrelation_d_1_CT_c16  \
# 0                                 0.621409                         0.358521
# 1                                 0.386610                         0.461358
# 2                                 0.827485                         0.448845
# 3                                 0.636081                         0.648129
# 4                                 0.541285                         0.836665
# ..                                     ...                              ...
# 134                               0.251001                         0.671027
# 135                               0.503062                         0.301369
# 136                               0.474448                         0.462240
# 137                               0.317042                         0.783835
# 138                               0.609464                         0.638366
#
#      glszm_SmallAreaEmphasis_PET_b2  first_order_Maximum_CT
# 0                          0.887481                0.379239
# 1                          0.623011                0.185193
# 2                          0.361833                0.333916
# 3                          0.000525                0.124981
# 4                          0.296403                0.047566
# ..                              ...                     ...
# 134                        0.269413                0.089012
# 135                        0.568794                0.393884
# 136                        0.634948                0.212256
# 137                        0.511355                0.053333
# 138                        0.436945                0.147921
#
# [139 rows x 5 columns]

# %%
MAASTRO_new
# Out:
#     glrlm_LowGrayLevelRunEmphasis_PET_b2  \
# 0                               0.108874
# 1                               0.305178
# 2                               0.186982
# 3                               0.260511
# 4                               0.205505
# ..                                   ...
# 94                              0.101497
# 95                              0.157278
# 96                              0.188714
# 97                              0.179410
# 98                              0.268314
#
#     gldm_HighGrayLevelEmphasis_d_1_CT_b20  glcm_Autocorrelation_d_1_CT_c16  \
# 0                             1483.666194                       192.231457
# 1                             2969.880344                        97.043711
# 2                             1981.654020                       189.006881
# 3                             3013.279652                        89.769620
# 4                             2192.606114                       112.952004
# ..                                    ...                              ...
# 94                            1966.765954                        48.979926
# 95                            2656.699180                       171.978518
# 96                            2848.165242                       197.769903
# 97                            2056.250143                       103.710049
# 98                            2791.766749                       111.680520
#
#     glszm_SmallAreaEmphasis_PET_b2  first_order_Maximum_CT
# 0                         0.224914             1226.795917
# 1                         0.051926             1876.570382
# 2                         0.195581             1269.217095
# 3                         0.101441             1951.924395
# 4                         0.088613             1646.853670
# ..                             ...                     ...
# 94                        0.286434             2311.845731
# 95                        0.065943             1299.857157
# 96                        0.132816             1256.024949
# 97                        0.274536             1668.742962
# 98                        0.264816             1654.841840
#
# [99 rows x 5 columns]

# %%
MAASTRO_new_std
# Out:
#     glrlm_LowGrayLevelRunEmphasis_PET_b2  \
# 0                               0.111542
# 1                               0.400156
# 2                               0.226379
# 3                               0.334485
# 4                               0.253613
# ..                                   ...
# 94                              0.100697
# 95                              0.182708
# 96                              0.228927
# 97                              0.215248
# 98                              0.345957
#
#     gldm_HighGrayLevelEmphasis_d_1_CT_b20  glcm_Autocorrelation_d_1_CT_c16  \
# 0                                0.453109                         0.762640
# 1                                0.921365                         0.370147
# 2                                0.610008                         0.749344
# 3                                0.935039                         0.340153
# 4                                0.676472                         0.435743
# ..                                    ...                              ...
# 94                               0.605317                         0.171963
# 95                               0.822692                         0.679130
# 96                               0.883017                         0.785477
# 97                               0.633511                         0.397635
# 98                               0.865247                         0.430500
#
#     glszm_SmallAreaEmphasis_PET_b2  first_order_Maximum_CT
# 0                         0.484745                0.064892
# 1                         0.111913                0.445617
# 2                         0.421525                0.089748
# 3                         0.218631                0.489770
# 4                         0.190983                0.311019
# ..                             ...                     ...
# 94                        0.617336                0.700660
# 95                        0.142123                0.107701
# 96                        0.286251                0.082019
# 97                        0.591692                0.323844
# 98                        0.570745                0.315699
#
# [99 rows x 5 columns]

# %% [markdown]
# # Modelling

# %% [markdown]
# ### 1. CoxPHSurvivalAnalysis

# %% [markdown]
# #### Train

# %%
# Setting the y format for skf below  
y = clinical_train[['OS', 'event_OS']]

# Running to optuna for hyperparameter tuning 
def create_objective(model_class, metric, X, y):
    def objective(trial): 
        # Create and fit survival model 
        model = model_class()
        
        scores = [] 

        skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=123)
        
        for k, (train_index, test_index) in enumerate(skf.split(X, y.iloc[:, 1])): 
            X_train, X_test = X.iloc[train_index], X.iloc[test_index]
            y_train_df, y_test_df = y.iloc[train_index], y.iloc[test_index]
            
            # y_train into array 
            y_train = [] 
            for i, j in zip(y_train_df['event_OS'], y_train_df['OS']): 
                y_train.append((i, j))
            y_train = np.array(y_train, dtype=[('status', bool), ('time', np.int32)])

            # y_test into array
            y_test = [] 
            for i, j in zip(y_test_df['event_OS'], y_test_df['OS']): 
                y_test.append((i, j))
            y_test = np.array(y_test, dtype=[('status', bool), ('time', np.int32)])

            # Min Max Standardization
            excluded_columns = ['female', 
                                'cavum_oris',
                                'oropharynx',
                                'hypopharynx',
                                'larynx',
                                'histgrade_high',
                                'hpv_related',
                                'charlson',
                                'uicc8_III-IV'
                               ]
            excluded_columns = set(excluded_columns).intersection(X.columns)

            scaler = MinMaxScaler() 
            X_train_included = X_train.drop(excluded_columns, axis=1)
            X_test_included = X_test.drop(excluded_columns, axis=1)
                        
            if not X_train_included.empty and not X_test_included.empty:
                X_train_included_std = scaler.fit_transform(X_train_included)
                X_test_included_std = scaler.transform(X_test_included)
                
                # Concatenation
                X_train_std_df = pd.DataFrame(X_train_included_std, columns=X_train_included.columns, index=X_train_included.index)
                X_train_std = pd.concat([X_train_std_df, X_train[excluded_columns]], axis=1)

                X_test_std_df = pd.DataFrame(X_test_included_std, columns=X_test_included.columns, index=X_test_included.index)
                X_test_std = pd.concat([X_test_std_df, X_test[excluded_columns]], axis=1)
            
            else: 
                X_train_std = X_train
                X_test_std = X_test 
            
            model.fit(X_train_std, y_train)

            if metric == "c-index":
                # Make predictions using C-index 
                c_index_score = model.score(X_test_std, y_test)
                scores.append(c_index_score)
                print(f"Fold {k + 1} C-index: {c_index_score}")
                
            elif metric == "ibs":
                # Make predictions using IBS 
                lower, upper = np.percentile(y_test["time"], [10, 90])    
                times = np.arange(lower, upper)
                cox_surv_prob = np.row_stack([fn(times) for fn in model.predict_survival_function(X_test_std)])
                ibs = integrated_brier_score(y_test, y_test, cox_surv_prob, times)
                scores.append(ibs)
                print(f"Fold {k + 1} IBS: {ibs}")
            else:
                raise ValueError("Invalid metric. Use 'C-index' or 'ibs'.")
        
        # Return the mean of scores
        return np.mean(scores)
    
    return objective

# C-index
study_cindex = optuna.create_study(direction="maximize", sampler=optuna.samplers.TPESampler(seed=123))
objective_cindex = create_objective(CoxPHSurvivalAnalysis, "c-index", X_new, y)
study_cindex.optimize(objective_cindex, n_trials=1, show_progress_bar=True)
print("\n")
print("* Best trial for C-index: \n", study_cindex.best_trial)
print("\n")
print("* Best Score for C-index: \n", study_cindex.best_value)

# Example usage for IBS
study_ibs = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(seed=123))
objective_ibs = create_objective(CoxPHSurvivalAnalysis, "ibs", X_new, y)
study_ibs.optimize(objective_ibs, n_trials=1, show_progress_bar=True)
print("\n")
print("* Best trial for IBS: \n", study_ibs.best_trial)
print("\n")
print("* Best Score for IBS: \n", study_ibs.best_value)
# Out:
# [I 2024-04-18 15:32:26,429] A new study created in memory with name: no-name-7e52ced8-8276-402f-8c97-959f9038bbc6
#   0%|          | 0/1 [00:00<?, ?it/s]
# Fold 1 C-index: 0.5757575757575758
# Fold 2 C-index: 0.7008928571428571
# Fold 3 C-index: 0.6911764705882353
# Fold 4 C-index: 0.7848101265822784
# [I 2024-04-18 15:32:27,022] A new study created in memory with name: no-name-964e8e4a-acd5-4b6d-867e-1b9ff75e10cf
# Fold 5 C-index: 0.6572769953051644
# [I 2024-04-18 15:32:27,018] Trial 0 finished with value: 0.6819828050752222 and parameters: {}. Best is trial 0 with value: 0.6819828050752222.
#
#
# * Best trial for C-index:
#  FrozenTrial(number=0, state=TrialState.COMPLETE, values=[0.6819828050752222], datetime_start=datetime.datetime(2024, 4, 18, 15, 32, 26, 672078), datetime_complete=datetime.datetime(2024, 4, 18, 15, 32, 27, 17793), params={}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={}, trial_id=0, value=None)
#
#
# * Best Score for C-index:
#  0.6819828050752222
#   0%|          | 0/1 [00:00<?, ?it/s]
# Fold 1 IBS: 0.20987262133292206
# Fold 2 IBS: 0.19599327849180784
# Fold 3 IBS: 0.18652280797191473
# Fold 4 IBS: 0.1876056238803755
# Fold 5 IBS: 0.24669719485123703
# [I 2024-04-18 15:32:27,646] Trial 0 finished with value: 0.2053383053056514 and parameters: {}. Best is trial 0 with value: 0.2053383053056514.
#
#
# * Best trial for IBS:
#  FrozenTrial(number=0, state=TrialState.COMPLETE, values=[0.2053383053056514], datetime_start=datetime.datetime(2024, 4, 18, 15, 32, 27, 212360), datetime_complete=datetime.datetime(2024, 4, 18, 15, 32, 27, 646248), params={}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={}, trial_id=0, value=None)
#
#
# * Best Score for IBS:
#  0.2053383053056514

# %%
# Setting a dictionary to save the train results 
train_cindex = {} 
train_ibs = {} 

# Saving the values to the dictionary 
train_cindex['CoxPH'] = np.round(study_cindex.best_value, 3)
train_ibs['CoxPH'] = np.round(study_ibs.best_value, 3)

# %%
print("train_cindex: ", np.round(study_cindex.best_value, 3))
print("train_ibs: ", np.round(study_ibs.best_value, 3))
# Out:
# train_cindex:  0.682
# train_ibs:  0.205

# %% [markdown]
# #### Test

# %%
# y into array 
lists = [] 
for i, j in zip(y['event_OS'], y['OS']): 
    lists.append((i, j))

y = np.array(lists, dtype=[('status', bool), ('time', np.int32)])

# %%
# Test on MAASTRO 
cph = CoxPHSurvivalAnalysis()

cph.fit(X_new_std, y)

# Save C-index 
c_index = cph.score(MAASTRO_new_std, y_MAASTRO)
c_index = np.round(c_index, 3)
print('Concordance index:', c_index)

# Save IBS 
lower, upper = np.percentile(y_MAASTRO["time"], [10, 90])
times = np.arange(lower, upper)
surv_prob = np.row_stack([fn(times) for fn in cph.predict_survival_function(MAASTRO_new_std)])
ibs = integrated_brier_score(y_MAASTRO,y_MAASTRO, surv_prob, times)
ibs = np.round(ibs, 3)
print('IBS score:', ibs)
# Out:
# CoxPHSurvivalAnalysis()
# Concordance index: 0.625
# IBS score: 0.216

# %%
# Setting a dictionary to save the test results 
test_cindex = {} 
test_ibs = {}

# %%
# Saving the values to the dictionary 
test_cindex['CoxPH'] = c_index
test_ibs['CoxPH'] = ibs

# %% [markdown]
# ### 2. CoxnetSurvivalAnalysis - Ridge

# %% [markdown]
# #### Train

# %%
# Setting the y format 
y = clinical_train[['OS', 'event_OS']]

# Running to optuna for hyperparameter tuning 
def create_objective(model_class, metric, X, y):
    def objective(trial): 
        # Create and fit survival model 
        model = model_class(l1_ratio=0.0000001, 
                            fit_baseline_model=True)
        
        scores = [] 

        skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=123)
        
        for k, (train_index, test_index) in enumerate(skf.split(X, y.iloc[:, 1])): 
            X_train, X_test = X.iloc[train_index], X.iloc[test_index]
            y_train_df, y_test_df = y.iloc[train_index], y.iloc[test_index]
            
            # y_train into array 
            y_train = [] 
            for i, j in zip(y_train_df['event_OS'], y_train_df['OS']): 
                y_train.append((i, j))
            y_train = np.array(y_train, dtype=[('status', bool), ('time', np.int32)])

            # y_test into array
            y_test = [] 
            for i, j in zip(y_test_df['event_OS'], y_test_df['OS']): 
                y_test.append((i, j))
            y_test = np.array(y_test, dtype=[('status', bool), ('time', np.int32)])

            # Min Max Standardization
            excluded_columns = ['female', 
                                'cavum_oris',
                                'oropharynx',
                                'hypopharynx',
                                'larynx',
                                'histgrade_high',
                                'hpv_related',
                                'charlson',
                                'uicc8_III-IV'
                               ]
            excluded_columns = set(excluded_columns).intersection(X.columns)

            scaler = MinMaxScaler() 
            X_train_included = X_train.drop(excluded_columns, axis=1)
            X_test_included = X_test.drop(excluded_columns, axis=1)
                        
            if not X_train_included.empty and not X_test_included.empty:
                X_train_included_std = scaler.fit_transform(X_train_included)
                X_test_included_std = scaler.transform(X_test_included)
                
                # Concatenation
                X_train_std_df = pd.DataFrame(X_train_included_std, columns=X_train_included.columns, index=X_train_included.index)
                X_train_std = pd.concat([X_train_std_df, X_train[excluded_columns]], axis=1)

                X_test_std_df = pd.DataFrame(X_test_included_std, columns=X_test_included.columns, index=X_test_included.index)
                X_test_std = pd.concat([X_test_std_df, X_test[excluded_columns]], axis=1)
            
            else: 
                X_train_std = X_train
                X_test_std = X_test 
            
            model.fit(X_train_std, y_train)

            if metric == "c-index":
                # Make predictions using C-index 
                c_index_score = model.score(X_test_std, y_test)
                scores.append(c_index_score)
                print(f"Fold {k + 1} C-index: {c_index_score}")
                
            elif metric == "ibs":
                # Make predictions using IBS 
                lower, upper = np.percentile(y_test["time"], [10, 90])    
                times = np.arange(lower, upper)
                cox_surv_prob = np.row_stack([fn(times) for fn in model.predict_survival_function(X_test_std)])
                ibs = integrated_brier_score(y_test, y_test, cox_surv_prob, times)
                scores.append(ibs)
                print(f"Fold {k + 1} IBS: {ibs}")
            else:
                raise ValueError("Invalid metric. Use 'C-index' or 'ibs'.")
        
        # Return the mean of scores
        return np.mean(scores)
    
    return objective

# C-index
study_cindex = optuna.create_study(direction="maximize", sampler=optuna.samplers.TPESampler(seed=123))
objective_cindex = create_objective(CoxnetSurvivalAnalysis, "c-index", X_new, y)
study_cindex.optimize(objective_cindex, n_trials=1, show_progress_bar=True)
print("\n")
print("* Best trial for C-index: \n", study_cindex.best_trial)
print("\n")
print("* Best Score for C-index: \n", study_cindex.best_value)

# Example usage for IBS
study_ibs = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(seed=123))
objective_ibs = create_objective(CoxnetSurvivalAnalysis, "ibs", X_new, y)
study_ibs.optimize(objective_ibs, n_trials=1, show_progress_bar=True)
print("\n")
print("* Best trial for IBS: \n", study_ibs.best_trial)
print("\n")
print("* Best Score for IBS: \n", study_ibs.best_value)
# Out:
# [I 2024-04-18 15:32:28,074] A new study created in memory with name: no-name-8189b716-c50c-47c3-bc7e-04ca8d3a2a17
#   0%|          | 0/1 [00:00<?, ?it/s]
# [I 2024-04-18 15:32:28,454] A new study created in memory with name: no-name-fcad07e7-42fc-4bb3-99c7-b7d8740bb832
# Fold 1 C-index: 0.5844155844155844
# Fold 2 C-index: 0.6919642857142857
# Fold 3 C-index: 0.6838235294117647
# Fold 4 C-index: 0.7552742616033755
# Fold 5 C-index: 0.6150234741784038
# [I 2024-04-18 15:32:28,409] Trial 0 finished with value: 0.6661002270646827 and parameters: {}. Best is trial 0 with value: 0.6661002270646827.
#
#
# * Best trial for C-index:
#  FrozenTrial(number=0, state=TrialState.COMPLETE, values=[0.6661002270646827], datetime_start=datetime.datetime(2024, 4, 18, 15, 32, 28, 221070), datetime_complete=datetime.datetime(2024, 4, 18, 15, 32, 28, 409329), params={}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={}, trial_id=0, value=None)
#
#
# * Best Score for C-index:
#  0.6661002270646827
#   0%|          | 0/1 [00:00<?, ?it/s]
# Fold 1 IBS: 0.21397652041130774
# Fold 2 IBS: 0.22157791531152185
# Fold 3 IBS: 0.2045359454751937
# Fold 4 IBS: 0.22473803934427816
# Fold 5 IBS: 0.21812431528818227
# [I 2024-04-18 15:32:28,738] Trial 0 finished with value: 0.21659054716609677 and parameters: {}. Best is trial 0 with value: 0.21659054716609677.
#
#
# * Best trial for IBS:
#  FrozenTrial(number=0, state=TrialState.COMPLETE, values=[0.21659054716609677], datetime_start=datetime.datetime(2024, 4, 18, 15, 32, 28, 497005), datetime_complete=datetime.datetime(2024, 4, 18, 15, 32, 28, 737936), params={}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={}, trial_id=0, value=None)
#
#
# * Best Score for IBS:
#  0.21659054716609677

# %%
train_cindex['CoxRidge'] = np.round(study_cindex.best_value, 3)
train_ibs['CoxRidge'] = np.round(study_ibs.best_value, 3)

# %%
print("train_cindex: ", np.round(study_cindex.best_value, 3))
print("train_ibs: ", np.round(study_ibs.best_value, 3))
# Out:
# train_cindex:  0.666
# train_ibs:  0.217

# %% [markdown]
# #### Test

# %%
# y into array 
lists = [] 
for i, j in zip(y['event_OS'], y['OS']): 
    lists.append((i, j))

y = np.array(lists, dtype=[('status', bool), ('time', np.int32)])

# %%
# A function for building the best model with the best parameters 
def create_best_model(model_class, best_params):
    best_params['l1_ratio'] = 0.0000001
    best_params['fit_baseline_model']=True
    return model_class(**best_params)

# Set the best model 
best_model_cindex = create_best_model(CoxnetSurvivalAnalysis, 
                                      study_cindex.best_params)

# Train the best model for C-index on the whole dataset
best_model_cindex.fit(X_new_std, y)

# Evaluate the best model for C-index on MAASTRO dataset
c_index = best_model_cindex.score(MAASTRO_new_std, y_MAASTRO)
c_index = np.round(c_index, 3)
print("test_cindex :", c_index)

# Set the best model 
best_model_ibs = create_best_model(CoxnetSurvivalAnalysis, study_ibs.best_params)

# Train the best model for IBS on the whole dataset
best_model_ibs.fit(X_new_std, y)

# Evaluate the best model for IBS on MAASTRO dataset
lower, upper = np.percentile(y_MAASTRO["time"], [10, 90])
times = np.arange(lower, upper)
surv_prob = np.row_stack([fn(times) for fn in best_model_ibs.predict_survival_function(MAASTRO_new_std)])
ibs = integrated_brier_score(y_MAASTRO,y_MAASTRO, surv_prob, times)
ibs = np.round(ibs, 3)
print("test_ibs: ", ibs)
# Out:
# CoxnetSurvivalAnalysis(fit_baseline_model=True, l1_ratio=1e-07)
# test_cindex : 0.624
# CoxnetSurvivalAnalysis(fit_baseline_model=True, l1_ratio=1e-07)
# test_ibs:  0.221

# %%
# Saving the values to the dictionary 
test_cindex['CoxRidge'] = c_index
test_ibs['CoxRidge'] = ibs

# %% [markdown]
# ### 3. CoxnetSurvivalAnalysis - Lasso

# %% [markdown]
# #### Train

# %%
# Setting the y format 
y = clinical_train[['OS', 'event_OS']]

def create_objective(model_class, metric, X, y):
    def objective(trial): 
        # Create and fit survival model 
        model = model_class(l1_ratio=1, 
                            fit_baseline_model=True)
        
        scores = [] 

        skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=123)
        
        for k, (train_index, test_index) in enumerate(skf.split(X, y.iloc[:, 1])): 
            X_train, X_test = X.iloc[train_index], X.iloc[test_index]
            y_train_df, y_test_df = y.iloc[train_index], y.iloc[test_index]
            
            # y_train into array 
            y_train = [] 
            for i, j in zip(y_train_df['event_OS'], y_train_df['OS']): 
                y_train.append((i, j))
            y_train = np.array(y_train, dtype=[('status', bool), ('time', np.int32)])

            # y_test into array
            y_test = [] 
            for i, j in zip(y_test_df['event_OS'], y_test_df['OS']): 
                y_test.append((i, j))
            y_test = np.array(y_test, dtype=[('status', bool), ('time', np.int32)])

            # Min Max Standardization
            excluded_columns = ['female', 
                                'cavum_oris',
                                'oropharynx',
                                'hypopharynx',
                                'larynx',
                                'histgrade_high',
                                'hpv_related',
                                'charlson',
                                'uicc8_III-IV'
                               ]
            excluded_columns = set(excluded_columns).intersection(X.columns)

            scaler = MinMaxScaler() 
            X_train_included = X_train.drop(excluded_columns, axis=1)
            X_test_included = X_test.drop(excluded_columns, axis=1)
                        
            if not X_train_included.empty and not X_test_included.empty:
                X_train_included_std = scaler.fit_transform(X_train_included)
                X_test_included_std = scaler.transform(X_test_included)
                
                # Concatenation
                X_train_std_df = pd.DataFrame(X_train_included_std, columns=X_train_included.columns, index=X_train_included.index)
                X_train_std = pd.concat([X_train_std_df, X_train[excluded_columns]], axis=1)

                X_test_std_df = pd.DataFrame(X_test_included_std, columns=X_test_included.columns, index=X_test_included.index)
                X_test_std = pd.concat([X_test_std_df, X_test[excluded_columns]], axis=1)
            
            else: 
                X_train_std = X_train
                X_test_std = X_test 
            
            model.fit(X_train_std, y_train)

            if metric == "c-index":
                # Make predictions using C-index 
                c_index_score = model.score(X_test_std, y_test)
                scores.append(c_index_score)
                print(f"Fold {k + 1} C-index: {c_index_score}")
                
            elif metric == "ibs":
                # Make predictions using IBS 
                lower, upper = np.percentile(y_test["time"], [10, 90])    
                times = np.arange(lower, upper)
                cox_surv_prob = np.row_stack([fn(times) for fn in model.predict_survival_function(X_test_std)])
                ibs = integrated_brier_score(y_test, y_test, cox_surv_prob, times)
                scores.append(ibs)
                print(f"Fold {k + 1} IBS: {ibs}")
            else:
                raise ValueError("Invalid metric. Use 'C-index' or 'ibs'.")
        
        # Return the mean of scores
        return np.mean(scores)
    
    return objective

# C-index
study_cindex = optuna.create_study(direction="maximize", sampler=optuna.samplers.TPESampler(seed=123))
objective_cindex = create_objective(CoxnetSurvivalAnalysis, "c-index", X_new, y)
study_cindex.optimize(objective_cindex, n_trials=1, show_progress_bar=True)
print("\n")
print("* Best trial for C-index: \n", study_cindex.best_trial)
print("\n")
print("* Best Score for C-index: \n", study_cindex.best_value)

# Example usage for IBS
study_ibs = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(seed=123))
objective_ibs = create_objective(CoxnetSurvivalAnalysis, "ibs", X_new, y)
study_ibs.optimize(objective_ibs, n_trials=1, show_progress_bar=True)
print("\n")
print("* Best trial for IBS: \n", study_ibs.best_trial)
print("\n")
print("* Best Score for IBS: \n", study_ibs.best_value)
# Out:
# [I 2024-04-18 15:32:29,156] A new study created in memory with name: no-name-5c891d0d-c367-4924-bd91-ee99e231ae23
#   0%|          | 0/1 [00:00<?, ?it/s]
# Fold 1 C-index: 0.5800865800865801
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7890295358649789
# Fold 5 C-index: 0.6713615023474179
# [I 2024-04-18 15:32:29,754] Trial 0 finished with value: 0.6883826385057338 and parameters: {}. Best is trial 0 with value: 0.6883826385057338.
# [I 2024-04-18 15:32:29,832] A new study created in memory with name: no-name-0f2baac2-26ff-48e5-929b-22ae812db6d4
# * Best trial for C-index:
#  FrozenTrial(number=0, state=TrialState.COMPLETE, values=[0.6883826385057338], datetime_start=datetime.datetime(2024, 4, 18, 15, 32, 29, 206362), datetime_complete=datetime.datetime(2024, 4, 18, 15, 32, 29, 754015), params={}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={}, trial_id=0, value=None)
#
#
# * Best Score for C-index:
#  0.6883826385057338
#   0%|          | 0/1 [00:00<?, ?it/s]
# Fold 1 IBS: 0.20800697492537626
# Fold 2 IBS: 0.19572506403735254
# Fold 3 IBS: 0.18485454862672576
# Fold 4 IBS: 0.18807815234008982
# Fold 5 IBS: 0.24623096124446583
# [I 2024-04-18 15:32:30,680] Trial 0 finished with value: 0.20457914023480206 and parameters: {}. Best is trial 0 with value: 0.20457914023480206.
#
#
# * Best trial for IBS:
#  FrozenTrial(number=0, state=TrialState.COMPLETE, values=[0.20457914023480206], datetime_start=datetime.datetime(2024, 4, 18, 15, 32, 29, 869002), datetime_complete=datetime.datetime(2024, 4, 18, 15, 32, 30, 679745), params={}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={}, trial_id=0, value=None)
#
#
# * Best Score for IBS:
#  0.20457914023480206

# %%
train_cindex['CoxLasso'] = np.round(study_cindex.best_value, 3)
train_ibs['CoxLasso'] = np.round(study_ibs.best_value, 3)

# %%
print("train_cindex: ", np.round(study_cindex.best_value, 3))
print("train_ibs: ", np.round(study_ibs.best_value, 3))
# Out:
# train_cindex:  0.688
# train_ibs:  0.205

# %% [markdown]
# #### Test

# %%
# y into array 
lists = [] 
for i, j in zip(y['event_OS'], y['OS']): 
    lists.append((i, j))

y = np.array(lists, dtype=[('status', bool), ('time', np.int32)])

# %%
# A function for building the best model with the best parameters 
def create_best_model(model_class, best_params):
    best_params['l1_ratio'] = 1
    best_params['fit_baseline_model']=True
    return model_class(**best_params)

# Set the best model 
best_model_cindex = create_best_model(CoxnetSurvivalAnalysis, 
                                      study_cindex.best_params)

# Train the best model for C-index on the whole dataset
best_model_cindex.fit(X_new_std, y)

# Evaluate the best model for C-index on MAASTRO dataset
c_index = best_model_cindex.score(MAASTRO_new_std, y_MAASTRO)
c_index = np.round(c_index, 3)
print("test_cindex :", c_index)

# Set the best model 
best_model_ibs = create_best_model(CoxnetSurvivalAnalysis, study_ibs.best_params)

# Train the best model for IBS on the whole dataset
best_model_ibs.fit(X_new_std, y)

# Evaluate the best model for IBS on MAASTRO dataset
lower, upper = np.percentile(y_MAASTRO["time"], [10, 90])
times = np.arange(lower, upper)
surv_prob = np.row_stack([fn(times) for fn in best_model_ibs.predict_survival_function(MAASTRO_new_std)])
ibs = integrated_brier_score(y_MAASTRO,y_MAASTRO, surv_prob, times)
ibs = np.round(ibs, 3)
print("test_ibs: ", ibs)
# Out:
# CoxnetSurvivalAnalysis(fit_baseline_model=True, l1_ratio=1)
# test_cindex : 0.626
# CoxnetSurvivalAnalysis(fit_baseline_model=True, l1_ratio=1)
# test_ibs:  0.215

# %%
# Saving the values to the dictionary 
test_cindex['CoxLasso'] = c_index
test_ibs['CoxLasso'] = ibs

# %% [markdown]
# ### 4. CoxnetSurvivalAnalysis - ElasticNet

# %% [markdown]
# #### Train

# %%
# Setting the y format 
y = clinical_train[['OS', 'event_OS']]

def create_objective(model_class, metric, X, y):
    def objective(trial): 
        # Suggest values for hyperparameters
        l1_ratio = trial.suggest_float("l1_ratio", 0.0001, 1)
        
        # Create and fit survival model 
        model = model_class(l1_ratio=l1_ratio, 
                           fit_baseline_model=True)
        
        scores = [] 

        skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=123)
        
        for k, (train_index, test_index) in enumerate(skf.split(X, y.iloc[:, 1])): 
            X_train, X_test = X.iloc[train_index], X.iloc[test_index]
            y_train_df, y_test_df = y.iloc[train_index], y.iloc[test_index]
            
            # y_train into array 
            y_train = [] 
            for i, j in zip(y_train_df['event_OS'], y_train_df['OS']): 
                y_train.append((i, j))
            y_train = np.array(y_train, dtype=[('status', bool), ('time', np.int32)])

            # y_test into array
            y_test = [] 
            for i, j in zip(y_test_df['event_OS'], y_test_df['OS']): 
                y_test.append((i, j))
            y_test = np.array(y_test, dtype=[('status', bool), ('time', np.int32)])

            # Min Max Standardization
            excluded_columns = ['female', 
                                'cavum_oris',
                                'oropharynx',
                                'hypopharynx',
                                'larynx',
                                'histgrade_high',
                                'hpv_related',
                                'charlson',
                                'uicc8_III-IV'
                               ]
            excluded_columns = set(excluded_columns).intersection(X.columns)

            scaler = MinMaxScaler() 
            X_train_included = X_train.drop(excluded_columns, axis=1)
            X_test_included = X_test.drop(excluded_columns, axis=1)
                        
            if not X_train_included.empty and not X_test_included.empty:
                X_train_included_std = scaler.fit_transform(X_train_included)
                X_test_included_std = scaler.transform(X_test_included)
                
                # Concatenation
                X_train_std_df = pd.DataFrame(X_train_included_std, columns=X_train_included.columns, index=X_train_included.index)
                X_train_std = pd.concat([X_train_std_df, X_train[excluded_columns]], axis=1)

                X_test_std_df = pd.DataFrame(X_test_included_std, columns=X_test_included.columns, index=X_test_included.index)
                X_test_std = pd.concat([X_test_std_df, X_test[excluded_columns]], axis=1)
            
            else: 
                X_train_std = X_train
                X_test_std = X_test 
            
            model.fit(X_train_std, y_train)

            if metric == "c-index":
                # Make predictions using C-index 
                c_index_score = model.score(X_test_std, y_test)
                scores.append(c_index_score)
                print(f"Fold {k + 1} C-index: {c_index_score}")
                
            elif metric == "ibs":
                # Make predictions using IBS 
                lower, upper = np.percentile(y_test["time"], [10, 90])    
                times = np.arange(lower, upper)
                cox_surv_prob = np.row_stack([fn(times) for fn in model.predict_survival_function(X_test_std)])
                ibs = integrated_brier_score(y_test, y_test, cox_surv_prob, times)
                scores.append(ibs)
                print(f"Fold {k + 1} IBS: {ibs}")
            else:
                raise ValueError("Invalid metric. Use 'C-index' or 'ibs'.")
        
        # Return the mean of scores
        return np.mean(scores)
    
    return objective

# C-index
study_cindex = optuna.create_study(direction="maximize", sampler=optuna.samplers.TPESampler(seed=123))
objective_cindex = create_objective(CoxnetSurvivalAnalysis, "c-index", X_new, y)
study_cindex.optimize(objective_cindex, n_trials=100, show_progress_bar=True)
print("\n")
print("* Best trial for C-index: \n", study_cindex.best_trial)
print("\n")
print("* Best Score for C-index: \n", study_cindex.best_value)

# Example usage for IBS
study_ibs = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(seed=123))
objective_ibs = create_objective(CoxnetSurvivalAnalysis, "ibs", X_new, y)
study_ibs.optimize(objective_ibs, n_trials=100, show_progress_bar=True)
print("\n")
print("* Best trial for IBS: \n", study_ibs.best_trial)
print("\n")
print("* Best Score for IBS: \n", study_ibs.best_value)
# Out:
# [I 2024-04-18 15:32:31,393] A new study created in memory with name: no-name-b932113e-15e4-4cd3-a46d-03eac242ac6e
#   0%|          | 0/100 [00:00<?, ?it/s]
# Fold 1 C-index: 0.5757575757575758
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7848101265822784
# Fold 5 C-index: 0.6666666666666666
# [I 2024-04-18 15:32:32,179] Trial 0 finished with value: 0.6857339886472424 and parameters: {'l1_ratio': 0.6964995386793018}. Best is trial 0 with value: 0.6857339886472424.
# Fold 1 C-index: 0.5714285714285714
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7805907172995781
# Fold 5 C-index: 0.6666666666666666
# [I 2024-04-18 15:32:32,876] Trial 1 finished with value: 0.6840243059249016 and parameters: {'l1_ratio': 0.28621072101688444}. Best is trial 0 with value: 0.6857339886472424.
# Fold 1 C-index: 0.5714285714285714
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7805907172995781
# Fold 5 C-index: 0.6666666666666666
# [I 2024-04-18 15:32:33,478] Trial 2 finished with value: 0.6840243059249016 and parameters: {'l1_ratio': 0.22692876841884668}. Best is trial 0 with value: 0.6857339886472424.
# Fold 1 C-index: 0.5714285714285714
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7805907172995781
# Fold 5 C-index: 0.6666666666666666
# [I 2024-04-18 15:32:34,115] Trial 3 finished with value: 0.6840243059249016 and parameters: {'l1_ratio': 0.5513596376059829}. Best is trial 0 with value: 0.6857339886472424.
# Fold 1 C-index: 0.5757575757575758
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7848101265822784
# Fold 5 C-index: 0.6666666666666666
# [I 2024-04-18 15:32:34,697] Trial 4 finished with value: 0.6857339886472424 and parameters: {'l1_ratio': 0.7194970228885845}. Best is trial 0 with value: 0.6857339886472424.
# Fold 1 C-index: 0.5714285714285714
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7805907172995781
# Fold 5 C-index: 0.6666666666666666
# [I 2024-04-18 15:32:35,298] Trial 5 finished with value: 0.6840243059249016 and parameters: {'l1_ratio': 0.4231641494784485}. Best is trial 0 with value: 0.6857339886472424.
# Fold 1 C-index: 0.5800865800865801
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7890295358649789
# Fold 5 C-index: 0.6713615023474179
# [I 2024-04-18 15:32:35,851] Trial 6 finished with value: 0.6883826385057338 and parameters: {'l1_ratio': 0.980766121964777}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5757575757575758
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7848101265822784
# Fold 5 C-index: 0.6666666666666666
# [I 2024-04-18 15:32:36,514] Trial 7 finished with value: 0.6857339886472424 and parameters: {'l1_ratio': 0.6848612556110047}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5714285714285714
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7805907172995781
# Fold 5 C-index: 0.6666666666666666
# [I 2024-04-18 15:32:37,240] Trial 8 finished with value: 0.6840243059249016 and parameters: {'l1_ratio': 0.4809838082942125}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5714285714285714
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7805907172995781
# Fold 5 C-index: 0.6666666666666666
# [I 2024-04-18 15:32:37,873] Trial 9 finished with value: 0.6840243059249016 and parameters: {'l1_ratio': 0.3921783064423311}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5800865800865801
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7890295358649789
# Fold 5 C-index: 0.6713615023474179
# [I 2024-04-18 15:32:38,221] Trial 10 finished with value: 0.6883826385057338 and parameters: {'l1_ratio': 0.9843563326681124}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5800865800865801
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7890295358649789
# Fold 5 C-index: 0.6713615023474179
# [I 2024-04-18 15:32:38,753] Trial 11 finished with value: 0.6883826385057338 and parameters: {'l1_ratio': 0.9972280068904047}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5800865800865801
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7890295358649789
# Fold 5 C-index: 0.6713615023474179
# [I 2024-04-18 15:32:39,320] Trial 12 finished with value: 0.6883826385057338 and parameters: {'l1_ratio': 0.9946087870438435}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5800865800865801
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7848101265822784
# Fold 5 C-index: 0.6713615023474179
# [I 2024-04-18 15:32:39,874] Trial 13 finished with value: 0.6875387566491937 and parameters: {'l1_ratio': 0.8521165717679541}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5757575757575758
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7763713080168776
# Fold 5 C-index: 0.6666666666666666
# [I 2024-04-18 15:32:40,391] Trial 14 finished with value: 0.6840462249341623 and parameters: {'l1_ratio': 0.1015556329868651}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5800865800865801
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7890295358649789
# Fold 5 C-index: 0.6713615023474179
# [I 2024-04-18 15:32:40,859] Trial 15 finished with value: 0.6883826385057338 and parameters: {'l1_ratio': 0.8659212232095017}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5800865800865801
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7890295358649789
# Fold 5 C-index: 0.6713615023474179
# [I 2024-04-18 15:32:41,736] Trial 16 finished with value: 0.6883826385057338 and parameters: {'l1_ratio': 0.8592866247617579}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5757575757575758
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7848101265822784
# Fold 5 C-index: 0.6713615023474179
# [I 2024-04-18 15:32:42,093] Trial 17 finished with value: 0.6866729557833928 and parameters: {'l1_ratio': 0.8140829029918109}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5757575757575758
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7805907172995781
# Fold 5 C-index: 0.6666666666666666
# [I 2024-04-18 15:32:42,668] Trial 18 finished with value: 0.6848901067907025 and parameters: {'l1_ratio': 0.5819463953201167}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5800865800865801
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7890295358649789
# Fold 5 C-index: 0.6713615023474179
# [I 2024-04-18 15:32:43,184] Trial 19 finished with value: 0.6883826385057338 and parameters: {'l1_ratio': 0.9535087433508003}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5757575757575758
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7848101265822784
# Fold 5 C-index: 0.6666666666666666
# [I 2024-04-18 15:32:43,707] Trial 20 finished with value: 0.6857339886472424 and parameters: {'l1_ratio': 0.7540198302114602}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5800865800865801
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7890295358649789
# Fold 5 C-index: 0.6713615023474179
# [I 2024-04-18 15:32:44,332] Trial 21 finished with value: 0.6883826385057338 and parameters: {'l1_ratio': 0.9453140545316446}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5800865800865801
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7890295358649789
# Fold 5 C-index: 0.6713615023474179
# [I 2024-04-18 15:32:44,672] Trial 22 finished with value: 0.6883826385057338 and parameters: {'l1_ratio': 0.9952149413953396}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5800865800865801
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7890295358649789
# Fold 5 C-index: 0.6713615023474179
# [I 2024-04-18 15:32:45,141] Trial 23 finished with value: 0.6883826385057338 and parameters: {'l1_ratio': 0.8898693182098678}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5757575757575758
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7890295358649789
# Fold 5 C-index: 0.6713615023474179
# [I 2024-04-18 15:32:45,737] Trial 24 finished with value: 0.6875168376399329 and parameters: {'l1_ratio': 0.7805647035680947}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5800865800865801
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7890295358649789
# Fold 5 C-index: 0.6713615023474179
# [I 2024-04-18 15:32:46,259] Trial 25 finished with value: 0.6883826385057338 and parameters: {'l1_ratio': 0.9368557715647121}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5757575757575758
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.6715686274509803
# Fold 4 C-index: 0.7763713080168776
# Fold 5 C-index: 0.6103286384976526
# [I 2024-04-18 15:32:46,444] Trial 26 finished with value: 0.6678766585160458 and parameters: {'l1_ratio': 0.015423757551295547}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5757575757575758
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7805907172995781
# Fold 5 C-index: 0.6666666666666666
# [I 2024-04-18 15:32:47,077] Trial 27 finished with value: 0.6848901067907025 and parameters: {'l1_ratio': 0.6022588122254688}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5757575757575758
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7848101265822784
# Fold 5 C-index: 0.6666666666666666
# [I 2024-04-18 15:32:47,785] Trial 28 finished with value: 0.6857339886472424 and parameters: {'l1_ratio': 0.6499747968454208}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5800865800865801
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7890295358649789
# Fold 5 C-index: 0.6713615023474179
# [I 2024-04-18 15:32:48,516] Trial 29 finished with value: 0.6883826385057338 and parameters: {'l1_ratio': 0.9010792166439672}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5757575757575758
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7890295358649789
# Fold 5 C-index: 0.6713615023474179
# [I 2024-04-18 15:32:49,024] Trial 30 finished with value: 0.6875168376399329 and parameters: {'l1_ratio': 0.8107108448948633}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5800865800865801
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7890295358649789
# Fold 5 C-index: 0.6713615023474179
# [I 2024-04-18 15:32:49,575] Trial 31 finished with value: 0.6883826385057338 and parameters: {'l1_ratio': 0.9790160904460925}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5800865800865801
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7890295358649789
# Fold 5 C-index: 0.6713615023474179
# [I 2024-04-18 15:32:50,077] Trial 32 finished with value: 0.6883826385057338 and parameters: {'l1_ratio': 0.9889509715055751}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5800865800865801
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7890295358649789
# Fold 5 C-index: 0.6713615023474179
# [I 2024-04-18 15:32:50,389] Trial 33 finished with value: 0.6883826385057338 and parameters: {'l1_ratio': 0.9033942188713268}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5800865800865801
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7890295358649789
# Fold 5 C-index: 0.6713615023474179
# [I 2024-04-18 15:32:50,899] Trial 34 finished with value: 0.6883826385057338 and parameters: {'l1_ratio': 0.9969906676119189}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5800865800865801
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7890295358649789
# Fold 5 C-index: 0.6713615023474179
# [I 2024-04-18 15:32:51,461] Trial 35 finished with value: 0.6883826385057338 and parameters: {'l1_ratio': 0.9145273991086058}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5714285714285714
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7805907172995781
# Fold 5 C-index: 0.6666666666666666
# [I 2024-04-18 15:32:52,254] Trial 36 finished with value: 0.6840243059249016 and parameters: {'l1_ratio': 0.23789482035414378}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5757575757575758
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7848101265822784
# Fold 5 C-index: 0.6666666666666666
# [I 2024-04-18 15:32:52,943] Trial 37 finished with value: 0.6857339886472424 and parameters: {'l1_ratio': 0.7342815000174964}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5800865800865801
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7890295358649789
# Fold 5 C-index: 0.6713615023474179
# [I 2024-04-18 15:32:53,655] Trial 38 finished with value: 0.6883826385057338 and parameters: {'l1_ratio': 0.8450450825036032}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5714285714285714
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7805907172995781
# Fold 5 C-index: 0.6666666666666666
# [I 2024-04-18 15:32:54,312] Trial 39 finished with value: 0.6840243059249016 and parameters: {'l1_ratio': 0.35153102114871604}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5757575757575758
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7848101265822784
# Fold 5 C-index: 0.6666666666666666
# [I 2024-04-18 15:32:55,084] Trial 40 finished with value: 0.6857339886472424 and parameters: {'l1_ratio': 0.6762726602177129}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5800865800865801
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7890295358649789
# Fold 5 C-index: 0.6713615023474179
# [I 2024-04-18 15:32:55,802] Trial 41 finished with value: 0.6883826385057338 and parameters: {'l1_ratio': 0.9440922341009589}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5800865800865801
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7890295358649789
# Fold 5 C-index: 0.6713615023474179
# [I 2024-04-18 15:32:56,448] Trial 42 finished with value: 0.6883826385057338 and parameters: {'l1_ratio': 0.8629643445340418}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5757575757575758
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7869198312236287
# Fold 5 C-index: 0.6713615023474179
# [I 2024-04-18 15:32:56,787] Trial 43 finished with value: 0.6870948967116629 and parameters: {'l1_ratio': 0.8119687552544277}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5800865800865801
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7890295358649789
# Fold 5 C-index: 0.6713615023474179
# [I 2024-04-18 15:32:57,275] Trial 44 finished with value: 0.6883826385057338 and parameters: {'l1_ratio': 0.8940576552266526}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5714285714285714
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7805907172995781
# Fold 5 C-index: 0.6666666666666666
# [I 2024-04-18 15:32:57,871] Trial 45 finished with value: 0.6840243059249016 and parameters: {'l1_ratio': 0.5034995787719242}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5800865800865801
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7890295358649789
# Fold 5 C-index: 0.6713615023474179
# [I 2024-04-18 15:32:58,512] Trial 46 finished with value: 0.6883826385057338 and parameters: {'l1_ratio': 0.9428787838786565}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5800865800865801
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7890295358649789
# Fold 5 C-index: 0.6713615023474179
# [I 2024-04-18 15:32:59,138] Trial 47 finished with value: 0.6883826385057338 and parameters: {'l1_ratio': 0.9991045282580079}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5800865800865801
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7890295358649789
# Fold 5 C-index: 0.6713615023474179
# [I 2024-04-18 15:32:59,700] Trial 48 finished with value: 0.6883826385057338 and parameters: {'l1_ratio': 0.8577244154633872}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5800865800865801
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7890295358649789
# Fold 5 C-index: 0.6713615023474179
# [I 2024-04-18 15:33:00,227] Trial 49 finished with value: 0.6883826385057338 and parameters: {'l1_ratio': 0.9586049921503356}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5757575757575758
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7890295358649789
# Fold 5 C-index: 0.6713615023474179
# [I 2024-04-18 15:33:00,871] Trial 50 finished with value: 0.6875168376399329 and parameters: {'l1_ratio': 0.7809764372372684}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5800865800865801
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7890295358649789
# Fold 5 C-index: 0.6713615023474179
# [I 2024-04-18 15:33:01,545] Trial 51 finished with value: 0.6883826385057338 and parameters: {'l1_ratio': 0.8631278036473559}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5800865800865801
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7890295358649789
# Fold 5 C-index: 0.6713615023474179
# [I 2024-04-18 15:33:02,125] Trial 52 finished with value: 0.6883826385057338 and parameters: {'l1_ratio': 0.9266288431945623}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5757575757575758
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7848101265822784
# Fold 5 C-index: 0.6713615023474179
# [I 2024-04-18 15:33:02,937] Trial 53 finished with value: 0.6866729557833928 and parameters: {'l1_ratio': 0.8192377382294467}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5800865800865801
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7890295358649789
# Fold 5 C-index: 0.6713615023474179
# [I 2024-04-18 15:33:03,467] Trial 54 finished with value: 0.6883826385057338 and parameters: {'l1_ratio': 0.9672083616741531}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5800865800865801
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7890295358649789
# Fold 5 C-index: 0.6713615023474179
# [I 2024-04-18 15:33:03,913] Trial 55 finished with value: 0.6883826385057338 and parameters: {'l1_ratio': 0.8742571855758281}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5757575757575758
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7848101265822784
# Fold 5 C-index: 0.6666666666666666
# [I 2024-04-18 15:33:04,632] Trial 56 finished with value: 0.6857339886472424 and parameters: {'l1_ratio': 0.7636926705520951}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5800865800865801
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7890295358649789
# Fold 5 C-index: 0.6713615023474179
# [I 2024-04-18 15:33:05,233] Trial 57 finished with value: 0.6883826385057338 and parameters: {'l1_ratio': 0.9260327748159877}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5757575757575758
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7848101265822784
# Fold 5 C-index: 0.6713615023474179
# [I 2024-04-18 15:33:05,819] Trial 58 finished with value: 0.6866729557833928 and parameters: {'l1_ratio': 0.7011320294801376}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5757575757575758
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7848101265822784
# Fold 5 C-index: 0.6713615023474179
# [I 2024-04-18 15:33:06,549] Trial 59 finished with value: 0.6866729557833928 and parameters: {'l1_ratio': 0.8355538047979535}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5800865800865801
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7890295358649789
# Fold 5 C-index: 0.6713615023474179
# [I 2024-04-18 15:33:07,145] Trial 60 finished with value: 0.6883826385057338 and parameters: {'l1_ratio': 0.9592288320846707}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5800865800865801
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7890295358649789
# Fold 5 C-index: 0.6713615023474179
# [I 2024-04-18 15:33:07,863] Trial 61 finished with value: 0.6883826385057338 and parameters: {'l1_ratio': 0.8972958419850556}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5800865800865801
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7890295358649789
# Fold 5 C-index: 0.6713615023474179
# [I 2024-04-18 15:33:08,671] Trial 62 finished with value: 0.6883826385057338 and parameters: {'l1_ratio': 0.9775556761497737}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5800865800865801
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7890295358649789
# Fold 5 C-index: 0.6713615023474179
# [I 2024-04-18 15:33:09,325] Trial 63 finished with value: 0.6883826385057338 and parameters: {'l1_ratio': 0.9260812672003349}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5800865800865801
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7890295358649789
# Fold 5 C-index: 0.6713615023474179
# [I 2024-04-18 15:33:10,214] Trial 64 finished with value: 0.6883826385057338 and parameters: {'l1_ratio': 0.9632917998931937}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5800865800865801
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7890295358649789
# Fold 5 C-index: 0.6713615023474179
# [I 2024-04-18 15:33:10,792] Trial 65 finished with value: 0.6883826385057338 and parameters: {'l1_ratio': 0.8857628084789331}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5757575757575758
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7890295358649789
# Fold 5 C-index: 0.6713615023474179
# [I 2024-04-18 15:33:11,348] Trial 66 finished with value: 0.6875168376399329 and parameters: {'l1_ratio': 0.7827287009465914}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5757575757575758
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7763713080168776
# Fold 5 C-index: 0.6666666666666666
# [I 2024-04-18 15:33:11,897] Trial 67 finished with value: 0.6840462249341623 and parameters: {'l1_ratio': 0.10022359348974141}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5800865800865801
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7890295358649789
# Fold 5 C-index: 0.6713615023474179
# [I 2024-04-18 15:33:12,496] Trial 68 finished with value: 0.6883826385057338 and parameters: {'l1_ratio': 0.9176027744187163}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5800865800865801
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7890295358649789
# Fold 5 C-index: 0.6713615023474179
# [I 2024-04-18 15:33:13,015] Trial 69 finished with value: 0.6883826385057338 and parameters: {'l1_ratio': 0.9982048868245822}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5757575757575758
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7805907172995781
# Fold 5 C-index: 0.6666666666666666
# [I 2024-04-18 15:33:13,616] Trial 70 finished with value: 0.6848901067907025 and parameters: {'l1_ratio': 0.6278366970608916}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5800865800865801
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7890295358649789
# Fold 5 C-index: 0.6713615023474179
# [I 2024-04-18 15:33:13,916] Trial 71 finished with value: 0.6883826385057338 and parameters: {'l1_ratio': 0.9449221521583583}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5800865800865801
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7890295358649789
# Fold 5 C-index: 0.6713615023474179
# [I 2024-04-18 15:33:14,407] Trial 72 finished with value: 0.6883826385057338 and parameters: {'l1_ratio': 0.9674129718028212}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5800865800865801
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7890295358649789
# Fold 5 C-index: 0.6713615023474179
# [I 2024-04-18 15:33:15,124] Trial 73 finished with value: 0.6883826385057338 and parameters: {'l1_ratio': 0.9003575197631176}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5757575757575758
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7848101265822784
# Fold 5 C-index: 0.6713615023474179
# [I 2024-04-18 15:33:16,104] Trial 74 finished with value: 0.6866729557833928 and parameters: {'l1_ratio': 0.8374702319757452}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5800865800865801
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7890295358649789
# Fold 5 C-index: 0.6713615023474179
# [I 2024-04-18 15:33:16,913] Trial 75 finished with value: 0.6883826385057338 and parameters: {'l1_ratio': 0.9387158115133097}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5800865800865801
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7890295358649789
# Fold 5 C-index: 0.6713615023474179
# [I 2024-04-18 15:33:17,669] Trial 76 finished with value: 0.6883826385057338 and parameters: {'l1_ratio': 0.9794888852309296}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5800865800865801
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7890295358649789
# Fold 5 C-index: 0.6713615023474179
# [I 2024-04-18 15:33:18,451] Trial 77 finished with value: 0.6883826385057338 and parameters: {'l1_ratio': 0.8764022265854029}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5800865800865801
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7890295358649789
# Fold 5 C-index: 0.6713615023474179
# [I 2024-04-18 15:33:19,238] Trial 78 finished with value: 0.6883826385057338 and parameters: {'l1_ratio': 0.9139351574494488}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5800865800865801
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7890295358649789
# Fold 5 C-index: 0.6713615023474179
# [I 2024-04-18 15:33:19,902] Trial 79 finished with value: 0.6883826385057338 and parameters: {'l1_ratio': 0.9476291012026437}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5800865800865801
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7890295358649789
# Fold 5 C-index: 0.6713615023474179
# [I 2024-04-18 15:33:20,259] Trial 80 finished with value: 0.6883826385057338 and parameters: {'l1_ratio': 0.9985853972125646}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5800865800865801
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7890295358649789
# Fold 5 C-index: 0.6713615023474179
# [I 2024-04-18 15:33:21,047] Trial 81 finished with value: 0.6883826385057338 and parameters: {'l1_ratio': 0.9715295015478137}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5714285714285714
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7805907172995781
# Fold 5 C-index: 0.6666666666666666
# [I 2024-04-18 15:33:21,935] Trial 82 finished with value: 0.6840243059249016 and parameters: {'l1_ratio': 0.5233803160109376}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5800865800865801
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7890295358649789
# Fold 5 C-index: 0.6713615023474179
# [I 2024-04-18 15:33:22,657] Trial 83 finished with value: 0.6883826385057338 and parameters: {'l1_ratio': 0.9426889451388358}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5714285714285714
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7805907172995781
# Fold 5 C-index: 0.6666666666666666
# [I 2024-04-18 15:33:23,349] Trial 84 finished with value: 0.6840243059249016 and parameters: {'l1_ratio': 0.4519551909198334}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5714285714285714
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7805907172995781
# Fold 5 C-index: 0.6666666666666666
# [I 2024-04-18 15:33:24,301] Trial 85 finished with value: 0.6840243059249016 and parameters: {'l1_ratio': 0.33218847491866843}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5800865800865801
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7890295358649789
# Fold 5 C-index: 0.6713615023474179
# [I 2024-04-18 15:33:24,766] Trial 86 finished with value: 0.6883826385057338 and parameters: {'l1_ratio': 0.9968734977072655}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5800865800865801
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7890295358649789
# Fold 5 C-index: 0.6713615023474179
# [I 2024-04-18 15:33:25,484] Trial 87 finished with value: 0.6883826385057338 and parameters: {'l1_ratio': 0.8721264332588197}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5757575757575758
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7890295358649789
# Fold 5 C-index: 0.6713615023474179
# [I 2024-04-18 15:33:26,095] Trial 88 finished with value: 0.6875168376399329 and parameters: {'l1_ratio': 0.8034397848038504}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5800865800865801
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7890295358649789
# Fold 5 C-index: 0.6713615023474179
# [I 2024-04-18 15:33:26,719] Trial 89 finished with value: 0.6883826385057338 and parameters: {'l1_ratio': 0.9021759595189587}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5800865800865801
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7890295358649789
# Fold 5 C-index: 0.6713615023474179
# [I 2024-04-18 15:33:27,469] Trial 90 finished with value: 0.6883826385057338 and parameters: {'l1_ratio': 0.8434730779424877}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5800865800865801
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7890295358649789
# Fold 5 C-index: 0.6713615023474179
# [I 2024-04-18 15:33:28,197] Trial 91 finished with value: 0.6883826385057338 and parameters: {'l1_ratio': 0.9744891524849301}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5800865800865801
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7890295358649789
# Fold 5 C-index: 0.6713615023474179
# [I 2024-04-18 15:33:28,800] Trial 92 finished with value: 0.6883826385057338 and parameters: {'l1_ratio': 0.9293401552632715}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5800865800865801
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7890295358649789
# Fold 5 C-index: 0.6713615023474179
# [I 2024-04-18 15:33:29,798] Trial 93 finished with value: 0.6883826385057338 and parameters: {'l1_ratio': 0.8874133464949068}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5800865800865801
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7890295358649789
# Fold 5 C-index: 0.6713615023474179
# [I 2024-04-18 15:33:30,597] Trial 94 finished with value: 0.6883826385057338 and parameters: {'l1_ratio': 0.9224222442084746}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5800865800865801
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7890295358649789
# Fold 5 C-index: 0.6713615023474179
# [I 2024-04-18 15:33:31,558] Trial 95 finished with value: 0.6883826385057338 and parameters: {'l1_ratio': 0.9571875784427385}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5800865800865801
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7890295358649789
# Fold 5 C-index: 0.6713615023474179
# [I 2024-04-18 15:33:32,294] Trial 96 finished with value: 0.6883826385057338 and parameters: {'l1_ratio': 0.981045659285129}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5800865800865801
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7890295358649789
# Fold 5 C-index: 0.6713615023474179
# [I 2024-04-18 15:33:32,989] Trial 97 finished with value: 0.6883826385057338 and parameters: {'l1_ratio': 0.8568549346658406}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5757575757575758
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7848101265822784
# Fold 5 C-index: 0.6713615023474179
# [I 2024-04-18 15:33:33,661] Trial 98 finished with value: 0.6866729557833928 and parameters: {'l1_ratio': 0.826480486643492}. Best is trial 6 with value: 0.6883826385057338.
# Fold 1 C-index: 0.5757575757575758
# Fold 2 C-index: 0.7053571428571429
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7848101265822784
# [I 2024-04-18 15:33:34,327] A new study created in memory with name: no-name-f5a15b76-e049-427a-a399-a478fe04e838
# Fold 5 C-index: 0.6666666666666666
# [I 2024-04-18 15:33:34,320] Trial 99 finished with value: 0.6857339886472424 and parameters: {'l1_ratio': 0.7446166564618295}. Best is trial 6 with value: 0.6883826385057338.
#
#
# * Best trial for C-index:
#  FrozenTrial(number=6, state=TrialState.COMPLETE, values=[0.6883826385057338], datetime_start=datetime.datetime(2024, 4, 18, 15, 32, 35, 350014), datetime_complete=datetime.datetime(2024, 4, 18, 15, 32, 35, 851780), params={'l1_ratio': 0.980766121964777}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'l1_ratio': FloatDistribution(high=1.0, log=False, low=0.0001, step=None)}, trial_id=6, value=None)
#
#
# * Best Score for C-index:
#  0.6883826385057338
#   0%|          | 0/100 [00:00<?, ?it/s]
# Fold 1 IBS: 0.20803163542751857
# Fold 2 IBS: 0.1957176547660314
# Fold 3 IBS: 0.18482241577078837
# Fold 4 IBS: 0.18820845770289446
# Fold 5 IBS: 0.24619930694548325
# [I 2024-04-18 15:33:35,118] Trial 0 finished with value: 0.20459589412254325 and parameters: {'l1_ratio': 0.6964995386793018}. Best is trial 0 with value: 0.20459589412254325.
# Fold 1 IBS: 0.20816176421196383
# Fold 2 IBS: 0.1957421177291814
# Fold 3 IBS: 0.18484693909613936
# Fold 4 IBS: 0.18833413987890033
# Fold 5 IBS: 0.2461060016673796
# [I 2024-04-18 15:33:35,921] Trial 1 finished with value: 0.2046381925167129 and parameters: {'l1_ratio': 0.28621072101688444}. Best is trial 0 with value: 0.20459589412254325.
# Fold 1 IBS: 0.2081761898750979
# Fold 2 IBS: 0.1957351532062053
# Fold 3 IBS: 0.18472120403257847
# Fold 4 IBS: 0.18837888372056025
# Fold 5 IBS: 0.24612450346136128
# [I 2024-04-18 15:33:36,421] Trial 2 finished with value: 0.20462718685916062 and parameters: {'l1_ratio': 0.22692876841884668}. Best is trial 0 with value: 0.20459589412254325.
# Fold 1 IBS: 0.2081033380436098
# Fold 2 IBS: 0.19571552505982892
# Fold 3 IBS: 0.18470963258095535
# Fold 4 IBS: 0.18828931736397872
# Fold 5 IBS: 0.2461531974045893
# [I 2024-04-18 15:33:37,127] Trial 3 finished with value: 0.20459420209059243 and parameters: {'l1_ratio': 0.5513596376059829}. Best is trial 3 with value: 0.20459420209059243.
# Fold 1 IBS: 0.2080056146043676
# Fold 2 IBS: 0.19572678426317763
# Fold 3 IBS: 0.18476190732206402
# Fold 4 IBS: 0.1882320779508285
# Fold 5 IBS: 0.24617162025019435
# [I 2024-04-18 15:33:37,821] Trial 4 finished with value: 0.20457960087812638 and parameters: {'l1_ratio': 0.7194970228885845}. Best is trial 4 with value: 0.20457960087812638.
# Fold 1 IBS: 0.2081170028341325
# Fold 2 IBS: 0.19573320306745765
# Fold 3 IBS: 0.18473212654675536
# Fold 4 IBS: 0.1883258750171995
# Fold 5 IBS: 0.2461407188035701
# [I 2024-04-18 15:33:38,538] Trial 5 finished with value: 0.20460978525382298 and parameters: {'l1_ratio': 0.4231641494784485}. Best is trial 4 with value: 0.20457960087812638.
# Fold 1 IBS: 0.2079837441858809
# Fold 2 IBS: 0.19572080557649219
# Fold 3 IBS: 0.18478742293498293
# Fold 4 IBS: 0.18809726047079353
# Fold 5 IBS: 0.24622011278349787
# [I 2024-04-18 15:33:39,189] Trial 6 finished with value: 0.20456186919032948 and parameters: {'l1_ratio': 0.980766121964777}. Best is trial 6 with value: 0.20456186919032948.
# Fold 1 IBS: 0.20801680207058434
# Fold 2 IBS: 0.19571366631812012
# Fold 3 IBS: 0.18478405648686166
# Fold 4 IBS: 0.18822327332538696
# Fold 5 IBS: 0.2461892469633428
# [I 2024-04-18 15:33:39,941] Trial 7 finished with value: 0.2045854090328592 and parameters: {'l1_ratio': 0.6848612556110047}. Best is trial 6 with value: 0.20456186919032948.
# Fold 1 IBS: 0.2081055487258603
# Fold 2 IBS: 0.19573776010051078
# Fold 3 IBS: 0.18470490252046806
# Fold 4 IBS: 0.18828750024920318
# Fold 5 IBS: 0.24616960553253922
# [I 2024-04-18 15:33:40,688] Trial 8 finished with value: 0.20460106342571632 and parameters: {'l1_ratio': 0.4809838082942125}. Best is trial 6 with value: 0.20456186919032948.
# Fold 1 IBS: 0.2081162188260722
# Fold 2 IBS: 0.19574126195870353
# Fold 3 IBS: 0.1847250470511559
# Fold 4 IBS: 0.18832644496455533
# Fold 5 IBS: 0.2461455950645673
# [I 2024-04-18 15:33:41,852] Trial 9 finished with value: 0.20461091357301084 and parameters: {'l1_ratio': 0.3921783064423311}. Best is trial 6 with value: 0.20456186919032948.
# Fold 1 IBS: 0.2079881430674038
# Fold 2 IBS: 0.1957215732761679
# Fold 3 IBS: 0.18479889596601973
# Fold 4 IBS: 0.1880936533453858
# Fold 5 IBS: 0.24622217540473654
# [I 2024-04-18 15:33:42,612] Trial 10 finished with value: 0.2045648882119427 and parameters: {'l1_ratio': 0.9843563326681124}. Best is trial 6 with value: 0.20456186919032948.
# Fold 1 IBS: 0.20800367718007545
# Fold 2 IBS: 0.19572449594598712
# Fold 3 IBS: 0.18469250346496263
# Fold 4 IBS: 0.1880808662971411
# Fold 5 IBS: 0.2462294279204595
# [I 2024-04-18 15:33:43,339] Trial 11 finished with value: 0.20454619416172518 and parameters: {'l1_ratio': 0.9972280068904047}. Best is trial 11 with value: 0.20454619416172518.
# Fold 1 IBS: 0.20800080664571
# Fold 2 IBS: 0.1957237715506948
# Fold 3 IBS: 0.1846832291232003
# Fold 4 IBS: 0.18808323100458813
# Fold 5 IBS: 0.24622809142848048
# [I 2024-04-18 15:33:44,326] Trial 12 finished with value: 0.20454382595053472 and parameters: {'l1_ratio': 0.9948264745658929}. Best is trial 12 with value: 0.20454382595053472.
# Fold 1 IBS: 0.21349169570485618
# Fold 2 IBS: 0.22099169263147658
# Fold 3 IBS: 0.20395623188482162
# Fold 4 IBS: 0.22409530803621358
# Fold 5 IBS: 0.21813910749003484
# [I 2024-04-18 15:33:44,691] Trial 13 finished with value: 0.21613480714948058 and parameters: {'l1_ratio': 0.03152521162798527}. Best is trial 12 with value: 0.20454382595053472.
# Fold 1 IBS: 0.2079881346544506
# Fold 2 IBS: 0.19572110392775752
# Fold 3 IBS: 0.18476448630112674
# Fold 4 IBS: 0.18814288129012977
# Fold 5 IBS: 0.24620658364772915
# [I 2024-04-18 15:33:45,664] Trial 14 finished with value: 0.20456463796423874 and parameters: {'l1_ratio': 0.8887005110166508}. Best is trial 12 with value: 0.20454382595053472.
# Fold 1 IBS: 0.20792962205170812
# Fold 2 IBS: 0.19573620729629695
# Fold 3 IBS: 0.18475594554477537
# Fold 4 IBS: 0.18819114213861232
# Fold 5 IBS: 0.24617434570326874
# [I 2024-04-18 15:33:46,813] Trial 15 finished with value: 0.2045574525469323 and parameters: {'l1_ratio': 0.8435258665171791}. Best is trial 12 with value: 0.20454382595053472.
# Fold 1 IBS: 0.20793990585340424
# Fold 2 IBS: 0.19572633567743483
# Fold 3 IBS: 0.18476861177970713
# Fold 4 IBS: 0.18818526608387529
# Fold 5 IBS: 0.24619295861586557
# [I 2024-04-18 15:33:47,902] Trial 16 finished with value: 0.2045626156020574 and parameters: {'l1_ratio': 0.8046771700892117}. Best is trial 12 with value: 0.20454382595053472.
# Fold 1 IBS: 0.20798936947092164
# Fold 2 IBS: 0.1957217869432189
# Fold 3 IBS: 0.18480254945672805
# Fold 4 IBS: 0.18809264704637782
# Fold 5 IBS: 0.24622274976378458
# [I 2024-04-18 15:33:48,859] Trial 17 finished with value: 0.2045658205362062 and parameters: {'l1_ratio': 0.9853615392538034}. Best is trial 12 with value: 0.20454382595053472.
# Fold 1 IBS: 0.2079228445412494
# Fold 2 IBS: 0.19572103188480772
# Fold 3 IBS: 0.18472330068464737
# Fold 4 IBS: 0.1881998788248074
# Fold 5 IBS: 0.24618352512947303
# [I 2024-04-18 15:33:50,040] Trial 18 finished with value: 0.20455011621299696 and parameters: {'l1_ratio': 0.7922918930288001}. Best is trial 12 with value: 0.20454382595053472.
# Fold 1 IBS: 0.2080774696799392
# Fold 2 IBS: 0.19571222420470263
# Fold 3 IBS: 0.18479089581334027
# Fold 4 IBS: 0.18826411535729337
# Fold 5 IBS: 0.2461649447278047
# [I 2024-04-18 15:33:51,226] Trial 19 finished with value: 0.20460192995661605 and parameters: {'l1_ratio': 0.608409044915716}. Best is trial 12 with value: 0.20454382595053472.
# Fold 1 IBS: 0.20797965352227624
# Fold 2 IBS: 0.19571946073583182
# Fold 3 IBS: 0.1847389320486559
# Fold 4 IBS: 0.1881503495238048
# Fold 5 IBS: 0.24620142603589154
# [I 2024-04-18 15:33:52,266] Trial 20 finished with value: 0.20455796437329207 and parameters: {'l1_ratio': 0.8818811135844746}. Best is trial 12 with value: 0.20454382595053472.
# Fold 1 IBS: 0.20793236397936973
# Fold 2 IBS: 0.19572291716395518
# Fold 3 IBS: 0.1847490937634785
# Fold 4 IBS: 0.1881917320391019
# Fold 5 IBS: 0.2461887961333215
# [I 2024-04-18 15:33:53,314] Trial 21 finished with value: 0.20455698061584537 and parameters: {'l1_ratio': 0.7991589143104526}. Best is trial 12 with value: 0.20454382595053472.
# Fold 1 IBS: 0.2079589906169464
# Fold 2 IBS: 0.19572893721972917
# Fold 3 IBS: 0.18484595998998346
# Fold 4 IBS: 0.18811864497281425
# Fold 5 IBS: 0.24622214381664348
# [I 2024-04-18 15:33:54,371] Trial 22 finished with value: 0.20457493532322335 and parameters: {'l1_ratio': 0.9130757617488995}. Best is trial 12 with value: 0.20454382595053472.
# Fold 1 IBS: 0.20799190024873238
# Fold 2 IBS: 0.19573670570697085
# Fold 3 IBS: 0.184734039963688
# Fold 4 IBS: 0.18819278563042682
# Fold 5 IBS: 0.24619948407763423
# [I 2024-04-18 15:33:55,388] Trial 23 finished with value: 0.20457098312549044 and parameters: {'l1_ratio': 0.7531499228527783}. Best is trial 12 with value: 0.20454382595053472.
# Fold 1 IBS: 0.2079595390154333
# Fold 2 IBS: 0.19572903306965062
# Fold 3 IBS: 0.18469694083230714
# Fold 4 IBS: 0.18811820207739285
# Fold 5 IBS: 0.24622240849347585
# [I 2024-04-18 15:33:56,392] Trial 24 finished with value: 0.20454522469765193 and parameters: {'l1_ratio': 0.9135035033403357}. Best is trial 12 with value: 0.20454382595053472.
# Fold 1 IBS: 0.20795582580956304
# Fold 2 IBS: 0.19572838344359583
# Fold 3 IBS: 0.18483734588304837
# Fold 4 IBS: 0.18812119993054519
# Fold 5 IBS: 0.2462206214853329
# [I 2024-04-18 15:33:57,370] Trial 25 finished with value: 0.20457267531041706 and parameters: {'l1_ratio': 0.9106143729430608}. Best is trial 12 with value: 0.20454382595053472.
# Fold 1 IBS: 0.20800403294652778
# Fold 2 IBS: 0.19572455738240155
# Fold 3 IBS: 0.1846936534448697
# Fold 4 IBS: 0.18808057561649952
# Fold 5 IBS: 0.2462295934448235
# [I 2024-04-18 15:33:58,283] Trial 26 finished with value: 0.2045464825670244 and parameters: {'l1_ratio': 0.9975263811621901}. Best is trial 12 with value: 0.20454382595053472.
# Fold 1 IBS: 0.20796161067855232
# Fold 2 IBS: 0.19572939487039318
# Fold 3 IBS: 0.1847030281170859
# Fold 4 IBS: 0.1881165285099557
# Fold 5 IBS: 0.24622340782504534
# [I 2024-04-18 15:33:59,267] Trial 27 finished with value: 0.2045467940002065 and parameters: {'l1_ratio': 0.9151226634923038}. Best is trial 12 with value: 0.20454382595053472.
# Fold 1 IBS: 0.20804290745609694
# Fold 2 IBS: 0.1957174945624923
# Fold 3 IBS: 0.18469072857513577
# Fold 4 IBS: 0.18824565636558177
# Fold 5 IBS: 0.24617826143580468
# [I 2024-04-18 15:34:00,291] Trial 28 finished with value: 0.20457500967902228 and parameters: {'l1_ratio': 0.6215958592208828}. Best is trial 12 with value: 0.20454382595053472.
# Fold 1 IBS: 0.20801583089430087
# Fold 2 IBS: 0.19571340391488215
# Fold 3 IBS: 0.1847812414431275
# Fold 4 IBS: 0.18822424135005814
# Fold 5 IBS: 0.24618858664093093
# [I 2024-04-18 15:34:01,270] Trial 29 finished with value: 0.2045846608486599 and parameters: {'l1_ratio': 0.6841119198950223}. Best is trial 12 with value: 0.20454382595053472.
# Fold 1 IBS: 0.2079400873497906
# Fold 2 IBS: 0.19573804715573084
# Fold 3 IBS: 0.18478339903861538
# Fold 4 IBS: 0.18813478364724892
# Fold 5 IBS: 0.2461800509409581
# [I 2024-04-18 15:34:02,724] Trial 30 finished with value: 0.20455527362646878 and parameters: {'l1_ratio': 0.8512940639677147}. Best is trial 12 with value: 0.20454382595053472.
# Fold 1 IBS: 0.20799073844513938
# Fold 2 IBS: 0.19572202526002044
# Fold 3 IBS: 0.18480662903176864
# Fold 4 IBS: 0.18809222432331557
# Fold 5 IBS: 0.24622339053302728
# [I 2024-04-18 15:34:05,656] Trial 31 finished with value: 0.2045670015186543 and parameters: {'l1_ratio': 0.9864858075876226}. Best is trial 12 with value: 0.20454382595053472.
# Fold 1 IBS: 0.20798105783250517
# Fold 2 IBS: 0.19573283556957335
# Fold 3 IBS: 0.18476063309174523
# Fold 4 IBS: 0.1881007784345453
# Fold 5 IBS: 0.24618817209252242
# [I 2024-04-18 15:34:09,792] Trial 32 finished with value: 0.2045526954041783 and parameters: {'l1_ratio': 0.930580777401446}. Best is trial 12 with value: 0.20454382595053472.
# Fold 1 IBS: 0.20800477097763376
# Fold 2 IBS: 0.1957246847876235
# Fold 3 IBS: 0.18469603943929533
# Fold 4 IBS: 0.18807996786169912
# Fold 5 IBS: 0.24622993673985416
# [I 2024-04-18 15:34:13,759] Trial 33 finished with value: 0.20454707996122118 and parameters: {'l1_ratio': 0.9981458715067252}. Best is trial 12 with value: 0.20454382595053472.
# Fold 1 IBS: 0.20822799221538965
# Fold 2 IBS: 0.19574928738566438
# Fold 3 IBS: 0.18477140439387835
# Fold 4 IBS: 0.18835503236546308
# Fold 5 IBS: 0.24609056671685825
# [I 2024-04-18 15:34:16,008] Trial 34 finished with value: 0.20463885661545073 and parameters: {'l1_ratio': 0.21553914253693035}. Best is trial 12 with value: 0.20454382595053472.
# Fold 1 IBS: 0.20799307026425684
# Fold 2 IBS: 0.19573482085012894
# Fold 3 IBS: 0.18479608209036535
# Fold 4 IBS: 0.18813777409282773
# Fold 5 IBS: 0.24619560448908145
# [I 2024-04-18 15:34:18,531] Trial 35 finished with value: 0.20457147035733209 and parameters: {'l1_ratio': 0.9403690908441681}. Best is trial 12 with value: 0.20454382595053472.
# Fold 1 IBS: 0.2079427556634106
# Fold 2 IBS: 0.1957385144040208
# Fold 3 IBS: 0.18479057920775163
# Fold 4 IBS: 0.1881326542423316
# Fold 5 IBS: 0.24618150185267376
# ...
# Fold 1 IBS: 0.2080095640247583
# Fold 2 IBS: 0.19573783385148913
# Fold 3 IBS: 0.18483984219200936
# Fold 4 IBS: 0.18812312970617515
# Fold 5 IBS: 0.24620423488163531
# [I 2024-04-18 15:34:36,157] Trial 54 finished with value: 0.20458292093121347 and parameters: {'l1_ratio': 0.9541190951832292}. Best is trial 12 with value: 0.20454382595053472.
# Fold 1 IBS: 0.2079771901567577
# Fold 2 IBS: 0.1957336280427229
# Fold 3 IBS: 0.18486375147583428
# Fold 4 IBS: 0.18815314118743856
# Fold 5 IBS: 0.24621335432544827
# [I 2024-04-18 15:34:36,802] Trial 55 finished with value: 0.20458821303764033 and parameters: {'l1_ratio': 0.8330154733530042}. Best is trial 12 with value: 0.20454382595053472.
# Fold 1 IBS: 0.20799731233514662
# Fold 2 IBS: 0.19572287235397987
# Fold 3 IBS: 0.1847908375686115
# Fold 4 IBS: 0.18813484899870528
# Fold 5 IBS: 0.246211469486519
# [I 2024-04-18 15:34:37,862] Trial 56 finished with value: 0.20457146814859245 and parameters: {'l1_ratio': 0.8961896150851258}. Best is trial 12 with value: 0.20454382595053472.
# Fold 1 IBS: 0.2080117323467668
# Fold 2 IBS: 0.19573820123448618
# Fold 3 IBS: 0.18484631271620172
# Fold 4 IBS: 0.18812120601802984
# Fold 5 IBS: 0.24620536127586282
# [I 2024-04-18 15:34:38,568] Trial 57 finished with value: 0.2045845627182695 and parameters: {'l1_ratio': 0.9559540674519176}. Best is trial 12 with value: 0.20454382595053472.
# Fold 1 IBS: 0.2079612636227832
# Fold 2 IBS: 0.19572933429158343
# Fold 3 IBS: 0.1847020081232535
# Fold 4 IBS: 0.18811680892533386
# Fold 5 IBS: 0.24622324047002084
# [I 2024-04-18 15:34:39,376] Trial 58 finished with value: 0.20454653108659496 and parameters: {'l1_ratio': 0.914851049078081}. Best is trial 12 with value: 0.20454382595053472.
# Fold 1 IBS: 0.20796948952900138
# Fold 2 IBS: 0.19571784743525414
# Fold 3 IBS: 0.18483021974741806
# Fold 4 IBS: 0.18821094027550347
# Fold 5 IBS: 0.24617406592643237
# [I 2024-04-18 15:34:40,339] Trial 59 finished with value: 0.2045805125827219 and parameters: {'l1_ratio': 0.7810591777213891}. Best is trial 12 with value: 0.20454382595053472.
# Fold 1 IBS: 0.20810497736357125
# Fold 2 IBS: 0.19572785582405663
# Fold 3 IBS: 0.18470877537158076
# Fold 4 IBS: 0.18828860758294416
# Fold 5 IBS: 0.24616209643300568
# [I 2024-04-18 15:34:41,352] Trial 60 finished with value: 0.20459846251503172 and parameters: {'l1_ratio': 0.5157727072002078}. Best is trial 12 with value: 0.20454382595053472.
# Fold 1 IBS: 0.2080055850517175
# Fold 2 IBS: 0.1957248243940696
# Fold 3 IBS: 0.1848503890421485
# Fold 4 IBS: 0.1880792973677591
# Fold 5 IBS: 0.24623031527742928
# [I 2024-04-18 15:34:42,150] Trial 61 finished with value: 0.20457808222662482 and parameters: {'l1_ratio': 0.9988300034065781}. Best is trial 12 with value: 0.20454382595053472.
# Fold 1 IBS: 0.20795976027327373
# Fold 2 IBS: 0.19572907173248008
# Fold 3 IBS: 0.18469759081609152
# Fold 4 IBS: 0.18811802337161793
# Fold 5 IBS: 0.24622251526391967
# [I 2024-04-18 15:34:42,945] Trial 62 finished with value: 0.20454539229147656 and parameters: {'l1_ratio': 0.9136761840466191}. Best is trial 12 with value: 0.20454382595053472.
# Fold 1 IBS: 0.2079459057604453
# Fold 2 IBS: 0.1957244431857801
# Fold 3 IBS: 0.1848150268566113
# Fold 4 IBS: 0.18812603262220565
# Fold 5 IBS: 0.24621581745368185
# [I 2024-04-18 15:34:43,795] Trial 63 finished with value: 0.20456544517574488 and parameters: {'l1_ratio': 0.9029768626619057}. Best is trial 12 with value: 0.20454382595053472.
# Fold 1 IBS: 0.2079426945432259
# Fold 2 IBS: 0.1957385037097387
# Fold 3 IBS: 0.18479041469338453
# Fold 4 IBS: 0.18813270303088067
# Fold 5 IBS: 0.2461814686352417
# [I 2024-04-18 15:34:44,426] Trial 64 finished with value: 0.2045571569224943 and parameters: {'l1_ratio': 0.8532496779154343}. Best is trial 12 with value: 0.20454382595053472.
# Fold 1 IBS: 0.20796711377828656
# Fold 2 IBS: 0.1957303537211652
# Fold 3 IBS: 0.18471921258247154
# Fold 4 IBS: 0.18811207936184124
# Fold 5 IBS: 0.24622605837909103
# [I 2024-04-18 15:34:44,983] Trial 65 finished with value: 0.20455096356457111 and parameters: {'l1_ratio': 0.9194492362897204}. Best is trial 12 with value: 0.20454382595053472.
# Fold 1 IBS: 0.20796203645720907
# Fold 2 IBS: 0.19573067579692893
# Fold 3 IBS: 0.18482335989234877
# Fold 4 IBS: 0.18816622669527752
# Fold 5 IBS: 0.24620509854550365
# [I 2024-04-18 15:34:45,478] Trial 66 finished with value: 0.20457747947745358 and parameters: {'l1_ratio': 0.8212800656863208}. Best is trial 12 with value: 0.20454382595053472.
# Fold 1 IBS: 0.20796294955908678
# Fold 2 IBS: 0.19573980061966179
# Fold 3 IBS: 0.18472547513522414
# Fold 4 IBS: 0.18811284384019933
# Fold 5 IBS: 0.246210300200674
# [I 2024-04-18 15:34:46,272] Trial 67 finished with value: 0.2045502738709692 and parameters: {'l1_ratio': 0.9641113987407882}. Best is trial 12 with value: 0.20454382595053472.
# Fold 1 IBS: 0.20796481908257755
# Fold 2 IBS: 0.19571661731509074
# Fold 3 IBS: 0.18469582145871066
# Fold 4 IBS: 0.1881632714721653
# Fold 5 IBS: 0.24619345770815546
# [I 2024-04-18 15:34:47,079] Trial 68 finished with value: 0.20454679740733991 and parameters: {'l1_ratio': 0.8701809662342422}. Best is trial 12 with value: 0.20454382595053472.
# Fold 1 IBS: 0.20797892768573212
# Fold 2 IBS: 0.19573246767371805
# Fold 3 IBS: 0.18475363427185984
# Fold 4 IBS: 0.18810251055251573
# Fold 5 IBS: 0.24618704915767797
# [I 2024-04-18 15:34:47,741] Trial 69 finished with value: 0.2045509178683007 and parameters: {'l1_ratio': 0.9288644164947022}. Best is trial 12 with value: 0.20454382595053472.
# Fold 1 IBS: 0.20805097568330982
# Fold 2 IBS: 0.19571989731500225
# Fold 3 IBS: 0.18471646162733646
# Fold 4 IBS: 0.18823977255775243
# Fold 5 IBS: 0.24618434798098465
# [I 2024-04-18 15:34:48,506] Trial 70 finished with value: 0.20458229103287712 and parameters: {'l1_ratio': 0.6278366970608916}. Best is trial 12 with value: 0.20454382595053472.
# Fold 1 IBS: 0.20798641117341007
# Fold 2 IBS: 0.19572077070507315
# Fold 3 IBS: 0.18475941982956756
# Fold 4 IBS: 0.18814438778009723
# Fold 5 IBS: 0.24620566406235048
# [I 2024-04-18 15:34:49,254] Trial 71 finished with value: 0.20456333071009972 and parameters: {'l1_ratio': 0.8873069100479395}. Best is trial 12 with value: 0.20454382595053472.
# Fold 1 IBS: 0.20795808765236296
# Fold 2 IBS: 0.19571529430916548
# Fold 3 IBS: 0.18482729506768805
# Fold 4 IBS: 0.1881691417852407
# Fold 5 IBS: 0.24618982621059776
# [I 2024-04-18 15:34:50,152] Trial 72 finished with value: 0.20457192900501098 and parameters: {'l1_ratio': 0.8649650240865763}. Best is trial 12 with value: 0.20454382595053472.
# Fold 1 IBS: 0.20801084806461104
# Fold 2 IBS: 0.19573805147164916
# Fold 3 IBS: 0.18484367348533168
# Fold 4 IBS: 0.18812199065749516
# Fold 5 IBS: 0.24620490204147444
# [I 2024-04-18 15:34:50,979] Trial 73 finished with value: 0.20458389314411227 and parameters: {'l1_ratio': 0.9552049529248103}. Best is trial 12 with value: 0.20454382595053472.
# Fold 1 IBS: 0.20797354537601045
# Fold 2 IBS: 0.19573153594532475
# Fold 3 IBS: 0.18473775981449833
# Fold 4 IBS: 0.18810687299085546
# Fold 5 IBS: 0.24622914863850653
# [I 2024-04-18 15:34:51,620] Trial 74 finished with value: 0.20455577255303908 and parameters: {'l1_ratio': 0.9245532519800576}. Best is trial 12 with value: 0.20454382595053472.
# Fold 1 IBS: 0.20797235399678046
# Fold 2 IBS: 0.1957162224155765
# Fold 3 IBS: 0.18475288660163738
# Fold 4 IBS: 0.18810663071344183
# Fold 5 IBS: 0.2462147538241458
# [I 2024-04-18 15:34:52,340] Trial 75 finished with value: 0.2045525695103164 and parameters: {'l1_ratio': 0.9715794796095396}. Best is trial 12 with value: 0.20454382595053472.
# Fold 1 IBS: 0.20792950612715963
# Fold 2 IBS: 0.19573618685134628
# Fold 3 IBS: 0.1847556344874158
# Fold 4 IBS: 0.18819124195142087
# Fold 5 IBS: 0.246174282375485
# [I 2024-04-18 15:34:53,134] Trial 76 finished with value: 0.20455737035856553 and parameters: {'l1_ratio': 0.843440542313693}. Best is trial 12 with value: 0.20454382595053472.
# Fold 1 IBS: 0.20795657418179092
# Fold 2 IBS: 0.19572899184341172
# Fold 3 IBS: 0.1847884749800495
# Fold 4 IBS: 0.18822540535280172
# Fold 5 IBS: 0.2461777956901063
# [I 2024-04-18 15:34:53,891] Trial 77 finished with value: 0.20457544840963204 and parameters: {'l1_ratio': 0.726664780585407}. Best is trial 12 with value: 0.20454382595053472.
# Fold 1 IBS: 0.2079563066706627
# Fold 2 IBS: 0.1957295523586033
# Fold 3 IBS: 0.1848126096785537
# Fold 4 IBS: 0.1881711556328635
# Fold 5 IBS: 0.24620196417603496
# [I 2024-04-18 15:34:54,629] Trial 78 finished with value: 0.2045743177033436 and parameters: {'l1_ratio': 0.8169215322546773}. Best is trial 12 with value: 0.20454382595053472.
# Fold 1 IBS: 0.20794944237238408
# Fold 2 IBS: 0.19572506197001632
# Fold 3 IBS: 0.18482460399250988
# Fold 4 IBS: 0.18812635955855447
# Fold 5 IBS: 0.2462175323320194
# [I 2024-04-18 15:34:55,392] Trial 79 finished with value: 0.20456860004509686 and parameters: {'l1_ratio': 0.9056863122482656}. Best is trial 12 with value: 0.20454382595053472.
# Fold 1 IBS: 0.20799605282626152
# Fold 2 IBS: 0.19573533077121624
# Fold 3 IBS: 0.18480424760293057
# Fold 4 IBS: 0.1881350936377744
# Fold 5 IBS: 0.2461971646928152
# [I 2024-04-18 15:34:56,114] Trial 80 finished with value: 0.2045735779061996 and parameters: {'l1_ratio': 0.9428286031546894}. Best is trial 12 with value: 0.20454382595053472.
# Fold 1 IBS: 0.20798862917800767
# Fold 2 IBS: 0.1957216579867175
# Fold 3 IBS: 0.1848003439653146
# Fold 4 IBS: 0.18809325451105033
# Fold 5 IBS: 0.24622240310033508
# [I 2024-04-18 15:34:56,795] Trial 81 finished with value: 0.20456525774828505 and parameters: {'l1_ratio': 0.9847545442383177}. Best is trial 12 with value: 0.20454382595053472.
# Fold 1 IBS: 0.20797588746419993
# Fold 2 IBS: 0.19571942930788225
# Fold 3 IBS: 0.18476336942724036
# Fold 4 IBS: 0.18810435280732538
# Fold 5 IBS: 0.2462164190763576
# [I 2024-04-18 15:34:57,372] Trial 82 finished with value: 0.20455589161660112 and parameters: {'l1_ratio': 0.9744125954880615}. Best is trial 12 with value: 0.20454382595053472.
# Fold 1 IBS: 0.2079820066012532
# Fold 2 IBS: 0.19573299927287843
# Fold 3 IBS: 0.18476343419830954
# Fold 4 IBS: 0.1881000085678636
# Fold 5 IBS: 0.24618867192294566
# [I 2024-04-18 15:34:58,028] Trial 83 finished with value: 0.2045534241126501 and parameters: {'l1_ratio': 0.9313471089545559}. Best is trial 12 with value: 0.20454382595053472.
# Fold 1 IBS: 0.20800199459507832
# Fold 2 IBS: 0.1957239769083056
# Fold 3 IBS: 0.1846870662964689
# Fold 4 IBS: 0.1880822534202764
# Fold 5 IBS: 0.24622864472932765
# [I 2024-04-18 15:34:58,708] Trial 84 finished with value: 0.20454478718989139 and parameters: {'l1_ratio': 0.9958190534984249}. Best is trial 12 with value: 0.20454382595053472.
# Fold 1 IBS: 0.20796330513792863
# Fold 2 IBS: 0.19571632022311466
# Fold 3 IBS: 0.1848414350792783
# Fold 4 IBS: 0.18816458779991177
# Fold 5 IBS: 0.2461926418119606
# [I 2024-04-18 15:34:59,693] Trial 85 finished with value: 0.2045756580104388 and parameters: {'l1_ratio': 0.8690028598701801}. Best is trial 12 with value: 0.20454382595053472.
# Fold 1 IBS: 0.20793853892226688
# Fold 2 IBS: 0.19573809333654563
# Fold 3 IBS: 0.18475273626854863
# Fold 4 IBS: 0.18818679768054844
# Fold 5 IBS: 0.2462034050805149
# [I 2024-04-18 15:35:00,767] Trial 86 finished with value: 0.2045639142576849 and parameters: {'l1_ratio': 0.7581698924632934}. Best is trial 12 with value: 0.20454382595053472.
# Fold 1 IBS: 0.2079584006609755
# Fold 2 IBS: 0.19572883407030744
# Fold 3 IBS: 0.18484435377465955
# Fold 4 IBS: 0.18811912137400444
# Fold 5 IBS: 0.24622185901743013
# [I 2024-04-18 15:35:01,694] Trial 87 finished with value: 0.20457451377947544 and parameters: {'l1_ratio': 0.9126160130247807}. Best is trial 12 with value: 0.20454382595053472.
# Fold 1 IBS: 0.20798577967596155
# Fold 2 IBS: 0.19572064852051613
# Fold 3 IBS: 0.18475756398024815
# Fold 4 IBS: 0.18814493962074036
# Fold 5 IBS: 0.24620532695515535
# [I 2024-04-18 15:35:02,618] Trial 88 finished with value: 0.20456285175052433 and parameters: {'l1_ratio': 0.886797285307293}. Best is trial 12 with value: 0.20454382595053472.
# Fold 1 IBS: 0.20797631283814727
# Fold 2 IBS: 0.19571950398793755
# Fold 3 IBS: 0.18476463203306315
# Fold 4 IBS: 0.18810400462396576
# Fold 5 IBS: 0.24621661937723724
# [I 2024-04-18 15:35:03,149] Trial 89 finished with value: 0.2045562145720702 and parameters: {'l1_ratio': 0.9747546694903735}. Best is trial 12 with value: 0.20454382595053472.
# Fold 1 IBS: 0.2081164320129942
# Fold 2 IBS: 0.1957329721380732
# Fold 3 IBS: 0.18473019373511038
# Fold 4 IBS: 0.18832662956080934
# Fold 5 IBS: 0.2461401300491492
# [I 2024-04-18 15:35:03,904] Trial 90 finished with value: 0.20460927149922728 and parameters: {'l1_ratio': 0.42277685474460014}. Best is trial 12 with value: 0.20454382595053472.
# Fold 1 IBS: 0.20799768156286036
# Fold 2 IBS: 0.1957232306016774
# Fold 3 IBS: 0.18482734183693067
# Fold 4 IBS: 0.18808580142606948
# Fold 5 IBS: 0.24622663451453777
# [I 2024-04-18 15:35:04,580] Trial 91 finished with value: 0.20457213798841511 and parameters: {'l1_ratio': 0.9922239180888909}. Best is trial 12 with value: 0.20454382595053472.
# Fold 1 IBS: 0.2080019355465925
# Fold 2 IBS: 0.1957363336597546
# Fold 3 IBS: 0.1848216983097074
# Fold 4 IBS: 0.18812988942410336
# Fold 5 IBS: 0.24620023605951066
# [I 2024-04-18 15:35:04,930] Trial 92 finished with value: 0.2045780185999337 and parameters: {'l1_ratio': 0.9477142699909586}. Best is trial 12 with value: 0.20454382595053472.
# Fold 1 IBS: 0.20799683719627293
# Fold 2 IBS: 0.19573546471054884
# Fold 3 IBS: 0.1848065728793704
# Fold 4 IBS: 0.18813440016452435
# Fold 5 IBS: 0.24619757466751127
# [I 2024-04-18 15:35:05,463] Trial 93 finished with value: 0.20457416992364555 and parameters: {'l1_ratio': 0.9434773707172622}. Best is trial 12 with value: 0.20454382595053472.
# Fold 1 IBS: 0.2080001119551345
# Fold 2 IBS: 0.19572365139107267
# Fold 3 IBS: 0.18483423029398743
# Fold 4 IBS: 0.1880838025548531
# Fold 5 IBS: 0.2462277677353828
# [I 2024-04-18 15:35:06,204] Trial 94 finished with value: 0.20457391278608608 and parameters: {'l1_ratio': 0.9942468665151741}. Best is trial 12 with value: 0.20454382595053472.
# Fold 1 IBS: 0.2080060809552706
# Fold 2 IBS: 0.1957249099221552
# Fold 3 IBS: 0.18485187299994107
# Fold 4 IBS: 0.188078888866549
# Fold 5 IBS: 0.24623054580213538
# [I 2024-04-18 15:35:06,846] Trial 95 finished with value: 0.20457845970921026 and parameters: {'l1_ratio': 0.9992471693779538}. Best is trial 12 with value: 0.20454382595053472.
# Fold 1 IBS: 0.2079713432916059
# Fold 2 IBS: 0.1957160458037741
# Fold 3 IBS: 0.18474988985707297
# Fold 4 IBS: 0.18810745687479236
# Fold 5 IBS: 0.24621426761143556
# [I 2024-04-18 15:35:07,758] Trial 96 finished with value: 0.20455180068773618 and parameters: {'l1_ratio': 0.9707718495392867}. Best is trial 12 with value: 0.20454382595053472.
# Fold 1 IBS: 0.2079571747813185
# Fold 2 IBS: 0.19572861961601165
# Fold 3 IBS: 0.18484101684905477
# Fold 4 IBS: 0.1881201111083998
# Fold 5 IBS: 0.24622127328534105
# [I 2024-04-18 15:35:08,405] Trial 97 finished with value: 0.20457363912802515 and parameters: {'l1_ratio': 0.9116620398101629}. Best is trial 12 with value: 0.20454382595053472.
# Fold 1 IBS: 0.20793467000666271
# Fold 2 IBS: 0.19572337407136067
# Fold 3 IBS: 0.18475525912453106
# Fold 4 IBS: 0.18818975607980032
# Fold 5 IBS: 0.2461900701384772
# [I 2024-04-18 15:35:09,077] Trial 98 finished with value: 0.20455862588416637 and parameters: {'l1_ratio': 0.8008388224661196}. Best is trial 12 with value: 0.20454382595053472.
# Fold 1 IBS: 0.20797222360459192
# Fold 2 IBS: 0.19571806648396856
# Fold 3 IBS: 0.1847174977725337
# Fold 4 IBS: 0.18815682699258532
# Fold 5 IBS: 0.24619744101661659
# [I 2024-04-18 15:35:09,822] Trial 99 finished with value: 0.20455241117405923 and parameters: {'l1_ratio': 0.8759852774200748}. Best is trial 12 with value: 0.20454382595053472.
#
#
# * Best trial for IBS:
#  FrozenTrial(number=12, state=TrialState.COMPLETE, values=[0.20454382595053472], datetime_start=datetime.datetime(2024, 4, 18, 15, 33, 43, 449315), datetime_complete=datetime.datetime(2024, 4, 18, 15, 33, 44, 326429), params={'l1_ratio': 0.9948264745658929}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'l1_ratio': FloatDistribution(high=1.0, log=False, low=0.0001, step=None)}, trial_id=12, value=None)
#
#
# * Best Score for IBS:
#  0.20454382595053472

# %%
train_cindex['CoxElastic'] = np.round(study_cindex.best_value, 3)
train_ibs['CoxElastic'] = np.round(study_ibs.best_value, 3)

# %%
print("train_cindex: ", np.round(study_cindex.best_value, 3))
print("train_ibs: ", np.round(study_ibs.best_value, 3))
# Out:
# train_cindex:  0.688
# train_ibs:  0.205

# %% [markdown]
# #### Test

# %%
# y into array 
lists = [] 
for i, j in zip(y['event_OS'], y['OS']): 
    lists.append((i, j))

y = np.array(lists, dtype=[('status', bool), ('time', np.int32)])

# %%
# A function for building the best model with the best parameters 
def create_best_model(model_class, best_params):
    return model_class(**best_params, fit_baseline_model=True)

# Set the best model 
best_model_cindex = create_best_model(CoxnetSurvivalAnalysis, 
                                      study_cindex.best_params)

# Train the best model for C-index on the whole dataset
best_model_cindex.fit(X_new_std, y)

# Evaluate the best model for C-index on MAASTRO dataset
c_index = best_model_cindex.score(MAASTRO_new_std, y_MAASTRO)
c_index = np.round(c_index, 3)
print("test_cindex :", c_index)

# Set the best model 
best_model_ibs = create_best_model(CoxnetSurvivalAnalysis, study_ibs.best_params)

# Train the best model for IBS on the whole dataset
best_model_ibs.fit(X_new_std, y)

# Evaluate the best model for IBS on MAASTRO dataset
lower, upper = np.percentile(y_MAASTRO["time"], [10, 90])
times = np.arange(lower, upper)
surv_prob = np.row_stack([fn(times) for fn in best_model_ibs.predict_survival_function(MAASTRO_new_std)])
ibs = integrated_brier_score(y_MAASTRO,y_MAASTRO, surv_prob, times)
ibs = np.round(ibs, 3)
print("test_ibs: ", ibs)
# Out:
# CoxnetSurvivalAnalysis(fit_baseline_model=True, l1_ratio=0.980766121964777)
# test_cindex : 0.626
# CoxnetSurvivalAnalysis(fit_baseline_model=True, l1_ratio=0.9948264745658929)
# test_ibs:  0.215

# %%
# Saving the values to the dictionary 
test_cindex['CoxElastic'] = c_index
test_ibs['CoxElastic'] = ibs

# %% [markdown]
# ### 5. Random Survival Forest

# %% [markdown]
# #### Train

# %%
# Setting the y format 
y = clinical_train[['OS', 'event_OS']]

def create_objective(model_class, metric, X, y):
    def objective(trial): 
        # Suggest values for hyperparameters
        min_samples_split = trial.suggest_int("min_samples_split", 2, 20)
        max_leaf_nodes = trial.suggest_int("max_leaf_nodes", 2, 20)
        min_samples_leaf = trial.suggest_int("min_samples_leaf", 1, 20)
        max_depth = trial.suggest_int("max_depth", 1, 20)
        n_estimators = trial.suggest_int("n_estimators", 1, 500)
        oob_score = trial.suggest_categorical("oob_score", [True, False])
        max_samples = trial.suggest_float("max_samples", 0.1, 1.0) 
        max_features = trial.suggest_categorical("max_features", ["auto", "sqrt", "log2", None])
        min_weight_fraction_leaf = trial.suggest_float("min_weight_fraction_leaf", 0.0, 0.5)
        
        # Include warm_start for C-index optimization
        if metric == "c-index":
            warm_start = trial.suggest_categorical("warm_start", [True, False])
        else:
            warm_start = False  # Exclude warm_start for other metrics
        
        # Create and fit survival model 
        model = model_class(min_samples_split=min_samples_split,
                            min_samples_leaf=min_samples_leaf,
                            max_leaf_nodes=max_leaf_nodes,
                            n_estimators=n_estimators, 
                            oob_score=oob_score,
                            warm_start=warm_start,
                            max_depth=max_depth,
                            max_features=max_features,
                            min_weight_fraction_leaf=min_weight_fraction_leaf, 
                            max_samples=max_samples, 
                            random_state=123)

        scores = [] 

        skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=123)
        
        for k, (train_index, test_index) in enumerate(skf.split(X, y.iloc[:, 1])): 
            X_train, X_test = X.iloc[train_index], X.iloc[test_index]
            y_train_df, y_test_df = y.iloc[train_index], y.iloc[test_index]
            
            # y_train into array 
            y_train = [] 
            for i, j in zip(y_train_df['event_OS'], y_train_df['OS']): 
                y_train.append((i, j))
            y_train = np.array(y_train, dtype=[('status', bool), ('time', np.int32)])

            # y_test into array
            y_test = [] 
            for i, j in zip(y_test_df['event_OS'], y_test_df['OS']): 
                y_test.append((i, j))
            y_test = np.array(y_test, dtype=[('status', bool), ('time', np.int32)])
            
            model.fit(X_train, y_train)

            if metric == "c-index":
                # Make predictions using C-index 
                c_index_score = model.score(X_test, y_test)
                scores.append(c_index_score)
                print(f"Fold {k + 1} C-index: {c_index_score}")
                
            elif metric == "ibs":
                # Make predictions using IBS 
                lower, upper = np.percentile(y_test["time"], [10, 90])    
                times = np.arange(lower, upper)
                cox_surv_prob = np.row_stack([fn(times) for fn in model.predict_survival_function(X_test)])
                ibs = integrated_brier_score(y_test, y_test, cox_surv_prob, times)
                scores.append(ibs)
                print(f"Fold {k + 1} IBS: {ibs}")
            else:
                raise ValueError("Invalid metric. Use 'C-index' or 'ibs'.")
        
        # Return the mean of scores
        return np.mean(scores)
    
    return objective

# C-index
study_cindex = optuna.create_study(direction="maximize", sampler=optuna.samplers.TPESampler(seed=123))
objective_cindex = create_objective(RandomSurvivalForest, "c-index", X_new, y)
study_cindex.optimize(objective_cindex, n_trials=100, show_progress_bar=True)
print("\n")
print("* Best trial for C-index: \n", study_cindex.best_trial)
print("\n")
print("* Best Score for C-index: \n", study_cindex.best_value)

# Example usage for IBS
study_ibs = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(seed=123))
objective_ibs = create_objective(RandomSurvivalForest, "ibs", X_new, y)
study_ibs.optimize(objective_ibs, n_trials=100, show_progress_bar=True)
print("\n")
print("* Best trial for IBS: \n", study_ibs.best_trial)
print("\n")
print("* Best Score for IBS: \n", study_ibs.best_value)
# Out:
# [I 2024-04-18 15:35:10,557] A new study created in memory with name: no-name-d263e4dc-eee3-4d3f-89b8-ba3f9430b683
#   0%|          | 0/100 [00:00<?, ?it/s]
# Fold 1 C-index: 0.5909090909090909
# Fold 2 C-index: 0.6785714285714286
# Fold 3 C-index: 0.7132352941176471
# Fold 4 C-index: 0.7805907172995781
# Fold 5 C-index: 0.6807511737089202
# [I 2024-04-18 15:35:17,855] Trial 0 finished with value: 0.6888115409213331 and parameters: {'min_samples_split': 15, 'max_leaf_nodes': 7, 'min_samples_leaf': 5, 'max_depth': 12, 'n_estimators': 360, 'oob_score': False, 'max_samples': 0.7163467647263769, 'max_features': None, 'min_weight_fraction_leaf': 0.2192861223398122, 'warm_start': False}. Best is trial 0 with value: 0.6888115409213331.
# Fold 1 C-index: 0.5757575757575758
# Fold 2 C-index: 0.6294642857142857
# Fold 3 C-index: 0.696078431372549
# Fold 4 C-index: 0.7805907172995781
# Fold 5 C-index: 0.6901408450704225
# [I 2024-04-18 15:35:23,842] Trial 1 finished with value: 0.6744063710428823 and parameters: {'min_samples_split': 16, 'max_leaf_nodes': 5, 'min_samples_leaf': 4, 'max_depth': 11, 'n_estimators': 266, 'oob_score': False, 'max_samples': 0.7520097923745717, 'max_features': 'sqrt', 'min_weight_fraction_leaf': 0.11413161543947781, 'warm_start': False}. Best is trial 0 with value: 0.6888115409213331.
# Fold 1 C-index: 0.5844155844155844
# Fold 2 C-index: 0.6294642857142857
# Fold 3 C-index: 0.7156862745098039
# Fold 4 C-index: 0.7721518987341772
# Fold 5 C-index: 0.6948356807511737
# [I 2024-04-18 15:35:28,924] Trial 2 finished with value: 0.679310744825005 and parameters: {'min_samples_split': 3, 'max_leaf_nodes': 10, 'min_samples_leaf': 9, 'max_depth': 10, 'n_estimators': 213, 'oob_score': False, 'max_samples': 0.9040502468054213, 'max_features': 'auto', 'min_weight_fraction_leaf': 0.15864274091016045, 'warm_start': False}. Best is trial 0 with value: 0.6888115409213331.
# Fold 1 C-index: 0.5
# Fold 2 C-index: 0.5
# Fold 3 C-index: 0.5
# Fold 4 C-index: 0.5
# Fold 5 C-index: 0.5
# [I 2024-04-18 15:35:30,479] Trial 3 finished with value: 0.5 and parameters: {'min_samples_split': 6, 'max_leaf_nodes': 11, 'min_samples_leaf': 20, 'max_depth': 11, 'n_estimators': 307, 'oob_score': False, 'max_samples': 0.6427541155698346, 'max_features': 'auto', 'min_weight_fraction_leaf': 0.3406503828963983, 'warm_start': True}. Best is trial 0 with value: 0.6888115409213331.
# Fold 1 C-index: 0.5
# Fold 2 C-index: 0.5
# Fold 3 C-index: 0.5
# Fold 4 C-index: 0.5
# Fold 5 C-index: 0.5
# [I 2024-04-18 15:35:32,514] Trial 4 finished with value: 0.5 and parameters: {'min_samples_split': 14, 'max_leaf_nodes': 13, 'min_samples_leaf': 13, 'max_depth': 14, 'n_estimators': 422, 'oob_score': False, 'max_samples': 0.3192997370831866, 'max_features': None, 'min_weight_fraction_leaf': 0.31362448602563436, 'warm_start': True}. Best is trial 0 with value: 0.6888115409213331.
# Fold 1 C-index: 0.6017316017316018
# Fold 2 C-index: 0.6026785714285714
# Fold 3 C-index: 0.75
# Fold 4 C-index: 0.7426160337552743
# Fold 5 C-index: 0.6995305164319249
# [I 2024-04-18 15:35:38,772] Trial 5 finished with value: 0.6793113446694745 and parameters: {'min_samples_split': 13, 'max_leaf_nodes': 12, 'min_samples_leaf': 4, 'max_depth': 4, 'n_estimators': 348, 'oob_score': False, 'max_samples': 0.5989449247459949, 'max_features': 'sqrt', 'min_weight_fraction_leaf': 0.021795731899520276, 'warm_start': False}. Best is trial 0 with value: 0.6888115409213331.
# Fold 1 C-index: 0.5930735930735931
# Fold 2 C-index: 0.6071428571428571
# Fold 3 C-index: 0.7156862745098039
# Fold 4 C-index: 0.7637130801687764
# Fold 5 C-index: 0.6666666666666666
# [I 2024-04-18 15:35:46,810] Trial 6 finished with value: 0.6692564943123395 and parameters: {'min_samples_split': 15, 'max_leaf_nodes': 20, 'min_samples_leaf': 8, 'max_depth': 16, 'n_estimators': 297, 'oob_score': True, 'max_samples': 0.45898866345354095, 'max_features': None, 'min_weight_fraction_leaf': 0.052954242528406914, 'warm_start': False}. Best is trial 0 with value: 0.6888115409213331.
# Fold 1 C-index: 0.5
# Fold 2 C-index: 0.5
# Fold 3 C-index: 0.5
# Fold 4 C-index: 0.5
# Fold 5 C-index: 0.5
# [I 2024-04-18 15:35:51,740] Trial 7 finished with value: 0.5 and parameters: {'min_samples_split': 14, 'max_leaf_nodes': 18, 'min_samples_leaf': 12, 'max_depth': 18, 'n_estimators': 193, 'oob_score': False, 'max_samples': 0.2539736462845892, 'max_features': 'auto', 'min_weight_fraction_leaf': 0.26076652969866615, 'warm_start': False}. Best is trial 0 with value: 0.6888115409213331.
# Fold 1 C-index: 0.5
# Fold 2 C-index: 0.5
# Fold 3 C-index: 0.5
# Fold 4 C-index: 0.5
# Fold 5 C-index: 0.647887323943662
# [I 2024-04-18 15:36:06,385] Trial 8 finished with value: 0.5295774647887324 and parameters: {'min_samples_split': 19, 'max_leaf_nodes': 5, 'min_samples_leaf': 6, 'max_depth': 11, 'n_estimators': 451, 'oob_score': True, 'max_samples': 0.6079231386323035, 'max_features': 'auto', 'min_weight_fraction_leaf': 0.30034928391679494, 'warm_start': False}. Best is trial 0 with value: 0.6888115409213331.
# Fold 1 C-index: 0.6017316017316018
# Fold 2 C-index: 0.5982142857142857
# Fold 3 C-index: 0.7647058823529411
# Fold 4 C-index: 0.7510548523206751
# Fold 5 C-index: 0.704225352112676
# [I 2024-04-18 15:36:15,085] Trial 9 finished with value: 0.683986394846436 and parameters: {'min_samples_split': 3, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'max_depth': 10, 'n_estimators': 274, 'oob_score': False, 'max_samples': 0.9348258161369327, 'max_features': 'log2', 'min_weight_fraction_leaf': 0.024289516422134394, 'warm_start': False}. Best is trial 0 with value: 0.6888115409213331.
# Fold 1 C-index: 0.5
# Fold 2 C-index: 0.5
# Fold 3 C-index: 0.5
# Fold 4 C-index: 0.5
# Fold 5 C-index: 0.5
# [I 2024-04-18 15:36:16,085] Trial 10 finished with value: 0.5 and parameters: {'min_samples_split': 9, 'max_leaf_nodes': 2, 'min_samples_leaf': 2, 'max_depth': 3, 'n_estimators': 51, 'oob_score': True, 'max_samples': 0.10345432981037916, 'max_features': None, 'min_weight_fraction_leaf': 0.49314452820084254, 'warm_start': True}. Best is trial 0 with value: 0.6888115409213331.
# Fold 1 C-index: 0.5584415584415584
# Fold 2 C-index: 0.5982142857142857
# Fold 3 C-index: 0.7107843137254902
# Fold 4 C-index: 0.7763713080168776
# Fold 5 C-index: 0.676056338028169
# [I 2024-04-18 15:36:19,186] Trial 11 finished with value: 0.6639735607852761 and parameters: {'min_samples_split': 9, 'max_leaf_nodes': 8, 'min_samples_leaf': 1, 'max_depth': 7, 'n_estimators': 109, 'oob_score': False, 'max_samples': 0.9894300173846429, 'max_features': 'log2', 'min_weight_fraction_leaf': 0.17782839593648317, 'warm_start': False}. Best is trial 0 with value: 0.6888115409213331.
# Fold 1 C-index: 0.5
# Fold 2 C-index: 0.5
# Fold 3 C-index: 0.5
# Fold 4 C-index: 0.5
# Fold 5 C-index: 0.5
# [I 2024-04-18 15:36:29,451] Trial 12 finished with value: 0.5 and parameters: {'min_samples_split': 2, 'max_leaf_nodes': 15, 'min_samples_leaf': 7, 'max_depth': 20, 'n_estimators': 398, 'oob_score': False, 'max_samples': 0.7986766477402025, 'max_features': 'log2', 'min_weight_fraction_leaf': 0.42991693404730996, 'warm_start': False}. Best is trial 0 with value: 0.6888115409213331.
# Fold 1 C-index: 0.5670995670995671
# Fold 2 C-index: 0.6830357142857143
# Fold 3 C-index: 0.7156862745098039
# Fold 4 C-index: 0.7637130801687764
# Fold 5 C-index: 0.6525821596244131
# [I 2024-04-18 15:36:42,178] Trial 13 finished with value: 0.6764233591376551 and parameters: {'min_samples_split': 20, 'max_leaf_nodes': 7, 'min_samples_leaf': 15, 'max_depth': 7, 'n_estimators': 490, 'oob_score': False, 'max_samples': 0.7951627193746391, 'max_features': 'log2', 'min_weight_fraction_leaf': 0.20232132793200283, 'warm_start': False}. Best is trial 0 with value: 0.6888115409213331.
# Fold 1 C-index: 0.5930735930735931
# Fold 2 C-index: 0.7901785714285714
# Fold 3 C-index: 0.8431372549019608
# Fold 4 C-index: 0.9409282700421941
# Fold 5 C-index: 0.8732394366197183
# [I 2024-04-18 15:36:46,937] Trial 14 finished with value: 0.8081114252132074 and parameters: {'min_samples_split': 6, 'max_leaf_nodes': 8, 'min_samples_leaf': 5, 'max_depth': 14, 'n_estimators': 363, 'oob_score': True, 'max_samples': 0.9820866984011651, 'max_features': None, 'min_weight_fraction_leaf': 0.09327278101528028, 'warm_start': True}. Best is trial 14 with value: 0.8081114252132074.
# Fold 1 C-index: 0.6017316017316018
# Fold 2 C-index: 0.7232142857142857
# Fold 3 C-index: 0.7549019607843137
# Fold 4 C-index: 0.8227848101265823
# Fold 5 C-index: 0.7511737089201878
# [I 2024-04-18 15:36:50,526] Trial 15 finished with value: 0.7307612734553942 and parameters: {'min_samples_split': 10, 'max_leaf_nodes': 2, 'min_samples_leaf': 10, 'max_depth': 14, 'n_estimators': 362, 'oob_score': True, 'max_samples': 0.4747428535255964, 'max_features': None, 'min_weight_fraction_leaf': 0.10572555214268262, 'warm_start': True}. Best is trial 14 with value: 0.8081114252132074.
# Fold 1 C-index: 0.5952380952380952
# Fold 2 C-index: 0.7232142857142857
# Fold 3 C-index: 0.7352941176470589
# Fold 4 C-index: 0.7805907172995781
# Fold 5 C-index: 0.704225352112676
# [I 2024-04-18 15:36:53,680] Trial 16 finished with value: 0.7077125136023388 and parameters: {'min_samples_split': 7, 'max_leaf_nodes': 2, 'min_samples_leaf': 16, 'max_depth': 15, 'n_estimators': 366, 'oob_score': True, 'max_samples': 0.44827686549014745, 'max_features': None, 'min_weight_fraction_leaf': 0.08885761749697696, 'warm_start': True}. Best is trial 14 with value: 0.8081114252132074.
# Fold 1 C-index: 0.5865800865800865
# Fold 2 C-index: 0.7098214285714286
# Fold 3 C-index: 0.7401960784313726
# Fold 4 C-index: 0.7932489451476793
# Fold 5 C-index: 0.7276995305164319
# [I 2024-04-18 15:36:56,015] Trial 17 finished with value: 0.7115092138493998 and parameters: {'min_samples_split': 6, 'max_leaf_nodes': 4, 'min_samples_leaf': 10, 'max_depth': 17, 'n_estimators': 197, 'oob_score': True, 'max_samples': 0.40997938514589805, 'max_features': None, 'min_weight_fraction_leaf': 0.14725080437769245, 'warm_start': True}. Best is trial 14 with value: 0.8081114252132074.
# Fold 1 C-index: 0.5844155844155844
# Fold 2 C-index: 0.7321428571428571
# Fold 3 C-index: 0.7549019607843137
# Fold 4 C-index: 0.8565400843881856
# Fold 5 C-index: 0.7699530516431925
# [I 2024-04-18 15:37:00,736] Trial 18 finished with value: 0.7395907076748267 and parameters: {'min_samples_split': 11, 'max_leaf_nodes': 15, 'min_samples_leaf': 11, 'max_depth': 14, 'n_estimators': 476, 'oob_score': True, 'max_samples': 0.49486202937316004, 'max_features': None, 'min_weight_fraction_leaf': 0.07958856082174798, 'warm_start': True}. Best is trial 14 with value: 0.8081114252132074.
# Fold 1 C-index: 0.577922077922078
# Fold 2 C-index: 0.7321428571428571
# Fold 3 C-index: 0.7352941176470589
# Fold 4 C-index: 0.7763713080168776
# Fold 5 C-index: 0.704225352112676
# [I 2024-04-18 15:37:04,999] Trial 19 finished with value: 0.7051911425683095 and parameters: {'min_samples_split': 11, 'max_leaf_nodes': 15, 'min_samples_leaf': 13, 'max_depth': 20, 'n_estimators': 485, 'oob_score': True, 'max_samples': 0.31478192981222664, 'max_features': None, 'min_weight_fraction_leaf': 0.004060792657387402, 'warm_start': True}. Best is trial 14 with value: 0.8081114252132074.
# Fold 1 C-index: 0.5735930735930735
# Fold 2 C-index: 0.7232142857142857
# Fold 3 C-index: 0.7254901960784313
# Fold 4 C-index: 0.810126582278481
# Fold 5 C-index: 0.6901408450704225
# [I 2024-04-18 15:37:08,959] Trial 20 finished with value: 0.7045129965469388 and parameters: {'min_samples_split': 12, 'max_leaf_nodes': 15, 'min_samples_leaf': 18, 'max_depth': 8, 'n_estimators': 436, 'oob_score': True, 'max_samples': 0.5424733681477546, 'max_features': 'sqrt', 'min_weight_fraction_leaf': 0.06792131711925453, 'warm_start': True}. Best is trial 14 with value: 0.8081114252132074.
# Fold 1 C-index: 0.5757575757575758
# Fold 2 C-index: 0.7321428571428571
# Fold 3 C-index: 0.7696078431372549
# Fold 4 C-index: 0.8481012658227848
# Fold 5 C-index: 0.784037558685446
# [I 2024-04-18 15:37:13,155] Trial 21 finished with value: 0.7419294201091837 and parameters: {'min_samples_split': 8, 'max_leaf_nodes': 17, 'min_samples_leaf': 11, 'max_depth': 14, 'n_estimators': 385, 'oob_score': True, 'max_samples': 0.52032232892894, 'max_features': None, 'min_weight_fraction_leaf': 0.11700787412103095, 'warm_start': True}. Best is trial 14 with value: 0.8081114252132074.
# Fold 1 C-index: 0.5800865800865801
# Fold 2 C-index: 0.7410714285714286
# Fold 3 C-index: 0.75
# Fold 4 C-index: 0.8523206751054853
# Fold 5 C-index: 0.7699530516431925
# [I 2024-04-18 15:37:20,291] Trial 22 finished with value: 0.7386863470813373 and parameters: {'min_samples_split': 7, 'max_leaf_nodes': 17, 'min_samples_leaf': 12, 'max_depth': 13, 'n_estimators': 499, 'oob_score': True, 'max_samples': 0.5530906437718417, 'max_features': None, 'min_weight_fraction_leaf': 0.13245885036945804, 'warm_start': True}. Best is trial 14 with value: 0.8081114252132074.
# Fold 1 C-index: 0.5887445887445888
# Fold 2 C-index: 0.7544642857142857
# Fold 3 C-index: 0.7990196078431373
# Fold 4 C-index: 0.9156118143459916
# Fold 5 C-index: 0.8403755868544601
# [I 2024-04-18 15:37:25,210] Trial 23 finished with value: 0.7796431767004928 and parameters: {'min_samples_split': 5, 'max_leaf_nodes': 18, 'min_samples_leaf': 8, 'max_depth': 18, 'n_estimators': 405, 'oob_score': True, 'max_samples': 0.7026509113834132, 'max_features': None, 'min_weight_fraction_leaf': 0.06920257545379271, 'warm_start': True}. Best is trial 14 with value: 0.8081114252132074.
# Fold 1 C-index: 0.6017316017316018
# Fold 2 C-index: 0.7633928571428571
# Fold 3 C-index: 0.803921568627451
# Fold 4 C-index: 0.9324894514767933
# Fold 5 C-index: 0.8497652582159625
# [I 2024-04-18 15:37:29,185] Trial 24 finished with value: 0.7902601474389331 and parameters: {'min_samples_split': 5, 'max_leaf_nodes': 20, 'min_samples_leaf': 8, 'max_depth': 18, 'n_estimators': 395, 'oob_score': True, 'max_samples': 0.8564796589693975, 'max_features': None, 'min_weight_fraction_leaf': 0.04740297840847098, 'warm_start': True}. Best is trial 14 with value: 0.8081114252132074.
# Fold 1 C-index: 0.6017316017316018
# Fold 2 C-index: 0.7723214285714286
# Fold 3 C-index: 0.8088235294117647
# Fold 4 C-index: 0.9240506329113924
# Fold 5 C-index: 0.8497652582159625
# [I 2024-04-18 15:37:32,994] Trial 25 finished with value: 0.7913384901684299 and parameters: {'min_samples_split': 5, 'max_leaf_nodes': 19, 'min_samples_leaf': 8, 'max_depth': 18, 'n_estimators': 322, 'oob_score': True, 'max_samples': 0.8642414423034398, 'max_features': None, 'min_weight_fraction_leaf': 0.04474971974378786, 'warm_start': True}. Best is trial 14 with value: 0.8081114252132074.
# Fold 1 C-index: 0.5887445887445888
# Fold 2 C-index: 0.8482142857142857
# Fold 3 C-index: 0.8823529411764706
# Fold 4 C-index: 0.9620253164556962
# Fold 5 C-index: 0.9295774647887324
# [I 2024-04-18 15:37:36,859] Trial 26 finished with value: 0.8421829193759546 and parameters: {'min_samples_split': 4, 'max_leaf_nodes': 20, 'min_samples_leaf': 3, 'max_depth': 19, 'n_estimators': 318, 'oob_score': True, 'max_samples': 0.8751615981612533, 'max_features': None, 'min_weight_fraction_leaf': 0.04200505214483813, 'warm_start': True}. Best is trial 26 with value: 0.8421829193759546.
# Fold 1 C-index: 0.5670995670995671
# Fold 2 C-index: 0.8616071428571429
# Fold 3 C-index: 0.9019607843137255
# Fold 4 C-index: 0.9746835443037974
# Fold 5 C-index: 0.9436619718309859
# [I 2024-04-18 15:37:40,338] Trial 27 finished with value: 0.8498026020810437 and parameters: {'min_samples_split': 4, 'max_leaf_nodes': 20, 'min_samples_leaf': 3, 'max_depth': 20, 'n_estimators': 319, 'oob_score': True, 'max_samples': 0.9879533276649035, 'max_features': None, 'min_weight_fraction_leaf': 0.011983605510188039, 'warm_start': True}. Best is trial 27 with value: 0.8498026020810437.
# Fold 1 C-index: 0.5627705627705628
# Fold 2 C-index: 0.875
# Fold 3 C-index: 0.8921568627450981
# Fold 4 C-index: 0.9746835443037974
# Fold 5 C-index: 0.9389671361502347
# [I 2024-04-18 15:37:42,875] Trial 28 finished with value: 0.8487156211939386 and parameters: {'min_samples_split': 3, 'max_leaf_nodes': 13, 'min_samples_leaf': 2, 'max_depth': 20, 'n_estimators': 235, 'oob_score': True, 'max_samples': 0.998980080573164, 'max_features': 'sqrt', 'min_weight_fraction_leaf': 0.0019034940959545485, 'warm_start': True}. Best is trial 27 with value: 0.8498026020810437.
# Fold 1 C-index: 0.5800865800865801
# Fold 2 C-index: 0.875
# Fold 3 C-index: 0.9068627450980392
# Fold 4 C-index: 0.9746835443037974
# Fold 5 C-index: 0.9389671361502347
# [I 2024-04-18 15:37:44,750] Trial 29 finished with value: 0.8551200011277302 and parameters: {'min_samples_split': 3, 'max_leaf_nodes': 17, 'min_samples_leaf': 2, 'max_depth': 20, 'n_estimators': 235, 'oob_score': True, 'max_samples': 0.9302980822531979, 'max_features': 'sqrt', 'min_weight_fraction_leaf': 0.021467459054890132, 'warm_start': True}. Best is trial 29 with value: 0.8551200011277302.
# Fold 1 C-index: 0.5584415584415584
# Fold 2 C-index: 0.8616071428571429
# Fold 3 C-index: 0.8921568627450981
# Fold 4 C-index: 0.9662447257383966
# Fold 5 C-index: 0.9295774647887324
# [I 2024-04-18 15:37:46,016] Trial 30 finished with value: 0.8416055509141855 and parameters: {'min_samples_split': 3, 'max_leaf_nodes': 14, 'min_samples_leaf': 1, 'max_depth': 16, 'n_estimators': 139, 'oob_score': True, 'max_samples': 0.9458947940639486, 'max_features': 'sqrt', 'min_weight_fraction_leaf': 0.006369977015457234, 'warm_start': True}. Best is trial 29 with value: 0.8551200011277302.
# Fold 1 C-index: 0.5800865800865801
# Fold 2 C-index: 0.8571428571428571
# Fold 3 C-index: 0.8774509803921569
# Fold 4 C-index: 0.9662447257383966
# Fold 5 C-index: 0.92018779342723
# [I 2024-04-18 15:37:49,130] Trial 31 finished with value: 0.840222587357444 and parameters: {'min_samples_split': 2, 'max_leaf_nodes': 17, 'min_samples_leaf': 3, 'max_depth': 20, 'n_estimators': 235, 'oob_score': True, 'max_samples': 0.883340232291943, 'max_features': 'sqrt', 'min_weight_fraction_leaf': 0.03268037382039034, 'warm_start': True}. Best is trial 29 with value: 0.8551200011277302.
# Fold 1 C-index: 0.5844155844155844
# Fold 2 C-index: 0.8794642857142857
# Fold 3 C-index: 0.8921568627450981
# Fold 4 C-index: 0.9620253164556962
# Fold 5 C-index: 0.9248826291079812
# [I 2024-04-18 15:37:51,977] Trial 32 finished with value: 0.8485889356877291 and parameters: {'min_samples_split': 4, 'max_leaf_nodes': 19, 'min_samples_leaf': 3, 'max_depth': 19, 'n_estimators': 250, 'oob_score': True, 'max_samples': 0.9973387465377965, 'max_features': 'sqrt', 'min_weight_fraction_leaf': 0.0027953627514292374, 'warm_start': True}. Best is trial 29 with value: 0.8551200011277302.
# Fold 1 C-index: 0.5887445887445888
# Fold 2 C-index: 0.8705357142857143
# Fold 3 C-index: 0.8921568627450981
# Fold 4 C-index: 0.9620253164556962
# Fold 5 C-index: 0.9295774647887324
# [I 2024-04-18 15:37:54,239] Trial 33 finished with value: 0.8486079894039659 and parameters: {'min_samples_split': 4, 'max_leaf_nodes': 18, 'min_samples_leaf': 3, 'max_depth': 19, 'n_estimators': 154, 'oob_score': True, 'max_samples': 0.9952904682486049, 'max_features': 'sqrt', 'min_weight_fraction_leaf': 0.001449390678020284, 'warm_start': True}. Best is trial 29 with value: 0.8551200011277302.
# Fold 1 C-index: 0.5584415584415584
# Fold 2 C-index: 0.8839285714285714
# Fold 3 C-index: 0.9068627450980392
# Fold 4 C-index: 0.9704641350210971
# Fold 5 C-index: 0.9436619718309859
# [I 2024-04-18 15:37:56,399] Trial 34 finished with value: 0.8526717963640504 and parameters: {'min_samples_split': 2, 'max_leaf_nodes': 16, 'min_samples_leaf': 1, 'max_depth': 20, 'n_estimators': 151, 'oob_score': True, 'max_samples': 0.8102079452857852, 'max_features': 'sqrt', 'min_weight_fraction_leaf': 0.002548796120006168, 'warm_start': True}. Best is trial 29 with value: 0.8551200011277302.
# Fold 1 C-index: 0.5735930735930735
# Fold 2 C-index: 0.6919642857142857
# Fold 3 C-index: 0.7230392156862745
# Fold 4 C-index: 0.759493670886076
# Fold 5 C-index: 0.6525821596244131
# [I 2024-04-18 15:37:57,894] Trial 35 finished with value: 0.6801344811008245 and parameters: {'min_samples_split': 2, 'max_leaf_nodes': 16, 'min_samples_leaf': 1, 'max_depth': 17, 'n_estimators': 92, 'oob_score': True, 'max_samples': 0.8022706676155099, 'max_features': 'sqrt', 'min_weight_fraction_leaf': 0.385560176300128, 'warm_start': True}. Best is trial 29 with value: 0.8551200011277302.
# Fold 1 C-index: 0.5714285714285714
# Fold 2 C-index: 0.7410714285714286
# Fold 3 C-index: 0.7450980392156863
# Fold 4 C-index: 0.8523206751054853
# Fold 5 C-index: 0.8028169014084507
# [I 2024-04-18 15:38:00,160] Trial 36 finished with value: 0.7425471231459244 and parameters: {'min_samples_split': 3, 'max_leaf_nodes': 13, 'min_samples_leaf': 2, 'max_depth': 20, 'n_estimators': 165, 'oob_score': True, 'max_samples': 0.7165866941586748, 'max_features': 'sqrt', 'min_weight_fraction_leaf': 0.185997229556796, 'warm_start': True}. Best is trial 29 with value: 0.8551200011277302.
# Fold 1 C-index: 0.5844155844155844
# Fold 2 C-index: 0.7366071428571429
# Fold 3 C-index: 0.7426470588235294
# [W 2024-04-18 15:38:02,316] Trial 37 failed with parameters: {'min_samples_split': 2, 'max_leaf_nodes': 13, 'min_samples_leaf': 5, 'max_depth': 16, 'n_estimators': 222, 'oob_score': True, 'max_samples': 0.9285056171877066, 'max_features': 'sqrt', 'min_weight_fraction_leaf': 0.23773292513973324, 'warm_start': True} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "/Users/minjeongcheon/opt/anaconda3/lib/python3.9/site-packages/optuna/study/_optimize.py", line 200, in _run_trial
#     value_or_values = func(trial)
#   File "/var/folders/64/jkqp6xyx2hj50dmd2pqfm3780000gn/T/ipykernel_16284/3295956579.py", line 56, in objective
#     model.fit(X_train, y_train)
#   File "/Users/minjeongcheon/opt/anaconda3/lib/python3.9/site-packages/sksurv/ensemble/forest.py", line 167, in fit
#     self._set_oob_score_and_attributes(X, (event, time))
#   File "/Users/minjeongcheon/opt/anaconda3/lib/python3.9/site-packages/sksurv/ensemble/forest.py", line 183, in _set_oob_score_and_attributes
#     p_estimator = estimator.predict(X[unsampled_indices, :], check_input=False)
#   File "/Users/minjeongcheon/opt/anaconda3/lib/python3.9/site-packages/sksurv/tree/tree.py", line 368, in predict
#     return chf[:, self.is_event_time_].sum(1)
# KeyboardInterrupt
# [W 2024-04-18 15:38:02,323] Trial 37 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/64/jkqp6xyx2hj50dmd2pqfm3780000gn/T/ipykernel_16284/3295956579.py in <module>
#      81 study_cindex = optuna.create_study(direction="maximize", sampler=optuna.samplers.TPESampler(seed=123))
#      82 objective_cindex = create_objective(RandomSurvivalForest, "c-index", X_new, y)
# ---> 83 study_cindex.optimize(objective_cindex, n_trials=100, show_progress_bar=True)
#      84 print("\n")
#      85 print("* Best trial for C-index: \n", study_cindex.best_trial)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/optuna/study/study.py in optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     449                 If nested invocation of this method occurs.
#     450         """
# --> 451         _optimize(
#     452             study=self,
#     453             func=func,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/optuna/study/_optimize.py in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      64     try:
#      65         if n_jobs == 1:
# ---> 66             _optimize_sequential(
#      67                 study,
#      68                 func,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/optuna/study/_optimize.py in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     161
#     162         try:
# --> 163             frozen_trial = _run_trial(study, func, catch)
#     164         finally:
#     165             # The following line mitigates memory problems that can be occurred in some
#
# ~/opt/anaconda3/lib/python3.9/site-packages/optuna/study/_optimize.py in _run_trial(study, func, catch)
#     249         and not isinstance(func_err, catch)
#     250     ):
# --> 251         raise func_err
#     252     return frozen_trial
#     253
#
# ~/opt/anaconda3/lib/python3.9/site-packages/optuna/study/_optimize.py in _run_trial(study, func, catch)
#     198     with get_heartbeat_thread(trial._trial_id, study._storage):
#     199         try:
# --> 200             value_or_values = func(trial)
#     201         except exceptions.TrialPruned as e:
#     202             # TODO(mamu): Handle multi-objective cases.
#
# /var/folders/64/jkqp6xyx2hj50dmd2pqfm3780000gn/T/ipykernel_16284/3295956579.py in objective(trial)
#      54             y_test = np.array(y_test, dtype=[('status', bool), ('time', np.int32)])
#      55
# ---> 56             model.fit(X_train, y_train)
#      57
#      58             if metric == "c-index":
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sksurv/ensemble/forest.py in fit(self, X, y, sample_weight)
#     165
#     166         if self.oob_score:
# --> 167             self._set_oob_score_and_attributes(X, (event, time))
#     168
#     169         return self
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sksurv/ensemble/forest.py in _set_oob_score_and_attributes(self, X, y)
#     181         for estimator in self.estimators_:
#     182             unsampled_indices = _generate_unsampled_indices(estimator.random_state, n_samples, n_samples_bootstrap)
# --> 183             p_estimator = estimator.predict(X[unsampled_indices, :], check_input=False)
#     184
#     185             predictions[unsampled_indices] += p_estimator
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sksurv/tree/tree.py in predict(self, X, check_input)
#     366         """
#     367         chf = self.predict_cumulative_hazard_function(X, check_input, return_array=True)
# --> 368         return chf[:, self.is_event_time_].sum(1)
#     369
#     370     def predict_cumulative_hazard_function(self, X, check_input=True, return_array=False):
#
# KeyboardInterrupt:

# %%
train_cindex['Randomsurvivalforest'] = np.round(study_cindex.best_value, 3)
train_ibs['Randomsurvivalforest'] = np.round(study_ibs.best_value, 3)

# %%
print("train_cindex: ", np.round(study_cindex.best_value, 3))
print("train_ibs: ", np.round(study_ibs.best_value, 3))

# %% [markdown]
# #### Test

# %%
# y into array 
lists = [] 
for i, j in zip(y['event_OS'], y['OS']): 
    lists.append((i, j))
    
y = np.array(lists, dtype=[('status', bool), ('time', np.int32)])

# %%
# A function for building the best model with the best parameters 
def create_best_model(model_class, best_params):
    best_params["random_state"]=123
    return model_class(**best_params)

# Set the best model 
best_model_cindex = create_best_model(RandomSurvivalForest, study_cindex.best_params)

# Train the best model for C-index on the whole dataset
best_model_cindex.fit(X_new, y)

# Evaluate the best model for C-index on MAASTRO dataset
c_index = best_model_cindex.score(MAASTRO_new, y_MAASTRO)
c_index = np.round(c_index, 3)
print("test_cindex: ", c_index)

# Set the best model 
best_model_ibs = create_best_model(RandomSurvivalForest, study_ibs.best_params)

# Train the best model for IBS on the whole dataset
best_model_ibs.fit(X_new, y)

# Evaluate the best model for IBS on MAASTRO dataset
lower, upper = np.percentile(y_MAASTRO["time"], [10, 90])
times = np.arange(lower, upper)
surv_prob = np.row_stack([fn(times) for fn in best_model_ibs.predict_survival_function(MAASTRO_new)])
ibs = integrated_brier_score(y_MAASTRO,y_MAASTRO, surv_prob, times)
ibs = np.round(ibs, 3)
print("test_ibs: ", ibs)

# %%
# Saving the values to the dictionary 
test_cindex['Randomsurvivalforest'] = c_index
test_ibs['Randomsurvivalforest'] = ibs

# %% [markdown]
# ### 6. ExtraSurvivalTrees

# %% [markdown]
# #### Train

# %%
# Setting the y format 
y = clinical_train[['OS', 'event_OS']]

def create_objective(model_class, metric, X, y):
    def objective(trial): 
        # Suggest values for hyperparameters 
        min_samples_split = trial.suggest_int("min_samples_split", 2, 20)
        max_leaf_nodes = trial.suggest_int("max_leaf_nodes", 2, 20)
        min_samples_leaf = trial.suggest_int("min_samples_leaf", 1, 20)
        max_depth = trial.suggest_int("max_depth", 1, 20)
        n_estimators = trial.suggest_int("n_estimators", 1, 500)
        oob_score = trial.suggest_categorical("oob_score", [True, False])
        warm_start = trial.suggest_categorical("warm_start", [True, False])
        max_features = trial.suggest_categorical("max_features", ["auto", "sqrt", "log2", None, 0.1, 1])
        max_samples = trial.suggest_float("max_samples", 0.1, 1.0) 
        min_weight_fraction_leaf = trial.suggest_float("min_weight_fraction_leaf", 0.0, 0.5)
        
        # Include warm_start for C-index optimization
        if metric == "c-index":
            warm_start = trial.suggest_categorical("warm_start", [True, False])
        else:
            warm_start = False  # Exclude warm_start for other metrics

        
        # Create and fit survival model 
        model = model_class(min_samples_split=min_samples_split,
                            min_samples_leaf=min_samples_leaf,
                            max_leaf_nodes=max_leaf_nodes,
                            n_estimators=n_estimators, 
                            oob_score=oob_score, 
                            max_features=max_features, 
                            warm_start=warm_start, 
                            max_samples=max_samples,
                            min_weight_fraction_leaf=min_weight_fraction_leaf, 
                            max_depth=max_depth, 
                            random_state=123) 
        
        scores = [] 
        
        skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=123)
        
        for k, (train_index, test_index) in enumerate(skf.split(X, y.iloc[:, 1])): 
            X_train, X_test = X.iloc[train_index], X.iloc[test_index]
            y_train_df, y_test_df = y.iloc[train_index], y.iloc[test_index]
            
            # y_train into array 
            y_train = [] 
            for i, j in zip(y_train_df['event_OS'], y_train_df['OS']): 
                y_train.append((i, j))
            y_train = np.array(y_train, dtype=[('status', bool), ('time', np.int32)])

            # y_test into array
            y_test = [] 
            for i, j in zip(y_test_df['event_OS'], y_test_df['OS']): 
                y_test.append((i, j))
            y_test = np.array(y_test, dtype=[('status', bool), ('time', np.int32)])

            model.fit(X_train, y_train)

            if metric == "c-index":
                # Make predictions using C-index 
                c_index_score = model.score(X_test, y_test)
                scores.append(c_index_score)
                print(f"Fold {k + 1} C-index: {c_index_score}")
                
            elif metric == "ibs":
                # Make predictions using IBS 
                lower, upper = np.percentile(y_test["time"], [10, 90])    
                times = np.arange(lower, upper)
                surv_prob = np.row_stack([fn(times) for fn in model.predict_survival_function(X_test)])
                ibs = integrated_brier_score(y_test, y_test, surv_prob, times)
                scores.append(ibs)
                print(f"Fold {k + 1} IBS: {ibs}")
            else:
                raise ValueError("Invalid metric. Use 'C-index' or 'ibs'.")
        
        # Return the mean of scores
        return np.mean(scores)
    
    return objective

# C-index
study_cindex = optuna.create_study(direction="maximize", sampler=optuna.samplers.TPESampler(seed=123))
objective_cindex = create_objective(ExtraSurvivalTrees, "c-index", X_new, y)
study_cindex.optimize(objective_cindex, n_trials=100, show_progress_bar=True)
print("\n")
print("* Best trial for C-index: \n", study_cindex.best_trial)
print("\n")
print("* Best Score for C-index: \n", study_cindex.best_value)

# Example usage for IBS
study_ibs = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(seed=123))
objective_ibs = create_objective(ExtraSurvivalTrees, "ibs", X_new, y)
study_ibs.optimize(objective_ibs, n_trials=100, show_progress_bar=True)
print("\n")
print("* Best trial for IBS: \n", study_ibs.best_trial)
print("\n")
print("* Best Score for IBS: \n", study_ibs.best_value)

# %%
train_cindex['ExtraSurvivalTrees'] = np.round(study_cindex.best_value, 3)
train_ibs['ExtraSurvivalTrees'] = np.round(study_ibs.best_value, 3)

# %%
print("train_cindex: ", np.round(study_cindex.best_value, 3))
print("train_ibs: ", np.round(study_ibs.best_value, 3))

# %% [markdown]
# #### Test

# %%
# y into array 
lists = [] 
for i, j in zip(y['event_OS'], y['OS']): 
    lists.append((i, j))

y = np.array(lists, dtype=[('status', bool), ('time', np.int32)])

# %%
# A function for building the best model with the best parameters 
def create_best_model(model_class, best_params):
    best_params["random_state"]=123
    return model_class(**best_params)

# Set the best model 
best_model_cindex = create_best_model(ExtraSurvivalTrees, study_cindex.best_params)

# Train the best model for C-index on the whole dataset
best_model_cindex.fit(X_new, y)

# Evaluate the best model for C-index on MAASTRO dataset
c_index = best_model_cindex.score(MAASTRO_new, y_MAASTRO)
c_index = np.round(c_index, 3)
print("C-index score:", c_index)

# Set the best model 
best_model_ibs = create_best_model(ExtraSurvivalTrees, study_ibs.best_params)

# Train the best model for IBS on the whole dataset
best_model_ibs.fit(X_new, y)

# Evaluate the best model for IBS on MAASTRO dataset
lower, upper = np.percentile(y_MAASTRO["time"], [10, 90])
times = np.arange(lower, upper)
surv_prob = np.row_stack([fn(times) for fn in best_model_ibs.predict_survival_function(MAASTRO_new)])
ibs = integrated_brier_score(y_MAASTRO,y_MAASTRO, surv_prob, times)
ibs = np.round(ibs, 3)
print("IBS:", ibs)

# %%
# Saving the values to the dictionary 
test_cindex['ExtraSurvivalTrees'] = c_index
test_ibs['ExtraSurvivalTrees'] = ibs

# %% [markdown]
# ### 7. GradientBoostingSurvivalAnalysis

# %% [markdown]
# #### Train

# %%
# Setting the y format 
y = clinical_train[['OS', 'event_OS']]

# Running to optuna for hyperparameter tuning
def create_objective(model_class, metric, X, y):
    def objective(trial): 
        # Suggest values for hyperparameters
        subsample = trial.suggest_float("subsample", 0.1, 1)
        learning_rate = trial.suggest_float("learning_rate", 0.001, 0.1)
        dropout_rate = trial.suggest_float("dropout_rate", 0.1, 1)
        n_estimators = trial.suggest_int("n_estimators", 1, 500)
        criterion = trial.suggest_categorical('criterion', ['friedman_mse', 'squared_error'])
        ccp_alpha = trial.suggest_float("ccp_alpha", 0.0, 10)
        min_weight_fraction_leaf = trial.suggest_float("min_weight_fraction_leaf", 0.0, 0.5)
        max_features = trial.suggest_categorical("max_features", ["auto", "sqrt", "log2", None, 0.1, 1])
        min_impurity_decrease = trial.suggest_loguniform('min_impurity_decrease', 1e-7, 1e-1)
        validation_fraction = trial.suggest_float("validation_fraction", 0.0, 1.0)
        min_samples_split = trial.suggest_int("min_samples_split", 2, 20)
        max_leaf_nodes = trial.suggest_int("max_leaf_nodes", 2, 20)
        min_samples_leaf = trial.suggest_int("min_samples_leaf", 1, 20)
        max_depth = trial.suggest_int("max_depth", 1, 20)
        
        # Create and fit survival model 
        model = model_class(subsample=subsample,
                            learning_rate=learning_rate,
                            dropout_rate=dropout_rate,
                            n_estimators=n_estimators,
                            ccp_alpha=ccp_alpha, 
                            criterion=criterion,
                            min_samples_split=min_samples_split,
                            min_samples_leaf=min_samples_leaf,
                            min_weight_fraction_leaf=min_weight_fraction_leaf,
                            max_depth=max_depth,
                            max_features=max_features,
                            max_leaf_nodes=max_leaf_nodes, 
                            min_impurity_decrease=min_impurity_decrease,
                            validation_fraction=validation_fraction, 
                            random_state=123)
        
        scores = [] 
        
        skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=123)
        
        for k, (train_index, test_index) in enumerate(skf.split(X, y.iloc[:, 1])): 
            X_train, X_test = X.iloc[train_index], X.iloc[test_index]
            y_train_df, y_test_df = y.iloc[train_index], y.iloc[test_index]
            
            # y_train into array 
            y_train = [] 
            for i, j in zip(y_train_df['event_OS'], y_train_df['OS']): 
                y_train.append((i, j))
            y_train = np.array(y_train, dtype=[('status', bool), ('time', np.int32)])

            # y_test into array
            y_test = [] 
            for i, j in zip(y_test_df['event_OS'], y_test_df['OS']): 
                y_test.append((i, j))
            y_test = np.array(y_test, dtype=[('status', bool), ('time', np.int32)])

            model.fit(X_train, y_train)

            if metric == "c-index":
                # Make predictions using C-index 
                c_index_score = model.score(X_test, y_test)
                scores.append(c_index_score)
                print(f"Fold {k + 1} C-index: {c_index_score}")
                
            elif metric == "ibs":
                # Make predictions using IBS 
                lower, upper = np.percentile(y_test["time"], [10, 90])    
                times = np.arange(lower, upper)
                surv_prob = np.row_stack([fn(times) for fn in model.predict_survival_function(X_test)])
                ibs = integrated_brier_score(y_test, y_test, surv_prob, times)
                scores.append(ibs)
                print(f"Fold {k + 1} IBS: {ibs}")
            else:
                raise ValueError("Invalid metric. Use 'C-index' or 'ibs'.")
        
        # Return the mean of scores
        return np.mean(scores)
    
    return objective

# C-index
study_cindex = optuna.create_study(direction="maximize", sampler=optuna.samplers.TPESampler(seed=123))
objective_cindex = create_objective(GradientBoostingSurvivalAnalysis, "c-index", X_new, y)
study_cindex.optimize(objective_cindex, n_trials=100, show_progress_bar=True)
print("\n")
print("* Best trial for C-index: \n", study_cindex.best_trial)
print("\n")
print("* Best Score for C-index: \n", study_cindex.best_value)

# Example usage for IBS
study_ibs = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(seed=123))
objective_ibs = create_objective(GradientBoostingSurvivalAnalysis, "ibs", X_new, y)
study_ibs.optimize(objective_ibs, n_trials=100, show_progress_bar=True)
print("\n")
print("* Best trial for IBS: \n", study_ibs.best_trial)
print("\n")
print("* Best Score for IBS: \n", study_ibs.best_value)

# %%
train_cindex['GradientBoosting'] = np.round(study_cindex.best_value, 3)
train_ibs['GradientBoosting'] = np.round(study_ibs.best_value, 3)

# %%
print("train_cindex: ", np.round(study_cindex.best_value, 3))
print("train_ibs: ", np.round(study_ibs.best_value, 3))

# %% [markdown]
# #### Test

# %%
# y into array 
lists = [] 
for i, j in zip(y['event_OS'], y['OS']): 
    lists.append((i, j))

y = np.array(lists, dtype=[('status', bool), ('time', np.int32)])

# %%
# A function for building the best model with the best parameters 
def create_best_model(model_class, best_params):
    best_params["random_state"]=123
    return model_class(**best_params)

# Set the best model 
best_model_cindex = create_best_model(GradientBoostingSurvivalAnalysis, study_cindex.best_params)

# Train the best model for C-index on the whole dataset
best_model_cindex.fit(X_new, y)

# Evaluate the best model for C-index on MAASTRO dataset
c_index = best_model_cindex.score(MAASTRO_new, y_MAASTRO)
c_index = np.round(c_index, 3)
print("C-index score:", c_index)

# Set the best model 
best_model_ibs = create_best_model(GradientBoostingSurvivalAnalysis, study_ibs.best_params)

# Train the best model for IBS on the whole dataset
best_model_ibs.fit(X_new, y)

# Evaluate the best model for IBS on MAASTRO dataset
lower, upper = np.percentile(y_MAASTRO["time"], [10, 90])
times = np.arange(lower, upper)
surv_prob = np.row_stack([fn(times) for fn in best_model_ibs.predict_survival_function(MAASTRO_new)])
ibs = integrated_brier_score(y_MAASTRO,y_MAASTRO, surv_prob, times)
ibs = np.round(ibs, 3)
print("IBS:", ibs)

# %%
# Saving the values to the dictionary 
test_cindex['GradientBoosting'] = c_index
test_ibs['GradientBoosting'] = ibs

# %% [markdown]
# ### 8. ComponentwiseGradientBoostingSurvivalAnalysis

# %% [markdown]
# #### Train

# %%
# Setting the y format 
y = clinical_train[['OS', 'event_OS']]

def create_objective(model_class, metric, X, y):
    def objective(trial): 
        # Suggest values for hyperparameters
        subsample = trial.suggest_float("subsample", 0.1, 1)
        dropout_rate = trial.suggest_float("dropout_rate", 0.1, 1)
        n_estimators = trial.suggest_int("n_estimators", 1, 500)
        learning_rate = trial.suggest_float("learning_rate", 0.001, 0.1)
        
        # Create and fit survival model 
        model = model_class(subsample=subsample,
                            dropout_rate=dropout_rate,
                            n_estimators=n_estimators,
                            learning_rate=learning_rate,
                            random_state=123)
                
        scores = [] 
        
        skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=123)
        
        for k, (train_index, test_index) in enumerate(skf.split(X, y.iloc[:, 1])): 
            X_train, X_test = X.iloc[train_index], X.iloc[test_index]
            y_train_df, y_test_df = y.iloc[train_index], y.iloc[test_index]
            
            # y_train into array 
            y_train = [] 
            for i, j in zip(y_train_df['event_OS'], y_train_df['OS']): 
                y_train.append((i, j))
            y_train = np.array(y_train, dtype=[('status', bool), ('time', np.int32)])

            # y_test into array
            y_test = [] 
            for i, j in zip(y_test_df['event_OS'], y_test_df['OS']): 
                y_test.append((i, j))
            y_test = np.array(y_test, dtype=[('status', bool), ('time', np.int32)])

            # Min Max Standardization
            excluded_columns = ['female', 
                                'cavum_oris',
                                'oropharynx',
                                'hypopharynx',
                                'larynx',
                                'histgrade_high',
                                'hpv_related',
                                'charlson',
                                'uicc8_III-IV'
                               ]
            excluded_columns = set(excluded_columns).intersection(X.columns)

            scaler = MinMaxScaler() 
            X_train_included = X_train.drop(excluded_columns, axis=1)
            X_test_included = X_test.drop(excluded_columns, axis=1)
                        
            if not X_train_included.empty and not X_test_included.empty:
                X_train_included_std = scaler.fit_transform(X_train_included)
                X_test_included_std = scaler.transform(X_test_included)
                
                # Concatenation
                X_train_std_df = pd.DataFrame(X_train_included_std, columns=X_train_included.columns, index=X_train_included.index)
                X_train_std = pd.concat([X_train_std_df, X_train[excluded_columns]], axis=1)

                X_test_std_df = pd.DataFrame(X_test_included_std, columns=X_test_included.columns, index=X_test_included.index)
                X_test_std = pd.concat([X_test_std_df, X_test[excluded_columns]], axis=1)
            
            else: 
                X_train_std = X_train
                X_test_std = X_test 
            
            model.fit(X_train_std, y_train)

            if metric == "c-index":
                # Make predictions using C-index 
                c_index_score = model.score(X_test_std, y_test)
                scores.append(c_index_score)
                print(f"Fold {k + 1} C-index: {c_index_score}")
                
            elif metric == "ibs":
                # Make predictions using IBS 
                lower, upper = np.percentile(y_test["time"], [10, 90])    
                times = np.arange(lower, upper)
                surv_prob = np.row_stack([fn(times) for fn in model.predict_survival_function(X_test_std)])
                ibs = integrated_brier_score(y_test, y_test, surv_prob, times)
                scores.append(ibs)
                print(f"Fold {k + 1} IBS: {ibs}")
            else:
                raise ValueError("Invalid metric. Use 'C-index' or 'ibs'.")
        
        # Return the mean of scores
        return np.mean(scores)
    
    return objective


# C-index
study_cindex = optuna.create_study(direction="maximize", sampler=optuna.samplers.TPESampler(seed=123))
objective_cindex = create_objective(ComponentwiseGradientBoostingSurvivalAnalysis, "c-index", X_new, y)
study_cindex.optimize(objective_cindex, n_trials=100, show_progress_bar=True)
print("\n")
print("* Best trial for C-index: \n", study_cindex.best_trial)
print("\n")
print("* Best hyperparameters for C-index: \n", study_cindex.best_params)
print("\n")
print("* Best Score for C-index: \n", study_cindex.best_value)

# IBS
study_ibs = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(seed=123))
objective_ibs = create_objective(ComponentwiseGradientBoostingSurvivalAnalysis, "ibs", X_new, y)
study_ibs.optimize(objective_ibs, n_trials=100, show_progress_bar=True)
print("\n")
print("* Best trial for IBS: \n", study_ibs.best_trial)
print("\n")
print("* Best hyperparameters for IBS: \n", study_ibs.best_params)
print("\n")
print("* Best Score for IBS: \n", study_ibs.best_value)

# %%
train_cindex['ComponentwiseGradientBoosting'] = np.round(study_cindex.best_value, 3)
train_ibs['ComponentwiseGradientBoosting'] = np.round(study_ibs.best_value, 3)

# %%
print("train_cindex: ", np.round(study_cindex.best_value, 3))
print("train_ibs: ", np.round(study_ibs.best_value, 3))

# %% [markdown]
# #### Test

# %%
# y into array 
lists = [] 
for i, j in zip(y['event_OS'], y['OS']): 
    lists.append((i, j))

y = np.array(lists, dtype=[('status', bool), ('time', np.int32)])

# %%
# A function for building the best model with the best parameters 
def create_best_model(model_class, best_params):
    best_params["random_state"]=123
    return model_class(**best_params)

# Set the best model 
best_model_cindex = create_best_model(ComponentwiseGradientBoostingSurvivalAnalysis, study_cindex.best_params)

# Train the best model for C-index on the whole dataset
best_model_cindex.fit(X_new_std, y)

# Evaluate the best model for C-index on MAASTRO dataset
c_index = best_model_cindex.score(MAASTRO_new_std, y_MAASTRO)
c_index = np.round(c_index, 3)
print("C-index score:", c_index)

# Set the best model 
best_model_ibs = create_best_model(ComponentwiseGradientBoostingSurvivalAnalysis, study_ibs.best_params)

# Train the best model for IBS on the whole dataset
best_model_ibs.fit(X_new_std, y)

# Evaluate the best model for IBS on MAASTRO dataset
lower, upper = np.percentile(y_MAASTRO["time"], [10, 90])
times = np.arange(lower, upper)
surv_prob = np.row_stack([fn(times) for fn in best_model_ibs.predict_survival_function(MAASTRO_new_std)])
ibs = integrated_brier_score(y_MAASTRO,y_MAASTRO, surv_prob, times)
ibs = np.round(ibs, 3)
print("IBS:", ibs)

# %%
# Saving the values to the dictionary 
test_cindex['ComponentwiseGradientBoosting'] = c_index
test_ibs['ComponentwiseGradientBoosting'] = ibs

# %% [markdown]
# ## Results

# %%
df_train_cindex = pd.DataFrame(train_cindex, index=['C-index']).transpose().sort_values(by='C-index', ascending=False)
df_train_cindex['rank'] = df_train_cindex['C-index'].rank(ascending=False)
df_train_cindex

# %%
df_train_ibs = pd.DataFrame(train_ibs, index=['IBS']).transpose().sort_values(by='IBS', ascending=True)
df_train_ibs['rank'] = df_train_ibs['IBS'].rank(ascending=True)
df_train_ibs

# %%
df_test_cindex = pd.DataFrame(test_cindex, index=['C-index']).transpose().sort_values(by='C-index', ascending=False)
df_test_cindex['rank'] = df_test_cindex['C-index'].rank(ascending=False)
df_test_cindex

# %%
df_test_ibs = pd.DataFrame(test_ibs, index=['IBS']).transpose().sort_values(by='IBS', ascending=True)
df_test_ibs['rank'] = df_test_ibs['IBS'].rank(ascending=True)
df_test_ibs

# %%
# Renaming the column "index" to "model" 
df_train_cindex = df_train_cindex.reset_index().rename(columns={"index": "model"})
df_train_ibs = df_train_ibs.reset_index().rename(columns={"index": "model"})
df_test_cindex = df_test_cindex.reset_index().rename(columns={"index": "model"})
df_test_ibs = df_test_ibs.reset_index().rename(columns={"index": "model"})

# Save the files 
dfs = [df_train_cindex, df_train_ibs, df_test_cindex, df_test_ibs]  # List of your DataFrames
file_path = 'path_to_your_folder/'  # Folder path where you want to save the files

# List of corresponding file names
file_names = ['train_cindex.csv', 'train_ibs.csv', 'test_cindex.csv', 'test_ibs.csv']


dfs = [df_train_cindex, df_train_ibs, df_test_cindex, df_test_ibs]  # List of your DataFrames
file_path = '/Users/minjeongcheon/Desktop/results_thesis/d2/os/minmax/fs_hv/'  # Folder path where you want to save the files

# List of corresponding file names
file_names = ['train_cindex.csv', 'train_ibs.csv', 'test_cindex.csv', 'test_ibs.csv']

# Modify the file names to match the desired format
modified_file_names = ['d2_os_minmax_fs_hv_' + file_name for file_name in file_names]

# Loop through each DataFrame and save them with corresponding modified file names
for df, modified_file_name in zip(dfs, modified_file_names):
    file_path_name = file_path + modified_file_name  # Construct the full file path
    df.to_csv(file_path_name, index=False)  # Save the DataFrame to CSV file

# %%
from datetime import date

current_date = date.today()
print(current_date)
